# %%
# !bash neural_model.sh
# Out:
# bash: neural_model.sh: No such file or directory
# 100%|| 25/25 [00:01<00:00, 14.06it/s]
# INFO - 01/15/26 18:13:56 - 0:01:30 - Running average train loss is 0.8541689229011535 at epoch 35
# INFO - 01/15/26 18:13:56 - 0:01:30 - At 36-th epoch with lr 0.000225.
# 100%|| 25/25 [00:01<00:00, 13.96it/s]
# INFO - 01/15/26 18:13:58 - 0:01:31 - Running average train loss is 0.8465451192855835 at epoch 36
# INFO - 01/15/26 18:13:58 - 0:01:31 - At 37-th epoch with lr 0.000231.
# 100%|| 25/25 [00:01<00:00, 14.00it/s]
# INFO - 01/15/26 18:14:00 - 0:01:33 - Running average train loss is 0.8374873900413513 at epoch 37
# INFO - 01/15/26 18:14:00 - 0:01:33 - At 38-th epoch with lr 0.000237.
# 100%|| 25/25 [00:01<00:00, 14.06it/s]
# INFO - 01/15/26 18:14:01 - 0:01:35 - Running average train loss is 0.8296046948432922 at epoch 38
# INFO - 01/15/26 18:14:01 - 0:01:35 - At 39-th epoch with lr 0.000244.
# 100%|| 25/25 [00:01<00:00, 14.02it/s]
# ...

# %%
# !ls
