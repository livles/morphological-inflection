# %%
# %cd /dss/dsshome1/03/ge87wod2/morphological-inflection/neural_baseline/neural-transducer
# !ls
# Out:
# /dss/dsshome1/03/ge87wod2/morphological-inflection/neural_baseline/neural-transducer
# LICENSE   README.md    environment.yml	neural-model.ipynb  setup.cfg  train.sh
# Makefile  checkpoints  example		neural_model.sh     src

# %%
# !bash neural_model.sh
# Out:
# no change     /dss/dsshome1/03/ge87wod2/miniconda/condabin/conda
# no change     /dss/dsshome1/03/ge87wod2/miniconda/bin/conda
# no change     /dss/dsshome1/03/ge87wod2/miniconda/bin/conda-env
# no change     /dss/dsshome1/03/ge87wod2/miniconda/bin/activate
# no change     /dss/dsshome1/03/ge87wod2/miniconda/bin/deactivate
# no change     /dss/dsshome1/03/ge87wod2/miniconda/etc/profile.d/conda.sh
# no change     /dss/dsshome1/03/ge87wod2/miniconda/etc/fish/conf.d/conda.fish
# no change     /dss/dsshome1/03/ge87wod2/miniconda/shell/condabin/Conda.psm1
# no change     /dss/dsshome1/03/ge87wod2/miniconda/shell/condabin/conda-hook.ps1
# no change     /dss/dsshome1/03/ge87wod2/miniconda/lib/python3.13/site-packages/xontrib/conda.xsh
# no change     /dss/dsshome1/03/ge87wod2/miniconda/etc/profile.d/conda.csh
# no change     /dss/dsshome1/03/ge87wod2/.bashrc
# No action taken.
# Jupyter detected...
# 2 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - pytorch
# ...
