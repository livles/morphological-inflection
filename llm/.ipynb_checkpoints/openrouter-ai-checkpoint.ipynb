# %%
# !pip install dotenv openai
# Out:
# Requirement already satisfied: dotenv in /dss/dsshome1/03/ge87wod2/miniconda/lib/python3.13/site-packages (0.9.9)
# Requirement already satisfied: openai in /dss/dsshome1/03/ge87wod2/miniconda/lib/python3.13/site-packages (2.8.1)
# Requirement already satisfied: python-dotenv in /dss/dsshome1/03/ge87wod2/miniconda/lib/python3.13/site-packages (from dotenv) (1.1.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /dss/dsshome1/03/ge87wod2/miniconda/lib/python3.13/site-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /dss/dsshome1/03/ge87wod2/miniconda/lib/python3.13/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /dss/dsshome1/03/ge87wod2/miniconda/lib/python3.13/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /dss/dsshome1/03/ge87wod2/miniconda/lib/python3.13/site-packages (from openai) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /dss/dsshome1/03/ge87wod2/miniconda/lib/python3.13/site-packages (from openai) (2.11.7)
# Requirement already satisfied: sniffio in /dss/dsshome1/03/ge87wod2/miniconda/lib/python3.13/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /dss/dsshome1/03/ge87wod2/miniconda/lib/python3.13/site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /dss/dsshome1/03/ge87wod2/miniconda/lib/python3.13/site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /dss/dsshome1/03/ge87wod2/miniconda/lib/python3.13/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in /dss/dsshome1/03/ge87wod2/miniconda/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /dss/dsshome1/03/ge87wod2/miniconda/lib/python3.13/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /dss/dsshome1/03/ge87wod2/miniconda/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /dss/dsshome1/03/ge87wod2/miniconda/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /dss/dsshome1/03/ge87wod2/miniconda/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /dss/dsshome1/03/ge87wod2/miniconda/lib/python3.13/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.0)

# %% [markdown]
# # qwen/qwen3-4b:free

# %%
# get api api key, source: https://www.geeksforgeeks.org/python/how-to-create-and-use-env-files-in-python/

# importing os module for environment variables
import os
# importing necessary functions from dotenv library
from dotenv import load_dotenv, dotenv_values 
# loading variables from .env file
load_dotenv(dotenv_path="/dss/dsshome1/03/ge87wod2/morphological-inflection/.env",override=True) 

# accessing and printing value
print(os.getenv("OPENROUTER_API_KEY"))
OPENROUTER_API_KEY=os.getenv("OPENROUTER_API_KEY")
# Out:
# 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

# %%
model = "qwen/qwen3-4b:free"
model = "openai/gpt-oss-120b"
model = "meta-llama/llama-3.3-70b-instruct:free"
model = "qwen/qwen3-14b:free"


# source: https://openrouter.ai/docs/quickstart

import requests
import json

response = requests.post(
  url="https://openrouter.ai/api/v1/chat/completions",
  headers={
    "Authorization": f"Bearer {OPENROUTER_API_KEY}"
  },
  data=json.dumps({
    "model": model, # Optional
    "messages":[
    {"role": "system", "content": f"""You are an expert documentary linguist specializing in morphological inflection in the language {lang}. You are given a lemma in {lang} and features in the hierarchical annotation schema UniMorph 4.0. Inflect the lemma according to the features and output only the inflected form."""},
    {"role": "user", "content": f"Inflect lemma + features: {lemma} + {features}"}
  ],
  })
)
print(response.json()["choices"][0]["message"]["content"])
# Out:
# Βισάλτηςς

# %%
# model = "qwen/qwen3-4b:free"
# model = "qwen/qwen3-14b:free"
model = "meta-llama/llama-3.3-70b-instruct:free"
model = "openai/gpt-oss-120b"
model_name = model.split("/")[-1]
sigmorphon_path = "/dss/dsshome1/03/ge87wod2/morphological-inflection/2023InflectionST/part1/data/"
dataset = ".tst"
#model = "openai/gpt-oss-120b"
data_path = "./data/" + model_name + "/"
lang_code = "sme"
lang = "Sámi"
# line = "Βισάλτης	N;ACC(DU)	Βῐσᾰ́λτᾱ"
# line = "δορκάς	N;NOM(SG)	δορκᾰ́ς"

from openai import OpenAI
client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key=OPENROUTER_API_KEY,
)
in_path = sigmorphon_path + lang_code + dataset
out_path = data_path + lang_code + "_" + model_name + ".out"
import os
if not os.path.isdir(data_path): os.mkdir(data_path)
with open (in_path,"r") as in_file, open(out_path,"w") as out_file:
    correct = 0
    lines = in_file.readlines()
    line_count = len(lines)
    for line in lines:
      if line == "": continue
      lemma, features, target = line.split("\t")
      response = client.chat.completions.create(
        extra_headers={
        },
        model=model,
        messages=[
          {"role": "system", "content": f"""You are an expert documentary linguist specializing in morphological inflection in the language {lang}. You are given a lemma in {lang} and features in the hierarchical annotation schema UniMorph 4.0. Inflect the lemma according to the features and output only the inflected form."""},
          {"role": "user", "content": f"Inflect lemma + features: {lemma} + {features}"}
        ],
      )
      pred = (response.choices[0].message).content
      if pred == target: 
         correct = correct + 1
         print (pred,"is correct.")
      else: print(pred,target)
      out_file.write(lemma + "\t" + features + "\t" + pred + "\n")
      out_file.flush()
      acc = correct / line_count
      outfile.write("test acc "+lang_name+" " + acc+"\n")
print(acc,lang)
# Out:
# abstráktat abstrávttaid
#
# abstrákta abstrávtta
#
# abstráktbát abstrávttaiguin
#
# abstráktain abstrávttain
#
# abstrákta abstráktan
#
# abstrákti abstrávttaid
#
# abstrákta abstrávtta
#
# abstráktain abstrávttaide
#
# abstráktas abstráktii
#
# abstráktat abstrávttat
#
# abstrákta abstrákta
#
# abstráktat abstrávttain
#
# abstrákta abstrávttas
#
# almmáskit almmáskivččiime
#
# almmášččin almmáskivččiimet
#
# almmáskán almmáskivččen
#
# almmáskivvat almmáskivččiide
#
# almmáskit almmáskivččiidet
#
# almmáskit almmáskivččiiga
#
# almmáskit almmáskivččii
#
# almmáskuvvet almmáskehkot
#
# almmáskait almmáskeahkki
#
# almmásk almmás
#
# almmáskit almmáskehkoset
#
# almmáskit almmáskehkos
#
# almmáskivvah almmáskežže
#
# almmáskččima almmáskeažžat
#
# almmáskit almmáskeažžabeahtti
#
# almmáskit almmáskeažžabehtet
#
# almmáskit almmáskeaččat
#
# almmáskit almmáskežžet
#
# almmáskit almmáskeš
#
# almmáškitem almmásketne
#
# almmáskemi almmáskit
#
# almmáskin almmáskan
#
# almmáskat almmáskeahppi
#
# almmáskte almmáskehpet
#
# almmáskit almmáskat
#
# almmáskba almmáskeaba
#
# almmáská almmáska
#
# almmáskim almmáskeimme
#
# almmáskín almmáskin
#
# almmáskit almmáskeidde
#
# almmási almmáskeigga
#
# almmásti almmáske
#
# amasaid apmasiid
#
# amasa apmasa
#
# amasbboh apmasiiguin
#
# amasm apmasiin
#
# amas amasin
#
# amasi apmasiid
#
# amasa apmasa
#
# amasin apmasiidda
#
# amasas apmasii
#
# amasat apmasat
#
# amas amas
#
# amasat apmasiin
#
#  apmasis
#
# atomat atomaid
#
# atoma atoma
#
# atomiguin atomaiguin
#
# atomain atomain
#
# atoma atoman
#
# atomij atomaid
#
# atomas atoma
#
# atoma atomaide
#
# atomas atomii
#
# atomat atomat
#
# atoma atoma
#
# atomii atomain
#
# atoma atomas
#
# bieđgâččime bieđgáleimmet
#
# bieđgágan bieđgálin
#
# bieđgáččat bieđgáleidde
#
# bieđgát bieđgálit
#
# bieđgát bieđgáleigga
#
# bieđgádit bieđgále
#
# bieđgáččii bieđgálii
#
# bieđgán bieđgášeimme
#
# bieđgáččep bieđgášeimmet
#
# bieđgečat bieđgášeiddet
#
# bieđgáččat bieđgášit
#
# bieđgá bieđgájehkon
#
# bieđgai bieđgájeahkki
#
# bieđgát bieđgájehket
#
# bieđga bieđgá
#
# bieđgá bieđgájehkoska
#
# bieđgáččát bieđgážetne
#
# bieđgašmet bieđgážit
#
# bieđgán bieđgážan
#
# bieđgát bieđgážeahppi
#
# bieđgašat bieđgážehpet
#
# bieđgášt bieđgážeaba
#
# bieđgân bieđgájetne
#
# bieđgamme bieđgát
#
# bieđgán bieđgán
#
# bieđgátte bieđgábeahtti
#
# bieđgát bieđgábehtet
#
# bieđgát bieđgájit
#
# bieđgim bieđgáimet
#
# bieđgáin bieđgájin
#
# bieđget bieđgáidet
#
# bieđgehit bieđgájedje
#
# buddet buddeleimme
#
# buddeččân buddelin
#
# buddet buddeleiddet
#
# buddit buddelit
#
# buddega buddeleigga
#
# buddet buddele
#
# buddis buddelii
#
# buddet buddešeimmet
#
# buddet buddešin
#
# buddet buddešeidde
#
# buddaš buddešit
#
# buddet buddešeigga
#
# detččii buddeše
#
# buddap buddejetnot
#
# budde buddejehkon
#
# buddet buddejehket
#
# buddet budde
#
# buddet buddejehkoset
#
# buddaisttá buddežeahppi
#
# buddet buddežehpet
#
# buddet buddežat
#
# buddet buddežeaba
#
# buddet buddet
#
# buddan budden
#
# buddete buddebeahtti
#
# buddebbet buddebehtet
#
# buddet buddejit
#
# buddim buddiime
#
# buddin buddejin
#
# buddi buddiiga
#
# buddet buddejedje
#
# báistit báisttáleimmet
#
# báiván báisttálin
#
# báistit báisttáleidde
#
# báistit báisttáleiddet
#
# báhtáččii báisttálit
#
# báiste báisttáleigga
#
# báistit báisttále
#
# bástit báisttálii
#
# báistivvan báisttášeimme
#
# báistin báisttášin
#
# bástitte báisttášeidde
#
# bástit báisttášeigga
#
# básččii báisttáše
#
# bášte báisttášii
#
# báidte báistu
#
# báistap báistot
#
# bstit báistet
#
# bástiš báisttežan
#
# báhpit báisttežehpet
#
# báistitsa báisttežeaba
#
# bástit báisttežit
#
# báistá báistteža
#
# báistimet báiste
#
# báistte báistibehtet
#
# báista báistá
#
# báisti báisttiime
#
# báistim báisttiimet
#
# bástin báisten
#
# báididet báisttiidet
#
# báistii báisttiiga
#
# bástit báiste
#
# báisti báisttii
#
# bálgat bálgáidan
#
# bálgán bálgán
#
# bálgániguin bálgáidanguin
#
# bálgánin bálgáinan
#
# bálgán bálggisinin
#
# bálgái bálgáidan
#
# bálgá bálgán
#
# bálgáni bálgáidasan
#
# bálgánsi bálgásan
#
# bálgán bálgán
#
# bálgá bálgáinan
#
# bálgá bálgástan
