# %% [markdown]
# # Prerequisites

# %%
# %cd /dss/dsshome1/03/ge87wod2/morphological-inflection/ByT5/
#import sys
#print(sys.version)
#!python3 --version
# Out:
# /dss/dsshome1/03/ge87wod2/morphological-inflection/ByT5
# /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !pip uninstall transformers datasets accelerate torch ipywidgets python-dotenv pickleshare -y
#!pip install transformers==4.36.2  datasets==4.3.0 accelerate==0.27.2
# !pip install -U transformers accelerate datasets
# !pip install torch==2.9.1
# !pip install ipywidgets==8.1.7
# !pip install python-dotenv==1.2.1 pickleshare==0.7.5
# Out:
# WARNING: Skipping transformers as it is not installed.
# WARNING: Skipping datasets as it is not installed.
# WARNING: Skipping accelerate as it is not installed.
# WARNING: Skipping torch as it is not installed.
# WARNING: Skipping ipywidgets as it is not installed.
# WARNING: Skipping python-dotenv as it is not installed.
# WARNING: Skipping pickleshare as it is not installed.
# Collecting transformers
#   Using cached transformers-5.6.2-py3-none-any.whl.metadata (33 kB)
# Collecting accelerate
#   Using cached accelerate-1.13.0-py3-none-any.whl.metadata (19 kB)
# Collecting datasets
#   Using cached datasets-4.8.4-py3-none-any.whl.metadata (19 kB)
# Collecting huggingface-hub<2.0,>=1.5.0 (from transformers)
#   Using cached huggingface_hub-1.12.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from transformers) (26.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Collecting regex>=2025.10.22 (from transformers)
#   Using cached regex-2026.4.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Using cached tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Collecting typer (from transformers)
#   Using cached typer-0.24.2-py3-none-any.whl.metadata (15 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Using cached safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Requirement already satisfied: tqdm>=4.27 in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from transformers) (4.67.3)
# Requirement already satisfied: psutil in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from accelerate) (7.2.2)
# Collecting torch>=2.0.0 (from accelerate)
#   Using cached torch-2.11.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting filelock (from datasets)
#   Using cached filelock-3.29.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting pyarrow>=21.0.0 (from datasets)
#   Using cached pyarrow-24.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Collecting dill<0.4.2,>=0.3.0 (from datasets)
#   Using cached dill-0.4.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: httpx<1.0.0 in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from datasets) (0.28.1)
# Collecting xxhash (from datasets)
#   Using cached xxhash-3.7.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.20 (from datasets)
#   Using cached multiprocess-0.70.19-py310-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2024.6.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.10.1)
# Requirement already satisfied: anyio in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1.0.0->datasets) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<1.0.0->datasets) (3.7)
# Requirement already satisfied: h11>=0.16 in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Collecting hf-xet<2.0.0,>=1.4.3 (from huggingface-hub<2.0,>=1.5.0->transformers)
#   Using cached hf_xet-1.4.3-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: typing-extensions>=4.1.0 in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets) (2.0.7)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->accelerate) (70.3.0)
# Collecting sympy>=1.13.3 (from torch>=2.0.0->accelerate)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->accelerate) (3.1.4)
# Collecting cuda-toolkit==13.0.2 (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->accelerate)
#   Using cached cuda_toolkit-13.0.2-py2.py3-none-any.whl.metadata (9.4 kB)
# Collecting cuda-bindings<14,>=13.0.3 (from torch>=2.0.0->accelerate)
#   Using cached cuda_bindings-13.2.0-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.3 kB)
# Collecting nvidia-cudnn-cu13==9.19.0.56 (from torch>=2.0.0->accelerate)
#   Using cached nvidia_cudnn_cu13-9.19.0.56-py3-none-manylinux_2_27_x86_64.whl.metadata (1.9 kB)
# Collecting nvidia-cusparselt-cu13==0.8.0 (from torch>=2.0.0->accelerate)
#   Using cached nvidia_cusparselt_cu13-0.8.0-py3-none-manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting nvidia-nccl-cu13==2.28.9 (from torch>=2.0.0->accelerate)
#   Using cached nvidia_nccl_cu13-2.28.9-py3-none-manylinux_2_18_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvshmem-cu13==3.4.5 (from torch>=2.0.0->accelerate)
#   Using cached nvidia_nvshmem_cu13-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting triton==3.6.0 (from torch>=2.0.0->accelerate)
#   Using cached triton-3.6.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink==13.0.88.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->accelerate)
#   Using cached nvidia_nvjitlink-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvtx==13.0.85.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->accelerate)
#   Using cached nvidia_nvtx-13.0.85-py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cufft==12.0.0.61.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->accelerate)
#   Using cached nvidia_cufft-12.0.0.61-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse==12.6.3.3.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->accelerate)
#   Using cached nvidia_cusparse-12.6.3.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cuda-runtime==13.0.96.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->accelerate)
#   Using cached nvidia_cuda_runtime-13.0.96-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-nvrtc==13.0.88.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->accelerate)
#   Using cached nvidia_cuda_nvrtc-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufile==1.15.1.6.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->accelerate)
#   Using cached nvidia_cufile-1.15.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver==12.0.4.66.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->accelerate)
#   Using cached nvidia_cusolver-12.0.4.66-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-curand==10.4.0.35.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->accelerate)
#   Using cached nvidia_curand-10.4.0.35-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cublas==13.1.0.3.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->accelerate)
#   Using cached nvidia_cublas-13.1.0.3-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti==13.0.85.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch>=2.0.0->accelerate)
#   Using cached nvidia_cuda_cupti-13.0.85-py3-none-manylinux_2_25_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Collecting click>=8.2.1 (from typer->transformers)
#   Using cached click-8.3.3-py3-none-any.whl.metadata (2.6 kB)
# Collecting shellingham>=1.3.0 (from typer->transformers)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.10/dist-packages (from typer->transformers) (13.7.1)
# Collecting annotated-doc>=0.0.2 (from typer->transformers)
#   Using cached annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (4.0.3)
# Collecting cuda-pathfinder~=1.1 (from cuda-bindings<14,>=13.0.3->torch>=2.0.0->accelerate)
#   Using cached cuda_pathfinder-1.5.3-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=12.3.0->typer->transformers) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from rich>=12.3.0->typer->transformers) (2.20.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=2.0.0->accelerate)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from anyio->httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.0->accelerate) (2.1.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers) (0.1.2)
# Using cached transformers-5.6.2-py3-none-any.whl (10.4 MB)
# Using cached accelerate-1.13.0-py3-none-any.whl (383 kB)
# Using cached datasets-4.8.4-py3-none-any.whl (526 kB)
# Using cached dill-0.4.1-py3-none-any.whl (120 kB)
# Using cached huggingface_hub-1.12.0-py3-none-any.whl (646 kB)
# Using cached filelock-3.29.0-py3-none-any.whl (39 kB)
# Using cached multiprocess-0.70.19-py310-none-any.whl (134 kB)
# Using cached pyarrow-24.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (48.8 MB)
# Using cached regex-2026.4.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (793 kB)
# Using cached safetensors-0.7.0-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (507 kB)
# Using cached tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# Using cached torch-2.11.0-cp310-cp310-manylinux_2_28_x86_64.whl (530.6 MB)
# Using cached cuda_toolkit-13.0.2-py2.py3-none-any.whl (2.4 kB)
# Using cached nvidia_cudnn_cu13-9.19.0.56-py3-none-manylinux_2_27_x86_64.whl (366.1 MB)
# Using cached nvidia_cusparselt_cu13-0.8.0-py3-none-manylinux2014_x86_64.whl (169.9 MB)
# Using cached nvidia_nccl_cu13-2.28.9-py3-none-manylinux_2_18_x86_64.whl (196.5 MB)
# Using cached nvidia_nvshmem_cu13-3.4.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (60.4 MB)
# Using cached triton-3.6.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (188.1 MB)
# Using cached nvidia_cublas-13.1.0.3-py3-none-manylinux_2_27_x86_64.whl (423.1 MB)
# Using cached nvidia_cuda_cupti-13.0.85-py3-none-manylinux_2_25_x86_64.whl (10.7 MB)
# Using cached nvidia_cuda_nvrtc-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (90.2 MB)
# Using cached nvidia_cuda_runtime-13.0.96-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.2 MB)
# Using cached nvidia_cufft-12.0.0.61-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (214.1 MB)
# Using cached nvidia_cufile-1.15.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
# Using cached nvidia_curand-10.4.0.35-py3-none-manylinux_2_27_x86_64.whl (59.5 MB)
# Using cached nvidia_cusolver-12.0.4.66-py3-none-manylinux_2_27_x86_64.whl (200.9 MB)
# Using cached nvidia_cusparse-12.6.3.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (145.9 MB)
# Using cached nvidia_nvjitlink-13.0.88-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (40.7 MB)
# Using cached nvidia_nvtx-13.0.85-py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (148 kB)
# Using cached typer-0.24.2-py3-none-any.whl (55 kB)
# Using cached xxhash-3.7.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (193 kB)
# Using cached annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Using cached click-8.3.3-py3-none-any.whl (110 kB)
# Using cached cuda_bindings-13.2.0-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (6.3 MB)
# Using cached hf_xet-1.4.3-cp37-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.2 MB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached cuda_pathfinder-1.5.3-py3-none-any.whl (49 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: nvidia-cusparselt-cu13, mpmath, cuda-toolkit, xxhash, triton, sympy, shellingham, safetensors, regex, pyarrow, nvidia-nvtx, nvidia-nvshmem-cu13, nvidia-nvjitlink, nvidia-nccl-cu13, nvidia-curand, nvidia-cufile, nvidia-cuda-runtime, nvidia-cuda-nvrtc, nvidia-cuda-cupti, nvidia-cublas, hf-xet, filelock, dill, cuda-pathfinder, click, annotated-doc, nvidia-cusparse, nvidia-cufft, nvidia-cudnn-cu13, multiprocess, cuda-bindings, typer, nvidia-cusolver, huggingface-hub, torch, tokenizers, datasets, transformers, accelerate
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 16.1.0
#     Uninstalling pyarrow-16.1.0:
#       Successfully uninstalled pyarrow-16.1.0
#   Attempting uninstall: click
#     Found existing installation: click 8.1.7
#     Uninstalling click-8.1.7:
#       Successfully uninstalled click-8.1.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 24.6.0 requires pyarrow<16.2.0a0,>=16.1.0, but you have pyarrow 24.0.0 which is incompatible.
# Successfully installed accelerate-1.13.0 annotated-doc-0.0.4 click-8.3.3 cuda-bindings-13.2.0 cuda-pathfinder-1.5.3 cuda-toolkit-13.0.2 datasets-4.8.4 dill-0.4.1 filelock-3.29.0 hf-xet-1.4.3 huggingface-hub-1.12.0 mpmath-1.3.0 multiprocess-0.70.19 nvidia-cublas-13.1.0.3 nvidia-cuda-cupti-13.0.85 nvidia-cuda-nvrtc-13.0.88 nvidia-cuda-runtime-13.0.96 nvidia-cudnn-cu13-9.19.0.56 nvidia-cufft-12.0.0.61 nvidia-cufile-1.15.1.6 nvidia-curand-10.4.0.35 nvidia-cusolver-12.0.4.66 nvidia-cusparse-12.6.3.3 nvidia-cusparselt-cu13-0.8.0 nvidia-nccl-cu13-2.28.9 nvidia-nvjitlink-13.0.88 nvidia-nvshmem-cu13-3.4.5 nvidia-nvtx-13.0.85 pyarrow-24.0.0 regex-2026.4.4 safetensors-0.7.0 shellingham-1.5.4 sympy-1.14.0 tokenizers-0.22.2 torch-2.11.0 transformers-5.6.2 triton-3.6.0 typer-0.24.2 xxhash-3.7.0
# Collecting torch==2.9.1
#   Using cached torch-2.9.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from torch==2.9.1) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (2024.6.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch==2.9.1)
#   Using cached nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch==2.9.1)
#   Using cached nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch==2.9.1)
#   Using cached nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch==2.9.1)
#   Using cached nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch==2.9.1)
#   Using cached nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch==2.9.1)
#   Using cached nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch==2.9.1)
#   Using cached nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch==2.9.1)
#   Using cached nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch==2.9.1)
#   Using cached nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch==2.9.1)
#   Using cached nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting nvidia-nccl-cu12==2.27.5 (from torch==2.9.1)
#   Using cached nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvshmem-cu12==3.3.20 (from torch==2.9.1)
#   Using cached nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch==2.9.1)
#   Using cached nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch==2.9.1)
#   Using cached nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch==2.9.1)
#   Using cached nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.5.1 (from torch==2.9.1)
#   Using cached triton-3.5.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.13.3->torch==2.9.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.9.1) (2.1.5)
# Using cached torch-2.9.1-cp310-cp310-manylinux_2_28_x86_64.whl (899.8 MB)
# Using cached nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
# Using cached nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
# Using cached nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
# Using cached nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
# Using cached nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
# Using cached nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
# Using cached nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
# Using cached nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
# Using cached nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
# Using cached nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
# Using cached nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.3 MB)
# Using cached nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
# Using cached nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (124.7 MB)
# Using cached nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Using cached triton-3.5.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (170.3 MB)
# Installing collected packages: nvidia-cusparselt-cu12, triton, nvidia-nvtx-cu12, nvidia-nvshmem-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch
#   Attempting uninstall: triton
#     Found existing installation: triton 3.6.0
#     Uninstalling triton-3.6.0:
#       Successfully uninstalled triton-3.6.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.11.0
#     Uninstalling torch-2.11.0:
#       Successfully uninstalled torch-2.11.0
# Successfully installed nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.5 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvshmem-cu12-3.3.20 nvidia-nvtx-cu12-12.8.90 torch-2.9.1 triton-3.5.1
# Collecting ipywidgets==8.1.7
#   Using cached ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from ipywidgets==8.1.7) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from ipywidgets==8.1.7) (8.39.0)
# Requirement already satisfied: traitlets>=4.3.1 in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from ipywidgets==8.1.7) (5.14.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets==8.1.7)
#   Using cached widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets==8.1.7)
#   Using cached jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: decorator in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.1.7) (5.2.1)
# Requirement already satisfied: exceptiongroup in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.1.7) (1.3.1)
# Requirement already satisfied: jedi>=0.16 in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.1.7) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.1.7) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.7) (4.7.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.1.7) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.1.7) (2.20.0)
# Requirement already satisfied: stack_data in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.1.7) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets==8.1.7) (4.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets==8.1.7) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets==8.1.7) (0.7.0)
# Requirement already satisfied: wcwidth in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets==8.1.7) (0.6.0)
# Requirement already satisfied: executing>=1.2.0 in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets==8.1.7) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets==8.1.7) (3.0.1)
# Requirement already satisfied: pure-eval in /dss/dsshome1/03/ge87wod2/.local/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets==8.1.7) (0.2.3)
# Using cached ipywidgets-8.1.7-py3-none-any.whl (139 kB)
# Using cached jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
# Using cached widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
# Installing collected packages: widgetsnbextension, jupyterlab_widgets, ipywidgets
# Successfully installed ipywidgets-8.1.7 jupyterlab_widgets-3.0.16 widgetsnbextension-4.0.15
# Collecting python-dotenv==1.2.1
#   Using cached python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Collecting pickleshare==0.7.5
#   Using cached pickleshare-0.7.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Using cached python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Using cached pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Installing collected packages: pickleshare, python-dotenv
# Successfully installed pickleshare-0.7.5 python-dotenv-1.2.1

# %%
from dotenv import load_dotenv
import os

load_dotenv("../../.env",override=True)

HF_TOKEN = os.getenv("HF_TOKEN")

#print("HF_TOKEN: ", HF_TOKEN)

 # source: https://huggingface.co/docs/transformers/v4.28.1/tasks/summarization
from huggingface_hub import login
login(HF_TOKEN)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from dotenv import load_dotenv
#       2 import os
#       4 load_dotenv("../../.env",override=True)
#
# ModuleNotFoundError: No module named 'dotenv'

# %% [markdown]
# # Continued Pre-training

# %%
# from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Trainer, TrainingArguments
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Seq2SeqTrainer, Seq2SeqTrainingArguments
from datasets import load_dataset
import random
# get tokenizer and sentinal tokens for masking
tokenizer = AutoTokenizer.from_pretrained("google/byt5-small")
extra_id_0 = tokenizer.convert_tokens_to_ids("<extra_id_0>")
extra_id_1 = tokenizer.convert_tokens_to_ids("<extra_id_1>")
print(extra_id_0, extra_id_1)

# Load pre-trained model
model = AutoModelForSeq2SeqLM.from_pretrained("google/byt5-small")
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, return_tensors="pt")
random.seed(10)
# Masking by processing the data line by line
mask_sequence_ratio_perc = 25
def preprocess_function(examples): # receives unmasked sentence as input
    # get input sentence
    input_ids_batch = []
    attention_mask_batch = []
    labels_batch = []
    
    inputs_batch = examples["input"]
    for inputs in inputs_batch:
        inputs = inputs.strip()
        model_inputs = tokenizer(inputs)
        input_ids = model_inputs.input_ids
        attention_mask = model_inputs.attention_mask
        # print(input_ids, attention_mask, len(input_ids),len(attention_mask))
        
        # mask 15% of the bytes randomly in the tokenized sentence leaving out bordering bytes.
        length = round(len(input_ids) * mask_sequence_ratio_perc / 100) # mask 20% of bytes (T5 and mT5 do that for tokens)
        max_start_index = len(input_ids) - length -1  # 2 bytes + eos byte-> 3 - 1x eos - 1= 1 -> index 0 or 1 possible, eos does not count to bytes
        start_index = random.randrange(1, max_start_index -1) # leave out first bytes and last byte "full stop: 49"
        exclusive_end_index = start_index + length
        masked_input_ids = (  input_ids[:start_index] + [extra_id_0] + input_ids[exclusive_end_index :]  )
        masked_labels_ids = ([extra_id_0]+ input_ids[start_index: exclusive_end_index] +[extra_id_1])
        
        # update attention mask and labels and add to batch
        attention_mask = [1] * len(masked_input_ids)
        input_ids_batch.append(masked_input_ids)
        attention_mask_batch.append(attention_mask)
        labels_batch.append(masked_labels_ids)
    return {
        "input_ids": input_ids_batch,
        "attention_mask": attention_mask_batch,
        "labels": labels_batch
    }

# load dataset
lang = "csb-sent"
train_path = f"/dss/dsshome1/03/ge87wod2/morphological-inflection/preprocessing/preprocessing_to_json_or_tsv/data/{lang}_trn.tsv"
eval_path = f"/dss/dsshome1/03/ge87wod2/morphological-inflection/preprocessing/preprocessing_to_json_or_tsv/data/{lang}_dev.tsv"
dataset = load_dataset("csv", delimiter="\t",column_names=["input"],data_files={"train": train_path,"validation": eval_path},quoting=3) # disable quote parsing
tokenized_dataset = dataset.map(preprocess_function, batched=True)
print(tokenized_dataset["train"]["input_ids"])
print(tokenized_dataset)

output_model = f"{lang}-{mask_sequence_ratio_perc}perc-byte"
print(output_model)
output_dir = "./byt5_small/optimal-12epochs-"+output_model
#training_args = Seq2SeqTrainingArguments (
#    output_dir=output_dir,
#    overwrite_output_dir=True,
#    num_train_epochs=4,
#    per_device_train_batch_size=16,
#    per_device_eval_batch_size=16,
#    learning_rate=5e-5,
#    weight_decay=0.01,
#    evaluation_strategy = "epoch",
#    save_total_limit=3,
#)

training_args = Seq2SeqTrainingArguments(
    output_dir="byt5_small/"+output_model,
    eval_strategy="epoch",
    learning_rate=5e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    weight_decay=0.01,
    save_total_limit=3,
    num_train_epochs=12,
    predict_with_generate=True,
    save_strategy="epoch",
    fp16=False,# did not work with True #change to bf16=True for XPU 
    #bf16 = True, # performance was best without setting fp16 or bf16 to true
    push_to_hub=True,
    warmup_steps = 500,
    load_best_model_at_end=True, # otherwise not model with minimum loss during training, like https://huggingface.co/docs/transformers/tasks/sequence_classification
)


trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["validation"],
    data_collator=data_collator,
    processing_class=tokenizer,
)


# Pretrain the model
trainer.train()
trainer.push_to_hub()
# !rm -rf ./byt5_small/*
# Out:
# 259 260
# Loading weights:   0%|          | 0/172 [00:00<?, ?it/s]
# [transformers] The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.
# Map:   0%|          | 0/9000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Column([[70, 125, 198, 166, 118, 119, 114, 47, 35, 102, 107, 198, 181, 102, 35, 113, 108, 104, 35, 109, 104, 35, 119, 114, 35, 115, 117, 100, 122, 108, 103, 200, 133, 114, 122, 114, 47, 35, 110, 198, 181, 113, 119, 120, 100, 117, 198, 166, 35, 113, 100, 125, 198, 172, 122, 198, 183, 35, 118, 198, 166, 35, 118, 119, 198, 182, 200, 133, 35, 106, 117, 198, 174, 35, 259, 119, 117, 120, 112, 104, 200, 135, 119, 100, 102, 107, 35, 198, 181, 35, 112, 104, 102, 107, 100, 113, 108, 102, 125, 113, 124, 35, 119, 117, 100, 110, 119, 120, 117, 125, 104, 49, 1], [70, 125, 104, 259, 198, 172, 102, 124, 47, 35, 105, 100, 117, 122, 108, 35, 118, 198, 166, 35, 122, 113, 104, 119, 35, 200, 191, 198, 183, 200, 133, 119, 114, 48, 102, 125, 104, 117, 122, 108, 114, 113, 114, 49, 1], [90, 104, 35, 90, 117, 114, 102, 200, 133, 100, 122, 108, 120, 35, 125, 104, 119, 110, 200, 133, 35, 118, 198, 166, 35, 125, 35, 118, 200, 133, 114, 122, 108, 100, 113, 114, 105, 108, 111, 118, 102, 125, 108, 112, 100, 35, 115, 117, 199, 136, 103, 114, 112, 100, 47, 259, 109, 108, 113, 49, 35, 105, 108, 125, 109, 114, 111, 114, 106, 100, 35, 115, 117, 114, 105, 49, 1], [77, 100, 110, 113, 114, 35, 229, 131, 161, 103, 104, 108, 35, 106, 117, 100, 102, 108, 100, 35, 115, 117, 108, 113, 102, 104, 115, 118, 35, 108, 113, 35, 74, 103, 100, 113, 125, 110, 37, 35, 103, 198, 183, 200, 133, 35, 115, 198, 181, 118, 119, 100, 122, 108, 102, 35, 110, 111, 198, 183, 118, 125, 259, 120, 35, 118, 122, 49, 1], [77, 108, 259, 35, 119, 114, 61, 35, 69, 198, 188, 105, 105, 100, 111, 114, 47, 35, 85, 114, 102, 107, 104, 118, 119, 104, 117, 47, 35, 86, 124, 117, 100, 102, 120, 118, 198, 174, 35, 108, 35, 118, 119, 114, 111, 198, 174, 102, 100, 35, 118, 119, 198, 182, 113, 120, 35, 229, 131, 150, 35, 68, 111, 101, 100, 113, 124, 49, 1], ...])
# DatasetDict({
#     train: Dataset({
#         features: ['input', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 9000
#     })
#     validation: Dataset({
#         features: ['input', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 1000
#     })
# })
# csb-sent-25perc-byte
#     <div>
#
#       <progress value='6756' max='6756' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6756/6756 1:14:05, Epoch 12/12]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>5.248104</td>
#       <td>2.213883</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.190641</td>
#       <td>1.756992</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.913982</td>
#       <td>1.612527</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.778502</td>
#       <td>1.403192</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.638601</td>
#       <td>1.336530</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>1.547044</td>
#       <td>1.260736</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.480259</td>
#       <td>1.225125</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.401665</td>
#       <td>1.204536</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.370856</td>
#       <td>1.189890</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.352250</td>
#       <td>1.178837</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.340708</td>
#       <td>1.172211</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.328797</td>
#       <td>1.170195</td>
#     </tr>
#   </tbody>
# </table><p>
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# [transformers] There were missing keys in the checkpoint model loaded: ['encoder.embed_tokens.weight', 'decoder.embed_tokens.weight'].
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B

# %%
# from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Trainer, TrainingArguments
from datasets import load_dataset
import math, random
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Trainer, TrainingArguments
import torch
tokenizer = AutoTokenizer.from_pretrained("google/byt5-small")
# tokenized_dataset = dataset.map(preprocess_function, batched=True)
model = AutoModelForSeq2SeqLM.from_pretrained("google/byt5-small")

sentinal_token_1 = tokenizer("<extra_id_0>", return_tensors="pt").to(model.device).input_ids # skip eos value "1"
sentinal_token_2 = tokenizer("<extra_id_1>", return_tensors="pt").to(model.device).input_ids # skip eos value "1"
extra_id_0 = int(sentinal_token_1[0][0])
extra_id_1 = int(sentinal_token_2[0][0])
print(extra_id_0, extra_id_1)

model_inputs = tokenizer("我是一条狗.")
#model_inputs = tokenizer(".")
input_ids = model_inputs.input_ids
attention_mask = model_inputs.attention_mask
print(input_ids, attention_mask, len(input_ids),len(attention_mask))

# mask 15% of the bytes in the tokenized sentence
length = round(len(input_ids) * 0.15) # mask 15% of character (T5 and mT5 do that for tokens)
max_start_index = len(input_ids) - length  # 2 chars -> 2-1=1 -> index 0 or 1 possible
random.seed(10)
start_index = random.randrange(1, max_start_index ) # leave out first and last character
exclusive_end_index = start_index + length
masked_input_ids = (  input_ids[:start_index] + [extra_id_0] + input_ids[exclusive_end_index :]  )
masked_labels_ids = ([extra_id_0]+ input_ids[start_index: exclusive_end_index] +[extra_id_1])

# update attention mask and labels
attention_mask = [1] * len(masked_input_ids)
model_inputs["attention_mask"] = attention_mask
model_inputs["labels"] = masked_labels_ids

print(input_ids, masked_input_ids,masked_labels_ids)
print(model_inputs)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 # from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Trainer, TrainingArguments
# ----> 2 from datasets import load_dataset
#       3 import math, random
#       4 from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Trainer, TrainingArguments
#
# ModuleNotFoundError: No module named 'datasets'

# %%
# from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Trainer, TrainingArguments
from datasets import load_dataset

from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Trainer, TrainingArguments
from datasets import load_dataset

# Load domain-specific text (replace with your own corpus)
lang = "csb-pol-sent"
train_path = f"/dss/dsshome1/03/ge87wod2/morphological-inflection/preprocessing/preprocessing_to_json_or_tsv/data/{lang}_trn.tsv"
eval_path = f"/dss/dsshome1/03/ge87wod2/morphological-inflection/preprocessing/preprocessing_to_json_or_tsv/data/{lang}_dev.tsv"
dataset = load_dataset("csv", delimiter="\t",column_names=["input","labels"],data_files={"train": train_path,"validation": eval_path},quoting=3) # disable quote parsing


# Tokenizing
def preprocess_function(examples):
    inputs = examples["input"]
    model_inputs = tokenizer(inputs)
    labels = tokenizer(text_target=examples["labels"],padding=True) # same length irrelevant here, so no truncation or padding
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs




tokenizer = AutoTokenizer.from_pretrained("google/byt5-small")
tokenized_dataset = dataset.map(preprocess_function, batched=True)




# Load pre-trained model
model = AutoModelForSeq2SeqLM.from_pretrained("google/byt5-small")
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, return_tensors="pt")
# Training arguments
training_args = TrainingArguments (
    output_dir="./byt5_small/"+lang+"-8epochs",
    overwrite_output_dir=True,
    num_train_epochs=8,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    learning_rate=2e-5,
    weight_decay=0.01,
    evaluation_strategy = "epoch",
    #predict_with_generate=True,
   # save_steps=10_000,
    save_total_limit=3,
)

# Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["validation"],
    data_collator=data_collator,
    tokenizer=tokenizer,
)

# Pretrain the model
trainer.train()
trainer.push_to_hub()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# 2026-04-12 13:26:29.946699: I tensorflow/core/platform/cpu_feature_guard.cc:211] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Map:   0%|          | 0/9000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='31' max='4504' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  31/4504 00:21 < 55:51, 1.33 it/s, Epoch 0.05/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 60
#      50 trainer = Trainer(
#      51     model=model,
#      52     args=training_args,
#    (...)
#      56     tokenizer=tokenizer,
#      57 )
#      59 # Pretrain the model
# ---> 60 trainer.train()
#      61 trainer.push_to_hub()
#
# File /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1537, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1535         hf_hub_utils.enable_progress_bars()
#    1536 else:
# -> 1537     return inner_training_loop(
#    1538         args=args,
#    1539         resume_from_checkpoint=resume_from_checkpoint,
#    1540         trial=trial,
#    1541         ignore_keys_for_eval=ignore_keys_for_eval,
#    1542     )
#
# File /usr/local/lib/python3.10/dist-packages/transformers/trainer.py:1859, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1853 with self.accelerator.accumulate(model):
#    1854     tr_loss_step = self.training_step(model, inputs)
#    1856 if (
#    1857     args.logging_nan_inf_filter
#    1858     and not is_torch_tpu_available()
# -> 1859     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    1860 ):
#    1861     # if loss is nan or inf simply add the average of previous logged losses
#    1862     tr_loss += tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#    1863 else:
#
# KeyboardInterrupt:

# %% [markdown]
# # Fine-tuning small pre-trained ByT5 model using dataset

# %%
LANGS = ["grc","dan","fra","sme","deu","nav","jap","klr","eng","mul","deu_eng"]
LANGS = LANGS[-2:]
LANGS = ["mul_2","amh","pol","ote"]
LANGS = ["mul_2","amh","pol","ote"]
LANGS = ["mul-language-code","mul-language-word"]
LANGS = ["mul-language-code"]
LANGS = ["pol"]
#LANGS = ["slavic-family"]
#LANGS = ["slk"] # ces, slk, dsb
#CHECKPOINT = "google/byt5-small"
#language = "csb-gemini" 
#mask_sequence_ratio_perc = 25
CHECKPOINT = "livles/csb-pol-byte-25perc-sent"
PATH_JSON_DATA = "../preprocessing/preprocessing_to_json_or_tsv/data/"

for lang in LANGS:
    print(lang)
    from datasets import load_dataset
#    dataset = load_dataset("csv", delimiter = "\t", column_names = ["input","target"],data_files={"train": PATH_JSON_DATA + lang + "_trn.tsv", "validation": PATH_JSON_DATA + lang + "_dev.tsv"})
    dataset = load_dataset("json", data_files={"train": PATH_JSON_DATA + lang + "_trn.json", "validation": PATH_JSON_DATA + lang + "_dev.json"})

    print(dataset["train"][0])

    from transformers import AutoTokenizer

    checkpoint = "google/byt5-small"
    tokenizer = AutoTokenizer.from_pretrained(checkpoint)
    # -

    import torch

    from transformers import (
        AutoTokenizer,
        TrainingArguments,
        Trainer,
        AutoModelForSeq2SeqLM,
        Seq2SeqTrainingArguments,
        Seq2SeqTrainer
    )
    from datasets import load_dataset

    def preprocess_function(examples):
        # inputs = [prefix + doc for doc in examples["text"]]
        inputs = examples["input"]
        model_inputs = tokenizer(inputs)

        labels = tokenizer(text_target=examples["target"]) # same length irrelevant here, so no truncation or padding

        model_inputs["labels"] = labels["input_ids"]
        return model_inputs


    tokenized_dataset = dataset.map(preprocess_function, batched=True)
    print(tokenized_dataset)
    sample = tokenized_dataset["train"][0]
    print(sample["labels"])

    from transformers import DataCollatorForSeq2Seq

    data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=checkpoint)

    from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer

    checkpoint = CHECKPOINT
    model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    #out_dir = "byt5_small/"+CHECKPOINT.split("/")[1]+"-"+lang
    out_dir = "byt5_small/"+lang
    training_args = Seq2SeqTrainingArguments(
        output_dir= out_dir,
        eval_strategy="epoch",
        learning_rate=5e-5,
        per_device_train_batch_size=16,
        per_device_eval_batch_size=16,
        weight_decay=0.01,
        save_total_limit=3,
        num_train_epochs=12,
        predict_with_generate=True,
        # save_strategy="epoch",
        fp16=False,# did not work with True #change to bf16=True for XPU 
        #bf16 = True, # performance was best without setting fp16 or bf16 to true
        push_to_hub=True,
        warmup_steps = 500,
        save_strategy = "epoch",
        load_best_model_at_end=True, # otherwise not model with minimum loss during training, like https://huggingface.co/docs/transformers/tasks/sequence_classification
        metric_for_best_model="eval_loss" # new
    )

    trainer = Seq2SeqTrainer(
        model=model,
        args=training_args,
        train_dataset=tokenized_dataset["train"],
        eval_dataset=tokenized_dataset["validation"],
        processing_class=tokenizer,
        data_collator=data_collator,   
    )

    trainer.train()
    trainer.push_to_hub()
# Out:
# pol
# {'input': 'Inflect zacny | ADJ;ACC(SG,FEM)', 'target': 'zacną'}
# Map:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['input', 'target', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 10000
#     })
#     validation: Dataset({
#         features: ['input', 'target', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 1000
#     })
# })
# [125, 100, 102, 113, 199, 136, 1]
# Loading weights:   0%|          | 0/170 [00:00<?, ?it/s]
# [transformers] The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.
#     <div>
#
#       <progress value='7500' max='7500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [7500/7500 28:23, Epoch 12/12]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.105857</td>
#       <td>0.284595</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.359272</td>
#       <td>0.096927</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.200913</td>
#       <td>0.064115</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.086910</td>
#       <td>0.052172</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.068169</td>
#       <td>0.052970</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.055866</td>
#       <td>0.056879</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.047496</td>
#       <td>0.055106</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.037623</td>
#       <td>0.056999</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.031930</td>
#       <td>0.060084</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.031771</td>
#       <td>0.059114</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.029089</td>
#       <td>0.062634</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.025562</td>
#       <td>0.062306</td>
#     </tr>
#   </tbody>
# </table><p>
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# [transformers] There were missing keys in the checkpoint model loaded: ['encoder.embed_tokens.weight', 'decoder.embed_tokens.weight'].
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B

# %% [markdown]
# # Fine-Tuning with more epochs

# %%
# !rm -rf /dss/dsshome1/03/ge87wod2/morphological-inflection/ByT5/byt5_small/*
LANGS = ["5lang-sample"]
#LANGS = ["slavic-family"]

PATH_JSON_DATA = "../preprocessing/preprocessing_to_json/data/"

for lang in LANGS:
    from datasets import load_dataset
    dataset = load_dataset("json", data_files={"train": PATH_JSON_DATA + lang + "_trn.json", "validation": PATH_JSON_DATA + lang + "_dev.json"})

    print(dataset["train"][0])

    from transformers import AutoTokenizer

    checkpoint = "google/byt5-small"
    tokenizer = AutoTokenizer.from_pretrained(checkpoint)
    # 

    import torch

    from transformers import (
        AutoTokenizer,
        TrainingArguments,
        Trainer,
        AutoModelForSeq2SeqLM,
        Seq2SeqTrainingArguments,
        Seq2SeqTrainer
    )
    from datasets import load_dataset

    def preprocess_function(examples):
        # inputs = [prefix + doc for doc in examples["text"]]
        inputs = examples["input"]
        model_inputs = tokenizer(inputs)

        labels = tokenizer(text_target=examples["target"]) # same length irrelevant here, so no truncation or padding

        model_inputs["labels"] = labels["input_ids"]
        return model_inputs


    tokenized_dataset = dataset.map(preprocess_function, batched=True)
    print(tokenized_dataset)
    sample = tokenized_dataset["train"][0]
    print(sample["labels"])

    from transformers import DataCollatorForSeq2Seq

    data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=checkpoint)

    from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer

    model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    training_args = Seq2SeqTrainingArguments(
        output_dir="byt5_small/"+lang+"_13epochs",
        eval_strategy="epoch",
        learning_rate=5e-5,
        per_device_train_batch_size=16,
        per_device_eval_batch_size=16,
        weight_decay=0.01,
        save_total_limit=3,
        num_train_epochs=12,
        predict_with_generate=True,
        fp16=False,# did not work with True #change to bf16=True for XPU 
        #bf16 = True, # performance was best without setting fp16 or bf16 to true
        push_to_hub=True,
        warmup_steps = 500,
        save_strategy="epoch",
        load_best_model_at_end=True, # otherwise not model with minimum loss during training, like https://huggingface.co/docs/transformers/tasks/sequence_classification,
        greater_is_better=False,
        metric_for_best_model="eval_loss"
    )

    trainer = Seq2SeqTrainer(
        model=model,
        args=training_args,
        train_dataset=tokenized_dataset["train"],
        eval_dataset=tokenized_dataset["validation"],
        tokenizer=tokenizer,
        data_collator=data_collator,
        # compute_metrics=compute_metrics,
    )

    trainer.train()
    trainer.push_to_hub()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 9
#       7 for lang in LANGS:
#       8     from datasets import load_dataset
# ----> 9     dataset = load_dataset("json", data_files={"train": PATH_JSON_DATA + lang + "_trn.json", "validation": PATH_JSON_DATA + lang + "_dev.json"})
#      11     print(dataset["train"][0])
#      13     from transformers import AutoTokenizer
#
# File /usr/local/lib/python3.10/dist-packages/datasets/load.py:1688, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1683 verification_mode = VerificationMode(
#    1684     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    1685 )
#    1687 # Create a dataset builder
# -> 1688 builder_instance = load_dataset_builder(
#    1689     path=path,
#    1690     name=name,
#    1691     data_dir=data_dir,
#    1692     data_files=data_files,
#    1693     cache_dir=cache_dir,
#    1694     features=features,
#    1695     download_config=download_config,
#    1696     download_mode=download_mode,
#    1697     revision=revision,
#    1698     token=token,
#    1699     storage_options=storage_options,
#    1700     **config_kwargs,
#    1701 )
#    1703 # Return iterable dataset in case of streaming
#    1704 if streaming:
#
# File /usr/local/lib/python3.10/dist-packages/datasets/load.py:1315, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, **config_kwargs)
#    1313 if features is not None:
#    1314     features = _fix_for_backward_compatible_features(features)
# -> 1315 dataset_module = dataset_module_factory(
#    1316     path,
#    1317     revision=revision,
#    1318     download_config=download_config,
#    1319     download_mode=download_mode,
#    1320     data_dir=data_dir,
#    1321     data_files=data_files,
#    1322     cache_dir=cache_dir,
#    1323 )
#    1324 # Get dataset builder class
#    1325 builder_kwargs = dataset_module.builder_kwargs
#
# File /usr/local/lib/python3.10/dist-packages/datasets/load.py:1055, in dataset_module_factory(path, revision, download_config, download_mode, data_dir, data_files, cache_dir, **download_kwargs)
#    1047 # Try packaged
#    1048 if path in _PACKAGED_DATASETS_MODULES:
#    1049     return PackagedDatasetModuleFactory(
#    1050         path,
#    1051         data_dir=data_dir,
#    1052         data_files=data_files,
#    1053         download_config=download_config,
#    1054         download_mode=download_mode,
# -> 1055     ).get_module()
#    1056 # Try locally
#    1057 elif path.endswith(filename):
#
# File /usr/local/lib/python3.10/dist-packages/datasets/load.py:533, in PackagedDatasetModuleFactory.get_module(self)
#     527 base_path = Path(self.data_dir or "").expanduser().resolve().as_posix()
#     528 patterns = (
#     529     sanitize_patterns(self.data_files)
#     530     if self.data_files is not None
#     531     else get_data_patterns(base_path, download_config=self.download_config)
#     532 )
# --> 533 data_files = DataFilesDict.from_patterns(
#     534     patterns,
#     535     download_config=self.download_config,
#     536     base_path=base_path,
#     537 )
#     539 module_path, hash = _PACKAGED_DATASETS_MODULES[self.name]
#     541 builder_kwargs = {
#     542     "data_files": data_files,
#     543     "dataset_name": self.name,
#     544 }
#
# File /usr/local/lib/python3.10/dist-packages/datasets/data_files.py:723, in DataFilesDict.from_patterns(cls, patterns, base_path, allowed_extensions, download_config)
#     718 out = cls()
#     719 for key, patterns_for_key in patterns.items():
#     720     out[key] = (
#     721         patterns_for_key
#     722         if isinstance(patterns_for_key, DataFilesList)
# --> 723         else DataFilesList.from_patterns(
#     724             patterns_for_key,
#     725             base_path=base_path,
#     726             allowed_extensions=allowed_extensions,
#     727             download_config=download_config,
#     728         )
#     729     )
#     730 return out
#
# File /usr/local/lib/python3.10/dist-packages/datasets/data_files.py:616, in DataFilesList.from_patterns(cls, patterns, base_path, allowed_extensions, download_config)
#     613 for pattern in patterns:
#     614     try:
#     615         data_files.extend(
# --> 616             resolve_pattern(
#     617                 pattern,
#     618                 base_path=base_path,
#     619                 allowed_extensions=allowed_extensions,
#     620                 download_config=download_config,
#     621             )
#     622         )
#     623     except FileNotFoundError:
#     624         if not has_magic(pattern):
#
# File /usr/local/lib/python3.10/dist-packages/datasets/data_files.py:403, in resolve_pattern(pattern, base_path, allowed_extensions, download_config)
#     401     if allowed_extensions is not None:
#     402         error_msg += f" with any supported extension {list(allowed_extensions)}"
# --> 403     raise FileNotFoundError(error_msg)
#     404 return out
#
# FileNotFoundError: Unable to find '/dss/dsshome1/03/ge87wod2/morphological-inflection/ByT5/../preprocessing/preprocessing_to_json/data/5lang-sample_trn.json'

# %% [markdown]
# # Inference

# %%
# SETTINGS = ["grc","dan","fra","sme","deu","nav","jap","klr","eng","mul","deu_eng"] + ["mul_2","ote","pol","amh"] + ["mul-language-code","mul-language-word"]
SETTINGS = ["mul"]
SETTINGS = ["5lang-sample"]
BASE_TEST_LANGUAGES_OF_SETTING = {"slavic":["csb"],"slavic-word":["csb"],"slavic-family":["pol","ces","csb","dsb","slk"],"5lang-sample":["deu","nav","klr","amh","grc"],"5lang-sample_16epochs":["amh"],
                                 "sme-15ksamples":["sme"],"sme-20ksamples":["sme"],"klr-15ksamples":["klr"],"klr-20ksamples":["klr"],"slavic-distant-word": ["pol","ces","csb","dsb","slk","mkd","rus","bel"],"slavic-distant-word-or-family": ["csb"], # ["pol","ces","csb","dsb","slk","mkd","rus","bel"],
                                  "csb-pol":["csb","pol"], "csb-pol-sent-pol": ["csb", "pol"], "csb-pol-sent-6epochs-pol": ["csb", "pol"],"slavic-distant":["csb"],
                                  "csb-sent-6epochs-pol": ["csb", "pol"], "dsb":["dsb"],"slk":["slk"],"ces":["ces"],"grc":["grc"],"sme":["sme"],"klr":["klr"],"nav":["nav"],
                                  "mul-language-word":["klr"],"pol":["csb"],"amh":["amh"],"mul_2":["sme","klr","grc"],"csb-pol-byte-sent-pol":["csb"],"csb-pol-byte-20perc-sent-pol":["csb","pol"],"csb-sent-25perc-byte-pol":["csb","pol"],"csb-pol-byte-25perc-sent-pol":["csb","pol"],"csb-pol-30perc-byte-sent-pol":["csb"],"csb-pol":["csb"],"hier-csb-gemini":["csb"],"9epochs-hier-csb-gemini":["csb"],
                                  "hier-csb-pol":["csb"], "12epochs-csb-sent-25perc-byte-pol":["csb","pol"]
                                 }
CODES = {"slavic": [""],"slavic-word":["-lang-word"],"slavic-family":["-family","-lang-word","-word-or-family"],"5lang-sample":["-lang-word"],"5lang-sample_16epochs":["-lang-word"],"5lang-sample_13epochs":["-lang-word"],"sme-15ksamples":[""],"sme-20ksamples":[""],"klr-15ksamples":[""],"klr-20ksamples":[""],"slavic-distant-word":["-lang-word"],"slavic-distant-word-or-family":["-family"],"csb-pol":[""],"csb-pol-sent-pol":[""],"csb-pol-sent-6epochs-pol": [""],"csb-sent-6epochs-pol": [""],"ces":[""],"slk":[""],"dsb":[""],"grc":[""],"sme":[""],"klr":[""],
        "mul-language-word":["-lang-word"],"nav":[""],"pol":[""],"amh":[""],"mul_2":[""],"csb-pol":[""],"csb-pol-byte-sent-pol":[""],"csb-pol-byte-20perc-sent-pol":[""],"csb-pol-byte-25perc-sent-pol":[""],"csb-sent-25perc-byte-pol":[""],"csb-pol-30perc-byte-sent-pol":[""],"csb-pol":[""],"hier-csb-gemini":[""],"9epochs-hier-csb-gemini":[""],
        "hier-csb-pol":[""], "slavic-distant" : [""],"12epochs-csb-sent-25perc-byte-pol":[""]}
SETTINGS = ["slavic","slavic-word"]
SETTINGS = ["sme-15ksamples","sme-20ksamples","klr-15ksamples","klr-20ksamples","5lang-sample_16epochs"]
SETTINGS = ["csb-sent-6epochs-pol"]
SETTINGS = ["slavic"]
SETTINGS = ["csb-pol-30perc-byte-sent-pol"]
SETTINGS = ["hier-csb-pol"]
SETTINGS = ["csb-sent-25perc-byte-pol","csb-pol-byte-25perc-sent-pol"]
SETTINGS = ["12epochs-csb-sent-25perc-byte-pol"]
#SETTINGS = ["mul-language-word"]

#TEST_LANGS_OLD = ["grc","dan","fra","sme","deu","nav","jap","klr","eng"] 
#TEST_LANGS = ["grc","dan","fra","sme","deu","nav","jap","klr","eng"] + ["ote","pol","amh","csb"]
#lang5_LANGS = ["deu","nav","klr","amh","grc"]
#lang_code = ""
ERROR_ANALYSIS_PATH = "/dss/dsshome1/03/ge87wod2/morphological-inflection/error_analysis_lucy/byt5"
for lang_setting in SETTINGS:
    test_langs = BASE_TEST_LANGUAGES_OF_SETTING[lang_setting]
    #if lang_setting == "mul": LANG_CODES = ["-language-word","-language-code",""] # test with no language code/word too
    #else: LANG_CODES = [""]
    #for lang_code in LANG_CODES:
        #if lang_setting in ( "deu_eng", "mul") and lang_code == "": test_langs = TEST_LANGS_OLD
        #elif lang_setting in ["mul_2","mul"]: test_langs = TEST_LANGS # test multilingual model on all languages it was trained on + Kashubian
        #elif lang_setting == "5lang-sample": test_langs = lang5_LANGS
        #elif lang_setting == "pol": test_langs = ["pol","csb"] # test Polish model on Kashubian also
        #else: 
    for lang_code in CODES[lang_setting]:
        for test_lang in test_langs:
            import torch
            from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
            PRETRAINED_MODEL = "google/byt5-small"
            FINETUNED_MODEL ="livles/"+lang_setting
            #FINETUNED_MODEL ="./byt5_small/"+lang_setting + lang_code
            MODEL = FINETUNED_MODEL
            print(MODEL)
            tokenizer = AutoTokenizer.from_pretrained(
                FINETUNED_MODEL,
            )
            model = AutoModelForSeq2SeqLM.from_pretrained(
                FINETUNED_MODEL,
                dtype=torch.float16,
                device_map="auto"
            )
            from datasets import load_dataset
            OUT_DIR = "output_byt5_small/" + lang_setting + "/" 
            PATH_TO_JSON_TEST_FILE = "../preprocessing/preprocessing_to_json_or_tsv/data/" + test_lang + lang_code+ "_tst.json"
            #ERROR_ANALYSIS_PATH = "/dss/dsshome1/03/ge87wod2/morphological-inflection/error_analysis_lucy/byt5/" + lang_setting + "/" + test_lang + lang_code + ".errors"
            print("test file: ",PATH_TO_JSON_TEST_FILE)
            PATH_TO_ORIG_TEST_FILE = "/dss/dsshome1/03/ge87wod2/morphological-inflection/2023InflectionST/part1/data/" + test_lang + ".tst"
            from pathlib import Path
            Path(OUT_DIR).mkdir(parents=True, exist_ok=True)
            with open (OUT_DIR + test_lang + lang_code + "_byt5-small.out","w") as out_file, open (PATH_TO_ORIG_TEST_FILE, "r") as test_file: #, open (ERROR_ANALYSIS_PATH, "w") as error_file
                dataset = load_dataset("json",data_files={"test":PATH_TO_JSON_TEST_FILE})
                covered_test_lines = dataset["test"]["input"]
                LEN = len(covered_test_lines)
                COUNTER = 0

                # preds = map (generate,covered_test_lines)
                for line in covered_test_lines:
                    input_ids = tokenizer(line, return_tensors="pt").to(model.device)
                    output = model.generate(
                        **input_ids,
                        max_new_tokens=50,
                        num_beams=4,
                        #early_stopping=True
                    )
                    output_string = (tokenizer.decode(output[0], skip_special_tokens=True))
                    ref_line = test_file.readline()
                    lemma, features, ref = ref_line.strip().split("\t")

                    # evaluate
                    if (ref == output_string):
                        COUNTER += 1
                        print(ref,output_string)
                    else:
                        print("ref:",ref,"pred:",output_string)
                     #   error_file.write("ref\t"+ref_line+"\n")
                      #  error_file.write("byt5\t"+line+"\n\n")
                       # error_file.flush()
                    # write
                    out_file.write(lemma + "\t" +features+ "\t" + output_string + "\n")
                    out_file.flush()
                accuracy = COUNTER / LEN
                out_file.write("accuracy:"+ str(accuracy)+"\n")
                print(accuracy)
# Out:
# livles/csb-sent-25perc-byte-pol
# Loading weights:   0%|          | 0/170 [00:00<?, ?it/s]
# [transformers] The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.
# test file:  ../preprocessing/preprocessing_to_json_or_tsv/data/csb_tst.json
# ref: narzãdzacze pred: narzãdzôcze
# ref: narzãdzaczom pred: narzãdzôczom
# ref: narzãdzaczu pred: narzãdzôczu
# ref: narzãdzaczama pred: narzãdzôczami
# ref: narzãdzaczu pred: narzãdzôczu
# ref: narzãdzaczowi pred: narzãdzôczowi
# ref: narzãdzacza pred: narzãdzôcza
# ref: narzãdzaczach pred: narzãdzôczach
# ref: narzãdzaczów pred: narzãdzôczy
# ref: narzãdzaczã pred: narzãdzôczem
# ref: narzãdzacze pred: narzãdzôcze
# ref: narzãdzacza pred: narzãdzôcz
# narzãdzôcz narzãdzôcz
# ref: narzãdzacze pred: narzãdzôcze
# ref: Jastrë pred: Jastrów
# Jastrach Jastrach
# ref: Jastróm pred: Jastrom
# Jastrów Jastrów
# ref: Jastrama pred: Jastrów
# ref: Jastrë pred: Jastrów
# ref: Jastrë pred: Jastry
# ref: pòniedzałczi pred: pòniedzôłki
# ref: pòniedzałkóm pred: pòniedzôłkom
# ref: pòniedzałkù pred: pòniedzôłku
# ref: pòniedzałkama pred: pòniedzôłkami
# ref: pòniedzałkù pred: pòniedzôłku
# ref: poniedzałkòwi pred: pòniedzôłkowi
# ref: pòniedzałkù pred: pòniedzôłka
# ref: pòniedzałkach pred: pòniedzôłkach
# ref: pòniedzałków pred: pòniedzôłków
# ref: pòniedzałkã pred: pòniedzôłkiem
# ref: pòniedzałczi pred: pòniedzôłki
# pòniedzôłk pòniedzôłk
# pòniedzôłk pòniedzôłk
# ref: pòniedzałczi pred: pòniedzôłki
# ref: pùjczi pred: pùjki
# pùjkom pùjkom
# ref: pùjkù pred: pùjku
# ref: pùjkama pred: pùjkami
# ref: pùjkù pred: pùjku
# ref: pùjkòwi pred: pùjkowi
# pùjka pùjka
# pùjkach pùjkach
# pùjków pùjków
# ref: pùjkã pred: pùjkiem
# ref: pùjczi pred: pùjki
# ref: pùjka pred: pùjk
# pùjk pùjk
# ref: pùjczi pred: pùjki
# ref: môlniczi pred: môlniki
# ref: môlnikòm pred: môlnikom
# ref: môlnikù pred: môlniku
# ref: môlnikama pred: môlnikami
# ref: môlnikù pred: môlniku
# ref: môlnikòwi pred: môlnikowi
# môlnika môlnika
# môlnikach môlnikach
# môlników môlników
# ref: môlnikã pred: môlnikiem
# ref: môlniczi pred: môlniki
# môlnik môlnik
# môlnik môlnik
# ref: môlniczi pred: môlniki
# ref: wòłiwaczë pred: wòłiwôcze
# ref: wòłiwaczom pred: wòłiwôczom
# ref: wòłiwaczu pred: wòłiwôczu
# ref: wòłiwaczama pred: wòłiwôczami
# ref: wòłiwaczu pred: wòłiwôczu
# ref: wòłiwaczowi pred: wòłiwôczowi
# ref: wòłiwacza pred: wòłiwôcza
# ref: wòłiwaczach pred: wòłiwôczach
# ref: wòłiwaczów pred: wòłiwôczów
# ref: wòłiwaczã pred: wòłiwôczem
# ref: wòłiwaczë pred: wòłiwôcze
# ref: wòłiwacza pred: wòłiwôcz
# wòłiwôcz wòłiwôcz
# ref: wòłiwaczë pred: wòłiwôcze
# ref: łżëkwiôtë pred: łżëkwioty
# ref: łżëkwiôtom pred: łżëkwiotom
# ref: łżëkwiôce pred: łżëkwiotowi
# ref: łżëkwiôtama pred: łżëkwiotami
# ref: łżëkwiôce pred: łżëkwiocie
# ref: łżëkwiôtowi pred: łżëkwiotowi
# ref: łżëkwiôta pred: łżëkwiotu
# ref: łżëkwiôtach pred: łżëkwiotach
# ref: łżëkwiôtów pred: łżëkwiotów
# ref: łżëkwiôtã pred: łżëkwiotem
# ref: łżëkwiôtë pred: łżëkwioty
# ref: łżëkwiôta pred: łżëkwiot
# ref: łżëkwiôt pred: łżëkwiot
# ref: łżëkwiôtë pred: łżëkwioty
# ref: lëstopadniczi pred: lëstopadniki
# ref: lëstopadnikòm pred: lëstopadnikom
# ref: lëstopadnikù pred: lëstopadniku
# ref: lëstopadnikama pred: lëstopadnikami
# ref: lëstopadnikù pred: lëstopadniku
# ref: lëstopadnikòwi pred: lëstopadnikowi
# lëstopadnika lëstopadnika
# lëstopadnikach lëstopadnikach
# lëstopadników lëstopadników
# ref: lëstopadnikã pred: lëstopadnikiem
# ref: lëstopadniczi pred: lëstopadniki
# lëstopadnika lëstopadnika
# lëstopadnik lëstopadnik
# ref: lëstopadniczi pred: lëstopadniki
# ref: sobòtë pred: sobòty
# ref: sobòtóm pred: sobòtom
# ref: sobòto pred: sobòcie
# ref: sobòtama pred: sobòtami
# ref: sobòce pred: sobòcie
# ref: sobòce pred: sobòcie
# ref: sobòtë pred: sobòty
# sobòtach sobòtach
# ref: sobòtów pred: sobòt
# ref: sobòtã pred: sobòtą
# ref: sobòtë pred: sobòty
# ref: sobòtã pred: sobòtę
# sobòta sobòta
# ref: sobòtë pred: sobòty
# ref: kònie pred: kóń
# ref: kòniom pred: koniom
# ref: kòniu pred: kóń
# ref: kòniama pred: kóńmi
# ref: kòniu pred: konie
# ref: kòniowi pred: koniowi
# ref: kònia pred: konia
# ref: kòniach pred: kóńcach
# ref: kòni pred: kóń
# ref: kòniã pred: kóńmi
# ref: kònie pred: kóń
# ref: kònia pred: kóń
# kóń kóń
# ref: kònie pred: kóń
# ref: nazéwacze pred: nazéwôcze
# ref: nazéwaczom pred: nazéwôczom
# ref: nazéwaczu pred: nazéwôczu
# ref: nazéwaczama pred: nazéwôczami
# ref: nazéwaczu pred: nazéwôczu
# ref: nazéwaczowi pred: nazéwôczowi
# ref: nazéwacza pred: nazéwôcza
# ref: nazéwaczach pred: nazéwôczach
# ref: nazéwaczów pred: nazéwôczy
# ref: nazéwaczã pred: nazéwôczem
# ref: nazéwacze pred: nazéwôcze
# ref: nazéwacza pred: nazéwôcz
# nazéwôcz nazéwôcz
# ref: nazéwacze pred: nazéwôcze
# ref: piątczi pred: piątki
# ref: piątkóm pred: piątkom
# ref: piątkù pred: piątku
# ref: piątkama pred: piątkami
# ref: piątkù pred: piątku
# ref: piątkòwi pred: piątkowi
# ref: piątkù pred: piątka
# piątkach piątkach
# piątków piątków
# ref: piątkã pred: piątkiem
# ref: piątczi pred: piątki
# piątk piątk
# piątk piątk
# ref: piątczi pred: piątki
# ref: rënczi pred: rënki
# ref: rënkóm pred: rënkom
# ref: stolem pred: rënku
# ref: rënkama pred: rënkami
# ref: rënkù pred: rënku
# ref: rënkòwi pred: rënkowi
# ref: rënkù pred: rënka
# rënkach rënkach
# rënków rënków
# ref: rënkã pred: rënkiem
# ref: rënczi pred: rënki
# rënk rënk
# rënk rënk
# ref: rënczi pred: rënki
# ref: wtórczi pred: wtórki
# ref: wtórkòm pred: wtórkom
# ref: wtórkù pred: wtórku
# ref: wtórkama pred: wtórkami
# ref: wtórkù pred: wtórku
# ref: wtórkòwi pred: wtórkowi
# wtórka wtórka
# wtórkach wtórkach
# wtórków wtórków
# ref: wtórkã pred: wtórkiem
# ref: wtórczi pred: wtórki
# wtórk wtórk
# wtórk wtórk
# ref: wtórczi pred: wtórki
# ref: winowacze pred: winowôcze
# ref: winowaczom pred: winowôczom
# ref: winowaczu pred: winowôczu
# ref: winowaczama pred: winowôczami
# ref: winowaczu pred: winowôczu
# ref: winowaczowi pred: winowôczowi
# ref: winowacza pred: winowôcza
# ref: winowaczach pred: winowôczach
# ref: winowaczów pred: winowôczy
# ref: winowaczã pred: winowôczem
# ref: winowacze pred: winowôcze
# ref: winowacza pred: winowôcz
# winowôcz winowôcz
# ref: winowacze pred: winowôcze
# ref: òjcowie pred: òjcy
# ref: òjcóm pred: òjcom
# ref: òjcze pred: òjcu
# ref: òjcama pred: òjcami
# òjcu òjcu
# ref: òjcu pred: òjcowi
# òjca òjca
# òjcach òjcach
# òjców òjców
# ref: òjcã pred: òjcem
# òjcem òjcem
# ref: òjców pred: òjcy
# ref: òjca pred: òjc
# òjc òjc
# ref: òjcowie pred: òjcy
# latawiska latawiska
# ref: latawiskóm pred: latawiskom
# ref: latawiskù pred: latawisko
# ref: latawiskama pred: latawiskami
# ref: latawiskù pred: latawisku
# ref: latawiskù pred: latawiskowi
# latawiska latawiska
# latawiskach latawiskach
# latawisków latawisków
# ref: latawiskã pred: latawiskiem
# latawiska latawiska
# ref: latawiskò pred: latawiskó
# ref: latawiskò pred: latawisko
# latawiska latawiska
# ref: Jastra pred: Jastry
# Jastrach Jastrach
# ref: Jastróm pred: Jastrom
# ref: Jastrów pred: Jastr
# ref: Jastrama pred: Jastry
# ref: Jastra pred: Jastry
# ref: Jastra pred: Jastry
# czerwińce czerwińce
# czerwińcom czerwińcom
# czerwińcu czerwińcu
# ref: czerwińcama pred: czerwińcami
# czerwińcu czerwińcu
# czerwińcowi czerwińcowi
# czerwińca czerwińca
# czerwińcach czerwińcach
# czerwińców czerwińców
# ref: czerwińcã pred: czerwińcem
# czerwińce czerwińce
# ref: czerwińca pred: czerwińc
# czerwińc czerwińc
# ref: czerwińc pred: czerwińce
# ref: rujanë pred: rujany
# rujanom rujanom
# rujanie rujanie
# ref: rujanama pred: rujanami
# rujanie rujanie
# rujanowi rujanowi
# rujana rujana
# rujanach rujanach
# rujanów rujanów
# ref: rujanã pred: rujanem
# ref: rujanë pred: rujany
# ref: rujana pred: rujan
# rujan rujan
# ref: rujanë pred: rujany
# ref: dôwacze pred: dôwôcze
# ref: dôwaczom pred: dôwôczom
# ref: dôwaczu pred: dôwôczu
# ref: dôwaczama pred: dôwôczami
# ref: dôwaczu pred: dôwôczu
# ref: dôwaczowi pred: dôwôczowi
# dôwôcza dôwôcza
# ref: dôwaczach pred: dôwôczach
# ref: dôwaczów pred: dôwôczy
# ref: dôwaczã pred: dôwôczem
# ref: dôwacze pred: dôwôcze
# ref: dôwacza pred: dôwôcz
# dôwôcz dôwôcz
# ref: dôwacze pred: dôwôcze
# ref: serca pred: serce
# ref: sercóm pred: sercom
# ref: serce pred: sercu
# ref: sercama pred: sercami
# sercu sercu
# ref: serce pred: sercu
# sercu sercu
# serca serca
# sercach sercach
# serców serców
# ref: serc pred: serców
# ref: sercã pred: sercem
# sercem sercem
# ref: serca pred: serce
# serce serce
# serce serce
# ref: serca pred: serce
# ref: lëpince pred: lëpincy
# lëpincom lëpincom
# lëpincu lëpincu
# ref: lëpincama pred: lëpincami
# lëpincu lëpincu
# lëpincowi lëpincowi
# lëpinca lëpinca
# lëpincach lëpincach
# lëpinców lëpinców
# ref: lëpincã pred: lëpincem
# ref: lëpince pred: lëpincy
# lëpinc lëpinc
# lëpinc lëpinc
# ref: lëpince pred: lëpincy
# ref: séwniczi pred: séwniki
# ref: séwnikòm pred: séwnikom
# ref: séwnikù pred: séwniku
# ref: séwnikama pred: séwnikami
# ref: séwnikù pred: séwniku
# ref: séwnikòwi pred: séwnikowi
# séwnika séwnika
# séwnikach séwnikach
# séwników séwników
# ref: séwnikã pred: séwnikiem
# ref: séwniczi pred: séwniki
# ref: séwnika pred: séwnik
# séwnik séwnik
# ref: séwniczi pred: séwniki
# ref: zélniczi pred: zélniki
# ref: zélnikòm pred: zélnikom
# ref: zélnikù pred: zélniku
# ref: zélnikama pred: zélnikami
# ref: zélnikù pred: zélniku
# ref: zélnikòwi pred: zélnikowi
# zélnika zélnika
# zélnikach zélnikach
# zélników zélników
# ref: zélnikã pred: zélnikiem
# ref: zélniczi pred: zélniki
# ref: zélnika pred: zélnik
# zélnik zélnik
# ref: zélniczi pred: zélniki
# ref: stëczniczi pred: stëczniki
# ref: stëcznikòm pred: stëcznikom
# ref: stëcznikù pred: stëczniku
# ref: stëcznikama pred: stëcznikami
# ref: stëcznikù pred: stëczniku
# ref: stëcznikòwi pred: stëcznikowi
# stëcznika stëcznika
# stëcznikach stëcznikach
# stëczników stëczników
# ref: stëcznikã pred: stëcznikiem
# ref: stëczniczi pred: stëczniki
# ref: stëcznika pred: stëcznik
# stëcznik stëcznik
# ref: stëczniczi pred: stëczniki
# ref: strzodë pred: strzody
# ref: strzodóm pred: strzodom
# ref: strzodo pred: strzodzie
# ref: strzodama pred: strzodami
# ref: strzodze pred: strzodzie
# ref: strzodze pred: strzodzie
# ref: strzodë pred: strzody
# strzodach strzodach
# ref: strzodów pred: strzod
# ref: strzodã pred: strzodą
# ref: strzodë pred: strzody
# ref: strzodã pred: strzodę
# strzoda strzoda
# ref: strzodë pred: strzody
# ref: maje pred: moje
# ref: majom pred: mojom
# ref: maju pred: moju
# ref: majima pred: mojami
# ref: maju pred: moju
# ref: majowi pred: mojowi
# ref: maja pred: moja
# ref: majach pred: mojach
# ref: majów pred: môjów
# ref: majã pred: mojem
# ref: maje pred: moje
# ref: môj pred: moj
# môj môj
# ref: maje pred: moje
# ref: strumianniczi pred: strumianniki
# ref: strumiannikòm pred: strumiannikom
# ref: strumiannikù pred: strumianniku
# ref: strumiannikama pred: strumiannikami
# ref: strumiannikù pred: strumianniku
# ref: strumiannikòwi pred: strumiannikowi
# strumiannika strumiannika
# strumiannikach strumiannikach
# strumianników strumianników
# ref: strumiannikã pred: strumiannikiem
# ref: strumianniczi pred: strumianniki
# strumiannik strumiannik
# strumiannik strumiannik
# ref: strumianniczi pred: strumianniki
# tidzénie tidzénie
# ref: tidzénióm pred: tidzéniom
# tidzéniu tidzéniu
# ref: tidzénama pred: tidzéniami
# tidzéniu tidzéniu
# tidzéniowi tidzéniowi
# tidzénia tidzénia
# ref: tidzénach pred: tidzéniach
# ref: tidzéniów pred: tidzéń
# ref: tidzénã pred: tidzéniem
# tidzénie tidzénie
# tidzéń tidzéń
# tidzéń tidzéń
# tidzénie tidzénie
# ref: czwôrtczi pred: czwôrtki
# ref: czwôrtkóm pred: czwôrtkom
# ref: czwôrtkù pred: czwôrtku
# ref: czwôrtkama pred: czwôrtkami
# ref: czwôrtkù pred: czwôrtku
# ref: czwôrtkòwi pred: czwôrtkowi
# ref: czwôrtkù pred: czwôrtka
# czwôrtkach czwôrtkach
# czwôrtków czwôrtków
# ref: czwôrtkã pred: czwôrtkiem
# ref: czwôrtczi pred: czwôrtki
# czwôrtk czwôrtk
# czwôrtk czwôrtk
# ref: czwôrtczi pred: czwôrtki
# ref: kòtë pred: kòty
# kòtom kòtom
# ref: kòce pred: kòtowi
# ref: kòtama pred: kòtami
# ref: kòce pred: kocie
# ref: kòtowi pred: kotowi
# ref: kòtu pred: kotowi
# ref: kòta pred: kotu
# kòtach kòtach
# kòtów kòtów
# ref: kòtã pred: kotem
# ref: kòtë pred: kòty
# ref: kòta pred: kòt
# kòt kòt
# ref: kòtë pred: kòty
# ref: gromiczniczi pred: gromiczniki
# ref: gromicznikòm pred: gromicznikom
# ref: gromicznikù pred: gromiczniku
# ref: gromicznikama pred: gromicznikami
# ref: gromicznikù pred: gromiczniku
# ref: gromicznikòwi pred: gromicznikowi
# gromicznika gromicznika
# gromicznikach gromicznikach
# gromiczników gromiczników
# ref: gromicznikã pred: gromicznikiem
# ref: gromiczniczi pred: gromiczniki
# ref: gromicznika pred: gromicznik
# gromicznik gromicznik
# ref: gromiczniczi pred: gromiczniki
# rodzôcze rodzôcze
# rodzôczom rodzôczom
# rodzôczu rodzôczu
# ref: rodzôczama pred: rodzôczami
# rodzôczu rodzôczu
# rodzôczowi rodzôczowi
# rodzôcza rodzôcza
# rodzôczach rodzôczach
# ref: rodzôczów pred: rodzôczy
# ref: rodzôczã pred: rodzôczem
# rodzôcze rodzôcze
# ref: rodzôcza pred: rodzôcz
# rodzôcz rodzôcz
# rodzôcze rodzôcze
# niedzele niedzele
# ref: niedzelóm pred: niedzelom
# niedzelo niedzelo
# ref: niedzelama pred: niedzelami
# ref: niedzeli pred: niedzele
# ref: niedzeli pred: niedzele
# niedzeli niedzeli
# niedzelach niedzelach
# ref: niedzelów pred: niedzel
# ref: niedzelã pred: niedzelą
# niedzele niedzele
# ref: niedzelã pred: niedzelę
# niedzela niedzela
# niedzele niedzele
# ref: gòdniczi pred: gòdniki
# ref: gòdnikòm pred: gòdnikom
# ref: gòdnikù pred: gòdniku
# ref: gòdnikama pred: gòdnikami
# ref: gòdnikù pred: gòdniku
# ref: gòdnikòwi pred: gòdnikowi
# gòdnika gòdnika
# gòdnikach gòdnikach
# gòdników gòdników
# ref: gòdnikã pred: gòdnikiem
# ref: gòdniczi pred: gòdniki
# ref: gòdnika pred: gòdnik
# gòdnik gòdnik
# ref: gòdniczi pred: gòdniki
# ref: stolemë pred: stolemy
# ref: stolemóm pred: stolemom
# ref: stolem pred: stolemie
# ref: stolemama pred: stolemami
# stolemie stolemie
# ref: stolemòwi pred: stolemowi
# ref: stolema pred: stolemu
# stolemach stolemach
# stolemów stolemów
# ref: stolemã pred: stolemem
# ref: stolemów pred: stolemy
# ref: stolema pred: stolem
# stolem stolem
# ref: stolemë pred: stolemy
# 0.3045186640471513
# livles/csb-sent-25perc-byte-pol
# Loading weights:   0%|          | 0/170 [00:00<?, ?it/s]
# [transformers] The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.
# test file:  ../preprocessing/preprocessing_to_json_or_tsv/data/pol_tst.json
# bezgrzeszne bezgrzeszne
# bezgrzeszne bezgrzeszne
# bezgrzesznego bezgrzesznego
# bezgrzesznego bezgrzesznego
# bezgrzesznego bezgrzesznego
# bezgrzesznej bezgrzesznej
# bezgrzesznej bezgrzesznej
# bezgrzesznej bezgrzesznej
# bezgrzesznemu bezgrzesznemu
# bezgrzesznemu bezgrzesznemu
# bezgrzeszny bezgrzeszny
# bezgrzesznych bezgrzesznych
# bezgrzesznych bezgrzesznych
# bezgrzesznych bezgrzesznych
# bezgrzesznym bezgrzesznym
# bezgrzesznym bezgrzesznym
# bezgrzesznymi bezgrzesznymi
# uchwytami uchwytami
# uchwyt uchwyt
# uchwytom uchwytom
# ref: uchwytowi pred: uchwycie
# uchwytów uchwytów
# uchwyty uchwyty
# uchwyty uchwyty
# uchwyty uchwyty
# zdaniami podrzędnymi zdaniami podrzędnymi
# zdania podrzędnego zdania podrzędnego
# zdania podrzędne zdania podrzędne
# zdania podrzędne zdania podrzędne
# zdaniem podrzędnym zdaniem podrzędnym
# ref: zdanie podrzędne pred: zdaniu podrzędne
# ref: zdaniu podrzędnym pred: zdaniu podrzędnemu
# zdań podrzędnych zdań podrzędnych
# będą nosili będą nosili
# ref: będą nosiły pred: będziecie nosiły
# ref: będziecie nosili pred: będą nosili
# będziecie nosiły będziecie nosiły
# będzie nosiła będzie nosiła
# będzie nosił będzie nosił
# ref: będziesz nosiła pred: będzie nosiła
# niech nosi niech nosi
# ref: noście pred: nosiliście
# nosić nosić
# nosiłabym nosiłabym
# nosiłabyś nosiłabyś
# nosiłaby nosiłaby
# nosiłam nosiłam
# nosiłbym nosiłbym
# nosiłbyś nosiłbyś
# nosiłeś nosiłeś
# nosilibyście nosilibyście
# nosilibyśmy nosilibyśmy
# ref: nosiliby pred: nosilibyście
# nosiliście nosiliście
# nosiliśmy nosiliśmy
# nosili nosili
# nosiłoby nosiłoby
# nosił nosił
# nosiłyście nosiłyście
# nosiły nosiły
# ref: nosimy pred: nosiłyśmy
# ref: nosisz pred: nosiło
# ref: nośmy pred: nosimy
# nosząca nosząca
# noszące noszące
# ref: noszące pred: nosące
# noszący noszący
# ref: noszą pred: nosiły
# noszenie noszenie
# ref: noszeni pred: noszący
# ref: noszę pred: nosiłem
# ref: noszona pred: nosząca
# ref: noszone pred: noszące
# ref: noszone pred: noszące
# ref: noszono pred: noszące
# kosmonaucie kosmonaucie
# kosmonaucie kosmonaucie
# ref: kosmonauci pred: kosmonauty
# kosmonautach kosmonautach
# kosmonautą kosmonautą
# kosmonauta kosmonauta
# kosmonautę kosmonautę
# ref: kosmonautów pred: kosmonauty
# ref: kosmonautów pred: kosmonaut
# kosmonauty kosmonauty
# łączach łączach
# łączami łączami
# łącza łącza
# łącze łącze
# łącze łącze
# ref: łącze pred: łączu
# ref: łączu pred: łączowi
# łączu łączu
# rosołach rosołach
# rosołami rosołami
# rosołem rosołem
# ref: rosole pred: rosoło
# ref: rosół pred: rosoł
# rosołów rosołów
# rosoły rosoły
# bękarcie bękarcie
# bękarcie bękarcie
# bękartach bękartach
# bękartami bękartami
# bękartom bękartom
# ref: bękartowi pred: bękarcowi
# bękartów bękartów
# naukowa naukowa
# naukowe naukowe
# naukowe naukowe
# naukowe naukowe
# naukowego naukowego
# naukowego naukowego
# naukowego naukowego
# naukowego naukowego
# naukowej naukowej
# naukowemu naukowemu
# naukowemu naukowemu
# naukowych naukowych
# naukowych naukowych
# naukowych naukowych
# naukowym naukowym
# naukowym naukowym
# naukowymi naukowymi
# szufladami szufladami
# szufladą szufladą
# szufladę szufladę
# ref: szuflado pred: szufladzie
# szuflady szuflady
# szuflady szuflady
# szuflady szuflady
# rzepikami rzepikami
# rzepikiem rzepikiem
# rzepiki rzepiki
# rzepik rzepik
# rzepik rzepik
# rzepików rzepików
# rzepiku rzepiku
# rzepiku rzepiku
# ref: gnojach pred: gnójach
# ref: gnojami pred: gnójami
# ref: gnojem pred: gnójem
# ref: gnoje pred: gnóje
# ref: gnoje pred: gnóje
# gnój gnój
# gnój gnój
# gnojowi gnojowi
# gnoju gnoju
# gnoju gnoju
# winogronowe winogronowe
# winogronowe winogronowe
# winogronowe winogronowe
# winogronowego winogronowego
# winogronowego winogronowego
# winogronowej winogronowej
# winogronowej winogronowej
# winogronowej winogronowej
# winogronowemu winogronowemu
# winogronowemu winogronowemu
# winogronowy winogronowy
# winogronowym winogronowym
# winogronowym winogronowym
# będą kleili będą kleili
# ref: będą kleiły pred: będziecie kleiły
# ref: będę kleiła pred: będziesz kleiła
# ref: będę kleił pred: będziesz kleił
# będziecie kleiły będziecie kleiły
# będzie kleiło będzie kleiło
# ref: będziemy kleili pred: będą kleili
# ref: kleicie pred: kleiłyście
# ref: kleić pred: kleiło
# kleiłabym kleiłabym
# kleiłabyś kleiłabyś
# kleiłam kleiłam
# kleiłby kleiłby
# kleiłem kleiłem
# kleiłeś kleiłeś
# kleilibyśmy kleilibyśmy
# kleiliście kleiliście
# kleiliśmy kleiliśmy
# kleiło kleiło
# kleił kleił
# kleiłybyście kleiłybyście
# ref: kleiłyby pred: kleiłybyście
# kleiłyście kleiłyście
# kleiłyśmy kleiłyśmy
# ref: kleimy pred: kleiłyśmy
# klejąca klejąca
# klejące klejące
# klejący klejący
# klejący klejący
# ref: kleją pred: kleiły
# ref: klejeni pred: klejący
# ref: klejona pred: klejąca
# ref: klejono pred: klejące
# ref: klej pred: będziesz kleił
# uczuciach uczuciach
# uczuciami uczuciami
# uczucia uczucia
# uczucia uczucia
# ref: uczucie pred: uczuciu
# uczuciu uczuciu
# edylach edylach
# edylami edylami
# ref: edyla pred: edylu
# ref: edyli pred: edyle
# edyl edyl
# edylom edylom
# ref: edylowie pred: edyle
# edylu edylu
# edylu edylu
# tłumaczeniach tłumaczeniach
# tłumaczenia tłumaczenia
# tłumaczenia tłumaczenia
# tłumaczeniem tłumaczeniem
# tłumaczenie tłumaczenie
# ref: tłumaczenie pred: tłumaczeniu
# tłumaczeniu tłumaczeniu
# tłumaczeniu tłumaczeniu
# plombą plombą
# plomba plomba
# plombę plombę
# plombie plombie
# plombie plombie
# plomb plomb
# ref: plombo pred: plombie
# plomby plomby
# plomby plomby
# nieśmiertelną nieśmiertelną
# nieśmiertelną nieśmiertelną
# nieśmiertelnego nieśmiertelnego
# nieśmiertelnej nieśmiertelnej
# nieśmiertelnej nieśmiertelnej
# nieśmiertelnej nieśmiertelnej
# nieśmiertelnemu nieśmiertelnemu
# nieśmiertelni nieśmiertelni
# nieśmiertelnych nieśmiertelnych
# nieśmiertelnych nieśmiertelnych
# nieśmiertelnym nieśmiertelnym
# kulach kulach
# kulą kulą
# kula kula
# kule kule
# kule kule
# ref: kuli pred: kule
# ref: kuli pred: kuly
# kul kul
# brzoskwiniową brzoskwiniową
# brzoskwiniowa brzoskwiniowa
# brzoskwiniowe brzoskwiniowe
# brzoskwiniowe brzoskwiniowe
# brzoskwiniowego brzoskwiniowego
# brzoskwiniowego brzoskwiniowego
# brzoskwiniowego brzoskwiniowego
# brzoskwiniowej brzoskwiniowej
# brzoskwiniowej brzoskwiniowej
# brzoskwiniowi brzoskwiniowi
# brzoskwiniowy brzoskwiniowy
# brzoskwiniowych brzoskwiniowych
# brzoskwiniowych brzoskwiniowych
# brzoskwiniowych brzoskwiniowych
# brzoskwiniowym brzoskwiniowym
# brzoskwiniowymi brzoskwiniowymi
# istnieniach istnieniach
# istnienia istnienia
# istnienia istnienia
# istnienia istnienia
# istnienie istnienie
# ref: istnienie pred: istnieniu
# istnieniom istnieniom
# ref: istnień pred: istnieni
# martwą martwą
# martwa martwa
# martwe martwe
# martwe martwe
# martwego martwego
# martwego martwego
# martwemu martwemu
# martwemu martwemu
# martwi martwi
# martwy martwy
# martwy martwy
# martwych martwych
# martwych martwych
# martwym martwym
# martwym martwym
# martwym martwym
# martwym martwym
# martwymi martwymi
# napięciach napięciach
# napięcia napięcia
# napięcia napięcia
# napięcia napięcia
# napięcie napięcie
# napięciu napięciu
# ref: napięć pred: napięci
# dziwce dziwce
# dziwkami dziwkami
# dziwką dziwką
# dziwki dziwki
# dziwki dziwki
# dziwkom dziwkom
# ref: dziwko pred: dziwce
# kompromisem kompromisem
# kompromisie kompromisie
# kompromisie kompromisie
# kompromis kompromis
# kompromisom kompromisom
# kompromisowi kompromisowi
# kompromisów kompromisów
# kompromisu kompromisu
# kompromisy kompromisy
# klanami klanami
# klanem klanem
# klanie klanie
# klan klan
# klanom klanom
# klanowi klanowi
# klany klany
# klany klany
# klany klany
# polanach polanach
# polanami polanami
# polana polana
# polanę polanę
# polanie polanie
# polanie polanie
# polanom polanom
# ref: polano pred: polanie
# polany polany
# polany polany
# ref: niech wyrządzą pred: niech wyrządzili
# ref: niech wyrządzę pred: niech wyrządzi
# ref: wyrządzeni pred: wyrządzonych
# ref: wyrządzę pred: będziemy wyrządziły
# wyrządziłabym wyrządziłabym
# wyrządziłabyś wyrządziłabyś
# wyrządziłaś wyrządziłaś
# wyrządziła wyrządziła
# wyrządziłbym wyrządziłbym
# wyrządziłbyś wyrządziłbyś
# wyrządziłby wyrządziłby
# wyrządziłeś wyrządziłeś
# wyrządzilibyście wyrządzilibyście
# wyrządzilibyśmy wyrządzilibyśmy
# ref: wyrządziliby pred: wyrządzilibyście
# wyrządziliście wyrządziliście
# wyrządziliśmy wyrządziliśmy
# wyrządziłoby wyrządziłoby
# wyrządził wyrządził
# wyrządziłybyśmy wyrządziłybyśmy
# wyrządziłyście wyrządziłyście
# wyrządziłyśmy wyrządziłyśmy
# wyrządziły wyrządziły
# ref: wyrządzimy pred: będziemy wyrządzili
# wyrządzona wyrządzona
# wyrządzone wyrządzone
# ref: wyrządzono pred: wyrządzone
# ref: wyrządź pred: niech wyrządzi
# niższą niższą
# niższa niższa
# niższe niższe
# niższe niższe
# niższego niższego
# niższego niższego
# niższej niższej
# niższemu niższemu
# niższych niższych
# niższym niższym
# niższym niższym
# niższym niższym
# niższym niższym
# nastolatkach nastolatkach
# nastolatkami nastolatkami
# nastolatka nastolatka
# nastolatki nastolatki
# nastolatki nastolatki
# ref: nastolatków pred: nastolatki
# nastolatku nastolatku
# zbiegach zbiegach
# ref: zbiega pred: zbieg
# zbieg zbieg
# zbiegom zbiegom
# ref: zbiegowie pred: zbiegi
# ref: zbiegów pred: zbiegi
# zbiegu zbiegu
# ref: szkutnicy pred: szkutniki
# szkutnikach szkutnikach
# szkutnikami szkutnikami
# szkutnika szkutnika
# szkutnikom szkutnikom
# szkutników szkutników
# szkutniku szkutniku
# samotniejsi samotniejsi
# samotniejszą samotniejszą
# samotniejszą samotniejszą
# samotniejsza samotniejsza
# samotniejsze samotniejsze
# samotniejsze samotniejsze
# samotniejsze samotniejsze
# samotniejszego samotniejszego
# samotniejszego samotniejszego
# samotniejszej samotniejszej
# samotniejszej samotniejszej
# samotniejszemu samotniejszemu
# samotniejszy samotniejszy
# samotniejszy samotniejszy
# samotniejszych samotniejszych
# samotniejszych samotniejszych
# samotniejszym samotniejszym
# samotniejszym samotniejszym
# samotniejszymi samotniejszymi
# mitozach mitozach
# mitoza mitoza
# mitozę mitozę
# mitozie mitozie
# mitozom mitozom
# mitozy mitozy
# asemblerach asemblerach
# asemblerami asemblerami
# asemblera asemblera
# asemblerowi asemblerowi
# asemblerów asemblerów
# asemblery asemblery
# asemblery asemblery
# asemblerze asemblerze
# asemblerze asemblerze
# automacie automacie
# automatami automatami
# automat automat
# ref: automatowi pred: automacie
# automaty automaty
# automaty automaty
# kasztanach kasztanach
# kasztanami kasztanami
# kasztan kasztan
# kasztan kasztan
# kasztany kasztany
# kasztany kasztany
# ref: śródmózgowiach pred: śródmózgowcach
# ref: śródmózgowiami pred: śródmózgowcami
# śródmózgowia śródmózgowia
# śródmózgowie śródmózgowie
# śródmózgowie śródmózgowie
# ref: śródmózgowi pred: śródmózgowców
# ref: śródmózgowiu pred: śródmózgowcu
# ref: śródmózgowiu pred: śródmózgowcu
# ref: lisiąt pred: lisięcy
# ref: lisięciem pred: lisięmi
# ref: lisięciu pred: lisięowi
# ref: lisięciu pred: lisię
# lisię lisię
# lisię lisię
# ref: lisiętach pred: lisięch
# ref: lisiętami pred: lisięmi
# ref: lisięta pred: lisię
# ref: lisięta pred: lisię
# ref: lisiętom pred: lisięom
# graniach graniach
# ref: granią pred: graną
# granie granie
# granie granie
# ref: grani pred: grania
# grań grań
# basach basach
# basie basie
# basie basie
# bas bas
# bas bas
# basy basy
# woskowiną woskowiną
# woskowina woskowina
# ref: woskowino pred: woskowinie
# ref: zadadzą pred: będziecie zadały
# sinologia sinologia
# sinologię sinologię
# ref: sinologii pred: sinologiowi
# sinologii sinologii
# sinologii sinologii
# sinologio sinologio
# kurami kurami
# kur kur
# kurom kurom
# kurowi kurowi
# kurów kurów
# kurze kurze
# kurze kurze
# przysięgach przysięgach
# przysięgami przysięgami
# przysięga przysięga
# przysięgi przysięgi
# przysięgom przysięgom
# przysięgo przysięgo
# nonanem nonanem
# nonanie nonanie
# nonan nonan
# nonan nonan
# nonanów nonanów
# nonany nonany
# elektrowniami elektrowniami
# elektrownie elektrownie
# elektrownie elektrownie
# elektrownie elektrownie
# ref: elektrowni pred: elektrownie
# elektrowni elektrowni
# elektrowniom elektrowniom
# fotografach fotografach
# fotografami fotografami
# fotografem fotografem
# fotografie fotografie
# fotograf fotograf
# ref: fotografów pred: fotografy
# ref: będą machały pred: będziesz machał
# ref: będę machała pred: będzie machała
# ref: będę machał pred: będziemy machały
# ref: będziecie machali pred: będą machali
# będzie machała będzie machała
# będzie machało będzie machało
# będzie machał będzie machał
# ref: będziemy machali pred: będą machali
# ref: będziemy machały pred: będziemy machali
# ref: będziesz machała pred: będzie machała
# będziesz machał będziesz machał
# ref: machający pred: machani
# machający machający
# machajcie machajcie
# machajmy machajmy
# machałaby machałaby
# machałam machałam
# machałaś machałaś
# machała machała
# machałbym machałbym
# machałby machałby
# machałem machałem
# machalibyście machalibyście
# machalibyśmy machalibyśmy
# machaliśmy machaliśmy
# machałoby machałoby
# machałybyśmy machałybyśmy
# ref: machałyby pred: machałybyście
# machałyście machałyście
# machałyśmy machałyśmy
# machały machały
# ref: macham pred: machałam
# machane machane
# machanie machanie
# machani machani
# ref: machano pred: machane
# ref: machasz pred: machało
# niech macha niech macha
# jonosferach jonosferach
# jonosfera jonosfera
# jonosferom jonosferom
# jonosfery jonosfery
# jonosfery jonosfery
# jonosfery jonosfery
# jonosferze jonosferze
# ref: lodach pred: lódach
# ref: lodem pred: lódem
# lód lód
# lodom lodom
# lodowi lodowi
# ref: lodów pred: lódów
# lodzie lodzie
# ref: będą siąknąły pred: będziecie siąknęły
# będą siąknęli będą siąknęli
# ref: będziemy siąknęli pred: będą siąknęli
# ref: będzie siąknąła pred: będzie siąknęła
# ref: będzie siąknąło pred: będzie siąknęło
# ref: będzie siąknął pred: będzie siąknęł
# ref: będziesz siąknąła pred: będzie siąknęła
# ref: będziesz siąknął pred: będziesz siąknęł
# niech siąkną niech siąkną
# ref: niech siąknie pred: niech siąknę
# siąknąca siąknąca
# siąknące siąknące
# siąknące siąknące
# siąknący siąknący
# ref: siąknąłabyś pred: siąknęłabyś
# ref: siąknąłaby pred: siąknęłaby
# ref: siąknąła pred: siąknęła
# siąknąłbyś siąknąłbyś
# ref: siąknąłeś pred: siąknęłeś
# siąknąłybyście siąknąłybyście
# siąknąłybyśmy siąknąłybyśmy
# ref: siąknąłyby pred: siąknęłybyście
# ref: siąknąłyśmy pred: siąknęłyśmy
# ref: siąkną pred: siąknęły
# ref: siąknęlibyście pred: siąknąlibyście
# ref: siąknęlibyśmy pred: siąknąlibyśmy
# ref: siąknęliście pred: siąknąliście
# ref: siąknęliśmy pred: siąknąliśmy
# ref: siąknę pred: siąknęło
# ref: siąkniemy pred: siąknęłyśmy
# ref: siąkniesz pred: siąknęło
# ref: siąknie pred: siąknę
# ref: siąknijcie pred: niech siąkną
# ref: siąknijmy pred: niech siąkną
# ref: siąknij pred: niech siąknę
# najdzikszą najdzikszą
# najdziksza najdziksza
# najdziksze najdziksze
# najdziksze najdziksze
# najdzikszego najdzikszego
# najdzikszej najdzikszej
# najdzikszej najdzikszej
# najdzikszej najdzikszej
# najdzikszemu najdzikszemu
# najdzikszy najdzikszy
# najdzikszy najdzikszy
# najdzikszych najdzikszych
# najdzikszych najdzikszych
# najdzikszym najdzikszym
# peronach peronach
# peronem peronem
# peronie peronie
# peronom peronom
# peronów peronów
# perony perony
# sygnałach sygnałach
# sygnałami sygnałami
# sygnał sygnał
# sygnałom sygnałom
# sygnały sygnały
# sygnały sygnały
# najlżejszą najlżejszą
# najlżejsza najlżejsza
# najlżejsze najlżejsze
# najlżejsze najlżejsze
# najlżejsze najlżejsze
# najlżejszego najlżejszego
# najlżejszego najlżejszego
# najlżejszej najlżejszej
# najlżejszemu najlżejszemu
# najlżejszy najlżejszy
# najlżejszych najlżejszych
# najlżejszych najlżejszych
# najlżejszym najlżejszym
# najlżejszymi najlżejszymi
# wybuchach wybuchach
# wybuchem wybuchem
# wybuch wybuch
# wybuch wybuch
# wybuchowi wybuchowi
# wybuchu wybuchu
# ref: wybuchu pred: wybucha
# wybuchu wybuchu
# wybuchy wybuchy
# wybuchy wybuchy
# ref: sekście pred: sekstowi
# ref: sekście pred: sekscie
# sekstą sekstą
# seksta seksta
# sekst sekst
# sekstom sekstom
# seksto seksto
# seksty seksty
# seksty seksty
# seksty seksty
# bocianach bocianach
# bocianami bocianami
# bociana bociana
# bocianem bocianem
# bocianie bocianie
# bocian bocian
# bocianom bocianom
# bocianów bocianów
# bociany bociany
# bociany bociany
# trwania trwania
# trwanie trwanie
# trwanie trwanie
# trwaniu trwaniu
# trwaniu trwaniu
# ref: będę marła pred: będziesz mrzała
# ref: będziecie marli pred: będą mrzeli
# ref: będziecie marły pred: będziecie mrzeli
# ref: będzie marła pred: będzie mrzała
# ref: będzie marło pred: będzie mrzało
# ref: będzie marł pred: będzie mrzał
# ref: będziemy marli pred: będą mrzeli
# ref: marcie pred: mrzenie
# ref: marłabyś pred: mrzałabyś
# ref: marłam pred: mrzałam
# ref: marłaś pred: mrzałaś
# ref: marła pred: mrzała
# ref: marłbyś pred: mrzałbyś
# ref: marłby pred: mrzałby
# ref: marłeś pred: mrzałeś
# ref: marlibyście pred: mrzelibyście
# ref: marlibyśmy pred: mrzelibyśmy
# ref: marł pred: mrzał
# ref: marłyby pred: mrzałybyście
# ref: marłyśmy pred: mrzałyśmy
# ref: marły pred: mrzały
# ref: mrące pred: mrzące
# ref: mrące pred: mrzące
# ref: mrąc pred: mrząc
# ref: mrący pred: mrzący
# ref: mrący pred: mrzący
# ref: mrzecie pred: mrzałyście
# mrzeć mrzeć
# ref: mrzemy pred: mrzałyśmy
# ref: mrze pred: mrzeł
# ref: mrzyjcie pred: mrzeliście
# ref: mrzyj pred: niech mrze
# ref: niech mrą pred: niech mrzą
# niech mrze niech mrze
# oczopląsach oczopląsach
# oczopląs oczopląs
# oczopląsowi oczopląsowi
# oczopląsy oczopląsy
# przewodniczącego przewodniczącego
# ref: przewodniczących pred: przewodniczące
# przewodniczących przewodniczących
# przewodniczącym przewodniczącym
# ref: przewodniczący pred: przewodnicząca
# ref: przewodniczący pred: przewodniczące
# mięczakach mięczakach
# mięczakami mięczakami
# ref: mięczaka pred: mięczak
# mięczaka mięczaka
# mięczakiem mięczakiem
# mięczaki mięczaki
# mięczaki mięczaki
# mięczaki mięczaki
# mięczak mięczak
# mięczakowi mięczakowi
# mięczaków mięczaków
# nieodpowiedzialna nieodpowiedzialna
# nieodpowiedzialne nieodpowiedzialne
# nieodpowiedzialne nieodpowiedzialne
# nieodpowiedzialne nieodpowiedzialne
# nieodpowiedzialne nieodpowiedzialne
# nieodpowiedzialnego nieodpowiedzialnego
# nieodpowiedzialnego nieodpowiedzialnego
# nieodpowiedzialnego nieodpowiedzialnego
# nieodpowiedzialnemu nieodpowiedzialnemu
# nieodpowiedzialnemu nieodpowiedzialnemu
# nieodpowiedzialni nieodpowiedzialni
# nieodpowiedzialny nieodpowiedzialny
# nieodpowiedzialnych nieodpowiedzialnych
# nieodpowiedzialnym nieodpowiedzialnym
# nieodpowiedzialnym nieodpowiedzialnym
# nieodpowiedzialnymi nieodpowiedzialnymi
# szalu szalu
# cyrkami cyrkami
# cyrkiem cyrkiem
# cyrki cyrki
# cyrk cyrk
# cyrk cyrk
# cyrków cyrków
# cyrku cyrku
# ref: cyrku pred: cyrka
# cyrku cyrku
# najjaśniejsi najjaśniejsi
# najjaśniejszą najjaśniejszą
# najjaśniejsza najjaśniejsza
# najjaśniejsze najjaśniejsze
# najjaśniejsze najjaśniejsze
# najjaśniejszego najjaśniejszego
# najjaśniejszej najjaśniejszej
# najjaśniejszej najjaśniejszej
# najjaśniejszych najjaśniejszych
# najjaśniejszych najjaśniejszych
# najjaśniejszych najjaśniejszych
# najjaśniejszym najjaśniejszym
# najjaśniejszym najjaśniejszym
# żenecie żenecie
# żenetami żenetami
# żenetą żenetą
# żeneta żeneta
# żenetę żenetę
# żenet żenet
# żenetom żenetom
# żenety żenety
# żenety żenety
# żenety żenety
# waściach waściach
# waściami waściami
# waści waści
# waści waści
# waści waści
# waści waści
# waści waści
# waść waść
# ref: otwarci pred: otwarti
# otwartą otwartą
# otwarta otwarta
# otwarte otwarte
# otwarte otwarte
# otwartego otwartego
# otwartej otwartej
# otwartej otwartej
# otwartej otwartej
# otwartemu otwartemu
# otwartemu otwartemu
# otwarty otwarty
# otwarty otwarty
# otwartych otwartych
# otwartym otwartym
# otwartym otwartym
# otwartymi otwartymi
# ref: dłużnicy pred: dłużniki
# ref: dłużnicy pred: dłużniki
# dłużnikami dłużnikami
# dłużnika dłużnika
# dłużnik dłużnik
# dłużnikowi dłużnikowi
# ref: manicure'ami pred: manicurami
# ref: manicure'em pred: manicurem
# manicure manicure
# ref: manicure'om pred: manicurom
# ref: manicure'y pred: manicury
# ref: manicure'y pred: manicure
# ref: manicure'y pred: manicury
# manicurze manicurze
# sefardyjscy sefardyjscy
# sefardyjski sefardyjski
# sefardyjskich sefardyjskich
# sefardyjskie sefardyjskie
# sefardyjskiego sefardyjskiego
# sefardyjskiego sefardyjskiego
# sefardyjskiej sefardyjskiej
# sefardyjskiej sefardyjskiej
# sefardyjskiemu sefardyjskiemu
# sefardyjskim sefardyjskim
# sefardyjskim sefardyjskim
# sefardyjskim sefardyjskim
# sefardyjskimi sefardyjskimi
# szynce szynce
# szynce szynce
# szynek szynek
# szynkami szynkami
# szynkę szynkę
# szynki szynki
# szynkom szynkom
# ref: szynko pred: szynce
# częstokołach częstokołach
# częstokołami częstokołami
# ref: częstokole pred: częstokolu
# ref: częstokół pred: częstokoł
# tulem tulem
# tul tul
# tulowi tulowi
# tulu tulu
# tulu tulu
# ścianami ścianami
# ściana ściana
# ścianę ścianę
# ścianom ścianom
# ref: ściano pred: ścianie
# ściany ściany
# ściany ściany
# ref: baracheł pred: barachłów
# barachłach barachłach
# barachła barachła
# barachła barachła
# barachła barachła
# barachło barachło
# barachło barachło
# ref: barachłu pred: barachłowi
# czczą czczą
# czcza czcza
# czcze czcze
# czcze czcze
# czcze czcze
# czczego czczego
# czczej czczej
# czczej czczej
# ref: czczy pred: czczych
# czczych czczych
# czczym czczym
# czczym czczym
# czczymi czczymi
# ref: Indianach pred: Indianinach
# ref: Indianie pred: Indianiny
# Indianinie Indianinie
# Indianinie Indianinie
# Indianin Indianin
# Indianinowi Indianinowi
# ref: Indian pred: Indianiny
# hodowlach hodowlach
# hodowlą hodowlą
# hodowla hodowla
# hodowle hodowle
# ref: hodowli pred: hodowle
# ref: hodowli pred: hodowle
# hodowli hodowli
# hodowlom hodowlom
# pacie pacie
# ref: pacie pred: patowi
# patami patami
# ref: pata pred: pat
# pat pat
# patowi patowi
# patów patów
# paty paty
# ilustracjach ilustracjach
# ilustracje ilustracje
# ilustracje ilustracje
# ilustracji ilustracji
# ilustracjom ilustracjom
# ref: ilustracjo pred: ilustracji
# rachunek rachunek
# rachunek rachunek
# rachunkach rachunkach
# rachunkiem rachunkiem
# rachunki rachunki
# rachunkowi rachunkowi
# rachunków rachunków
# rachunku rachunku
# rachunku rachunku
# zimową zimową
# zimową zimową
# zimowa zimowa
# zimowe zimowe
# zimowe zimowe
# zimowego zimowego
# zimowego zimowego
# zimowego zimowego
# zimowej zimowej
# zimowemu zimowemu
# zimowy zimowy
# zimowy zimowy
# zimowych zimowych
# zimowych zimowych
# zimowym zimowym
# zimowym zimowym
# zimowym zimowym
# rutenem rutenem
# ruten ruten
# chrabąszczach chrabąszczach
# chrabąszczami chrabąszczami
# ref: chrabąszcza pred: chrabąszcz
# chrabąszczem chrabąszczem
# chrabąszcze chrabąszcze
# chrabąszcze chrabąszcze
# chrabąszczom chrabąszczom
# chrabąszczowi chrabąszczowi
# chrabąszczy chrabąszczy
# miarami miarami
# miarę miarę
# miar miar
# miarom miarom
# ref: miaro pred: miarze
# miary miary
# miary miary
# ref: mierze pred: miarze
# dzieżach dzieżach
# dzieżami dzieżami
# dzieżą dzieżą
# dzieże dzieże
# dzieże dzieże
# dzieżom dzieżom
# dzieżo dzieżo
# ref: dzieży pred: dzieże
# dzieży dzieży
# małpeczce małpeczce
# małpeczkach małpeczkach
# małpeczkami małpeczkami
# małpeczki małpeczki
# małpeczkom małpeczkom
# ref: małpeczko pred: małpeczce
# koronach koronach
# koroną koroną
# korona korona
# koronę koronę
# koronie koronie
# koronom koronom
# ref: korono pred: koronie
# korony korony
# korony korony
# korony korony
# lipca lipca
# lipce lipce
# ref: lipce pred: lipcy
# ref: lipce pred: lipcy
# lipcom lipcom
# lipców lipców
# lipiec lipiec
# lipiec lipiec
# zupami zupami
# zupą zupą
# zupa zupa
# zupie zupie
# zup zup
# ref: zupo pred: zupie
# zupy zupy
# zupy zupy
# miocie miocie
# miotach miotach
# miotami miotami
# miot miot
# miotom miotom
# ref: miotowi pred: miocowi
# miotu miotu
# mioty mioty
# mioty mioty
# mioty mioty
# 0.791
# livles/csb-pol-byte-25perc-sent-pol
# Loading weights:   0%|          | 0/170 [00:00<?, ?it/s]
# [transformers] The tied weights mapping and config for this model specifies to tie shared.weight to lm_head.weight, but both are present in the checkpoints with different values, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning.
# test file:  ../preprocessing/preprocessing_to_json_or_tsv/data/csb_tst.json
# ref: narzãdzacze pred: narzãdzôcze
# ref: narzãdzaczom pred: narzãdzôczom
# ref: narzãdzaczu pred: narzãdzôczu
# ref: narzãdzaczama pred: narzãdzôczami
# ref: narzãdzaczu pred: narzãdzôczu
# ref: narzãdzaczowi pred: narzãdzôczowi
# ref: narzãdzacza pred: narzãdzôcza
# ref: narzãdzaczach pred: narzãdzôczach
# ref: narzãdzaczów pred: narzãdzôczy
# ref: narzãdzaczã pred: narzãdzôczem
# ref: narzãdzacze pred: narzãdzôcze
# ref: narzãdzacza pred: narzãdzôcz
# narzãdzôcz narzãdzôcz
# ref: narzãdzacze pred: narzãdzôcze
# Jastrë Jastrë
# Jastrach Jastrach
# ref: Jastróm pred: Jastrom
# Jastrów Jastrów
# ref: Jastrama pred: Jastrë
# Jastrë Jastrë
# Jastrë Jastrë
# ref: pòniedzałczi pred: pòniedzôłki
# ref: pòniedzałkóm pred: pòniedzôłkom
# ref: pòniedzałkù pred: pòniedzôłku
# ref: pòniedzałkama pred: pòniedzôłkami
# ref: pòniedzałkù pred: pòniedzôłcu
# ref: poniedzałkòwi pred: pòniedzôłcowi
# ref: pòniedzałkù pred: pòniedzôłku
# ref: pòniedzałkach pred: pòniedzôłkach
# ref: pòniedzałków pred: pòniedzôłków
# ref: pòniedzałkã pred: pòniedzôłkiem
# ref: pòniedzałczi pred: pòniedzôłki
# pòniedzôłk pòniedzôłk
# pòniedzôłk pòniedzôłk
# ref: pòniedzałczi pred: pòniedzôłki
# ref: pùjczi pred: pùjki
# pùjkom pùjkom
# ref: pùjkù pred: pùjku
# ref: pùjkama pred: pùjkami
# ref: pùjkù pred: pùjku
# ref: pùjkòwi pred: pùjkowi
# pùjka pùjka
# pùjkach pùjkach
# pùjków pùjków
# ref: pùjkã pred: pùjkiem
# ref: pùjczi pred: pùjki
# ref: pùjka pred: pùjk
# pùjk pùjk
# ref: pùjczi pred: pùjki
# ref: môlniczi pred: môlniki
# ref: môlnikòm pred: môlnikom
# ref: môlnikù pred: môlniku
# ref: môlnikama pred: môlnikami
# ref: môlnikù pred: môlniku
# ref: môlnikòwi pred: môlnikowi
# môlnika môlnika
# môlnikach môlnikach
# môlników môlników
# ref: môlnikã pred: môlnikiem
# ref: môlniczi pred: môlniki
# môlnik môlnik
# môlnik môlnik
# ref: môlniczi pred: môlniki
# ref: wòłiwaczë pred: wòłiwôcze
# ref: wòłiwaczom pred: wòłiwôczom
# ref: wòłiwaczu pred: wòłiwôczu
# ref: wòłiwaczama pred: wòłiwoczami
# ref: wòłiwaczu pred: wòłiwoczu
# ref: wòłiwaczowi pred: wòłiwoczowi
# ref: wòłiwacza pred: wòłiwocza
# ref: wòłiwaczach pred: wòłiwoczach
# ref: wòłiwaczów pred: wòłiwoczów
# ref: wòłiwaczã pred: wòłiwoczem
# ref: wòłiwaczë pred: wòłiwôcze
# ref: wòłiwacza pred: wòłiwôcz
# wòłiwôcz wòłiwôcz
# ref: wòłiwaczë pred: wòłiwôcze
# ref: łżëkwiôtë pred: łżëkwiôty
# ref: łżëkwiôtom pred: łżëkwiotom
# ref: łżëkwiôce pred: łżëkwiotowi
# ref: łżëkwiôtama pred: łżëkwiotami
# ref: łżëkwiôce pred: łżëkwiocie
# ref: łżëkwiôtowi pred: łżëkwiotowi
# ref: łżëkwiôta pred: łżëkwiotu
# ref: łżëkwiôtach pred: łżëkwiotach
# łżëkwiôtów łżëkwiôtów
# ref: łżëkwiôtã pred: łżëkwiotem
# ref: łżëkwiôtë pred: łżëkwiôty
# ref: łżëkwiôta pred: łżëkwiôt
# łżëkwiôt łżëkwiôt
# ref: łżëkwiôtë pred: łżëkwiôty
# ref: lëstopadniczi pred: lëstopadniki
# ref: lëstopadnikòm pred: lëstopadnikom
# ref: lëstopadnikù pred: lëstopadniku
# ref: lëstopadnikama pred: lëstopadnikami
# ref: lëstopadnikù pred: lëstopadniku
# ref: lëstopadnikòwi pred: lëstopadnikowi
# lëstopadnika lëstopadnika
# lëstopadnikach lëstopadnikach
# lëstopadników lëstopadników
# ref: lëstopadnikã pred: lëstopadnikiem
# ref: lëstopadniczi pred: lëstopadniki
# lëstopadnika lëstopadnika
# lëstopadnik lëstopadnik
# ref: lëstopadniczi pred: lëstopadniki
# ref: sobòtë pred: sobòty
# ref: sobòtóm pred: sobotom
# ref: sobòto pred: sobòcie
# ref: sobòtama pred: sobotami
# ref: sobòce pred: sobòcie
# sobòce sobòce
# ref: sobòtë pred: sobòty
# sobòtach sobòtach
# ref: sobòtów pred: sobòt
# ref: sobòtã pred: sobòtą
# ref: sobòtë pred: sobòty
# ref: sobòtã pred: sobòtę
# sobòta sobòta
# ref: sobòtë pred: sobòty
# ref: kònie pred: kóń
# ref: kòniom pred: końom
# ref: kòniu pred: kóń
# ref: kòniama pred: kóńmi
# ref: kòniu pred: konie
# ref: kòniowi pred: koniowi
# ref: kònia pred: kóń
# ref: kòniach pred: kóńcach
# ref: kòni pred: kóń
# ref: kòniã pred: kóńm
# ref: kònie pred: konie
# ref: kònia pred: kóń
# kóń kóń
# ref: kònie pred: kóń
# ref: nazéwacze pred: nazéwôcze
# ref: nazéwaczom pred: nazéwôczom
# ref: nazéwaczu pred: nazéwôczu
# ref: nazéwaczama pred: nazéwôczami
# ref: nazéwaczu pred: nazéwôczu
# ref: nazéwaczowi pred: nazéwôczowi
# ref: nazéwacza pred: nazéwôcza
# ref: nazéwaczach pred: nazéwôczach
# ref: nazéwaczów pred: nazéwôczów
# ref: nazéwaczã pred: nazéwôczem
# ref: nazéwacze pred: nazéwôcze
# ref: nazéwacza pred: nazéwôcz
# nazéwôcz nazéwôcz
# ref: nazéwacze pred: nazéwôcze
# ref: piątczi pred: piątki
# ref: piątkóm pred: piątkom
# ref: piątkù pred: piątku
# ref: piątkama pred: piątkami
# ref: piątkù pred: piątcu
# ref: piątkòwi pred: piątkowi
# ref: piątkù pred: piątka
# piątkach piątkach
# piątków piątków
# ref: piątkã pred: piątkiem
# ref: piątczi pred: piątki
# piątk piątk
# piątk piątk
# ref: piątczi pred: piątki
# ref: rënczi pred: rënki
# ref: rënkóm pred: rënkom
# ref: stolem pred: rënku
# ref: rënkama pred: rënkami
# ref: rënkù pred: rënku
# ref: rënkòwi pred: rënkowi
# ref: rënkù pred: rënku
# rënkach rënkach
# rënków rënków
# ref: rënkã pred: rënkiem
# ref: rënczi pred: rënki
# rënk rënk
# rënk rënk
# ref: rënczi pred: rënki
# ref: wtórczi pred: wtórki
# ref: wtórkòm pred: wtórkom
# ref: wtórkù pred: wtórku
# ref: wtórkama pred: wtórkami
# ref: wtórkù pred: wtórcu
# ref: wtórkòwi pred: wtórkowi
# wtórka wtórka
# wtórkach wtórkach
# wtórków wtórków
# ref: wtórkã pred: wtórkiem
# ref: wtórczi pred: wtórki
# wtórk wtórk
# wtórk wtórk
# ref: wtórczi pred: wtórki
# ref: winowacze pred: winowôcze
# ref: winowaczom pred: winowôczom
# ref: winowaczu pred: winowôczu
# ref: winowaczama pred: winowôczami
# ref: winowaczu pred: winowoczu
# ref: winowaczowi pred: winowôczowi
# ref: winowacza pred: winowôcza
# ref: winowaczach pred: winowoczach
# ref: winowaczów pred: winowôczów
# ref: winowaczã pred: winowôczem
# ref: winowacze pred: winowôcze
# ref: winowacza pred: winowôcz
# winowôcz winowôcz
# ref: winowacze pred: winowôcze
# ref: òjcowie pred: òjcy
# ref: òjcóm pred: òjcom
# ref: òjcze pred: òjcu
# ref: òjcama pred: òjcami
# òjcu òjcu
# ref: òjcu pred: òjcowi
# òjca òjca
# òjcach òjcach
# òjców òjców
# ref: òjcã pred: òjcem
# òjcem òjcem
# ref: òjców pred: òjcy
# ref: òjca pred: òjc
# òjc òjc
# ref: òjcowie pred: òjcy
# ref: latawiska pred: latawiski
# ref: latawiskóm pred: latawiskom
# ref: latawiskù pred: latawisko
# ref: latawiskama pred: latawiskami
# ref: latawiskù pred: latawisku
# ref: latawiskù pred: latawiskowi
# latawiska latawiska
# latawiskach latawiskach
# latawisków latawisków
# ref: latawiskã pred: latawiskiem
# ref: latawiska pred: latawiski
# latawiskò latawiskò
# ref: latawiskò pred: latawisko
# ref: latawiska pred: latawiski
# ref: Jastra pred: Jastry
# Jastrach Jastrach
# ref: Jastróm pred: Jastrom
# ref: Jastrów pred: Jastr
# ref: Jastrama pred: Jastry
# ref: Jastra pred: Jastry
# ref: Jastra pred: Jastry
# czerwińce czerwińce
# czerwińcom czerwińcom
# czerwińcu czerwińcu
# ref: czerwińcama pred: czerwińcami
# czerwińcu czerwińcu
# czerwińcowi czerwińcowi
# czerwińca czerwińca
# czerwińcach czerwińcach
# czerwińców czerwińców
# ref: czerwińcã pred: czerwińcem
# czerwińce czerwińce
# ref: czerwińca pred: czerwińc
# czerwińc czerwińc
# ref: czerwińc pred: czerwińce
# ref: rujanë pred: rujany
# rujanom rujanom
# rujanie rujanie
# ref: rujanama pred: rujanami
# rujanie rujanie
# rujanowi rujanowi
# ref: rujana pred: rujanu
# rujanach rujanach
# rujanów rujanów
# ref: rujanã pred: rujanem
# ref: rujanë pred: rujany
# ref: rujana pred: rujan
# rujan rujan
# ref: rujanë pred: rujany
# ref: dôwacze pred: dôwôcze
# ref: dôwaczom pred: dôwôczom
# ref: dôwaczu pred: dôwôczu
# ref: dôwaczama pred: dôwôczami
# ref: dôwaczu pred: dôwôczu
# ref: dôwaczowi pred: dôwôczowi
# dôwôcza dôwôcza
# ref: dôwaczach pred: dôwôczach
# ref: dôwaczów pred: dôwôczów
# ref: dôwaczã pred: dôwôczem
# ref: dôwacze pred: dôwôcze
# ref: dôwacza pred: dôwôcz
# dôwôcz dôwôcz
# ref: dôwacze pred: dôwôcze
# ref: serca pred: serce
# ref: sercóm pred: sercom
# ref: serce pred: sercu
# ref: sercama pred: sercami
# sercu sercu
# ref: serce pred: sercu
# ref: sercu pred: sercowi
# serca serca
# sercach sercach
# serców serców
# ref: serc pred: serców
# ref: sercã pred: sercem
# sercem sercem
# serca serca
# serce serce
# serce serce
# serca serca
# ref: lëpince pred: lëpincy
# lëpincom lëpincom
# lëpincu lëpincu
# ref: lëpincama pred: lëpincami
# lëpincu lëpincu
# lëpincowi lëpincowi
# lëpinca lëpinca
# lëpincach lëpincach
# lëpinców lëpinców
# ref: lëpincã pred: lëpincem
# ref: lëpince pred: lëpincy
# lëpinc lëpinc
# lëpinc lëpinc
# ref: lëpince pred: lëpincy
# ref: séwniczi pred: séwniki
# ref: séwnikòm pred: séwnikom
# ref: séwnikù pred: séwniku
# ref: séwnikama pred: séwnikami
# ref: séwnikù pred: séwniku
# ref: séwnikòwi pred: séwnikowi
# séwnika séwnika
# séwnikach séwnikach
# séwników séwników
# ref: séwnikã pred: séwnikiem
# ref: séwniczi pred: séwniki
# ref: séwnika pred: séwnik
# séwnik séwnik
# ref: séwniczi pred: séwniki
# ref: zélniczi pred: zélniki
# ref: zélnikòm pred: zélnikom
# ref: zélnikù pred: zélniku
# ref: zélnikama pred: zélnikami
# ref: zélnikù pred: zélniku
# ref: zélnikòwi pred: zélnikowi
# zélnika zélnika
# zélnikach zélnikach
# zélników zélników
# ref: zélnikã pred: zélnikiem
# ref: zélniczi pred: zélniki
# ref: zélnika pred: zélnik
# zélnik zélnik
# ref: zélniczi pred: zélniki
# ref: stëczniczi pred: stëczniki
# ref: stëcznikòm pred: stëcznikom
# ref: stëcznikù pred: stëczniku
# ref: stëcznikama pred: stëcznikami
# ref: stëcznikù pred: stëczniku
# ref: stëcznikòwi pred: stëcznikowi
# stëcznika stëcznika
# stëcznikach stëcznikach
# stëczników stëczników
# ref: stëcznikã pred: stëcznikiem
# ref: stëczniczi pred: stëczniki
# ref: stëcznika pred: stëcznik
# stëcznik stëcznik
# ref: stëczniczi pred: stëczniki
# ref: strzodë pred: strzody
# ref: strzodóm pred: strzodom
# ref: strzodo pred: strzodzie
# ref: strzodama pred: strzodami
# ref: strzodze pred: strzodzie
# ref: strzodze pred: strzodzie
# ref: strzodë pred: strzody
# strzodach strzodach
# ref: strzodów pred: strzod
# ref: strzodã pred: strzodą
# ref: strzodë pred: strzody
# ref: strzodã pred: strzodę
# strzoda strzoda
# ref: strzodë pred: strzody
# ref: maje pred: môje
# ref: majom pred: mojom
# ref: maju pred: môju
# ref: majima pred: môjami
# ref: maju pred: moju
# ref: majowi pred: mojowi
# ref: maja pred: môja
# ref: majach pred: mojach
# ref: majów pred: môjów
# ref: majã pred: môjem
# ref: maje pred: môje
# môj môj
# môj môj
# ref: maje pred: môje
# ref: strumianniczi pred: strumianniki
# ref: strumiannikòm pred: strumiannikom
# ref: strumiannikù pred: strumianniku
# ref: strumiannikama pred: strumiannikami
# ref: strumiannikù pred: strumianniku
# ref: strumiannikòwi pred: strumiannikowi
# strumiannika strumiannika
# strumiannikach strumiannikach
# strumianników strumianników
# ref: strumiannikã pred: strumiannikiem
# ref: strumianniczi pred: strumianniki
# strumiannik strumiannik
# strumiannik strumiannik
# ref: strumianniczi pred: strumianniki
# tidzénie tidzénie
# ref: tidzénióm pred: tidzéniom
# tidzéniu tidzéniu
# ref: tidzénama pred: tidzéniami
# tidzéniu tidzéniu
# tidzéniowi tidzéniowi
# tidzénia tidzénia
# ref: tidzénach pred: tidzéniach
# ref: tidzéniów pred: tidzéń
# ref: tidzénã pred: tidzéniem
# tidzénie tidzénie
# tidzéń tidzéń
# tidzéń tidzéń
# tidzénie tidzénie
# ref: czwôrtczi pred: czwôrtki
# ref: czwôrtkóm pred: czwôrtkom
# ref: czwôrtkù pred: czwôrtku
# ref: czwôrtkama pred: czwôrtkami
# ref: czwôrtkù pred: czwôrtku
# ref: czwôrtkòwi pred: czwôrtkowi
# ref: czwôrtkù pred: czwôrtka
# czwôrtkach czwôrtkach
# czwôrtków czwôrtków
# ref: czwôrtkã pred: czwôrtkiem
# ref: czwôrtczi pred: czwôrtki
# czwôrtk czwôrtk
# czwôrtk czwôrtk
# ref: czwôrtczi pred: czwôrtki
# ref: kòtë pred: kòty
# kòtom kòtom
# ref: kòce pred: kòtowi
# ref: kòtama pred: kòtami
# ref: kòce pred: kòcie
# kòtowi kòtowi
# ref: kòtu pred: kòtowi
# ref: kòta pred: kòtu
# kòtach kòtach
# kòtów kòtów
# ref: kòtã pred: kòtem
# ref: kòtë pred: kòty
# ref: kòta pred: kòt
# kòt kòt
# ref: kòtë pred: kòty
# ref: gromiczniczi pred: gromiczniki
# ref: gromicznikòm pred: gromicznikom
# ref: gromicznikù pred: gromiczniku
# ...
# martwe martwe
# martwe martwe
# martwego martwego
# martwego martwego
# martwemu martwemu
# martwemu martwemu
# martwi martwi
# martwy martwy
# martwy martwy
# martwych martwych
# martwych martwych
# martwym martwym
# martwym martwym
# martwym martwym
# martwym martwym
# martwymi martwymi
# napięciach napięciach
# napięcia napięcia
# napięcia napięcia
# napięcia napięcia
# napięcie napięcie
# napięciu napięciu
# ref: napięć pred: napięci
# dziwce dziwce
# dziwkami dziwkami
# dziwką dziwką
# dziwki dziwki
# dziwki dziwki
# dziwkom dziwkom
# ref: dziwko pred: dziwce
# kompromisem kompromisem
# kompromisie kompromisie
# kompromisie kompromisie
# kompromis kompromis
# kompromisom kompromisom
# kompromisowi kompromisowi
# kompromisów kompromisów
# kompromisu kompromisu
# kompromisy kompromisy
# klanami klanami
# klanem klanem
# klanie klanie
# klan klan
# klanom klanom
# klanowi klanowi
# klany klany
# klany klany
# klany klany
# polanach polanach
# polanami polanami
# polana polana
# polanę polanę
# polanie polanie
# polanie polanie
# polanom polanom
# ref: polano pred: polanie
# polany polany
# polany polany
# niech wyrządzą niech wyrządzą
# ref: niech wyrządzę pred: będziesz wyrządził
# ref: wyrządzeni pred: wyrządzenia
# ref: wyrządzę pred: będziesz wyrządziła
# wyrządziłabym wyrządziłabym
# wyrządziłabyś wyrządziłabyś
# wyrządziłaś wyrządziłaś
# wyrządziła wyrządziła
# wyrządziłbym wyrządziłbym
# wyrządziłbyś wyrządziłbyś
# wyrządziłby wyrządziłby
# wyrządziłeś wyrządziłeś
# wyrządzilibyście wyrządzilibyście
# wyrządzilibyśmy wyrządzilibyśmy
# wyrządziliby wyrządziliby
# wyrządziliście wyrządziliście
# wyrządziliśmy wyrządziliśmy
# wyrządziłoby wyrządziłoby
# wyrządził wyrządził
# wyrządziłybyśmy wyrządziłybyśmy
# wyrządziłyście wyrządziłyście
# wyrządziłyśmy wyrządziłyśmy
# wyrządziły wyrządziły
# ref: wyrządzimy pred: będziemy wyrządziły
# wyrządzona wyrządzona
# wyrządzone wyrządzone
# ref: wyrządzono pred: wyrządzone
# ref: wyrządź pred: będziesz wyrządził
# niższą niższą
# niższa niższa
# niższe niższe
# niższe niższe
# niższego niższego
# niższego niższego
# niższej niższej
# niższemu niższemu
# niższych niższych
# niższym niższym
# niższym niższym
# niższym niższym
# niższym niższym
# nastolatkach nastolatkach
# nastolatkami nastolatkami
# nastolatka nastolatka
# nastolatki nastolatki
# nastolatki nastolatki
# ref: nastolatków pred: nastolatki
# nastolatku nastolatku
# zbiegach zbiegach
# ref: zbiega pred: zbieg
# zbieg zbieg
# zbiegom zbiegom
# ref: zbiegowie pred: zbiegi
# ref: zbiegów pred: zbiegi
# zbiegu zbiegu
# ref: szkutnicy pred: szkutniki
# szkutnikach szkutnikach
# szkutnikami szkutnikami
# szkutnika szkutnika
# szkutnikom szkutnikom
# szkutników szkutników
# szkutniku szkutniku
# samotniejsi samotniejsi
# samotniejszą samotniejszą
# samotniejszą samotniejszą
# samotniejsza samotniejsza
# samotniejsze samotniejsze
# samotniejsze samotniejsze
# samotniejsze samotniejsze
# samotniejszego samotniejszego
# samotniejszego samotniejszego
# samotniejszej samotniejszej
# samotniejszej samotniejszej
# samotniejszemu samotniejszemu
# samotniejszy samotniejszy
# samotniejszy samotniejszy
# samotniejszych samotniejszych
# samotniejszych samotniejszych
# samotniejszym samotniejszym
# samotniejszym samotniejszym
# samotniejszymi samotniejszymi
# mitozach mitozach
# mitoza mitoza
# mitozę mitozę
# mitozie mitozie
# mitozom mitozom
# mitozy mitozy
# asemblerach asemblerach
# asemblerami asemblerami
# ref: asemblera pred: asembleru
# asemblerowi asemblerowi
# asemblerów asemblerów
# asemblery asemblery
# asemblery asemblery
# asemblerze asemblerze
# asemblerze asemblerze
# automacie automacie
# automatami automatami
# automat automat
# ref: automatowi pred: automacie
# automaty automaty
# automaty automaty
# kasztanach kasztanach
# kasztanami kasztanami
# kasztan kasztan
# kasztan kasztan
# kasztany kasztany
# kasztany kasztany
# ref: śródmózgowiach pred: śródmózgowcach
# ref: śródmózgowiami pred: śródmózgowcami
# śródmózgowia śródmózgowia
# śródmózgowie śródmózgowie
# śródmózgowie śródmózgowie
# ref: śródmózgowi pred: śródmózgowców
# ref: śródmózgowiu pred: śródmózgowcowi
# ref: śródmózgowiu pred: śródmózgowcu
# ref: lisiąt pred: lisień
# ref: lisięciem pred: lisięm
# ref: lisięciu pred: lisię
# ref: lisięciu pred: lisię
# lisię lisię
# lisię lisię
# ref: lisiętach pred: lisięch
# ref: lisiętami pred: lisięmi
# ref: lisięta pred: lisię
# ref: lisięta pred: lisięcie
# ref: lisiętom pred: lisięm
# ref: graniach pred: granach
# ref: granią pred: graną
# granie granie
# granie granie
# ref: grani pred: grania
# grań grań
# basach basach
# basie basie
# basie basie
# bas bas
# bas bas
# basy basy
# woskowiną woskowiną
# woskowina woskowina
# ref: woskowino pred: woskowinie
# ref: zadadzą pred: będziesz zadał
# sinologia sinologia
# sinologię sinologię
# ref: sinologii pred: sinologiowi
# sinologii sinologii
# sinologii sinologii
# sinologio sinologio
# kurami kurami
# kur kur
# kurom kurom
# kurowi kurowi
# kurów kurów
# kurze kurze
# kurze kurze
# przysięgach przysięgach
# przysięgami przysięgami
# przysięga przysięga
# przysięgi przysięgi
# przysięgom przysięgom
# przysięgo przysięgo
# nonanem nonanem
# nonanie nonanie
# nonan nonan
# nonan nonan
# nonanów nonanów
# nonany nonany
# elektrowniami elektrowniami
# elektrownie elektrownie
# elektrownie elektrownie
# elektrownie elektrownie
# ref: elektrowni pred: elektrownii
# elektrowni elektrowni
# elektrowniom elektrowniom
# fotografach fotografach
# fotografami fotografami
# fotografem fotografem
# fotografie fotografie
# fotograf fotograf
# ref: fotografów pred: fotografy
# ref: będą machały pred: będziesz machał
# ref: będę machała pred: będzie machała
# ref: będę machał pred: będzie machał
# będziecie machali będziecie machali
# będzie machała będzie machała
# będzie machało będzie machało
# będzie machał będzie machał
# będziemy machali będziemy machali
# będziemy machały będziemy machały
# ref: będziesz machała pred: będzie machała
# ref: będziesz machał pred: będzie machał
# ref: machający pred: machaliście
# ref: machający pred: machane
# machajcie machajcie
# machajmy machajmy
# machałaby machałaby
# machałam machałam
# machałaś machałaś
# machała machała
# machałbym machałbym
# machałby machałby
# machałem machałem
# machalibyście machalibyście
# machalibyśmy machalibyśmy
# machaliśmy machaliśmy
# machałoby machałoby
# machałybyśmy machałybyśmy
# ref: machałyby pred: machaliby
# machałyście machałyście
# machałyśmy machałyśmy
# ref: machały pred: machali
# ref: macham pred: machałem
# machane machane
# machanie machanie
# ref: machani pred: machaliście
# machano machano
# ref: machasz pred: macha
# niech macha niech macha
# jonosferach jonosferach
# jonosfera jonosfera
# jonosferom jonosferom
# jonosfery jonosfery
# jonosfery jonosfery
# jonosfery jonosfery
# jonosferze jonosferze
# lodach lodach
# ref: lodem pred: lódem
# lód lód
# lodom lodom
# lodowi lodowi
# ref: lodów pred: lódów
# lodzie lodzie
# ref: będą siąknąły pred: będzie siąknęło
# ref: będą siąknęli pred: będziecie siąknęli
# będziemy siąknęli będziemy siąknęli
# ref: będzie siąknąła pred: będzie siąknęła
# ref: będzie siąknąło pred: będzie siąknęło
# ref: będzie siąknął pred: będzie siąknęł
# ref: będziesz siąknąła pred: będzie siąknęła
# będziesz siąknął będziesz siąknął
# niech siąkną niech siąkną
# ref: niech siąknie pred: niech siąknę
# ref: siąknąca pred: siąknęłabyś
# siąknące siąknące
# siąknące siąknące
# siąknący siąknący
# ref: siąknąłabyś pred: siąknęłabyś
# ref: siąknąłaby pred: siąknęłaby
# ref: siąknąła pred: siąknęła
# ref: siąknąłbyś pred: siąknęłbyś
# ref: siąknąłeś pred: siąknęłeś
# ref: siąknąłybyście pred: siąknęłybyśmy
# ref: siąknąłybyśmy pred: siąknęłybyśmy
# ref: siąknąłyby pred: siąknęłyby
# ref: siąknąłyśmy pred: siąknęłyśmy
# siąkną siąkną
# siąknęlibyście siąknęlibyście
# siąknęlibyśmy siąknęlibyśmy
# ref: siąknęliście pred: siąknąliście
# ref: siąknęliśmy pred: siąknąliśmy
# ref: siąknę pred: siąknęło
# ref: siąkniemy pred: siąknęłyśmy
# ref: siąkniesz pred: siąknęło
# ref: siąknie pred: siąknę
# ref: siąknijcie pred: niech siąkną
# ref: siąknijmy pred: będziemy siąknęły
# ref: siąknij pred: niech siąknę
# najdzikszą najdzikszą
# najdziksza najdziksza
# najdziksze najdziksze
# najdziksze najdziksze
# najdzikszego najdzikszego
# najdzikszej najdzikszej
# najdzikszej najdzikszej
# najdzikszej najdzikszej
# najdzikszemu najdzikszemu
# najdzikszy najdzikszy
# najdzikszy najdzikszy
# najdzikszych najdzikszych
# najdzikszych najdzikszych
# najdzikszym najdzikszym
# peronach peronach
# peronem peronem
# peronie peronie
# peronom peronom
# peronów peronów
# perony perony
# sygnałach sygnałach
# sygnałami sygnałami
# sygnał sygnał
# sygnałom sygnałom
# sygnały sygnały
# sygnały sygnały
# najlżejszą najlżejszą
# najlżejsza najlżejsza
# najlżejsze najlżejsze
# najlżejsze najlżejsze
# najlżejsze najlżejsze
# najlżejszego najlżejszego
# najlżejszego najlżejszego
# najlżejszej najlżejszej
# najlżejszemu najlżejszemu
# najlżejszy najlżejszy
# najlżejszych najlżejszych
# najlżejszych najlżejszych
# najlżejszym najlżejszym
# najlżejszymi najlżejszymi
# wybuchach wybuchach
# wybuchem wybuchem
# wybuch wybuch
# wybuch wybuch
# wybuchowi wybuchowi
# wybuchu wybuchu
# wybuchu wybuchu
# wybuchu wybuchu
# wybuchy wybuchy
# wybuchy wybuchy
# ref: sekście pred: sekstowi
# ref: sekście pred: sekscie
# sekstą sekstą
# seksta seksta
# sekst sekst
# sekstom sekstom
# seksto seksto
# seksty seksty
# seksty seksty
# seksty seksty
# bocianach bocianach
# bocianami bocianami
# ref: bociana pred: bocianu
# bocianem bocianem
# bocianie bocianie
# bocian bocian
# bocianom bocianom
# bocianów bocianów
# bociany bociany
# bociany bociany
# trwania trwania
# trwanie trwanie
# trwanie trwanie
# trwaniu trwaniu
# trwaniu trwaniu
# ref: będę marła pred: będzie mrzała
# ref: będziecie marli pred: będziecie mrzali
# ref: będziecie marły pred: będziecie mrzały
# ref: będzie marła pred: będzie mrzeła
# ref: będzie marło pred: będzie mrzało
# ref: będzie marł pred: będzie mrzeł
# ref: będziemy marli pred: będziemy mrzali
# ref: marcie pred: mrzenie
# ref: marłabyś pred: mrzełabyś
# ref: marłam pred: mrzałam
# ref: marłaś pred: mrzełaś
# ref: marła pred: mrzeła
# ref: marłbyś pred: mrzełbyś
# ref: marłby pred: mrzełby
# ref: marłeś pred: mrzełeś
# ref: marlibyście pred: mrzelibyście
# ref: marlibyśmy pred: mrzelibyśmy
# ref: marł pred: mrzeł
# ref: marłyby pred: mrzeliby
# ref: marłyśmy pred: mrzeliśmy
# ref: marły pred: mrzeli
# ref: mrące pred: mrzące
# ref: mrące pred: mrzące
# ref: mrąc pred: mrzenie
# ref: mrący pred: mrzący
# ref: mrący pred: mrzenie
# ref: mrzecie pred: mrzące
# ref: mrzeć pred: mrzące
# ref: mrzemy pred: mrzałyśmy
# mrze mrze
# ref: mrzyjcie pred: mrzący
# ref: mrzyj pred: będziesz mrzał
# ref: niech mrą pred: niech mrzą
# niech mrze niech mrze
# oczopląsach oczopląsach
# oczopląs oczopląs
# oczopląsowi oczopląsowi
# oczopląsy oczopląsy
# przewodniczącego przewodniczącego
# ref: przewodniczących pred: przewodniczące
# przewodniczących przewodniczących
# przewodniczącym przewodniczącym
# przewodniczący przewodniczący
# ref: przewodniczący pred: przewodniczące
# mięczakach mięczakach
# mięczakami mięczakami
# ref: mięczaka pred: mięczak
# mięczaka mięczaka
# mięczakiem mięczakiem
# mięczaki mięczaki
# mięczaki mięczaki
# mięczaki mięczaki
# mięczak mięczak
# mięczakowi mięczakowi
# mięczaków mięczaków
# nieodpowiedzialna nieodpowiedzialna
# nieodpowiedzialne nieodpowiedzialne
# nieodpowiedzialne nieodpowiedzialne
# nieodpowiedzialne nieodpowiedzialne
# nieodpowiedzialne nieodpowiedzialne
# nieodpowiedzialnego nieodpowiedzialnego
# nieodpowiedzialnego nieodpowiedzialnego
# nieodpowiedzialnego nieodpowiedzialnego
# nieodpowiedzialnemu nieodpowiedzialnemu
# nieodpowiedzialnemu nieodpowiedzialnemu
# nieodpowiedzialni nieodpowiedzialni
# nieodpowiedzialny nieodpowiedzialny
# nieodpowiedzialnych nieodpowiedzialnych
# nieodpowiedzialnym nieodpowiedzialnym
# nieodpowiedzialnym nieodpowiedzialnym
# nieodpowiedzialnymi nieodpowiedzialnymi
# szalu szalu
# cyrkami cyrkami
# cyrkiem cyrkiem
# cyrki cyrki
# cyrk cyrk
# cyrk cyrk
# cyrków cyrków
# cyrku cyrku
# ref: cyrku pred: cyrka
# cyrku cyrku
# najjaśniejsi najjaśniejsi
# najjaśniejszą najjaśniejszą
# najjaśniejsza najjaśniejsza
# najjaśniejsze najjaśniejsze
# najjaśniejsze najjaśniejsze
# najjaśniejszego najjaśniejszego
# najjaśniejszej najjaśniejszej
# najjaśniejszej najjaśniejszej
# najjaśniejszych najjaśniejszych
# najjaśniejszych najjaśniejszych
# najjaśniejszych najjaśniejszych
# najjaśniejszym najjaśniejszym
# najjaśniejszym najjaśniejszym
# żenecie żenecie
# żenetami żenetami
# żenetą żenetą
# żeneta żeneta
# żenetę żenetę
# żenet żenet
# żenetom żenetom
# żenety żenety
# żenety żenety
# żenety żenety
# waściach waściach
# waściami waściami
# waści waści
# waści waści
# waści waści
# waści waści
# ref: waści pred: waście
# waść waść
# ref: otwarci pred: otwarty
# otwartą otwartą
# otwarta otwarta
# otwarte otwarte
# otwarte otwarte
# otwartego otwartego
# otwartej otwartej
# otwartej otwartej
# otwartej otwartej
# otwartemu otwartemu
# otwartemu otwartemu
# otwarty otwarty
# otwarty otwarty
# otwartych otwartych
# otwartym otwartym
# otwartym otwartym
# otwartymi otwartymi
# ref: dłużnicy pred: dłużniki
# ref: dłużnicy pred: dłużniki
# dłużnikami dłużnikami
# dłużnika dłużnika
# dłużnik dłużnik
# dłużnikowi dłużnikowi
# ref: manicure'ami pred: manicurami
# ref: manicure'em pred: manicurem
# ref: manicure pred: manicurę
# ref: manicure'om pred: manicurom
# ref: manicure'y pred: manicura
# ref: manicure'y pred: manicura
# ref: manicure'y pred: manicura
# manicurze manicurze
# sefardyjscy sefardyjscy
# sefardyjski sefardyjski
# sefardyjskich sefardyjskich
# sefardyjskie sefardyjskie
# sefardyjskiego sefardyjskiego
# sefardyjskiego sefardyjskiego
# sefardyjskiej sefardyjskiej
# sefardyjskiej sefardyjskiej
# sefardyjskiemu sefardyjskiemu
# sefardyjskim sefardyjskim
# sefardyjskim sefardyjskim
# sefardyjskim sefardyjskim
# sefardyjskimi sefardyjskimi
# szynce szynce
# szynce szynce
# szynek szynek
# szynkami szynkami
# szynkę szynkę
# szynki szynki
# szynkom szynkom
# ref: szynko pred: szynce
# częstokołach częstokołach
# częstokołami częstokołami
# ref: częstokole pred: częstokolu
# ref: częstokół pred: częstokoł
# tulem tulem
# tul tul
# tulowi tulowi
# tulu tulu
# tulu tulu
# ścianami ścianami
# ściana ściana
# ścianę ścianę
# ścianom ścianom
# ref: ściano pred: ścianie
# ściany ściany
# ściany ściany
# ref: baracheł pred: barachłów
# barachłach barachłach
# barachła barachła
# barachła barachła
# barachła barachła
# barachło barachło
# barachło barachło
# ref: barachłu pred: barachłowi
# czczą czczą
# czcza czcza
# czcze czcze
# czcze czcze
# czcze czcze
# czczego czczego
# czczej czczej
# czczej czczej
# czczy czczy
# czczych czczych
# czczym czczym
# czczym czczym
# czczymi czczymi
# ref: Indianach pred: Indianinach
# ref: Indianie pred: Indianiny
# Indianinie Indianinie
# Indianinie Indianinie
# Indianin Indianin
# Indianinowi Indianinowi
# ref: Indian pred: Indianiny
# hodowlach hodowlach
# hodowlą hodowlą
# hodowla hodowla
# hodowle hodowle
# hodowli hodowli
# hodowli hodowli
# hodowli hodowli
# hodowlom hodowlom
# pacie pacie
# ref: pacie pred: patowi
# patami patami
# ref: pata pred: pat
# pat pat
# patowi patowi
# patów patów
# paty paty
# ilustracjach ilustracjach
# ilustracje ilustracje
# ilustracje ilustracje
# ilustracji ilustracji
# ilustracjom ilustracjom
# ref: ilustracjo pred: ilustracji
# rachunek rachunek
# rachunek rachunek
# rachunkach rachunkach
# rachunkiem rachunkiem
# rachunki rachunki
# rachunkowi rachunkowi
# ref: rachunków pred: rachunek
# rachunku rachunku
# rachunku rachunku
# zimową zimową
# zimową zimową
# zimowa zimowa
# zimowe zimowe
# zimowe zimowe
# zimowego zimowego
# zimowego zimowego
# zimowego zimowego
# zimowej zimowej
# zimowemu zimowemu
# zimowy zimowy
# zimowy zimowy
# zimowych zimowych
# zimowych zimowych
# zimowym zimowym
# zimowym zimowym
# zimowym zimowym
# rutenem rutenem
# ruten ruten
# chrabąszczach chrabąszczach
# chrabąszczami chrabąszczami
# ref: chrabąszcza pred: chrabąszcz
# chrabąszczem chrabąszczem
# chrabąszcze chrabąszcze
# chrabąszcze chrabąszcze
# chrabąszczom chrabąszczom
# chrabąszczowi chrabąszczowi
# chrabąszczy chrabąszczy
# miarami miarami
# miarę miarę
# miar miar
# miarom miarom
# ref: miaro pred: miarze
# miary miary
# miary miary
# ref: mierze pred: miarze
# dzieżach dzieżach
# dzieżami dzieżami
# dzieżą dzieżą
# dzieże dzieże
# dzieże dzieże
# dzieżom dzieżom
# dzieżo dzieżo
# ref: dzieży pred: dzieżie
# dzieży dzieży
# małpeczce małpeczce
# małpeczkach małpeczkach
# małpeczkami małpeczkami
# małpeczki małpeczki
# małpeczkom małpeczkom
# ref: małpeczko pred: małpeczce
# koronach koronach
# koroną koroną
# korona korona
# koronę koronę
# koronie koronie
# koronom koronom
# ref: korono pred: koronie
# korony korony
# korony korony
# korony korony
# lipca lipca
# lipce lipce
# lipce lipce
# lipce lipce
# lipcom lipcom
# lipców lipców
# ref: lipiec pred: lipca
# ref: lipiec pred: lipc
# zupami zupami
# zupą zupą
# zupa zupa
# zupie zupie
# zup zup
# ref: zupo pred: zupie
# zupy zupy
# zupy zupy
# miocie miocie
# miotach miotach
# miotami miotami
# miot miot
# miotom miotom
# ref: miotowi pred: miocowi
# miotu miotu
# mioty mioty
# mioty mioty
# mioty mioty
# 0.797

# %% [markdown]
# # Mean Mask Length

# %%
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Seq2SeqTrainer, Seq2SeqTrainingArguments
from datasets import load_dataset
import random
import numpy
# get tokenizer and sentinal tokens for masking
tokenizer = AutoTokenizer.from_pretrained("google/byt5-small")

# Load pre-trained model
model = AutoModelForSeq2SeqLM.from_pretrained("google/byt5-small")
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, return_tensors="pt")
random.seed(10)

def preprocess_function(examples): # receives unmasked sentence as input
    inputs = examples
    inputs = inputs.strip()
    model_inputs = tokenizer(inputs)
    input_ids = model_inputs.input_ids
    attention_mask = model_inputs.attention_mask
    # print(input_ids, attention_mask, len(input_ids),len(attention_mask))
    # mask 15% of the bytes randomly in the tokenized sentence leaving out bordering bytes.
    len_sentence = len(input_ids)
    length = round(len(input_ids) * 0.25) # mask 15% of character (T5 and mT5 do that for tokens)
    return length



from array import array
# load dataset
lang = "csb-pol-sent"
train_path = f"/dss/dsshome1/03/ge87wod2/morphological-inflection/preprocessing/preprocessing_to_json_or_tsv/data/{lang}_trn.tsv"
eval_path = f"/dss/dsshome1/03/ge87wod2/morphological-inflection/preprocessing/preprocessing_to_json_or_tsv/data/{lang}_dev.tsv"
dataset = load_dataset("csv", delimiter="\t",column_names=["input"],data_files={"train": train_path,"validation": eval_path},quoting=3) # disable quote parsing
print(dataset["train"][1])
mean_train = sum(list(map(preprocess_function, dataset["train"]["input"]))) / 9000
mean_dev = sum( list( map(preprocess_function, dataset["validation"]["input"]) ) ) / 1000

print("mean" ,mean_train,mean_dev)
