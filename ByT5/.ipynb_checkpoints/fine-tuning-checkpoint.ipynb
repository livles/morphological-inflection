# %% [markdown]
# # Setup

# %%
# !pip install transformers torch datasets pip accelerate
# !pip install transformers --upgrade
# !pip install ipywidgets
# !pip install python-dotenv pickleshare
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.57.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.9.0)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (4.3.0)
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (24.2)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (1.11.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2025.10.23)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.10/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.10/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.10/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.10/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.10/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.10/dist-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.10/dist-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.10/dist-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.10/dist-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.10/dist-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.10/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.10/dist-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.10/dist-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.10/dist-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.10/dist-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.10/dist-packages (from torch) (3.5.0)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.27.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (3.10.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1.0.0->datasets) (4.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1.0.0->datasets) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1.0.0->datasets) (1.0.5)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<1.0.0->datasets) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (4.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1.0.0->datasets) (1.2.2)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.57.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2025.10.23)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.12.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.7.4)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (8.1.7)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (8.26.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (1.2.2)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (4.12.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (4.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (1.2.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (0.7.5)

# %% [markdown]
# # Training small pre-trained ByT5 model using dataset

# %%
# from dotenv import load_dotenv
# import os

# load_dotenv()

# HF_TOKEN = os.getenv("HF_TOKEN")

# # print("HF_TOKEN: ", HF_TOKEN)

# # source: https://huggingface.co/docs/transformers/v4.28.1/tasks/summarization
# from huggingface_hub import login

# login(HF_TOKEN)
LANGS = ["grc","dan","fra","sme","deu","nav","jap","klr","eng","mul","deu_eng"]
LANGS = LANGS[-2:]
LANGS = ["mul_2","amh","pol","ote"]
LANGS = ["mul_2","amh","pol","ote"]
LANGS = ["mul-language-code","mul-language-word"]
LANGS = ["mul-language-code"]
LANGS = ["5lang-sample"]


PATH_JSON_DATA = "../preprocessing/preprocessing_to_json/data/"

for lang in LANGS:
    from datasets import load_dataset
    # dataset= dataset.train_test_split(test_size=0.2) #train_size=10000,
    dataset = load_dataset("json", data_files={"train": PATH_JSON_DATA + lang + "_trn.json", "validation": PATH_JSON_DATA + lang + "_dev.json"})

    print(dataset["train"][0])

    from transformers import AutoTokenizer

    checkpoint = "google/byt5-small"
    tokenizer = AutoTokenizer.from_pretrained(checkpoint)
    # -

    import torch

    from transformers import (
        AutoTokenizer,
        TrainingArguments,
        Trainer,
        AutoModelForSeq2SeqLM,
        Seq2SeqTrainingArguments,
        Seq2SeqTrainer
    )
    from datasets import load_dataset

    def preprocess_function(examples):
        # inputs = [prefix + doc for doc in examples["text"]]
        inputs = examples["input"]
        model_inputs = tokenizer(inputs)

        labels = tokenizer(text_target=examples["target"]) # same length irrelevant here, so no truncation or padding

        model_inputs["labels"] = labels["input_ids"]
        return model_inputs


    tokenized_dataset = dataset.map(preprocess_function, batched=True)
    print(tokenized_dataset)
    sample = tokenized_dataset["train"][0]
    print(sample["labels"])

    from transformers import DataCollatorForSeq2Seq

    data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=checkpoint)

    # import evaluate

    # rouge = evaluate.load("rouge")

    # import numpy as np


    # def compute_metrics(eval_pred):
    #     predictions, labels = eval_pred
    #     decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    #     labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    #     decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    #     result = rouge.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)

    #     prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions]
    #     result["gen_len"] = np.mean(prediction_lens)

    #     return {k: round(v, 4) for k, v in result.items()}

    # import numpy as np
    # import evaluate

    # metric = evaluate.load("accuracy")

    # def compute_metrics(eval_pred):
    #     predictions, labels = eval_pred # TODO: labels vs title?

    #     decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)

    #     labels = np.where(labels != -100, labels, tokenizer.pad_token_id) # TODO: correct?

    #     decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    #     return metric.compute(predictions=predictions, references=labels)

    from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer

    model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    training_args = Seq2SeqTrainingArguments(
        output_dir="byt5_small/"+lang,
        eval_strategy="epoch",
        learning_rate=5e-5,
        per_device_train_batch_size=16,
        per_device_eval_batch_size=16,
        weight_decay=0.01,
        save_total_limit=3,
        num_train_epochs=4,
        predict_with_generate=True,
        # save_strategy="epoch",
        fp16=False,# did not work with True #change to bf16=True for XPU 
        #bf16 = True, # performance was best without setting fp16 or bf16 to true
        push_to_hub=True,
        warmup_steps = 500,
        # load_best_model_at_end=True, # otherwise not model with minimum loss during training, like https://huggingface.co/docs/transformers/tasks/sequence_classification
    )

    trainer = Seq2SeqTrainer(
        model=model,
        args=training_args,
        train_dataset=tokenized_dataset["train"],
        eval_dataset=tokenized_dataset["validation"],
        tokenizer=tokenizer,
        data_collator=data_collator,
        # compute_metrics=compute_metrics,
    )

    trainer.train()
    trainer.push_to_hub()
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# {'input': 'Navajo: Inflect náʼáłkad | V;IND;PFV;NOM(1,GRPL)', 'target': 'ńdaʼiilkad'}
# 2025-11-01 16:16:20.882874: I tensorflow/core/platform/cpu_feature_guard.cc:211] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Map:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['input', 'target', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 10000
#     })
#     validation: Dataset({
#         features: ['input', 'target', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 1000
#     })
# })
# [200, 135, 103, 100, 205, 191, 108, 108, 111, 110, 100, 103, 1]
# /tmp/ipykernel_301522/2453831306.py:129: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(
#     <div>
#
#       <progress value='2500' max='2500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2500/2500 12:57, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.696000</td>
#       <td>0.715448</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.788000</td>
#       <td>0.518034</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.591400</td>
#       <td>0.467004</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.488600</td>
#       <td>0.454720</td>
#     </tr>
#   </tbody>
# </table><p>
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B

# %% [markdown]
# # Testing models

# %%
# SETTINGS = ["grc","dan","fra","sme","deu","nav","jap","klr","eng","mul","deu_eng"] + ["mul_2","ote","pol","amh"] + ["mul-language-code","mul-language-word"]
SETTINGS = ["mul"]
SETTINGS = ["5lang-sample"]
TEST_LANGS_OLD = ["grc","dan","fra","sme","deu","nav","jap","klr","eng"] 
TEST_LANGS = ["grc","dan","fra","sme","deu","nav","jap","klr","eng"] + ["ote","pol","amh","csb"]
lang5_LANGS = ["deu","nav","klr","amh","grc"]
lang_code = ""
for lang_setting in SETTINGS:
    if lang_setting == "mul": LANG_CODES = ["-language-word","-language-code",""] # test with no language code/word too
    else: LANG_CODES = [""]
    for lang_code in LANG_CODES:
        if lang_setting in ( "deu_eng", "mul") and lang_code == "": test_langs = TEST_LANGS_OLD
        elif lang_setting in ["mul_2","mul"]: test_langs = TEST_LANGS # test multilingual model on all languages it was trained on + Kashubian
        elif lang_setting == "5lang-sample": test_langs = lang5_LANGS
        elif lang_setting == "pol": test_langs = ["pol","csb"] # test Polish model on Kashubian also
        else: test_langs = [lang_setting]
        for test_lang in test_langs:
            import torch
            from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
            PRETRAINED_MODEL = "google/byt5-small"
            #FINETUNED_MODEL ="livles/"+lang_setting + lang_code
            FINETUNED_MODEL ="./byt5_small/"+lang_setting + lang_code
            MODEL = FINETUNED_MODEL
            print(MODEL)
            tokenizer = AutoTokenizer.from_pretrained(
                FINETUNED_MODEL,
            )
            model = AutoModelForSeq2SeqLM.from_pretrained(
                FINETUNED_MODEL,
            dtype=torch.float16,
            device_map="auto"
            )

            from datasets import load_dataset
            OUT_DIR = "output_byt5_small/" + lang_setting + lang_code+ "/" 
            PATH_TO_JSON_TEST_FILE = "../preprocessing/preprocessing_to_json/data/" + test_lang + lang_code+ "_test.json"
            PATH_TO_ORIG_TEST_FILE = "../2023InflectionST/part1/data/" + test_lang + ".tst"
            with open (OUT_DIR + test_lang + lang_code + "_byt5-small.out","w") as out_file, open (PATH_TO_ORIG_TEST_FILE, "r") as test_file:
                COUNTER = 0
                dataset = load_dataset("json",data_files={"test":PATH_TO_JSON_TEST_FILE})
                covered_test_lines = dataset["test"]["input"]
                LEN = len(covered_test_lines)


                # preds = map (generate,covered_test_lines)
                for line in covered_test_lines:
                    input_ids = tokenizer(line, return_tensors="pt").to(model.device)
                    output = model.generate(
                        **input_ids,
                        max_new_tokens=50,
                        num_beams=4,
                        #early_stopping=True
                    )
                    output_string = (tokenizer.decode(output[0], skip_special_tokens=True))
                    lemma, features, ref = test_file.readline().strip().split("\t")

                    # evaluate
                    if (ref == output_string):
                        COUNTER += 1
                        print(ref,output_string)
                    else:
                        print("ref:",ref,"pred:",output_string)
                    
                    # write
                    out_file.write(lemma + "\t" +features+ "\t" + output_string + "\n")
                    out_file.flush()

                accuracy = COUNTER / LEN
                out_file.write("accuracy:"+ str(accuracy))
                print(accuracy)
# Out:
# ./byt5_small/5lang-sample
# ref: Aikido pred: Aikidookido
# ref: Aikido pred: Aikidookido
# ref: Aikidos pred: Aikidookido
# ref: Aikido pred: Aikidookido
# Anreisen Anreisen
# Anreise Anreise
# Anreisen Anreisen
# Anreise Anreise
# Anreisen Anreisen
# ref: Anreise pred: Anreisest
# Anreisen Anreisen
# Anreise Anreise
# ref: Arsenikesser pred: Arsenikessern
# Arsenikesser Arsenikesser
# Arsenikessern Arsenikessern
# Arsenikesser Arsenikesser
# ref: Arsenikesser pred: Arsenikessern
# ref: Arsenikessers pred: Arsenikesser
# ref: Arsenikesser pred: Arsenikessern
# Arsenikesser Arsenikesser
# Auslassungszeichen Auslassungszeichen
# Auslassungszeichen Auslassungszeichen
# Auslassungszeichen Auslassungszeichen
# Auslassungszeichen Auslassungszeichen
# Auslassungszeichen Auslassungszeichen
# ref: Auslassungszeichens pred: Auslassungszeichen
# Auslassungszeichen Auslassungszeichen
# Auslassungszeichen Auslassungszeichen
# Bergenten Bergenten
# Bergente Bergente
# Bergenten Bergenten
# Bergente Bergente
# Bergenten Bergenten
# Bergente Bergente
# Bergenten Bergenten
# Bergente Bergente
# ref: Berylliumsalze pred: Berylliumsalzen
# Berylliumsalz Berylliumsalz
# Berylliumsalzen Berylliumsalzen
# Berylliumsalz Berylliumsalz
# ref: Berylliumsalze pred: Berylliumsalzen
# ref: Berylliumsalzes pred: Berylliumsalz
# ref: Berylliumsalze pred: Berylliumsalzen
# Berylliumsalz Berylliumsalz
# Bettlaken Bettlaken
# Bettlaken Bettlaken
# Bettlaken Bettlaken
# Bettlaken Bettlaken
# ref: Bettlaken pred: Bettlaken usingen
# ref: Bettlakens pred: Bettlaken
# Bettlaken Bettlaken
# Bettlaken Bettlaken
# ref: Bilder pred: Bild usingen
# ref: Bild pred: Bild using
# ref: Bildern pred: Bild usingen
# ref: Bild pred: Bild using
# ref: Bilder pred: Bild usingen
# ref: Bildes pred: Bild using
# ref: Bilder pred: Bildern
# ref: Bild pred: Bild using
# ref: Brettspiele pred: Brettspielen
# Brettspiel Brettspiel
# Brettspielen Brettspielen
# Brettspiel Brettspiel
# ref: Brettspiele pred: Brettspielen
# ref: Brettspieles pred: Brettspiel
# ref: Brettspiele pred: Brettspielen
# Brettspiel Brettspiel
# Bridge Bridge
# ref: Bridge pred: Bridges
# ref: Bridge pred: Bridges
# Bridge Bridge
# Denken Denken
# Denken Denken
# ref: Denkens pred: Denken
# Denken Denken
# ref: Elfen pred: Elfe usingen
# ref: Elfen pred: Elfe using
# ref: Elfen pred: Elfen usingen
# ref: Elfen pred: Elfe using
# ref: Elfen pred: Elfe using
# ref: Elfen pred: Elfe usingen
# ref: Elfe pred: Elfe using
# ref: Ermittler pred: Ermittlern
# Ermittler Ermittler
# Ermittlern Ermittlern
# Ermittler Ermittler
# ref: Ermittler pred: Ermittlern
# ref: Ermittlers pred: Ermittler
# ref: Ermittler pred: Ermittlern
# Ermittler Ermittler
# ref: Fahnenträger pred: Fahnenträgern
# Fahnenträger Fahnenträger
# Fahnenträgern Fahnenträgern
# Fahnenträger Fahnenträger
# ref: Fahnenträger pred: Fahnenträgern
# ref: Fahnenträgers pred: Fahnenträger
# ref: Fahnenträger pred: Fahnenträgern
# Fahnenträger Fahnenträger
# ref: Felsen pred: Felsen usingen
# Felsen Felsen
# ref: Felsen pred: Felsen usingen
# Felsen Felsen
# ref: Felsen pred: Felsen usingen
# ref: Felsens pred: Felsen using
# ref: Felsen pred: Felsen usingen
# Felsen Felsen
# ref: Fichtelite pred: Fichteliten
# Fichtelit Fichtelit
# Fichtelit Fichtelit
# ref: Fichtelite pred: Fichteliten
# ref: Fichtelits pred: Fichtelit
# ref: Fichtelite pred: Fichteliten
# Fichtelit Fichtelit
# ref: Fumarolen pred: Fumarole
# Fumarole Fumarole
# Fumarolen Fumarolen
# Fumarole Fumarole
# Fumarolen Fumarolen
# Fumarole Fumarole
# ref: Fumarolen pred: Fumarole
# Fumarole Fumarole
# ref: Gesässe pred: Gesässen
# Gesäss Gesäss
# Gesässen Gesässen
# Gesäss Gesäss
# ref: Gesässe pred: Gesässen
# ref: Gesässes pred: Gesäss
# ref: Gesässe pred: Gesässen
# Gesäss Gesäss
# ref: Hits pred: ʔiusing
# ref: Hit pred: using
# ref: Hits pred: ʔiusing
# ref: Hit pred: using
# ref: Hits pred: ʔiusing
# ref: Hits pred: using
# ref: Hits pred: ʔiusing
# ref: Hit pred: using
# ref: Kakerlaken pred: Kakerlakki
# ref: Kakerlaken pred: Kakerlak
# ref: Kakerlaken pred: Kakerlakki
# ref: Kakerlaken pred: Kakerlak
# ref: Kakerlaken pred: Kakerlakki
# ref: Kakerlaken pred: Kakerlak
# ref: Kakerlaken pred: Kakerlakki
# Kakerlak Kakerlak
# Kolumbienrallen Kolumbienrallen
# Kolumbienralle Kolumbienralle
# Kolumbienrallen Kolumbienrallen
# Kolumbienralle Kolumbienralle
# Kolumbienrallen Kolumbienrallen
# Kolumbienralle Kolumbienralle
# Kolumbienrallen Kolumbienrallen
# Kolumbienralle Kolumbienralle
# ref: Lammfellhandschuhe pred: Lammfellhandschuhen
# Lammfellhandschuh Lammfellhandschuh
# Lammfellhandschuhen Lammfellhandschuhen
# Lammfellhandschuh Lammfellhandschuh
# ref: Lammfellhandschuhe pred: Lammfellhandschuhen
# ref: Lammfellhandschuhs pred: Lammfellhandschuh
# ref: Lammfellhandschuhe pred: Lammfellhandschuhen
# Lammfellhandschuh Lammfellhandschuh
# Leichenhallen Leichenhallen
# Leichenhalle Leichenhalle
# Leichenhallen Leichenhallen
# Leichenhalle Leichenhalle
# Leichenhallen Leichenhallen
# Leichenhalle Leichenhalle
# Leichenhallen Leichenhallen
# Leichenhalle Leichenhalle
# ref: Linguistinnen pred: Linguistin
# Linguistin Linguistin
# ref: Linguistinnen pred: Linguistini
# Linguistin Linguistin
# ref: Linguistinnen pred: Linguistini
# Linguistin Linguistin
# ref: Linguistinnen pred: Linguistin
# Linguistin Linguistin
# ref: Lonsdaleite pred: Lonsdaleit
# Lonsdaleit Lonsdaleit
# Lonsdaleiten Lonsdaleiten
# Lonsdaleit Lonsdaleit
# ref: Lonsdaleite pred: Lonsdaleiten
# ref: Lonsdaleite pred: Lonsdaleit
# Lonsdaleit Lonsdaleit
# Maiskolben Maiskolben
# Maiskolben Maiskolben
# Maiskolben Maiskolben
# Maiskolben Maiskolben
# Maiskolben Maiskolben
# ref: Maiskolbens pred: Maiskolben
# Maiskolben Maiskolben
# Maiskolben Maiskolben
# ref: Marokkaner pred: Marokkanern
# Marokkaner Marokkaner
# Marokkanern Marokkanern
# Marokkaner Marokkaner
# ref: Marokkaner pred: Marokkanern
# ref: Marokkaners pred: Marokkaner
# ref: Marokkaner pred: Marokkanern
# Marokkaner Marokkaner
# ref: Milchkühe pred: Milchkuh
# Milchkuh Milchkuh
# ref: Milchkühen pred: Milchkuh
# Milchkuh Milchkuh
# ref: Milchkühe pred: Milchkuh
# Milchkuh Milchkuh
# ref: Milchkühe pred: Milchkuh
# Milchkuh Milchkuh
# ref: Nudelhölzer pred: Nudelholzen
# Nudelholz Nudelholz
# ref: Nudelhölzern pred: Nudelholzen
# Nudelholz Nudelholz
# ref: Nudelhölzer pred: Nudelholzen
# ref: Nudelholzes pred: Nudelholz
# ref: Nudelhölzer pred: Nudelholzen
# Nudelholz Nudelholz
# Omnipotenz Omnipotenz
# Omnipotenz Omnipotenz
# Omnipotenz Omnipotenz
# Omnipotenz Omnipotenz
# Parzellen Parzellen
# Parzelle Parzelle
# Parzellen Parzellen
# Parzelle Parzelle
# Parzellen Parzellen
# Parzelle Parzelle
# Parzellen Parzellen
# Parzelle Parzelle
# ref: Pfifferlinge pred: Pfifferlingen
# Pfifferling Pfifferling
# Pfifferlingen Pfifferlingen
# Pfifferling Pfifferling
# ref: Pfifferlinge pred: Pfifferlingen
# ref: Pfifferlings pred: Pfifferling
# ref: Pfifferlinge pred: Pfifferlingen
# Pfifferling Pfifferling
# ref: Reaktionsschritte pred: Reaktionsschritten
# Reaktionsschritt Reaktionsschritt
# Reaktionsschritten Reaktionsschritten
# ref: Reaktionsschritt pred: Reaktionsschritte
# ref: Reaktionsschritte pred: Reaktionsschritten
# ref: Reaktionsschritts pred: Reaktionsschritte
# ref: Reaktionsschritte pred: Reaktionsschritten
# Reaktionsschritt Reaktionsschritt
# ref: Relaiskontakte pred: Relaiskontakten
# Relaiskontakt Relaiskontakt
# Relaiskontakten Relaiskontakten
# ref: Relaiskontakt pred: Relaiskontakte
# ref: Relaiskontakte pred: Relaiskontakten
# ref: Relaiskontaktes pred: Relaiskontakte
# ref: Relaiskontakte pred: Relaiskontakten
# Relaiskontakt Relaiskontakt
# ref: Salzteige pred: Salzteigen
# Salzteig Salzteig
# Salzteigen Salzteigen
# Salzteig Salzteig
# ref: Salzteige pred: Salzteigen
# ref: Salzteiges pred: Salzteig
# ref: Salzteige pred: Salzteigen
# Salzteig Salzteig
# ref: Sandmänner pred: Sandmannen
# Sandmann Sandmann
# ref: Sandmännern pred: Sandmannen
# Sandmann Sandmann
# ref: Sandmänner pred: Sandmannen
# ref: Sandmannes pred: Sandmann
# ref: Sandmänner pred: Sandmannen
# Sandmann Sandmann
# ref: Scheinwerfer pred: Scheinwerfern
# Scheinwerfer Scheinwerfer
# Scheinwerfern Scheinwerfern
# Scheinwerfer Scheinwerfer
# ref: Scheinwerfer pred: Scheinwerfern
# ref: Scheinwerfers pred: Scheinwerfer
# ref: Scheinwerfer pred: Scheinwerfern
# Scheinwerfer Scheinwerfer
# ref: Schlagbäume pred: Schlagbaumen
# Schlagbaum Schlagbaum
# ref: Schlagbäumen pred: Schlagbaumen
# Schlagbaum Schlagbaum
# ref: Schlagbäume pred: Schlagbaumen
# ref: Schlagbaumes pred: Schlagbaum
# ref: Schlagbäume pred: Schlagbaumen
# Schlagbaum Schlagbaum
# Schweizerinnen Schweizerinnen
# Schweizerin Schweizerin
# Schweizerinnen Schweizerinnen
# Schweizerin Schweizerin
# Schweizerinnen Schweizerinnen
# Schweizerinnen Schweizerinnen
# Schweizerin Schweizerin
# Schürzen Schürzen
# Schürze Schürze
# Schürzen Schürzen
# Schürze Schürze
# Schürzen Schürzen
# Schürze Schürze
# Schürzen Schürzen
# Schürze Schürze
# ref: Taifune pred: Taifun using
# Taifun Taifun
# ref: Taifunen pred: Taifun using
# Taifun Taifun
# ref: Taifune pred: Taifun using
# ref: Taifuns pred: Taifun
# ref: Taifune pred: Taifun
# Taifun Taifun
# ref: Tenside pred: Tensidusing
# Tensid Tensid
# ref: Tensiden pred: Tensidoosing
# Tensid Tensid
# ref: Tenside pred: Tensidoosing
# ref: Tensides pred: Tensid
# ref: Tenside pred: Tensidoosing
# Tensid Tensid
# ref: Theodizeen pred: Theodizees
# Theodizee Theodizee
# Theodizeen Theodizeen
# Theodizee Theodizee
# Theodizeen Theodizeen
# Theodizee Theodizee
# Theodizeen Theodizeen
# Theodizee Theodizee
# ref: Tukane pred: Tukan using
# ref: Tukan pred: Tukan using
# ref: Tukanen pred: Tukan using
# ref: Tukane pred: Tukan using
# ref: Tukans pred: Tukan using
# ref: Tukane pred: Tukan using
# ref: Tukan pred: Tukan using
# ref: Umweltministerien pred: Umweltministerium
# Umweltministerium Umweltministerium
# ref: Umweltministerien pred: Umweltministerium
# Umweltministerium Umweltministerium
# ref: Umweltministerien pred: Umweltministerium
# ref: Umweltministeriums pred: Umweltministerium
# ref: Umweltministerien pred: Umweltministerium
# Umweltministerium Umweltministerium
# ref: Unterschenkel pred: Unterschenkeln
# Unterschenkel Unterschenkel
# Unterschenkeln Unterschenkeln
# Unterschenkel Unterschenkel
# ref: Unterschenkel pred: Unterschenkeln
# ref: Unterschenkels pred: Unterschenkel
# ref: Unterschenkel pred: Unterschenkeln
# Unterschenkel Unterschenkel
# ref: Verschwörungstheoretiker pred: Verschwörungstheoretikern
# Verschwörungstheoretiker Verschwörungstheoretiker
# Verschwörungstheoretikern Verschwörungstheoretikern
# Verschwörungstheoretiker Verschwörungstheoretiker
# ref: Verschwörungstheoretiker pred: Verschwörungstheoretikern
# ref: Verschwörungstheoretikers pred: Verschwörungstheoretiker
# ref: Verschwörungstheoretiker pred: Verschwörungstheoretikern
# Verschwörungstheoretiker Verschwörungstheoretiker
# ref: Vollwaschmittel pred: Vollwaschmitteln
# Vollwaschmittel Vollwaschmittel
# Vollwaschmitteln Vollwaschmitteln
# Vollwaschmittel Vollwaschmittel
# ref: Vollwaschmittel pred: Vollwaschmitteln
# ref: Vollwaschmittel pred: Vollwaschmitteln
# Vollwaschmittel Vollwaschmittel
# ref: Vorbilder pred: Vorbildern
# Vorbild Vorbild
# Vorbildern Vorbildern
# Vorbild Vorbild
# ref: Vorbilder pred: Vorbildern
# ref: Vorbildes pred: Vorbild using
# Vorbilder Vorbilder
# Vorbild Vorbild
# ref: Wahlkämpfer pred: Wahlkämpfern
# Wahlkämpfer Wahlkämpfer
# Wahlkämpfern Wahlkämpfern
# Wahlkämpfer Wahlkämpfer
# ref: Wahlkämpfer pred: Wahlkämpfern
# ref: Wahlkämpfers pred: Wahlkämpfer
# ref: Wahlkämpfer pred: Wahlkämpfern
# Wahlkämpfer Wahlkämpfer
# ref: Wohnsitze pred: Wohnsitzen
# Wohnsitz Wohnsitz
# Wohnsitzen Wohnsitzen
# Wohnsitz Wohnsitz
# ref: Wohnsitze pred: Wohnsitzen
# ref: Wohnsitzes pred: Wohnsitz
# ref: Wohnsitze pred: Wohnsitzen
# Wohnsitz Wohnsitz
# ref: Zahnärztinnen pred: Zahnärztinen
# Zahnärztin Zahnärztin
# ref: Zahnärztinnen pred: Zahnärztinen
# Zahnärztin Zahnärztin
# ref: Zahnärztinnen pred: Zahnärztinen
# Zahnärztin Zahnärztin
# ref: Zahnärztinnen pred: Zahnärztinen
# Zahnärztin Zahnärztin
# ref: abalieniertest pred: abalieniertet
# ref: abalienierten pred: abalieniertet
# abalienieren abalienieren
# ref: abalienieren pred: abalienierten
# ref: abalienieret pred: abalienierten
# ref: abalienierest pred: abalienierte
# ref: abalienieren pred: abalienierten
# ref: abalienierten pred: abalieniertet
# ref: abalienierte pred: abalieniertet
# ref: abalieniertest pred: abalieniertet
# ref: abalienierten pred: abalieniertet
# ref: abalienierte pred: abalieniertet
# ref: abgelaufen pred: laufend
# ref: lauf ab pred: ablaufe
# ref: laufen ab pred: laufen
# ref: laufe ab pred: laufen
# ref: läuft ab pred: laufen
# ref: liefen ab pred: laufet
# ref: liefst ab pred: laufet
# ref: liefen ab pred: laufteten
# ref: lief ab pred: laufet
# ref: liefen ab pred: laufteten
# ref: liefe ab pred: lauftet
# ref: liefest ab pred: lauftet
# ref: applicirend pred: appliciren
# ref: applicirt pred: appliciret
# ref: applicirt pred: appliciren
# appliciren appliciren
# applicirtet applicirtet
# ref: applicirten pred: applicirtet
# ref: applicirte pred: applicirtet
# ref: appliciret pred: applicirest
# ref: applicirest pred: applicire
# ref: appliciren pred: applicirest
# ref: applicirten pred: applicirtete
# ref: applicirte pred: applicirtet
# ref: applicirte pred: applicirtet
# ref: heb auf pred: aufheben
# ref: hebt auf pred: aufheben
# ref: hob auf pred: aufhebtet
# ref: hobt auf pred: hebten auf
# ref: hoben auf pred: hebten auf
# ref: hob auf pred: aufhebtet
# ref: hebet auf pred: aufheben
# ref: hebest auf pred: aufheben
# ref: heben auf pred: aufheben
# ref: hebe auf pred: aufheben
# ref: höben auf pred: aufhebteten
# ref: höbe auf pred: aufhebtet
# ref: ausbrechend pred: ausbrechen
# ref: brecht aus pred: ausbrechen
# ref: breche aus pred: ausbreche
# ref: brechen aus pred: ausbrechen
# ref: bricht aus pred: ausbreche
# ref: brachen aus pred: ausbrechten
# ref: brach aus pred: ausbrechte
# ref: bracht aus pred: brechteten
# ref: brachen aus pred: brechteten
# ref: brach aus pred: ausbrechte
# ref: brechen aus pred: ausbrechen
# ref: brechet aus pred: ausbrechen
# ref: brächest aus pred: brechtet
# ref: ballastend pred: ballasten
# ballaste ballaste
# ref: ballastest pred: ballaste
# ref: ballastetest pred: ballastete
# ballastete ballastete
# ref: ballasten pred: ballasteten
# ref: ballastet pred: ballasteten
# ref: ballastest pred: ballastet
# ref: ballaste pred: ballastet
# ref: ballasteten pred: ballastteten
# ref: ballastetest pred: ballastetet
# ref: ballasteten pred: ballastteten
# ballastete ballastete
# befördert befördert
# ref: befördre pred: befördert
# ref: befördre pred: befördert
# ref: befördern pred: beförderten
# ref: beförderten pred: befördertet
# ref: beförderte pred: befördertet
# ref: befördern pred: beförderten
# ref: befördere pred: beförderte
# ref: beförderet pred: beförderten
# ref: beförderest pred: beförderte
# ref: befördern pred: beförderten
# ref: beförderten pred: befördertet
# ref: beförderte pred: befördertet
# ref: belügend pred: belügen
# ref: belogen pred: belügt
# ref: belügst pred: belügte
# belügen belügen
# ref: belügt pred: belügen
# ref: belogen pred: belügtet
# ref: belog pred: belügtet
# ref: belogt pred: belügtet
# belügen belügen
# ref: belüget pred: belügen
# ref: belüge pred: belügen
# ref: belöget pred: belügteten
# ref: belögen pred: belügteten
# ref: gebimmelt pred: bimmelten
# ref: bimmelt pred: bimmelten
# ref: bimmle pred: bimmelt
# ref: bimmle pred: bimmelten
# ref: bimmelt pred: bimmelten
# ref: bimmelten pred: bimmteten
# ref: bimmelte pred: bimmelten
# ref: bimmeltet pred: bimmteten
# ref: bimmelten pred: bimmteten
# ref: bimmele pred: bimmelten
# ref: bimmeln pred: bimmelten
# bimmelten bimmelten
# ref: bimmelte pred: bimmelten
# ref: gebummelt pred: bummelten
# ref: bummle pred: bummelte
# ref: bummeltet pred: bummelten
# ref: bummeltest pred: bummelten
# bummelten bummelten
# ref: bummelte pred: bummelten
# bummeln bummeln
# ref: bummeln pred: bummelten
# ref: bummelet pred: bummelten
# ref: bummeln pred: bummelten
# bummelten bummelten
# ref: bummelte pred: bummelten
# ref: bummelte pred: bummelten
# ref: dubliert pred: dublierten
# ref: dubliert pred: dublierten
# ref: dublieren pred: dublierten
# ref: dublierten pred: dubliertet
# dubliertet dubliertet
# ref: dubliertest pred: dubliertet
# ref: dublierten pred: dubliertet
# dublieren dublieren
# ref: dublieren pred: dublierten
# ref: dubliere pred: dublierte
# ref: dublierten pred: dubliertet
# ref: dublierte pred: dubliertet
# ref: leben ein pred: einleben
# ref: lebt ein pred: einleben
# ref: lebten ein pred: einlebten
# ref: lebtet ein pred: einlebten
# ref: lebtest ein pred: einlebten
# ref: lebten ein pred: einlebten
# ref: lebte ein pred: einlebte
# ref: leben ein pred: einleben
# ref: lebet ein pred: einleben
# ref: leben ein pred: einleben
# ref: lebten ein pred: einlebten
# ref: lebtet ein pred: einlebten
# ref: lebten ein pred: einlebten
# ref: empfindend pred: empfindet
# ref: empfunden pred: empfindet
# ref: empfinden pred: empfindet
# ref: empfinde pred: empfindet
# ref: empfinden pred: empfindet
# ref: empfanden pred: empfindeten
# ref: empfand pred: empfindete
# ref: empfinden pred: empfindeten
# ref: empfinde pred: empfindet
# ref: empfände pred: empfindete
# ref: empfändest pred: empfindete
# ref: empfänden pred: empfindeten
# ref: entführt pred: entführen
# ref: entführen pred: entführten
# ref: entführe pred: entführte
# ref: entführt pred: entführten
# entführen entführen
# ref: entführten pred: entführtet
# ref: entführte pred: entführtet
# ref: entführest pred: entführe
# ref: entführten pred: entführtet
# ref: entführte pred: entführtet
# ref: entführtest pred: entführtet
# ref: entführten pred: entführtet
# ref: entführte pred: entführtet
# ref: entmineralisierend pred: entmineralisieren
# ref: entmineralisier pred: entmineralisiert
# ref: entmineralisieren pred: entmineralisierten
# ref: entmineralisiere pred: entmineralisierte
# ref: entmineralisierst pred: entmineralisierte
# ref: entmineralisieren pred: entmineralisierten
# entmineralisieren entmineralisieren
# ref: entmineralisierest pred: entmineralisierte
# ref: entmineralisiere pred: entmineralisierte
# ref: entmineralisierte pred: entmineralisiertet
# entmineralisiertet entmineralisiertet
# ref: entmineralisiertest pred: entmineralisiertet
# ref: entmineralisierten pred: entmineralisiertet
# ref: entsage pred: entsagte
# ref: entsagen pred: entsagten
# ref: entsagt pred: entsagte
# ref: entsagtet pred: entsagten
# entsagten entsagten
# ref: entsagte pred: entsagtet
# ref: entsagen pred: entsagten
# ref: entsaget pred: entsagten
# ref: entsagen pred: entsagten
# ref: entsage pred: entsagte
# entsagten entsagten
# ref: entsagtet pred: entsagten
# ref: entsagte pred: entsagtet
# ref: entschließend pred: entschließen
# ref: entschließt pred: entschließen
# ref: entschließt pred: entschließe
# entschließen entschließen
# ref: entschließt pred: entschließe
# ref: entschlossen pred: entschließten
# ref: entschlossest pred: entschließte
# entschließen entschließen
# ref: entschließe pred: entschließen
# ref: entschließet pred: entschließen
# ref: entschlösset pred: entschließten
# ref: entschlössest pred: entschließtet
# ref: entschlösse pred: entschließte
# ref: etiolierend pred: etiolieren
# ref: etiolier pred: etioliert
# ref: etiolieren pred: etiolierten
# ref: etiolierst pred: etiolierte
# ref: etioliertest pred: etioliertet
# ref: etioliere pred: etiolierte
# ref: etiolieret pred: etiolierten
# ref: etiolieren pred: etiolierten
# ref: etioliere pred: etiolierte
# ref: etiolierte pred: etioliertet
# ref: etioliertest pred: etioliertet
# ref: etiolierte pred: etioliertet
# ref: expandierend pred: expandiert
# expandiert expandiert
# ref: expandiert pred: expandierten
# ref: expandierst pred: expandiert
# ref: expandiert pred: expandierte
# ref: expandierten pred: expandiertet
# ref: expandiertest pred: expandiertet
# ref: expandierte pred: expandiertet
# ref: expandierest pred: expandierte
# ref: expandieren pred: expandierten
# ref: expandiere pred: expandierte
# ref: expandierten pred: expandiertet
# ref: expandierten pred: expandiertet
# ref: feilschend pred: feilschen
# ref: feilscht pred: feilschten
# ref: feilscht pred: feilschten
# ref: feilschtest pred: feilschte
# feilschten feilschten
# ref: feilschet pred: feilschten
# ref: feilschest pred: feilschte
# ref: feilschen pred: feilschten
# ref: feilsche pred: feilschte
# ref: feilschten pred: feilschteten
# ref: feilschte pred: feilschtet
# ref: feilschten pred: feilschtet
# feilschte feilschte
# fluoriert fluoriert
# ref: fluoriert pred: fluorierten
# ref: fluorierten pred: fluoriertet
# ref: fluorierte pred: fluoriertet
# fluoriertet fluoriertet
# ref: fluorierten pred: fluoriertet
# ref: fluorierte pred: fluoriertet
# ref: fluorierest pred: fluorierte
# ref: fluorieren pred: fluorierten
# ref: fluoriere pred: fluorierte
# ref: fluorierten pred: fluoriertet
# ref: fluorierte pred: fluoriertet
# ref: fluoriertest pred: fluoriertet
# ref: impf pred: impfen
# ref: impfen pred: impften
# ref: impft pred: impften
# impfen impfen
# ref: impft pred: impfen
# ref: impftet pred: impfteten
# ref: impften pred: impfteten
# ref: impfte pred: impftet
# impfen impfen
# impfen impfen
# ref: impfe pred: impfen
# ref: impftet pred: impfteten
# ref: impften pred: impfteten
# ref: infizierend pred: infizieren
# ref: infiziert pred: infizierten
# ref: infizieren pred: infizierten
# ref: infizierten pred: infiziertet
# infiziertet infiziertet
# ref: infizierte pred: infiziertet
# ref: infizieren pred: infizierten
# ref: infizieret pred: infizierten
# ref: infizierest pred: infizierte
# ref: infiziere pred: infizierte
# ref: infizierte pred: infiziertet
# ref: infiziertest pred: infiziertet
# ref: infizierte pred: infiziertet
# ref: kiekend pred: kieken
# ref: gekiekt pred: kiekten
# ref: kieken pred: kiekten
# ref: kiekt pred: kiekten
# ref: kiekten pred: kiekteten
# ref: kiektet pred: kiekteten
# ref: kiekten pred: kiekteten
# ref: kiekte pred: kiektet
# kieken kieken
# ref: kieke pred: kieken
# ref: kiekte pred: kiektet
# ref: kiektest pred: kiektet
# ref: kiekte pred: kiektet
# ref: kipp pred: kippen
# ref: kippe pred: kippen
# ref: kippst pred: kippen
# ref: kippt pred: kippen
# ref: kipptet pred: kippteten
# ref: kippte pred: kipptete
# kippen kippen
# ref: kippe pred: kippen
# ref: kippe pred: kippen
# ref: kippten pred: kippteten
# ref: kippte pred: kipptete
# ref: kipptet pred: kippteten
# ref: kipptest pred: kipptete
# ref: geklirrt pred: klirrtet
# ref: klirrt pred: klirren
# ref: klirren pred: klirrst
# ref: klirre pred: klirrst
# ref: klirrt pred: klirrst
# ref: klirrten pred: klirrteten
# ref: klirrte pred: klirrtet
# ref: klirrten pred: klirrteten
# klirren klirren
# ref: klirrest pred: klirren
# ref: klirrten pred: klirrteten
# ref: klirrte pred: klirrtet
# ref: kontrahierend pred: kontrahieren
# kontrahiert kontrahiert
# ref: kontrahier pred: kontrahiert
# ref: kontrahiere pred: kontrahiert
# ref: kontrahiert pred: kontrahierte
# ref: kontrahierten pred: kontrahiertet
# kontrahiertet kontrahiertet
# kontrahieren kontrahieren
# ref: kontrahiere pred: kontrahierte
# ref: kontrahierte pred: kontrahiertet
# kontrahiertet kontrahiertet
# ref: kontrahiertest pred: kontrahiertet
# ref: kontrahierten pred: kontrahiertet
# ref: kümmernd pred: kümmert
# ref: kümmert pred: kümmerten
# ref: kümmre pred: kümmert
# ref: kümmerst pred: kümmert
# ref: kümmern pred: kümmerten
# kümmert kümmert
# ref: kümmerte pred: kümmertet
# kümmertet kümmertet
# ref: kümmertest pred: kümmertet
# ref: kümmerten pred: kümmertet
# ref: kümmere pred: kümmert
# ref: kümmerten pred: kümmertet
# ref: kümmerte pred: kümmertet
# liquidiert liquidiert
# ref: liquidiert pred: liquidierten
# liquidiert liquidiert
# ref: liquidierten pred: liquidiertet
# ref: liquidiertest pred: liquidiertet
# ref: liquidierten pred: liquidiertet
# ref: liquidierte pred: liquidiertet
# ref: liquidiere pred: liquidierte
# ref: liquidieren pred: liquidierten
# ref: liquidiere pred: liquidierte
# liquidiertet liquidiertet
# ref: liquidierten pred: liquidiertet
# ref: liquidierte pred: liquidiertet
# ref: gemulcht pred: mulchten
# ref: mulch pred: mulchen
# mulchen mulchen
# mulchen mulchen
# ref: mulcht pred: mulchen
# mulchten mulchten
# ref: mulchte pred: mulchten
# mulchten mulchten
# ref: mulchet pred: mulchen
# ref: mulchten pred: mulchteten
# ref: mulchte pred: mulchten
# ref: mulchten pred: mulchteten
# ref: genützt pred: nützte
# ref: nützten pred: nützteten
# ref: nützte pred: nütztet
# ref: nützen pred: nützten
# ref: nütze pred: nützte
# ref: nützet pred: nützten
# ref: nützest pred: nützte
# nützen nützen
# ref: nütze pred: nützte
# ref: nützte pred: nütztet
# ref: nütztest pred: nütztet
# ref: nützte pred: nütztet
# ref: paraphrasierend pred: paraphrasiert
# ref: paraphrasiert pred: paraphrasierten
# ref: paraphrasiert pred: paraphrasierte
# ref: paraphrasierten pred: paraphrasiertet
# paraphrasiertet paraphrasiertet
# ref: paraphrasieren pred: paraphrasiert
# ref: paraphrasiere pred: paraphrasierte
# ref: paraphrasierten pred: paraphrasiertet
# ref: paraphrasierte pred: paraphrasiertet
# paraphrasiertet paraphrasiertet
# ref: paraphrasiertest pred: paraphrasiertet
# ref: paraphrasierten pred: paraphrasiertet
# ref: paraphrasierte pred: paraphrasiertet
# ref: pubertiert pred: pubertierten
# ref: pubertier pred: pubertiert
# ref: pubertieren pred: pubertierten
# ref: pubertiert pred: pubertierte
# pubertiertet pubertiertet
# ref: pubertiertest pred: pubertiertet
# ref: pubertieren pred: pubertierten
# ref: pubertieret pred: pubertierten
# ref: pubertieren pred: pubertierten
# ref: pubertiere pred: pubertierte
# ref: pubertierte pred: pubertiertet
# pubertiertet pubertiertet
# ref: pubertiertest pred: pubertiertet
# ref: sabble pred: sabbelt
# ref: sabbeln pred: sabbelten
# ref: sabble pred: sabbelte
# ref: sabbelt pred: sabbelte
# ref: sabbeltet pred: sabbelten
# ref: sabbeltest pred: sabbelte
# sabbelten sabbelten
# ref: sabbelet pred: sabbelten
# ref: sabbelest pred: sabbelte
# ref: sabbeln pred: sabbelten
# ref: sabbele pred: sabbelte
# sabbelte sabbelte
# ref: sabbeltest pred: sabbelte
# ref: sehn pred: sehnen
# ref: sehnen pred: sehnten
# ref: sehnt pred: sehnten
# sehnen sehnen
# sehnten sehnten
# sehnten sehnten
# ref: sehnte pred: sehnten
# sehnen sehnen
# ref: sehne pred: sehnen
# ref: sehnte pred: sehntet
# ref: sehntet pred: sehnteten
# ref: sehnten pred: sehnteten
# ref: sehnte pred: sehntet
# ref: gespart pred: spartet
# ref: spart pred: spartet
# ref: spar pred: sparte
# ref: sparst pred: spartet
# ref: sparten pred: sparteten
# ref: sparen pred: spartet
# sparest sparest
# ref: sparen pred: spartet
# ref: sparte pred: spartete
# ref: spartet pred: sparteten
# ref: spartest pred: spartete
# ref: sparten pred: sparteten
# ref: sparte pred: spartete
# ref: getippt pred: tipptet
# ref: tippt pred: tippen
# ref: tippt pred: tippen
# ref: tippst pred: tippen
# tippen tippen
# ref: tippten pred: tippteten
# ref: tippte pred: tipptete
# ref: tippet pred: tippen
# ref: tippest pred: tippen
# ref: tipptet pred: tippteten
# ref: tippte pred: tipptete
# ref: umwandelnd pred: umwandelten
# ref: wandle um pred: umwandelte
# ref: wandelt um pred: umwandelten
# ref: wandelst um pred: umwandelte
# ref: wandeln um pred: umwandelten
# ref: wandelt um pred: umwandelte
# ref: wandeltet um pred: wandelten
# ref: wandelten um pred: umwandelten
# umwandeln umwandeln
# ref: wandele um pred: umwandelte
# ref: wandelest um pred: umwandelte
# ref: wandelte um pred: umwandelten
# ref: verscheissern pred: verscheisserten
# ref: verscheissert pred: verscheisserten
# ref: verscheisserst pred: verscheissert
# verscheissert verscheissert
# ref: verscheisserten pred: verscheissteten
# ref: verscheisserten pred: verscheissteten
# ref: verscheisserte pred: verscheisstet
# ref: verscheissern pred: verscheisserten
# ref: verscheissere pred: verscheissert
# ref: verscheisseret pred: verscheisserten
# ref: verscheissern pred: verscheisserten
# ref: verscheissertet pred: verscheissteten
# ref: verscheissertest pred: verscheisstet
# versorgt versorgt
# ref: versorg pred: versorgte
# ref: versorgen pred: versorgten
# ref: versorgten pred: versorgteten
# ref: versorgte pred: versorgtet
# ref: versorgtet pred: versorgteten
# ref: versorgte pred: versorgtet
# versorgen versorgen
# ref: versorgen pred: versorgten
# ref: versorgtet pred: versorgteten
# ref: versorgtest pred: versorgtet
# ref: versorgten pred: versorgteten
# ref: versorgte pred: versorgtet
# ref: verursachend pred: verursachen
# verursacht verursacht
# ref: verursacht pred: verursachten
# ref: verursacht pred: verursachte
# ref: verursachte pred: verursachtet
# ref: verursachtest pred: verursachtet
# ref: verursachte pred: verursachtet
# ref: verursache pred: verursachte
# ref: verursachest pred: verursachte
# ref: verursachen pred: verursachten
# ref: verursache pred: verursachte
# ref: verursachten pred: verursachteten
# ref: verursachte pred: verursachtet
# ref: verwandelnd pred: verwandelten
# ref: verwandelt pred: verwandelten
# verwandelten verwandelten
# ref: verwandeltet pred: verwandelten
# verwandelten verwandelten
# ref: verwandeln pred: verwandelt
# ref: verwandeln pred: verwandelten
# ref: verwandele pred: verwandelte
# ref: verwandelte pred: verwandeltet
# ref: verwandeltet pred: verwandelten
# ref: verwandeltest pred: verwandeltet
# verwandelten verwandelten
# ref: verwandelte pred: verwandeltet
# ref: wahrgenommen pred: wahrnehmen
# ref: nehmt wahr pred: wahrnehmen
# ref: nehmen wahr pred: wahrnehmen
# ref: nehme wahr pred: wahrnehme
# ref: nimmst wahr pred: wahrnehme
# ref: nahmt wahr pred: wahrnehmeten
# ref: nahmst wahr pred: wahrnehmet
# ref: nahmen wahr pred: wahrnehmeten
# ref: nahm wahr pred: wahrnehmet
# ref: nehmen wahr pred: wahrnehmen
# ref: nehme wahr pred: wahrnehme
# ref: nehmen wahr pred: wahrnehmen
# ref: nähmen wahr pred: wahrnehmeten
# ref: gewalzt pred: walzten
# ref: walzt pred: walzen
# ref: walzen pred: walzten
# ref: walzt pred: walzen
# walzten walzten
# ref: walztest pred: walzten
# ref: walze pred: walzen
# ref: walzet pred: walzen
# walzen walzen
# ref: walze pred: walzen
# ref: walzte pred: walzten
# ref: walztest pred: walzten
# ref: walzte pred: walzten
# wertet wertet
# wertet wertet
# wertet wertet
# werteten werteten
# werteten werteten
# ref: werten pred: werteten
# ref: wertet pred: werteten
# ref: werte pred: wertet
# ref: wertete pred: wertetet
# ref: wertetest pred: wertetet
# werteten werteten
# ref: wertete pred: wertetet
# ref: zementierend pred: zementieren
# zementiert zementiert
# ref: zementiert pred: zementieren
# ref: zementier pred: zementiere
# ref: zementieren pred: zementierten
# ref: zementiert pred: zementierte
# ref: zementierten pred: zementiertet
# ref: zementierten pred: zementiertet
# ref: zementierte pred: zementiertet
# ref: zementieren pred: zementierten
# ref: zementieret pred: zementierten
# ref: zementierte pred: zementiertet
# ref: zementierten pred: zementiertet
# ref: zugegeben pred: zugeben
# ref: gib zu pred: zugeben
# ref: geben zu pred: zugeben
# ref: gebt zu pred: zugeben
# ref: gibst zu pred: zugeben
# ref: geben zu pred: zugeben
# ref: gibt zu pred: zugeben
# ref: gaben zu pred: zugebteten
# ref: gab zu pred: zugebtet
# ref: gabst zu pred: zugebtet
# ref: gaben zu pred: zugebteten
# ref: gab zu pred: zugebtet
# ref: gebe zu pred: zugeben
# ref: Überlebenskünste pred: Überlebenskunsten
# Überlebenskunst Überlebenskunst
# ref: Überlebenskünsten pred: Überlebenskunsten
# Überlebenskunst Überlebenskunst
# ref: Überlebenskünste pred: Überlebenskunsten
# Überlebenskunst Überlebenskunst
# ref: Überlebenskünste pred: Überlebenskunsten
# Überlebenskunst Überlebenskunst
# 0.293
# ./byt5_small/5lang-sample
# ref: daʼdííníildíín pred: adiníłdíín
# ref: adííníildíín pred: adiníłdíín
# ref: adííníshdíín pred: adiníłdíín
# ref: daʼdíínółdíín pred: adiníłdíín
# ref: adíínółdíín pred: adiníłdíín
# ref: adííníłdíín pred: adiníłdíín
# ref: daʼdiníłdíín pred: adiníłdíín
# adiníłdíín adiníłdíín
# adiníłdíín adiníłdíín
# ref: dazhdiʼníłdíín pred: jidiníłdíín
# ref: adizhníłdíín pred: jííníłdíín
# ref: adizhníłdíín pred: jidiníłdíín
# ref: ahidaniiltʼé pred: aheełtʼé
# ref: ahiniiltʼé pred: aheełtʼé
# ref: ahinishtʼé pred: aheełtʼé
# ref: ahidanołtʼé pred: aheełtʼé
# ref: ahinołtʼé pred: aheełtʼé
# ref: ahiníłtʼé pred: aheełtʼé
# ref: ahidaałtʼé pred: aheełtʼé
# aheełtʼé aheełtʼé
# aheełtʼé aheełtʼé
# ref: ahidajíłtʼé pred: jííłtʼé
# ref: ahijíłtʼé pred: jííłtʼé
# ref: ahijíłtʼé pred: jííłtʼé
# ref: dadiniilyił pred: diłhił
# ref: diniilyił pred: diłhił
# ref: dinishhił pred: diłhił
# ref: dadinołhił pred: diłhił
# ref: dinołhił pred: diłhił
# ref: diníłhił pred: diłhił
# ref: dadiłhił pred: diłhił
# diłhił diłhił
# diłhił diłhił
# ref: dazhdiłhił pred: diłhił
# ref: jidiłhił pred: jiłhił
# ref: jidiłhił pred: jiłhił
# ref: dadiniitʼil pred: diʼil
# ref: diniitʼil pred: diʼil
# ref: dinishʼil pred: diʼil
# ref: dadinohʼil pred: diʼil
# ref: dinohʼil pred: diʼil
# ref: diníʼil pred: diʼil
# ref: dadiʼil pred: diʼil
# diʼil diʼil
# diʼil diʼil
# ref: dazhdiʼil pred: diʼil
# ref: jidiʼil pred: jiʼil
# ref: jidiʼil pred: jiʼil
# ref: dahoshiiké pred: hashké
# ref: hoshiiké pred: hashké
# ref: hoshishké pred: hashké
# ref: dahoshohké pred: hashké
# ref: hoshohké pred: hashké
# ref: hoshíníké pred: hashké
# ref: dahashké pred: hashké
# hashké hashké
# hashké hashké
# ref: dahojishké pred: hashké
# ref: hojishké pred: hajííshké
# ref: hojishké pred: hajííshké
# ref: dahashiiké pred: hashké
# ref: hashiiké pred: hashké
# ref: hashishké pred: hashké
# ref: dahashohké pred: hashké
# ref: hashohké pred: hashké
# ref: hashíníké pred: hashké
# ref: dahashké pred: hashké
# hashké hashké
# hashké hashké
# ref: dahajishké pred: hajishké
# ref: hajishké pred: hajííshké
# ref: hajishké pred: hajííshké
# ref: adeiildlóósh pred: iildlóósh
# ref: adaałdlóósh pred: iildlóósh
# ref: oołdlóósh pred: iildlóósh
# ref: anildlóósh pred: iildlóósh
# iildlóósh iildlóósh
# iildlóósh iildlóósh
# ref: adajildlóósh pred: jííldlóósh
# ref: ajildlóósh pred: jííldlóósh
# ref: adasiildloozh pred: iildlóósh
# ref: eeshdloozh pred: iildlóósh
# ref: adasoołdloozh pred: iildlóósh
# ref: oołdloozh pred: iildlóósh
# ref: adaashdloozh pred: iildlóósh
# ref: eeldloozh pred: iildlóósh
# ref: eeldloozh pred: iildlóósh
# ref: ajooldloozh pred: jííldlóósh
# ref: ajooldloozh pred: jildlóósh
# ref: adiildlosh pred: iildlóósh
# ref: adeeshdlosh pred: iildlóósh
# ref: adííldlosh pred: iildlóósh
# ref: adooldlosh pred: iildlóósh
# ref: azhdooldlosh pred: jííldlóósh
# ref: adeiidǫ́ǫ́s pred: iizǫ́ǫ́s
# ref: iidǫ́ǫ́s pred: iizǫ́ǫ́s
# ref: iisǫ́ǫ́s pred: iizǫ́ǫ́s
# ref: adaahsǫ́ǫ́s pred: iizǫ́ǫ́s
# ref: adeizǫ́ǫ́s pred: iizǫ́ǫ́s
# iizǫ́ǫ́s iizǫ́ǫ́s
# ref: adajizǫ́ǫ́s pred: jizǫ́ǫ́s
# ref: ajizǫ́ǫ́s pred: jizǫ́ǫ́s
# ref: íízǫ́ǫ́z pred: iizǫ́ǫ́s
# ref: adasoozǫ́ǫ́z pred: iizǫ́ǫ́s
# ref: íínízǫ́ǫ́z pred: iizǫ́ǫ́s
# ref: adeizǫ́ǫ́z pred: iizǫ́ǫ́s
# ref: ayíízǫ́ǫ́z pred: iizǫ́ǫ́s
# ref: adajizǫ́ǫ́z pred: jizǫ́ǫ́s
# ref: ajíízǫ́ǫ́z pred: jizǫ́ǫ́s
# ref: adiidǫ́ǫ́s pred: iizǫ́ǫ́s
# ref: adeesǫ́ǫ́s pred: iizǫ́ǫ́s
# ref: adadoohsǫ́ǫ́s pred: iizǫ́ǫ́s
# ref: adeidoozǫ́ǫ́s pred: iizǫ́ǫ́s
# ref: iidoozǫ́ǫ́s pred: iizǫ́ǫ́s
# ref: adazhdoozǫ́ǫ́s pred: jizǫ́ǫ́s
# ref: azhdoozǫ́ǫ́s pred: jizǫ́ǫ́s
# ref: azhdoozǫ́ǫ́s pred: jizǫ́ǫ́s
# ref: ndeiidá pred: naadádá
# ref: ndaahdá pred: naasing
# ref: nanidá pred: naadásing
# ref: ndaadá pred: naadádá
# ref: njidá pred: jíídá
# ref: nisiidzá pred: naadádá
# ref: ndasoohdzá pred: naasing
# ref: nisoohdzá pred: naasing
# ref: nisínídzá pred: naadásing
# ref: ndaasdzá pred: naasing
# ref: naasdzá pred: naadádá
# ref: naasdzá pred: naadásing
# ref: ndajisdzá pred: naadajizing
# ref: njisdzá pred: jíínídá
# ref: njisdzá pred: jíídá
# ref: ndadiidaał pred: nidoodáł
# ref: ndiidaał pred: nidoodásing
# ref: ndadoohdaał pred: naasing
# ref: ndíídaał pred: naadásing
# ref: ndadoodaał pred: nidoodáł
# ref: ndoodaał pred: naadásing
# ref: ndazhdoodaał pred: nijidoodá
# ref: nizhdoodaał pred: nijidoodá
# ref: ndeiiljooł pred: naashjooł
# ref: neiiljooł pred: naashjooł
# ref: naashjooł pred: naaljooł
# ref: ndaałjooł pred: naashjooł
# ref: naałjooł pred: naashjooł
# ref: ndaaljooł pred: naashjooł
# naaljooł naaljooł
# ref: ndajiljooł pred: naashjooł
# ref: njiljooł pred: jííljooł
# ref: ndashiiljool pred: naashjooł
# ref: nishishjool pred: naashjooł
# ref: ndashoołjool pred: naashjooł
# ref: nishoołjool pred: naashjooł
# ref: ndaashjool pred: naashjooł
# ref: naashjool pred: naashjooł
# ref: njishjool pred: jííljooł
# ref: njishjool pred: joołjooł
# ref: ndadiiljoł pred: naashjooł
# ref: ndoołjoł pred: naashjooł
# ref: ndooljoł pred: naashjooł
# ref: ndooljoł pred: naashjooł
# ref: ndazhdooljoł pred: naashjooł
# ref: nizhdooljoł pred: naashjooł
# ref: nideiiʼmaas pred: naamaas
# ref: neiiʼmaas pred: naamaas
# ref: naasmaas pred: naamaas
# ref: naahmaas pred: naamaas
# naamaas naamaas
# naamaas naamaas
# ref: nidajimaas pred: naamaas
# ref: nijimaas pred: naamaas
# ref: nijimaas pred: naamaas
# ref: nisiiʼmááz pred: naamaas
# ref: nisémááz pred: naamaas
# ref: nidasoomááz pred: naamaas
# ref: nidaazmááz pred: naamaas
# ref: naazmááz pred: naamaas
# ref: naazmááz pred: naamaas
# ref: nidajizmááz pred: naamaas
# ref: ndiiʼmas pred: naamaas
# ref: ndeesmas pred: naamaas
# ref: ndíímas pred: naamaas
# ref: ndoomas pred: naamaas
# ref: nizhdoomas pred: naamaas
# ref: nizhdoomas pred: naamaas
# ref: ndeiitaz pred: naatazhdootaz
# ref: naastaz pred: naataz
# ref: ndaahtaz pred: naatazhdootaz
# ref: naahtaz pred: naatazhdootaz
# ref: nanitaz pred: naataz
# ref: ndaataz pred: naatazhdootaz
# ref: naataz pred: naatazhdootaz
# naataz naataz
# ref: njitaz pred: jíítaz
# ref: njitaz pred: jíítaz
# ref: nisétaz pred: naataz
# ref: ndasootaz pred: naatazhdootaz
# ref: nisootaz pred: naatazhdootaz
# ref: nisínítaz pred: naataz
# ref: ndaaztaz pred: naatazhdootaz
# ref: naaztaz pred: naatazhdootaz
# ref: naaztaz pred: naataz
# ref: ndadiitas pred: naatazhdootaz
# ref: ndadoohtas pred: naatazhdootaz
# ref: ndootas pred: naashtaz
# ref: ndootas pred: naashtaz
# ref: ndazhdootas pred: naatazhdootaz
# ref: nizhdootas pred: naashtaz
# ref: nideiitłeeh pred: neitłeeh
# ref: neiitłeeh pred: neitłeeh
# ref: naashtłeeh pred: neitłeeh
# ref: nidaahtłeeh pred: neitłeeh
# ref: naahtłeeh pred: neitłeeh
# ref: nideitłeeh pred: neitłeeh
# neitłeeh neitłeeh
# ref: nidajitłeeh pred: nijitłeeh
# ref: nijitłeeh pred: njitłeeh
# ref: nijitłeeh pred: njitłeeh
# ref: nisiitłééʼ pred: neitłeeh
# ref: nidasootłééʼ pred: neitłeeh
# ref: nisínítłééʼ pred: neitłeeh
# ref: nideiztłééʼ pred: neitłeeh
# ref: nijiztłééʼ pred: njitłeeh
# ref: ndadiitłoh pred: nidootłeeh
# ref: ndiitłoh pred: neitłeeh
# ref: ndoohtłoh pred: neitłeeh
# ref: ndíítłoh pred: neitłeeh
# ref: ndeidootłoh pred: nidootłeeh
# ref: ndazhdootłoh pred: nijitłeeh
# ref: nizhdootłoh pred: nijitłeeh
# ref: nizhdootłoh pred: nijitłeeh
# ref: ndeiilbąąs pred: neiłbąąs
# ref: ndeiłbąąs pred: neiłbąąs
# neiłbąąs neiłbąąs
# njiłbąąs njiłbąąs
# ref: ndasiilbą́ą́z pred: neiłbąąs
# ref: nisiilbą́ą́z pred: neiłbąąs
# ref: niséłbą́ą́z pred: neiłbąąs
# ref: ndasoołbą́ą́z pred: neiłbąąs
# ref: nisoołbą́ą́z pred: neiłbąąs
# ref: nisíníłbą́ą́z pred: neiłbąąs
# ref: ndeisbą́ą́z pred: neiłbąąs
# ref: neisbą́ą́z pred: neiłbąąs
# ref: neisbą́ą́z pred: neiłbąąs
# ref: ndajisbą́ą́z pred: njiłbąąs
# ref: njisbą́ą́z pred: njiłbąąs
# ref: ndiilbąs pred: nidoołbąąs
# ref: ndadoołbąs pred: neidoołbąąs
# ref: ndoołbąs pred: neidoołbąąs
# ref: neidoołbąs pred: nidoołbąąs
# ref: neidoołbąs pred: nidoołbąąs
# ref: ndazhdoołbąs pred: njiłbąąs
# ref: nizhdoołbąs pred: njiłbąąs
# ref: nizhdoołbąs pred: njiłbąąs
# ref: nidaałgizh pred: neiłgizh
# ref: naałgizh pred: neiłgizh
# neiłgizh neiłgizh
# neiłgizh neiłgizh
# ref: nidajiłgizh pred: njiłgizh
# ref: nijiłgizh pred: njiłgizh
# ref: nishiilgizh pred: neiłgizh
# ref: nishéłgizh pred: neiłgizh
# ref: nidashoołgizh pred: neiłgizh
# ref: nishoołgizh pred: neiłgizh
# ref: nishíníłgizh pred: neiłgizh
# ref: nideishgizh pred: neiłgizh
# ref: neishgizh pred: neiłgizh
# ref: nijishgizh pred: njiłgizh
# ref: ndadiilgish pred: nidoołgizh
# ref: ndiilgish pred: neidoołgizh
# ref: ndadoołgish pred: neidoołgizh
# ref: ndoołgish pred: neidoołgizh
# ref: ndííłgish pred: neiłgizh
# ref: ndeidoołgish pred: nidoołgizh
# ref: neidoołgish pred: nidoołgizh
# ref: ndazhdoołgish pred: nijiłgizh
# ref: nizhdoołgish pred: njiłgizh
# ref: naasmaas pred: neiłmaas
# ref: ndaałmaas pred: neiłmaas
# ref: naniłmaas pred: neiłmaas
# ref: ndeiłmaas pred: neiłmaas
# neiłmaas neiłmaas
# neiłmaas neiłmaas
# njiłmaas njiłmaas
# njiłmaas njiłmaas
# ref: nisiilmááz pred: neiłmaas
# ref: ndasoołmááz pred: neiłmaas
# ref: nisoołmááz pred: neiłmaas
# ref: nisíníłmááz pred: neiłmaas
# ref: ndeismááz pred: neiłmaas
# ref: neismááz pred: neiłmaas
# ref: neismááz pred: neiłmaas
# ref: ndajismááz pred: njiłmaas
# ref: ndadiilmas pred: neiłmaas
# ref: ndiilmas pred: neiłmaas
# ref: ndadoołmas pred: neiłmaas
# ref: ndííłmas pred: neiłmaas
# ref: ndeidoołmas pred: neidoołmaas
# ref: neidoołmas pred: neiłmaas
# ref: nizhdoołmas pred: njiłmaas
# ref: ndeiiltseed pred: neiłtseed
# ref: neiiltseed pred: neiłtseed
# ref: ndaałtseed pred: neiłtseed
# ref: naałtseed pred: neiłtseed
# njiłtseed njiłtseed
# njiłtseed njiłtseed
# ref: ndasiiltseed pred: neiłtseed
# ref: nisiiltseed pred: neiłtseed
# ref: niséłtseed pred: neiłtseed
# ref: ndasoołtseed pred: neiłtseed
# ref: ndeistseed pred: neiłtseed
# ref: neistseed pred: neiłtseed
# ref: neistseed pred: neiłtseed
# ref: ndajistseed pred: njiłtseed
# ref: njistseed pred: njiłtseed
# ref: ndadiiltsił pred: nidoołtseed
# ref: ndiiltsił pred: nidoołtseed
# ref: ndeestsił pred: neiłtseed
# ref: ndadoołtsił pred: neidoołtseed
# ref: ndííłtsił pred: neiłtseed
# ref: neidoołtsił pred: nidoołtseed
# ref: neidoołtsił pred: nidoołtseed
# ref: nizhdoołtsił pred: njiłtseed
# ref: ndeiiltʼiʼ pred: neiłtʼiʼ
# ref: neiiltʼiʼ pred: neiłtʼiʼ
# ref: ndaałtʼiʼ pred: neiłtʼiʼ
# ref: ndeiłtʼiʼ pred: neiłtʼiʼ
# neiłtʼiʼ neiłtʼiʼ
# neiłtʼiʼ neiłtʼiʼ
# njiłtʼiʼ njiłtʼiʼ
# ref: ndasiiltʼiʼ pred: neiłtʼiʼ
# ref: niséłtʼiʼ pred: neiłtʼiʼ
# ref: ndasoołtʼiʼ pred: neiłtʼiʼ
# ref: nisoołtʼiʼ pred: neiłtʼiʼ
# ref: nisíníłtʼiʼ pred: neiłtʼiʼ
# ref: neistʼiʼ pred: neiłtʼiʼ
# ref: njistʼiʼ pred: njiłtʼiʼ
# ref: njistʼiʼ pred: njiłtʼiʼ
# ref: ndadiiltʼih pred: neiłtʼiʼ
# ref: ndiiltʼih pred: neiłtʼiʼ
# ref: ndeeshtʼih pred: neiłtʼiʼ
# ref: ndoołtʼih pred: neiłtʼiʼ
# ref: ndííłtʼih pred: neiłtʼiʼ
# ref: neidoołtʼih pred: nidoołtʼiʼ
# ref: nizhdoołtʼih pred: njiłtʼiʼ
# ref: nizhdoołtʼih pred: njiłtʼiʼ
# ref: neiitʼeesh pred: neiʼeesh
# ref: naashʼeesh pred: neiʼeesh
# ref: ndaahʼeesh pred: neiʼeesh
# ref: naahʼeesh pred: neiʼeesh
# ref: naniʼeesh pred: neiʼeesh
# neiʼeesh neiʼeesh
# njiʼeesh njiʼeesh
# ref: nishiitʼeezh pred: neiʼeesh
# ref: nishéʼeezh pred: neiʼeesh
# ref: ndashooʼeezh pred: neiʼeesh
# ref: nishooʼeezh pred: neiʼeesh
# ref: nishíníʼeezh pred: neiʼeesh
# ref: ndeizhʼeezh pred: neiʼeesh
# ref: ndajizhʼeezh pred: neiʼeesh
# ref: ndadiitʼish pred: neiʼeesh
# ref: ndeeshʼish pred: neiʼeesh
# ref: ndadoohʼish pred: neiʼeesh
# ref: ndííʼish pred: neiʼeesh
# ref: ndeidooʼish pred: neiʼeesh
# ref: neidooʼish pred: neiʼeesh
# ref: ndazhdooʼish pred: neiʼeesh
# ref: nizhdooʼish pred: neiʼeesh
# ref: nizhdooʼish pred: neiʼeesh
# ref: daneedǫ́ǫ́z pred: noodǫ́ǫ́z
# ref: niidǫ́ǫ́z pred: noodǫ́ǫ́z
# ref: neesdǫ́ǫ́z pred: noodǫ́ǫ́z
# ref: danisoohdǫ́ǫ́z pred: noodǫ́ǫ́z
# ref: noohdǫ́ǫ́z pred: noodǫ́ǫ́z
# ref: níínídǫ́ǫ́z pred: noodǫ́ǫ́z
# ref: daneesdǫ́ǫ́z pred: noodǫ́ǫ́z
# noodǫ́ǫ́z noodǫ́ǫ́z
# noodǫ́ǫ́z noodǫ́ǫ́z
# ref: dazhneesdǫ́ǫ́z pred: noodǫ́ǫ́z
# ref: jinoodǫ́ǫ́z pred: noodǫ́ǫ́z
# ref: jinoodǫ́ǫ́z pred: noodǫ́ǫ́z
# deiichʼid deiichʼid
# ref: yishchʼid pred: yichʼid
# ref: daahchʼid pred: deiichʼid
# ref: wohchʼid pred: yichʼid
# ref: deichʼid pred: yichʼid
# yichʼid yichʼid
# yichʼid yichʼid
# ref: dajichʼid pred: jichʼid
# jichʼid jichʼid
# ref: yíchʼid pred: yichʼid
# ref: daoochʼid pred: deiichʼid
# ref: woochʼid pred: yichʼid
# ref: yíníchʼid pred: yichʼid
# ref: dayííchʼid pred: yichʼid
# ref: yiyííchʼid pred: yichʼid
# ref: jííchʼid pred: jichʼid
# ref: dadiichʼił pred: doochʼid
# ref: diichʼił pred: doochʼid
# ref: doohchʼił pred: doochʼid
# ref: dííchʼił pred: doochʼid
# ref: deidoochʼił pred: deiichʼid
# ref: yidoochʼił pred: yishchʼid
# ref: jidoochʼił pred: jichʼid
# ref: dadiitsʼį́į́h pred: yidiitsʼį́į́h
# ref: diitsʼį́į́h pred: yidiitsʼį́į́h
# ref: diistsʼį́į́h pred: yidiitsʼį́į́h
# ref: doohtsʼį́į́h pred: yidiitsʼį́į́h
# ref: diitsʼį́į́h pred: yidiitsʼį́į́h
# yidiitsʼį́į́h yidiitsʼį́į́h
# ref: dazhdiitsʼį́į́h pred: jidiitsʼį́į́h
# ref: dadisiitsʼą́ą́ʼ pred: yidiitsʼį́į́h
# ref: disiitsʼą́ą́ʼ pred: yidiitsʼį́į́h
# ref: disétsʼą́ą́ʼ pred: yidiitsʼį́į́h
# ref: disootsʼą́ą́ʼ pred: yidiitsʼį́į́h
# ref: disínítsʼą́ą́ʼ pred: yidiitsʼį́į́h
# ref: deidiiztsʼą́ą́ʼ pred: yidiitsʼį́į́h
# ref: yidiiztsʼą́ą́ʼ pred: yidiitsʼį́į́h
# ref: dazdiiztsʼą́ą́ʼ pred: jidiitsʼį́į́h
# ref: jidiiztsʼą́ą́ʼ pred: jidiitsʼį́į́h
# ref: jidiiztsʼą́ą́ʼ pred: jidiitsʼį́į́h
# ref: dadidiitsʼį́į́ł pred: diitsʼį́į́h
# ref: dideestsʼį́į́ł pred: diitsʼį́į́h
# ref: dadidoohtsʼį́į́ł pred: diitsʼį́į́h
# ref: didoohtsʼį́į́ł pred: diitsʼį́į́h
# ref: deididootsʼį́į́ł pred: yidiitsʼį́į́h
# ref: dazhdidootsʼį́į́ł pred: jidiitsʼį́į́h
# deiigeeh deiigeeh
# ref: yishgeeh pred: yigeeh
# ref: daahgeeh pred: deiigeeh
# ref: nigeeh pred: yigeeh
# ref: daageeh pred: yigeeh
# yigeeh yigeeh
# yigeeh yigeeh
# ref: dajigeeh pred: jigeeh
# jigeeh jigeeh
# ref: dasiigoʼ pred: deiigeeh
# ref: yiigoʼ pred: yigeeh
# ref: dasoogoʼ pred: deiigeeh
# ref: woogoʼ pred: yigeeh
# ref: yígoʼ pred: yigeeh
# ref: yígoʼ pred: yigeeh
# ref: deeshgoh pred: deiigeeh
# ref: dadoohgoh pred: deiigeeh
# ref: dadoogoh pred: deiigeeh
# ref: doogoh pred: yigeeh
# ref: dazhdoogoh pred: jigeeh
# ref: jidoogoh pred: jigeeh
# ref: jidoogoh pred: jigeeh
# ref: yiikááh pred: deiighááh
# ref: yishááh pred: yighááh
# ref: wohkááh pred: deiighááh
# ref: wohʼaash pred: deiighááh
# ref: ninááh pred: yighááh
# yighááh yighááh
# yighááh yighááh
# ref: jiʼaash pred: jighááh
# jighááh jighááh
# ref: yiikai pred: deiighááh
# ref: yiitʼáázh pred: yighááh
# ref: yíyá pred: yighááh
# ref: woohkai pred: deiighááh
# ref: yíʼáázh pred: yighááh
# ref: jííʼáázh pred: jighááh
# ref: jííyá pred: jighááh
# ref: diikah pred: deiighááh
# ref: diitʼash pred: dooghááh
# ref: doohkah pred: dooghááh
# ref: doogááł pred: yighááh
# ref: doogááł pred: yighááh
# ref: jidoogááł pred: jighááh
# ref: jidoogááł pred: jighááh
# ref: deíníigeeh pred: deiigoh
# ref: yiigoh pred: deiigoh
# ref: yishgoh pred: yigoh
# ref: deínóhgeeh pred: deiigoh
# ref: wohgoh pred: deiigoh
# ref: yígoh pred: yising
# ref: deígeeh pred: yigoh
# yigoh yigoh
# yigoh yigoh
# ref: dajígeeh pred: jigoh
# ref: joogoh pred: jigoh
# ref: joogoh pred: jigoh
# deiijeeh deiijeeh
# ref: yiijeeh pred: yijeeh
# ref: yishjeeh pred: yijeeh
# ref: daahjeeh pred: deiijeeh
# ref: wohjeeh pred: jijeeh
# yijeeh yijeeh
# yijeeh yijeeh
# jijeeh jijeeh
# jijeeh jijeeh
# ref: shiijééʼ pred: yijeeh
# ref: shéjééʼ pred: yijeeh
# ref: dashoojééʼ pred: deiijeeh
# ref: shoojééʼ pred: deiijeeh
# ref: yizhjééʼ pred: yijeeh
# ref: yizhjééʼ pred: yijeeh
# ref: jizhjééʼ pred: jijeeh
# ref: dadiijah pred: deiijeeh
# ref: diijah pred: deiijeeh
# ref: deeshjah pred: deiijeeh
# ref: dadoojah pred: deiijeeh
# ref: dííjah pred: deiijeeh
# ref: dazhdoojah pred: jijeeh
# ref: jidoojah pred: jijeeh
# ref: deíníijį́į́h pred: yijį́į́ł
# ref: yiijį́į́ł pred: yijį́į́ł
# ref: yishjį́į́ł pred: yijį́į́ł
# ref: deínóhjį́į́h pred: yijį́į́ł
# ref: wohjį́į́ł pred: yijį́į́ł
# ref: yíjį́į́ł pred: yijį́į́ł
# ref: deíjį́į́h pred: yijį́į́ł
# yijį́į́ł yijį́į́ł
# yijį́į́ł yijį́į́ł
# ref: dajíjį́į́h pred: jijį́į́ł
# ref: joojį́į́ł pred: jijį́į́ł
# ref: joojį́į́ł pred: jį́į́ł
# ref: deíníiltłʼééh pred: deiiltłʼééł
# ref: yiiltłʼééł pred: yiltłʼééł
# ref: yishtłʼééł pred: yiltłʼééł
# ref: deínółtłʼééh pred: deiiltłʼééł
# ref: wołtłʼééł pred: yiltłʼééł
# ref: yíltłʼééł pred: yiltłʼééł
# ref: deíltłʼééh pred: yiltłʼééł
# yiltłʼééł yiltłʼééł
# yiltłʼééł yiltłʼééł
# ref: dajíltłʼééh pred: jiltłʼééł
# ref: jooltłʼééł pred: jiltłʼééł
# ref: jooltłʼééł pred: jiltłʼééł
# yiilʼaah yiilʼaah
# ref: yishʼaah pred: yisilʼaah
# ref: daałʼaah pred: deiilʼaah
# ref: wołʼaah pred: deiilʼaah
# ref: nilʼaah pred: yisilʼaah
# ref: deilʼaah pred: yiilʼaah
# ref: yilʼaah pred: yiilʼaah
# ref: dajilʼaah pred: jilʼaah
# ref: jilʼaah pred: jíílʼaah
# jilʼaah jilʼaah
# ref: deiilʼaad pred: deiilʼaah
# ref: yiilʼaad pred: yiilʼaah
# ref: daoołʼaad pred: deiilʼaah
# ref: woołʼaad pred: deiilʼaah
# ref: yínílʼaad pred: yisilʼaah
# ref: dayoolʼaad pred: yiilʼaah
# ref: yoolʼaad pred: yiilʼaah
# ref: joolʼaad pred: jíílʼaah
# ref: deeshʼaał pred: deiilʼaah
# ref: doołʼaał pred: deiilʼaah
# ref: deidoolʼaał pred: deiilʼaah
# ref: jidoolʼaał pred: jíílʼaah
# ref: deiilzhood pred: yishood
# ref: yiilzhood pred: yishood
# yishood yishood
# ref: daahshood pred: yishood
# ref: wohshood pred: yishood
# ref: nishood pred: yishood
# ref: deishood pred: yishood
# yishood yishood
# yishood yishood
# ref: dajishood pred: jishood
# jishood jishood
# jishood jishood
# ref: dashiilzhóód pred: yishood
# ref: yiilzhóód pred: yishood
# ref: yíshóód pred: yishood
# ref: dashooshóód pred: yishood
# ref: wooshóód pred: yishood
# ref: yíníshóód pred: yishood
# ref: deishóód pred: yishood
# ref: yiyííshóód pred: yishood
# ref: yiyííshóód pred: yishood
# ref: dajishóód pred: jishood
# ref: jííshóód pred: jishood
# ref: jííshóód pred: jishood
# ref: deiilzhóósh pred: yishóósh
# ref: yiilzhóósh pred: yishóósh
# yishóósh yishóósh
# ref: daahshóósh pred: yishóósh
# ref: wohshóósh pred: yishóósh
# ref: nishóósh pred: yishóósh
# ref: deishóósh pred: yishóósh
# yishóósh yishóósh
# yishóósh yishóósh
# ref: dajishóósh pred: jishóósh
# jishóósh jishóósh
# jishóósh jishóósh
# ref: deiilzhoozh pred: yishóósh
# ref: yiilzhoozh pred: yishóósh
# ref: yíshoozh pred: yishóósh
# ref: daooshoozh pred: yishóósh
# ref: wooshoozh pred: yishóósh
# ref: yíníshoozh pred: yishóósh
# ref: dayííshoozh pred: yishóósh
# ref: yiyííshoozh pred: yishóósh
# ref: yiyííshoozh pred: yishóósh
# ref: dajííshoozh pred: jishóósh
# ref: jííshoozh pred: jishóósh
# ref: jííshoozh pred: jishóósh
# deiitłeeh deiitłeeh
# ref: yiitłeeh pred: yitłeeh
# ref: yishtłeeh pred: yitłeeh
# ref: daahtłeeh pred: deiitłeeh
# ref: wohtłeeh pred: yitłeeh
# ref: nitłeeh pred: yitłeeh
# ref: deitłeeh pred: yitłeeh
# yitłeeh yitłeeh
# yitłeeh yitłeeh
# ref: dajitłeeh pred: jitłeeh
# jitłeeh jitłeeh
# jitłeeh jitłeeh
# ref: dasiitłééʼ pred: deiitłeeh
# ref: yiitłééʼ pred: yitłeeh
# ref: yítłééʼ pred: yitłeeh
# ref: dasootłééʼ pred: deiitłeeh
# ...
# ref: nijiztłééʼ pred: nijitłį́
# ref: ndadiitłoh pred: ndadiitłih
# ref: ndiitłoh pred: ndiitłih
# ref: ndoohtłoh pred: ndoohtłih
# ref: ndíítłoh pred: ndíítłih
# ref: ndeidootłoh pred: ndadootłih
# ref: ndazhdootłoh pred: ndazhdootłih
# ref: nizhdootłoh pred: nizhdootłih
# ref: nizhdootłoh pred: nizhdootłih
# ref: ndeiilbąąs pred: nideiilbąąs
# ref: ndeiłbąąs pred: nideiłbąąs
# neiłbąąs neiłbąąs
# ref: njiłbąąs pred: nijiłbąąs
# ref: ndasiilbą́ą́z pred: nidasiilbą́ą́z
# ref: nisiilbą́ą́z pred: niilbą́ą́z
# niséłbą́ą́z niséłbą́ą́z
# ref: ndasoołbą́ą́z pred: nidasoołbą́ą́z
# nisoołbą́ą́z nisoołbą́ą́z
# nisíníłbą́ą́z nisíníłbą́ą́z
# ref: ndeisbą́ą́z pred: nidaałbą́ą́z
# neisbą́ą́z neisbą́ą́z
# neisbą́ą́z neisbą́ą́z
# ref: ndajisbą́ą́z pred: nidajisbą́ą́z
# ref: njisbą́ą́z pred: nijisbą́ą́z
# ref: ndiilbąs pred: ndiilbą́ą́z
# ref: ndadoołbąs pred: ndadoołbą́ą́z
# ref: ndoołbąs pred: ndoołbą́ą́z
# ref: neidoołbąs pred: ndoołbą́ą́z
# ref: neidoołbąs pred: ndoołbą́ą́z
# ref: ndazhdoołbąs pred: ndazhdoołbą́ą́z
# ref: nizhdoołbąs pred: nizhdoołbą́ą́z
# ref: nizhdoołbąs pred: nizhdoołbą́ą́z
# nidaałgizh nidaałgizh
# naałgizh naałgizh
# neiłgizh neiłgizh
# neiłgizh neiłgizh
# nidajiłgizh nidajiłgizh
# nijiłgizh nijiłgizh
# ref: nishiilgizh pred: niilgizh
# nishéłgizh nishéłgizh
# nidashoołgizh nidashoołgizh
# nishoołgizh nishoołgizh
# nishíníłgizh nishíníłgizh
# ref: nideishgizh pred: nidaałgizh
# neishgizh neishgizh
# nijishgizh nijishgizh
# ref: ndadiilgish pred: ndadiilgizh
# ref: ndiilgish pred: ndiilgizh
# ref: ndadoołgish pred: ndadoołgizh
# ref: ndoołgish pred: ndoołgizh
# ref: ndííłgish pred: ndííłgizh
# ref: ndeidoołgish pred: ndadoołgizh
# ref: neidoołgish pred: ndoołgizh
# ref: ndazhdoołgish pred: ndazhdoołgizh
# ref: nizhdoołgish pred: nizhdoołgizh
# ref: naasmaas pred: nishłmaas
# ref: ndaałmaas pred: nidaałmaas
# ref: naniłmaas pred: niłmaas
# ndeiłmaas ndeiłmaas
# neiłmaas neiłmaas
# neiłmaas neiłmaas
# ref: njiłmaas pred: nijiłmaas
# ref: njiłmaas pred: nijiłmaas
# ref: nisiilmááz pred: niilmaaz
# ref: ndasoołmááz pred: nidasoołmaaz
# ref: nisoołmááz pred: nisoołmaaz
# ref: nisíníłmááz pred: nisíníłmaaz
# ref: ndeismááz pred: nideismaaz
# ref: neismááz pred: neismaaz
# ref: neismááz pred: neismaaz
# ref: ndajismááz pred: nidajismaaz
# ndadiilmas ndadiilmas
# ndiilmas ndiilmas
# ndadoołmas ndadoołmas
# ndííłmas ndííłmas
# ref: ndeidoołmas pred: ndadoołmas
# ref: neidoołmas pred: ndoołmas
# nizhdoołmas nizhdoołmas
# ref: ndeiiltseed pred: nideiiltseed
# ref: neiiltseed pred: niiltseed
# ref: ndaałtseed pred: nidaałtseed
# ref: naałtseed pred: nisoołtseed
# ref: njiłtseed pred: nijiłtseed
# ref: njiłtseed pred: nijiłtseed
# ref: ndasiiltseed pred: nidasiiltsid
# ref: nisiiltseed pred: niiltsid
# ref: niséłtseed pred: niséłtsééd
# ref: ndasoołtseed pred: nidasoołtsid
# ref: ndeistseed pred: nidaałtsid
# ref: neistseed pred: neistsid
# ref: neistseed pred: neistsid
# ref: ndajistseed pred: nidajistsid
# ref: njistseed pred: nijistsid
# ndadiiltsił ndadiiltsił
# ndiiltsił ndiiltsił
# ref: ndeestsił pred: ndeeshtsił
# ndadoołtsił ndadoołtsił
# ndííłtsił ndííłtsił
# ref: neidoołtsił pred: ndoołtsił
# ref: neidoołtsił pred: ndoołtsił
# nizhdoołtsił nizhdoołtsił
# ref: ndeiiltʼiʼ pred: nideiiltʼiʼ
# ref: neiiltʼiʼ pred: niiltʼiʼ
# ref: ndaałtʼiʼ pred: nidaałtʼiʼ
# ndeiłtʼiʼ ndeiłtʼiʼ
# neiłtʼiʼ neiłtʼiʼ
# neiłtʼiʼ neiłtʼiʼ
# ref: njiłtʼiʼ pred: nijiłtʼiʼ
# ref: ndasiiltʼiʼ pred: nidasiiltʼiʼ
# niséłtʼiʼ niséłtʼiʼ
# ref: ndasoołtʼiʼ pred: nidasoołtʼiʼ
# nisoołtʼiʼ nisoołtʼiʼ
# nisíníłtʼiʼ nisíníłtʼiʼ
# neistʼiʼ neistʼiʼ
# ref: njistʼiʼ pred: nijistʼiʼ
# ref: njistʼiʼ pred: nijiłtʼiʼ
# ref: ndadiiltʼih pred: ndadiiltʼił
# ref: ndiiltʼih pred: ndiiltʼił
# ref: ndeeshtʼih pred: ndeeshtʼił
# ref: ndoołtʼih pred: ndoołtʼił
# ref: ndííłtʼih pred: ndííłtʼił
# ref: neidoołtʼih pred: ndoołtʼił
# ref: nizhdoołtʼih pred: nizhdoołtʼił
# ref: nizhdoołtʼih pred: nizhdoołtʼił
# ref: neiitʼeesh pred: niiʼeesh
# ref: naashʼeesh pred: nishʼeesh
# ref: ndaahʼeesh pred: nidaahʼeesh
# naahʼeesh naahʼeesh
# ref: naniʼeesh pred: niniʼeesh
# neiʼeesh neiʼeesh
# ref: njiʼeesh pred: nijiʼeesh
# ref: nishiitʼeezh pred: niitʼéézh
# ref: nishéʼeezh pred: nishʼéézh
# ref: ndashooʼeezh pred: nidashooʼéézh
# ref: nishooʼeezh pred: nishooʼéézh
# ref: nishíníʼeezh pred: nishíníʼéézh
# ref: ndeizhʼeezh pred: nidaashʼéézh
# ref: ndajizhʼeezh pred: nidajizhʼéézh
# ndadiitʼish ndadiitʼish
# ref: ndeeshʼish pred: ndeeshʼosh
# ndadoohʼish ndadoohʼish
# ref: ndííʼish pred: ndííʼééł
# ref: ndeidooʼish pred: ndadooʼosh
# ref: neidooʼish pred: ndooʼosh
# ndazhdooʼish ndazhdooʼish
# ref: nizhdooʼish pred: nizhdooʼosh
# ref: nizhdooʼish pred: nizhdooʼosh
# ref: daneedǫ́ǫ́z pred: nidasiidǫ́ǫ́z
# niidǫ́ǫ́z niidǫ́ǫ́z
# ref: neesdǫ́ǫ́z pred: nisédǫ́ǫ́z
# ref: danisoohdǫ́ǫ́z pred: nidasoodǫ́ǫ́z
# ref: noohdǫ́ǫ́z pred: noodǫ́ǫ́z
# ref: níínídǫ́ǫ́z pred: noodǫ́ǫ́z
# ref: daneesdǫ́ǫ́z pred: nideidǫ́ǫ́z
# noodǫ́ǫ́z noodǫ́ǫ́z
# noodǫ́ǫ́z noodǫ́ǫ́z
# ref: dazhneesdǫ́ǫ́z pred: dajídǫ́ǫ́z
# ref: jinoodǫ́ǫ́z pred: nijidǫ́ǫ́z
# ref: jinoodǫ́ǫ́z pred: nijidǫ́ǫ́z
# deiichʼid deiichʼid
# yishchʼid yishchʼid
# daahchʼid daahchʼid
# wohchʼid wohchʼid
# deichʼid deichʼid
# yichʼid yichʼid
# yichʼid yichʼid
# dajichʼid dajichʼid
# jichʼid jichʼid
# yíchʼid yíchʼid
# ref: daoochʼid pred: dashoochʼid
# woochʼid woochʼid
# ref: yíníchʼid pred: shíníchʼid
# dayííchʼid dayííchʼid
# yiyííchʼid yiyííchʼid
# ref: jííchʼid pred: joochʼid
# dadiichʼił dadiichʼił
# diichʼił diichʼił
# doohchʼił doohchʼił
# dííchʼił dííchʼił
# ref: deidoochʼił pred: dadoochʼił
# ref: yidoochʼił pred: doochʼił
# jidoochʼił jidoochʼił
# ref: dadiitsʼį́į́h pred: deiitsʼį́į́h
# diitsʼį́į́h diitsʼį́į́h
# ref: diistsʼį́į́h pred: deistsʼį́į́h
# ref: doohtsʼį́į́h pred: wohtsʼį́į́h
# ref: diitsʼį́į́h pred: nidiitsʼį́į́h
# ref: yidiitsʼį́į́h pred: diitsʼį́į́h
# ref: dazhdiitsʼį́į́h pred: dajidiitsʼį́į́h
# ref: dadisiitsʼą́ą́ʼ pred: dadiitsʼį́į́ʼ
# ref: disiitsʼą́ą́ʼ pred: diitsʼį́į́ʼ
# ref: disétsʼą́ą́ʼ pred: díítsʼį́į́ʼ
# ref: disootsʼą́ą́ʼ pred: doohtsʼį́į́ʼ
# ref: disínítsʼą́ą́ʼ pred: díítsʼį́į́ʼ
# ref: deidiiztsʼą́ą́ʼ pred: dadiitsʼį́į́ʼ
# ref: yidiiztsʼą́ą́ʼ pred: yidiitsʼį́į́ʼ
# ref: dazdiiztsʼą́ą́ʼ pred: dajíítsʼį́į́ʼ
# ref: jidiiztsʼą́ą́ʼ pred: jidiitsʼį́į́ʼ
# ref: jidiiztsʼą́ą́ʼ pred: jíítsʼį́į́ʼ
# ref: dadidiitsʼį́į́ł pred: dadiitsʼį́į́ł
# ref: dideestsʼį́į́ł pred: deeshtsʼį́į́ł
# ref: dadidoohtsʼį́į́ł pred: dadoohtsʼį́į́ł
# ref: didoohtsʼį́į́ł pred: doohtsʼį́į́ł
# ref: deididootsʼį́į́ł pred: dadidootsʼį́į́ł
# ref: dazhdidootsʼį́į́ł pred: dazhdootsʼį́į́ł
# deiigeeh deiigeeh
# yishgeeh yishgeeh
# daahgeeh daahgeeh
# nigeeh nigeeh
# ref: daageeh pred: deigeeh
# yigeeh yigeeh
# yigeeh yigeeh
# dajigeeh dajigeeh
# jigeeh jigeeh
# ref: dasiigoʼ pred: dasiigeeʼ
# ref: yiigoʼ pred: yiigeeʼ
# ref: dasoogoʼ pred: dasoogeeʼ
# ref: woogoʼ pred: woogeeʼ
# ref: yígoʼ pred: yiyíígeeʼ
# ref: yígoʼ pred: yiyíígeeʼ
# ref: deeshgoh pred: deeshgih
# ref: dadoohgoh pred: dadoohgih
# ref: dadoogoh pred: dadoogih
# ref: doogoh pred: doogih
# ref: dazhdoogoh pred: dazhdoogih
# ref: jidoogoh pred: jidoogih
# ref: jidoogoh pred: jidoogih
# ref: yiikááh pred: deiigááh
# ref: yishááh pred: yishhááh
# ref: wohkááh pred: daahghááh
# ref: wohʼaash pred: wohhááh
# ref: ninááh pred: nighááh
# yighááh yighááh
# yighááh yighááh
# ref: jiʼaash pred: dajighááh
# jighááh jighááh
# ref: yiikai pred: dasiigááʼ
# ref: yiitʼáázh pred: yiigááʼ
# ref: yíyá pred: yíghááʼ
# ref: woohkai pred: dasoogááʼ
# ref: yíʼáázh pred: dayííghááʼ
# ref: jííʼáázh pred: dajííghááʼ
# ref: jííyá pred: jííghááʼ
# ref: diikah pred: dadiighaał
# ref: diitʼash pred: diigááł
# ref: doohkah pred: dadoohgah
# ref: doogááł pred: dooghaał
# ref: doogááł pred: dooghaał
# ref: jidoogááł pred: jidooghaał
# jidoogááł jidoogááł
# ref: deíníigeeh pred: deiigoh
# yiigoh yiigoh
# ref: yishgoh pred: yígoʼ
# ref: deínóhgeeh pred: dasoogoh
# ref: wohgoh pred: woogoh
# ref: yígoh pred: sínígoh
# ref: deígeeh pred: dayíígoh
# ref: yigoh pred: yiyíígoh
# ref: yigoh pred: yiyíígoh
# ref: dajígeeh pred: dajizgoh
# joogoh joogoh
# ref: joogoh pred: jíígoh
# deiijeeh deiijeeh
# yiijeeh yiijeeh
# yishjeeh yishjeeh
# daahjeeh daahjeeh
# wohjeeh wohjeeh
# yijeeh yijeeh
# yijeeh yijeeh
# jijeeh jijeeh
# jijeeh jijeeh
# ref: shiijééʼ pred: yiiją́
# ref: shéjééʼ pred: yíjííją́
# ref: dashoojééʼ pred: dasoojiʼ
# ref: shoojééʼ pred: wooją́
# ref: yizhjééʼ pred: yiyííjééʼ
# ref: yizhjééʼ pred: yiyííjééʼ
# ref: jizhjééʼ pred: jíjííją́
# ref: dadiijah pred: dadiijih
# ref: diijah pred: diiljih
# ref: deeshjah pred: deeshjih
# ref: dadoojah pred: dadoohjih
# ref: dííjah pred: dííjih
# ref: dazhdoojah pred: dazhdoojih
# ref: jidoojah pred: jidoojih
# ref: deíníijį́į́h pred: deiijį́į́l
# yiijį́į́ł yiijį́į́ł
# ref: yishjį́į́ł pred: yíjį́į́ł
# ref: deínóhjį́į́h pred: dasoojį́į́ł
# ref: wohjį́į́ł pred: woojį́į́ł
# ref: yíjį́į́ł pred: níjį́į́ł
# ref: deíjį́į́h pred: dayííjį́į́ł
# yijį́į́ł yijį́į́ł
# yijį́į́ł yijį́į́ł
# ref: dajíjį́į́h pred: dajijį́į́ł
# ref: joojį́į́ł pred: jijį́į́ł
# ref: joojį́į́ł pred: jijį́į́ł
# ref: deíníiltłʼééh pred: dasiiltłʼiil
# yiiltłʼééł yiiltłʼééł
# ref: yishtłʼééł pred: yíltłʼééł
# ref: deínółtłʼééh pred: dasoołtłʼiil
# ref: wołtłʼééł pred: woołtłʼééł
# ref: yíltłʼééł pred: síníltłʼééł
# ref: deíltłʼééh pred: dayííltłʼééł
# yiltłʼééł yiltłʼééł
# yiltłʼééł yiltłʼééł
# ref: dajíltłʼééh pred: dajistłʼiil
# jooltłʼééł jooltłʼééł
# ref: jooltłʼééł pred: jííltłʼééł
# yiilʼaah yiilʼaah
# yishʼaah yishʼaah
# ref: daałʼaah pred: daahłʼaah
# wołʼaah wołʼaah
# nilʼaah nilʼaah
# deilʼaah deilʼaah
# yilʼaah yilʼaah
# dajilʼaah dajilʼaah
# jilʼaah jilʼaah
# jilʼaah jilʼaah
# ref: deiilʼaad pred: dasiilʼaaʼ
# ref: yiilʼaad pred: yiilʼaaʼ
# ref: daoołʼaad pred: dasoołʼaaʼ
# ref: woołʼaad pred: woołʼaaʼ
# ref: yínílʼaad pred: sínílʼááʼ
# ref: dayoolʼaad pred: dayíílʼááʼ
# ref: yoolʼaad pred: yiyíílʼaaʼ
# ref: joolʼaad pred: jíílʼááʼ
# ref: deeshʼaał pred: deeshʼah
# doołʼaał doołʼaał
# ref: deidoolʼaał pred: dadoolʼaał
# jidoolʼaał jidoolʼaał
# deiilzhood deiilzhood
# yiilzhood yiilzhood
# yishood yishood
# daahshood daahshood
# wohshood wohshood
# nishood nishood
# deishood deishood
# yishood yishood
# yishood yishood
# dajishood dajishood
# jishood jishood
# jishood jishood
# ref: dashiilzhóód pred: deiilzhood
# ref: yiilzhóód pred: yiilzhood
# ref: yíshóód pred: yíshood
# ref: dashooshóód pred: dashooshood
# ref: wooshóód pred: wooshood
# ref: yíníshóód pred: shíníshood
# ref: deishóód pred: dayííshood
# ref: yiyííshóód pred: yishood
# ref: yiyííshóód pred: yishood
# ref: dajishóód pred: dajishood
# ref: jííshóód pred: jooshood
# ref: jííshóód pred: jííshood
# deiilzhóósh deiilzhóósh
# yiilzhóósh yiilzhóósh
# yishóósh yishóósh
# daahshóósh daahshóósh
# wohshóósh wohshóósh
# nishóósh nishóósh
# deishóósh deishóósh
# yishóósh yishóósh
# yishóósh yishóósh
# dajishóósh dajishóósh
# jishóósh jishóósh
# jishóósh jishóósh
# deiilzhoozh deiilzhoozh
# yiilzhoozh yiilzhoozh
# ref: yíshoozh pred: yíshóózh
# ref: daooshoozh pred: dashooshozh
# wooshoozh wooshoozh
# ref: yíníshoozh pred: yíníshóózh
# ref: dayííshoozh pred: dayííshóózh
# ref: yiyííshoozh pred: yishóózh
# ref: yiyííshoozh pred: yishóózh
# ref: dajííshoozh pred: dajishoozh
# jííshoozh jííshoozh
# ref: jííshoozh pred: jííshóózh
# deiitłeeh deiitłeeh
# yiitłeeh yiitłeeh
# yishtłeeh yishtłeeh
# daahtłeeh daahtłeeh
# wohtłeeh wohtłeeh
# nitłeeh nitłeeh
# deitłeeh deitłeeh
# yitłeeh yitłeeh
# yitłeeh yitłeeh
# dajitłeeh dajitłeeh
# jitłeeh jitłeeh
# jitłeeh jitłeeh
# ref: dasiitłééʼ pred: dasiitłį́į́ʼ
# ref: yiitłééʼ pred: yiitłą́
# ref: yítłééʼ pred: yítłį́į́ʼ
# ref: dasootłééʼ pred: dasootłį́į́ʼ
# ref: wootłééʼ pred: wootłį́
# ref: yínítłééʼ pred: sínítłą́
# ref: deiztłééʼ pred: dayíítłééʼ
# yiyíítłééʼ yiyíítłééʼ
# ref: yiyíítłééʼ pred: yiyíítłą́
# ref: dajiztłééʼ pred: dajíítłį́
# ref: jíítłééʼ pred: jootłį́
# ref: jíítłééʼ pred: jíítłą́
# deiitsʼǫs deiitsʼǫs
# yiitsʼǫs yiitsʼǫs
# ref: daoohtsʼǫs pred: daahootsʼǫs
# ref: yiitsʼǫs pred: niitsʼǫs
# ref: yiyiitsʼǫs pred: yiitsʼǫs
# jiitsʼǫs jiitsʼǫs
# ref: dasootsʼǫs pred: dasootsʼǫz
# ref: sootsʼǫs pred: wootsʼǫ́ǫ́z
# ref: sínítsʼǫs pred: sínítsʼǫ́z
# ref: deiztsʼǫs pred: dayiitsʼǫz
# ref: yiztsʼǫs pred: yiyiitsʼǫz
# ref: yiztsʼǫs pred: yiyiitsʼǫ́z
# ref: dajiztsʼǫs pred: dajiitsʼǫz
# ref: jiztsʼǫs pred: jiitsʼǫ́z
# ref: jiztsʼǫs pred: jiitsʼǫ́z
# ref: dadiitsʼǫs pred: dadiitsʼǫł
# ref: deestsʼǫs pred: deeshtsʼǫł
# ref: doohtsʼǫs pred: doohtsʼǫł
# ref: díítsʼǫs pred: díítsʼǫł
# ref: deidootsʼǫs pred: dadootsʼǫł
# ref: yidootsʼǫs pred: yidootsʼǫł
# ref: dazhdootsʼǫs pred: dazhdootsʼǫł
# ref: jidootsʼǫs pred: jidootsʼǫł
# deiiltsééh deiiltsééh
# yiiltsééh yiiltsééh
# ref: yiistsééh pred: yishłtsééh
# ref: dayoołtsééh pred: daałtsééh
# ref: yiiłtsééh pred: niłtsééh
# deiyiiłtsééh deiyiiłtsééh
# ref: yiyiiłtsééh pred: yiiłtsééh
# ref: yiyiiłtsééh pred: yiiłtsééh
# dajiiłtsééh dajiiłtsééh
# jiiłtsééh jiiłtsééh
# ref: yiiltsą́ pred: yiiltsiʼ
# ref: yiiłtsą́ pred: yíníłtsiʼ
# ref: yoołtsą́ pred: woołtsiʼ
# ref: yiniłtsą́ pred: síníłtsiʼ
# ref: yiyiiłtsą́ pred: yiyiiłtsiʼ
# ref: dajiiłtsą́ pred: dajííłtsééʼ
# ref: jiiłtsą́ pred: jiiłtsiʼ
# ref: jiiłtsą́ pred: jiiłtsiʼ
# ref: deidiiltsééł pred: dadiiltsih
# ref: yideestsééł pred: deeshtsih
# ref: deidoołtsééł pred: dadoołtsih
# ref: yidoołtsééł pred: doołtsih
# ref: deizhdoołtsééł pred: dazhdoołtsih
# deiiltsóóh deiiltsóóh
# yiiltsóóh yiiltsóóh
# ref: yiistsóóh pred: yishłtsóóh
# ref: daoołtsóóh pred: daałtsóóh
# ref: woołtsóóh pred: wołtsóóh
# ref: yiiłtsóóh pred: niłtsóóh
# ref: dayiiłtsóóh pred: deiyiiłtsóóh
# ref: yiyiiłtsóóh pred: yiiłtsóóh
# ref: yiyiiłtsóóh pred: yiiłtsóóh
# dajiiłtsóóh dajiiłtsóóh
# jiiłtsóóh jiiłtsóóh
# jiiłtsóóh jiiłtsóóh
# ref: deiiltsoii pred: deiiltsoʼ
# ref: yiiltsoii pred: yiiltsoʼ
# ref: yiiłtsoii pred: yishtsoʼ
# ref: daoołtsoii pred: dasoołtsoʼ
# ref: woołtsoii pred: woołtsoʼ
# ref: yiniłtsoii pred: síníłtsoʼ
# ref: dayiiłtsoii pred: deiyííłtsoʼ
# ref: yiyiiłtsoii pred: yiyiiłtsoʼ
# ref: yiyiiłtsoii pred: yiyiiłtsoʼ
# ref: dajiiłtsoii pred: dajííłtsoʼ
# ref: jiiłtsoii pred: jiiłtsoʼ
# ref: jiiłtsoii pred: jiiłtsoʼ
# deiilchʼal deiilchʼal
# wołchʼal wołchʼal
# niłchʼal niłchʼal
# yiłchʼal yiłchʼal
# dajiłchʼal dajiłchʼal
# jiłchʼal jiłchʼal
# deiilchʼal deiilchʼal
# yíłchʼal yíłchʼal
# ref: daoołchʼal pred: dasoołchʼal
# woołchʼal woołchʼal
# ref: yíníłchʼal pred: shíníłchʼal
# yiyííłchʼal yiyííłchʼal
# yiyííłchʼal yiyííłchʼal
# dajííłchʼal dajííłchʼal
# ref: jííłchʼal pred: joołchʼal
# jííłchʼal jííłchʼal
# deeshchʼał deeshchʼał
# ref: deidoołchʼał pred: dadoołchʼał
# ref: yidoołchʼał pred: doołchʼał
# ref: yidoołchʼał pred: doołchʼał
# dazhdoołchʼał dazhdoołchʼał
# jidoołchʼał jidoołchʼał
# jidoołchʼał jidoołchʼał
# deiildin deiildin
# yiildin yiildin
# yishdin yishdin
# daałdin daałdin
# wołdin wołdin
# niłdin niłdin
# deiłdin deiłdin
# yiłdin yiłdin
# yiłdin yiłdin
# dajiłdin dajiłdin
# jiłdin jiłdin
# jiłdin jiłdin
# dasiildin dasiildin
# ref: siildin pred: yiildin
# ref: séłdin pred: yíłdin
# dasoołdin dasoołdin
# ref: soołdin pred: wołdin
# síníłdin síníłdin
# ref: deisdin pred: dayííłdin
# ref: yisdin pred: yiłdin
# ref: dajisdin pred: dajííłdin
# ref: jisdin pred: jííłdin
# ref: jisdin pred: jííłdin
# deiilghaał deiilghaał
# yiilghaał yiilghaał
# yishhaał yishhaał
# daałhaał daałhaał
# wołhaał wołhaał
# niłhaał niłhaał
# deiłhaał deiłhaał
# yiłhaał yiłhaał
# yiłhaał yiłhaał
# dajiłhaał dajiłhaał
# jiłhaał jiłhaał
# jiłhaał jiłhaał
# deiilghaal deiilghaal
# yiilghaal yiilghaal
# yíłhaal yíłhaal
# ref: daoołhaal pred: dasoołhaal
# woołhaal woołhaal
# ref: yíníłhaal pred: síníłhaal
# dayííłhaal dayííłhaal
# ref: yiyííłhaal pred: yiłhaal
# yiyííłhaal yiyííłhaal
# dajííłhaal dajííłhaal
# jííłhaal jííłhaal
# jííłhaal jííłhaal
# deiilnaad deiilnaad
# yiilnaad yiilnaad
# yishnaad yishnaad
# niłnaad niłnaad
# yiłnaad yiłnaad
# dajiłnaad dajiłnaad
# jiłnaad jiłnaad
# jiłnaad jiłnaad
# ref: deiilnáád pred: dasiilnaad
# ref: yiilnáád pred: yiilnaad
# yíłnáád yíłnáád
# ref: yíníłnáád pred: síníłnáád
# dayííłnáád dayííłnáád
# yiyííłnáád yiyííłnáád
# dajííłnáád dajííłnáád
# jííłnáád jííłnáád
# jííłnáád jííłnáád
# diilnał diilnał
# ref: deeshnał pred: deeshnáł
# doołnał doołnał
# ref: deidoołnał pred: dadoołnał
# jidoołnał jidoołnał
# deiilneʼ deiilneʼ
# yiilneʼ yiilneʼ
# yishneʼ yishneʼ
# daałneʼ daałneʼ
# wołneʼ wołneʼ
# niłneʼ niłneʼ
# deiłneʼ deiłneʼ
# yiłneʼ yiłneʼ
# yiłneʼ yiłneʼ
# dajiłneʼ dajiłneʼ
# jiłneʼ jiłneʼ
# jiłneʼ jiłneʼ
# ref: deiilneʼ pred: dasiilneʼ
# yiilneʼ yiilneʼ
# yíłneʼ yíłneʼ
# ref: daoołneʼ pred: dasoołneʼ
# woołneʼ woołneʼ
# ref: yíníłneʼ pred: síníłneʼ
# dayííłneʼ dayííłneʼ
# yiyííłneʼ yiyííłneʼ
# yiyííłneʼ yiyííłneʼ
# dajííłneʼ dajííłneʼ
# jííłneʼ jííłneʼ
# jííłneʼ jííłneʼ
# deiiltin deiiltin
# yiiltin yiiltin
# yishtin yishtin
# daałtin daałtin
# wołtin wołtin
# niłtin niłtin
# deiłtin deiłtin
# yiłtin yiłtin
# yiłtin yiłtin
# dajiłtin dajiłtin
# jiłtin jiłtin
# jiłtin jiłtin
# ref: dasiiltin pred: deiiltin
# ref: siiltin pred: yiiltin
# ref: séłtin pred: yíłtin
# dasoołtin dasoołtin
# ref: soołtin pred: wołtin
# síníłtin síníłtin
# ref: deistin pred: dayííłtin

# %%
# %cd /dss/dsshome1/03/ge87wod2/morphological-inflection/ByT5/
# Out:
# /dss/dsshome1/03/ge87wod2/morphological-inflection/ByT5
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
