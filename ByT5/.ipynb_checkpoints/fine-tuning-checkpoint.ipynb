# %% [markdown]
# # Setup

# %%
# %cd /dss/dsshome1/03/ge87wod2/morphological-inflection/ByT5/
import sys
print(sys.version)
# !python3 --version
# Out:
# /dss/dsshome1/03/ge87wod2/morphological-inflection/ByT5
# 3.10.12 (main, Jul 29 2024, 16:56:48) [GCC 11.4.0]
# Python 3.10.12
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# works
# !pip uninstall transformers -y
#!pip uninstall -y torch torchvision
#!pip install torch torchvision --index-url https://download.pytorch.org/whl/cu120
#!pip install torch torchvision --index-url https://download.pytorch.org/whl/cu130
# !pip install transformers==4.36.2  datasets==4.3.0 accelerate==0.27.2
#!pip install transformers --upgrade
# !pip install torch==2.9.1
# !pip install ipywidgets==8.1.7
# !pip install python-dotenv==1.2.1 pickleshare==0.7.5
# Out:
# Found existing installation: transformers 4.57.3
# Uninstalling transformers-4.57.3:
#   Successfully uninstalled transformers-4.57.3
# Collecting transformers==4.36.2
#   Using cached transformers-4.36.2-py3-none-any.whl.metadata (126 kB)
# Requirement already satisfied: datasets==4.3.0 in /usr/local/lib/python3.10/dist-packages (4.3.0)
# Requirement already satisfied: accelerate==0.27.2 in /usr/local/lib/python3.10/dist-packages (0.27.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.2) (3.20.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.2) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.2) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.2) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.2) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.2) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.2) (2.32.3)
# Collecting tokenizers<0.19,>=0.14 (from transformers==4.36.2)
#   Using cached tokenizers-0.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.2) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.36.2) (4.67.1)
# Requirement already satisfied: pyarrow>=21.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets==4.3.0) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets==4.3.0) (0.4.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets==4.3.0) (2.2.1)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets==4.3.0) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets==4.3.0) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets==4.3.0) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets==4.3.0) (2024.5.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.27.2) (5.9.8)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.27.2) (2.9.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets==4.3.0) (3.9.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1.0.0->datasets==4.3.0) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1.0.0->datasets==4.3.0) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1.0.0->datasets==4.3.0) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<1.0.0->datasets==4.3.0) (3.7)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets==4.3.0) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.36.2) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.36.2) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.36.2) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.36.2) (2.0.7)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.27.2) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.27.2) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.27.2) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.27.2) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.27.2) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.27.2) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.27.2) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.27.2) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.27.2) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.27.2) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.27.2) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.27.2) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.27.2) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.27.2) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.27.2) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.27.2) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.27.2) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.27.2) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.27.2) (3.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==4.3.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==4.3.0) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==4.3.0) (2024.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets==4.3.0) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets==4.3.0) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets==4.3.0) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets==4.3.0) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets==4.3.0) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets==4.3.0) (4.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==4.3.0) (1.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.13.3->torch>=1.10.0->accelerate==0.27.2) (1.3.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1.0.0->datasets==4.3.0) (1.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate==0.27.2) (2.1.5)
# Using cached transformers-4.36.2-py3-none-any.whl (8.2 MB)
# Using cached tokenizers-0.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.22.2
#     Uninstalling tokenizers-0.22.2:
#       Successfully uninstalled tokenizers-0.22.2
# Successfully installed tokenizers-0.15.2 transformers-4.36.2
# Requirement already satisfied: torch==2.9.1 in /usr/local/lib/python3.10/dist-packages (2.9.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (2024.5.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.9.1) (3.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.13.3->torch==2.9.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.9.1) (2.1.5)
# Requirement already satisfied: ipywidgets==8.1.7 in /usr/local/lib/python3.10/dist-packages (8.1.7)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==8.1.7) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==8.1.7) (8.21.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==8.1.7) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==8.1.7) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /usr/local/lib/python3.10/dist-packages (from ipywidgets==8.1.7) (3.0.16)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.7) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.7) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.7) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.7) (3.0.46)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.7) (2.18.0)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.7) (0.6.3)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.7) (1.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets==8.1.7) (4.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets==8.1.7) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets==8.1.7) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets==8.1.7) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.1.7) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.1.7) (2.4.1)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.1.7) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets==8.1.7) (1.16.0)
# Requirement already satisfied: python-dotenv==1.2.1 in /usr/local/lib/python3.10/dist-packages (1.2.1)
# Requirement already satisfied: pickleshare==0.7.5 in /usr/local/lib/python3.10/dist-packages (0.7.5)

# %%
from dotenv import load_dotenv
import os

load_dotenv("../../.env",override=True)

HF_TOKEN = os.getenv("HF_TOKEN")

#print("HF_TOKEN: ", HF_TOKEN)

 # source: https://huggingface.co/docs/transformers/v4.28.1/tasks/summarization
 from huggingface_hub import login
#login()

# %% [markdown]
# # Pre-training
# with 10k sentences in Kashubian

# %%
# # source: https://corpora.uni-leipzig.de/en?corpusId=csb_wikipedia_2021
# # source: https://huggingface.co/docs/transformers/v4.57.1/en/model_doc/t5#transformers.T5Config
# sentences_path = "/dss/dsshome1/03/ge87wod2/morphological-inflection/data/leipzig-corpera-collection/csb_wikipedia_2021_10K/" + "csb_wikipedia_2021_10K-sentences.txt"
# import random
# import math
# with open (sentences_path,"r") as in_file:
   
#     lines = in_file.readlines()
#     for i in range(math.floor((len(lines)-1)/16)):
#         if i == 4: break
#         print(i)
#         inputs = []
#         labels = []
#         batch_lines = lines[i*16:min(i*16+16,len(lines))]
#         for line in batch_lines:
#             sentence = line.split("\t")[1] # cut out line number
#             words = sentence.split(" ")
#             end_index = len(words)-4
#             mask_len = 3
#             while (end_index < 1 and mask_len > 0 ):
#                 mask_len -= 1
#                 end_index += 1
#             start_index = random.randint(1,end_index) # mask 3 words: start mask between second and fourth last word
#             input_sentence = words[:start_index] + ["<extra_id_0>"] + words[start_index+mask_len:]
#             label_sentence = ["<extra_id_0>"]+words[start_index:start_index+mask_len]+["<extra_id_1>"]
#             input_sentence = " ".join(input_sentence)
#             label = " ".join(label_sentence)
#             inputs.append(input_sentence)
#             labels.append(label)
#             from transformers import AutoTokenizer, T5ForConditionalGeneration, AutoModelForSeq2SeqLM
#             tokenizer = AutoTokenizer.from_pretrained("google/byt5-small")
#             model = T5ForConditionalGeneration.from_pretrained("google/byt5-small")

#             # training
#             input_ids = tokenizer(inputs, return_tensors="pt",padding=True).input_ids
#             labels_batch = tokenizer(labels, return_tensors="pt",padding=True).input_ids
#             outputs = model(input_ids=input_ids, labels=labels_batch)
#             loss = outputs.loss
#             logits = outputs.logits
# print(inputs[0],labels[0])

# # inference
# input_ids = tokenizer(
#     "The <extra_id_0> walks in <extra_id_1> park", return_tensors="pt"
# ).input_ids  # Batch size 1
# outputs = model.generate(input_ids)
# print(tokenizer.decode(outputs[0], skip_special_tokens=True))
# # studies have shown that owning a dog is good for you.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[35], line 6
#       4 import random
#       5 import math
# ----> 6 with open (sentences_path,"r") as in_file:
#       8     lines = in_file.readlines()
#       9     for i in range(math.floor((len(lines)-1)/16)):
#
# File /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/dss/dsshome1/03/ge87wod2/morphological-inflection/data/leipzig-corpera-collection/csb_wikipedia_2021_10K/csb_wikipedia_2021_10K-sentences.txt'

# %%
# from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Trainer, TrainingArguments
from datasets import load_dataset

from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Trainer, TrainingArguments
from datasets import load_dataset

# Load domain-specific text (replace with your own corpus)
lang = "csb-pol-sent"
train_path = f"/dss/dsshome1/03/ge87wod2/morphological-inflection/preprocessing/preprocessing_to_json/data/{lang}_trn.tsv"
eval_path = f"/dss/dsshome1/03/ge87wod2/morphological-inflection/preprocessing/preprocessing_to_json/data/{lang}_dev.tsv"
dataset = load_dataset("csv", delimiter="\t",column_names=["input","labels"],data_files={"train": train_path,"validation": eval_path},quoting=3) # disable quote parsing


# Tokenizer
def preprocess_function(examples):
    # inputs = [prefix + doc for doc in examples["text"]]
    inputs = examples["input"]
    model_inputs = tokenizer(inputs)

    labels = tokenizer(text_target=examples["labels"],padding=True) # same length irrelevant here, so no truncation or padding

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

tokenizer = AutoTokenizer.from_pretrained("google/byt5-small")
tokenized_dataset = dataset.map(preprocess_function, batched=True)

# Load pre-trained model
model = AutoModelForSeq2SeqLM.from_pretrained("google/byt5-small")
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, return_tensors="pt")
# Training arguments
training_args = TrainingArguments (
    output_dir="./byt5_small/"+lang+"-8epochs",
    overwrite_output_dir=True,
    num_train_epochs=8,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    learning_rate=2e-5,
    weight_decay=0.01,
    evaluation_strategy = "epoch",
    #predict_with_generate=True,
   # save_steps=10_000,
    save_total_limit=3,
)

# Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    eval_dataset=tokenized_dataset["validation"],
    data_collator=data_collator,
    tokenizer=tokenizer,
)

# Pretrain the model
trainer.train()
trainer.push_to_hub()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
#     <div>
#
#       <progress value='2543' max='4504' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2543/4504 34:01 < 26:15, 1.24 it/s, Epoch 4.52/8]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>13.137500</td>
#       <td>1.289320</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.328700</td>
#       <td>0.876806</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.027500</td>
#       <td>0.780767</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.948500</td>
#       <td>0.708373</td>
#     </tr>
#   </tbody>
# </table><p>

# %% [markdown]
# # Fine-tuning small pre-trained ByT5 model using dataset

# %%
LANGS = ["grc","dan","fra","sme","deu","nav","jap","klr","eng","mul","deu_eng"]
LANGS = LANGS[-2:]
LANGS = ["mul_2","amh","pol","ote"]
LANGS = ["mul_2","amh","pol","ote"]
LANGS = ["mul-language-code","mul-language-word"]
LANGS = ["mul-language-code"]
LANGS = ["5lang-sample"]
#LANGS = ["slavic-family"]
LANGS = ["pol"]
CHECKPOINT = "livles/csb-sent-6epochs"

PATH_JSON_DATA = "../preprocessing/preprocessing_to_json/data/"

for lang in LANGS:
    from datasets import load_dataset
    dataset = load_dataset("json", data_files={"train": PATH_JSON_DATA + lang + "_trn.json", "validation": PATH_JSON_DATA + lang.split("-")[0] + "_dev.json"})

    print(dataset["train"][0])

    from transformers import AutoTokenizer

    checkpoint = "google/byt5-small"
    tokenizer = AutoTokenizer.from_pretrained(checkpoint)
    # -

    import torch

    from transformers import (
        AutoTokenizer,
        TrainingArguments,
        Trainer,
        AutoModelForSeq2SeqLM,
        Seq2SeqTrainingArguments,
        Seq2SeqTrainer
    )
    from datasets import load_dataset

    def preprocess_function(examples):
        # inputs = [prefix + doc for doc in examples["text"]]
        inputs = examples["input"]
        model_inputs = tokenizer(inputs)

        labels = tokenizer(text_target=examples["target"]) # same length irrelevant here, so no truncation or padding

        model_inputs["labels"] = labels["input_ids"]
        return model_inputs


    tokenized_dataset = dataset.map(preprocess_function, batched=True)
    print(tokenized_dataset)
    sample = tokenized_dataset["train"][0]
    print(sample["labels"])

    from transformers import DataCollatorForSeq2Seq

    data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=checkpoint)

    from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer

    checkpoint = CHECKPOINT
    model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    training_args = Seq2SeqTrainingArguments(
        output_dir="byt5_small/"+checkpoint.split("/")[1]+"-"+lang,
        evaluation_strategy="epoch",
        learning_rate=5e-5,
        per_device_train_batch_size=16,
        per_device_eval_batch_size=16,
        weight_decay=0.01,
        save_total_limit=3,
        num_train_epochs=4,
        predict_with_generate=True,
        # save_strategy="epoch",
        fp16=False,# did not work with True #change to bf16=True for XPU 
        #bf16 = True, # performance was best without setting fp16 or bf16 to true
        push_to_hub=True,
        warmup_steps = 500,
        # load_best_model_at_end=True, # otherwise not model with minimum loss during training, like https://huggingface.co/docs/transformers/tasks/sequence_classification
    )

    trainer = Seq2SeqTrainer(
        model=model,
        args=training_args,
        train_dataset=tokenized_dataset["train"],
        eval_dataset=tokenized_dataset["validation"],
        tokenizer=tokenizer,
        data_collator=data_collator,
        # compute_metrics=compute_metrics,
   
    )

    trainer.train()
    trainer.push_to_hub()
# Out:
# {'input': 'Inflect zacny | ADJ;ACC(SG,FEM)', 'target': 'zacną'}
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# DatasetDict({
#     train: Dataset({
#         features: ['input', 'target', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 10000
#     })
#     validation: Dataset({
#         features: ['input', 'target', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 1000
#     })
# })
# [125, 100, 102, 113, 199, 136, 1]
# config.json:   0%|          | 0.00/837 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.20G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/142 [00:00<?, ?B/s]
#     <div>
#
#       <progress value='2500' max='2500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2500/2500 10:28, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>3.102000</td>
#       <td>0.289269</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.403200</td>
#       <td>0.164241</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.269400</td>
#       <td>0.115364</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.170000</td>
#       <td>0.101796</td>
#     </tr>
#   </tbody>
# </table><p>
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B

# %%
#test
LANGS = ["grc","dan","fra","sme","deu","nav","jap","klr","eng","mul","deu_eng"]
LANGS = LANGS[-2:]
LANGS = ["mul_2","amh","pol","ote"]
LANGS = ["mul_2","amh","pol","ote"]
LANGS = ["mul-language-code","mul-language-word"]
LANGS = ["mul-language-code"]
LANGS = ["5lang-sample"]
#LANGS = ["slavic-family"]
LANGS = ["grc"]
CHECKPOINT = "livles/csb-sent-6epochs"

PATH_JSON_DATA = "../preprocessing/preprocessing_to_json/data/"

for lang in LANGS:
    from datasets import load_dataset
    dataset = load_dataset("json", data_files={"train": PATH_JSON_DATA + lang + "_train.json", "validation": PATH_JSON_DATA + lang.split("-")[0] + "_eval.json"})

    print(dataset["train"][0])

    from transformers import AutoTokenizer

    checkpoint = "google/byt5-small"
    tokenizer = AutoTokenizer.from_pretrained(checkpoint)
    # -

    import torch

    from transformers import (
        AutoTokenizer,
        TrainingArguments,
        Trainer,
        AutoModelForSeq2SeqLM,
        Seq2SeqTrainingArguments,
        Seq2SeqTrainer
    )
    from datasets import load_dataset

    def preprocess_function(examples):
        # inputs = [prefix + doc for doc in examples["text"]]
        inputs = examples["input"]
        model_inputs = tokenizer(inputs)

        labels = tokenizer(text_target=examples["target"]) # same length irrelevant here, so no truncation or padding

        model_inputs["labels"] = labels["input_ids"]
        return model_inputs


    tokenized_dataset = dataset.map(preprocess_function, batched=True)
    print(tokenized_dataset)
    sample = tokenized_dataset["train"][0]
    print(sample["labels"])

    from transformers import DataCollatorForSeq2Seq

    data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=checkpoint)

    from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer

    checkpoint = CHECKPOINT
    model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    training_args = Seq2SeqTrainingArguments(
        output_dir="byt5_small/"+"test",
        evaluation_strategy="epoch",
        learning_rate=5e-5,
        per_device_train_batch_size=16,
        per_device_eval_batch_size=16,
        weight_decay=0.01,
        save_total_limit=3,
        num_train_epochs=4,
        predict_with_generate=True,
        # save_strategy="epoch",
        fp16=True,# did not work with True #change to bf16=True for XPU 
        #bf16 = True, # performance was best without setting fp16 or bf16 to true
        push_to_hub=True,
        warmup_steps = 500,
        # load_best_model_at_end=True, # otherwise not model with minimum loss during training, like https://huggingface.co/docs/transformers/tasks/sequence_classification
    )

    trainer = Seq2SeqTrainer(
        model=model,
        args=training_args,
        train_dataset=tokenized_dataset["train"],
        eval_dataset=tokenized_dataset["validation"],
        tokenizer=tokenizer,
        data_collator=data_collator,
        # compute_metrics=compute_metrics,
   
    )

    trainer.train()
    trainer.push_to_hub()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 17
#      15 for lang in LANGS:
#      16     from datasets import load_dataset
# ---> 17     dataset = load_dataset("json", data_files={"train": PATH_JSON_DATA + lang + "_trn.json", "validation": PATH_JSON_DATA + lang.split("-")[0] + "_dev.json"})
#      19     print(dataset["train"][0])
#      21     from transformers import AutoTokenizer
#
# File /usr/local/lib/python3.10/dist-packages/datasets/load.py:1397, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1392 verification_mode = VerificationMode(
#    1393     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    1394 )
#    1396 # Create a dataset builder
# -> 1397 builder_instance = load_dataset_builder(
#    1398     path=path,
#    1399     name=name,
#    1400     data_dir=data_dir,
#    1401     data_files=data_files,
#    1402     cache_dir=cache_dir,
#    1403     features=features,
#    1404     download_config=download_config,
#    1405     download_mode=download_mode,
#    1406     revision=revision,
#    1407     token=token,
#    1408     storage_options=storage_options,
#    1409     **config_kwargs,
#    1410 )
#    1412 # Return iterable dataset in case of streaming
#    1413 if streaming:
#
# File /usr/local/lib/python3.10/dist-packages/datasets/load.py:1137, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, **config_kwargs)
#    1135 if features is not None:
#    1136     features = _fix_for_backward_compatible_features(features)
# -> 1137 dataset_module = dataset_module_factory(
#    1138     path,
#    1139     revision=revision,
#    1140     download_config=download_config,
#    1141     download_mode=download_mode,
#    1142     data_dir=data_dir,
#    1143     data_files=data_files,
#    1144     cache_dir=cache_dir,
#    1145 )
#    1146 # Get dataset builder class
#    1147 builder_kwargs = dataset_module.builder_kwargs
#
# File /usr/local/lib/python3.10/dist-packages/datasets/load.py:913, in dataset_module_factory(path, revision, download_config, download_mode, data_dir, data_files, cache_dir, **download_kwargs)
#     890 # We have several ways to get a dataset builder:
#     891 #
#     892 # - if path is the name of a packaged dataset module
#    (...)
#     904
#     905 # Try packaged
#     906 if path in _PACKAGED_DATASETS_MODULES:
#     907     return PackagedDatasetModuleFactory(
#     908         path,
#     909         data_dir=data_dir,
#     910         data_files=data_files,
#     911         download_config=download_config,
#     912         download_mode=download_mode,
# --> 913     ).get_module()
#     914 # Try locally
#     915 elif path.endswith(filename):
#
# File /usr/local/lib/python3.10/dist-packages/datasets/load.py:527, in PackagedDatasetModuleFactory.get_module(self)
#     521 base_path = Path(self.data_dir or "").expanduser().resolve().as_posix()
#     522 patterns = (
#     523     sanitize_patterns(self.data_files)
#     524     if self.data_files is not None
#     525     else get_data_patterns(base_path, download_config=self.download_config)
#     526 )
# --> 527 data_files = DataFilesDict.from_patterns(
#     528     patterns,
#     529     download_config=self.download_config,
#     530     base_path=base_path,
#     531 )
#     533 module_path, hash = _PACKAGED_DATASETS_MODULES[self.name]
#     535 builder_kwargs = {
#     536     "data_files": data_files,
#     537     "dataset_name": self.name,
#     538 }
#
# File /usr/local/lib/python3.10/dist-packages/datasets/data_files.py:701, in DataFilesDict.from_patterns(cls, patterns, base_path, allowed_extensions, download_config)
#     696 out = cls()
#     697 for key, patterns_for_key in patterns.items():
#     698     out[key] = (
#     699         patterns_for_key
#     700         if isinstance(patterns_for_key, DataFilesList)
# --> 701         else DataFilesList.from_patterns(
#     702             patterns_for_key,
#     703             base_path=base_path,
#     704             allowed_extensions=allowed_extensions,
#     705             download_config=download_config,
#     706         )
#     707     )
#     708 return out
#
# File /usr/local/lib/python3.10/dist-packages/datasets/data_files.py:594, in DataFilesList.from_patterns(cls, patterns, base_path, allowed_extensions, download_config)
#     591 for pattern in patterns:
#     592     try:
#     593         data_files.extend(
# --> 594             resolve_pattern(
#     595                 pattern,
#     596                 base_path=base_path,
#     597                 allowed_extensions=allowed_extensions,
#     598                 download_config=download_config,
#     599             )
#     600         )
#     601     except FileNotFoundError:
#     602         if not has_magic(pattern):
#
# File /usr/local/lib/python3.10/dist-packages/datasets/data_files.py:383, in resolve_pattern(pattern, base_path, allowed_extensions, download_config)
#     381     if allowed_extensions is not None:
#     382         error_msg += f" with any supported extension {list(allowed_extensions)}"
# --> 383     raise FileNotFoundError(error_msg)
#     384 return out
#
# FileNotFoundError: Unable to find '/dss/dsshome1/03/ge87wod2/morphological-inflection/ByT5/../preprocessing/preprocessing_to_json/data/grc_trn.json'

# %% [markdown]
# # Fine-Tuning with more epochs

# %%
# !rm -rf /dss/dsshome1/03/ge87wod2/morphological-inflection/ByT5/byt5_small/*
LANGS = ["5lang-sample"]
#LANGS = ["slavic-family"]



PATH_JSON_DATA = "../preprocessing/preprocessing_to_json/data/"

for lang in LANGS:
    from datasets import load_dataset
    dataset = load_dataset("json", data_files={"train": PATH_JSON_DATA + lang + "_trn.json", "validation": PATH_JSON_DATA + lang + "_dev.json"})

    print(dataset["train"][0])

    from transformers import AutoTokenizer

    checkpoint = "google/byt5-small"
    tokenizer = AutoTokenizer.from_pretrained(checkpoint)
    # 

    import torch

    from transformers import (
        AutoTokenizer,
        TrainingArguments,
        Trainer,
        AutoModelForSeq2SeqLM,
        Seq2SeqTrainingArguments,
        Seq2SeqTrainer
    )
    from datasets import load_dataset

    def preprocess_function(examples):
        # inputs = [prefix + doc for doc in examples["text"]]
        inputs = examples["input"]
        model_inputs = tokenizer(inputs)

        labels = tokenizer(text_target=examples["target"]) # same length irrelevant here, so no truncation or padding

        model_inputs["labels"] = labels["input_ids"]
        return model_inputs


    tokenized_dataset = dataset.map(preprocess_function, batched=True)
    print(tokenized_dataset)
    sample = tokenized_dataset["train"][0]
    print(sample["labels"])

    from transformers import DataCollatorForSeq2Seq

    data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=checkpoint)

    from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer

    model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    training_args = Seq2SeqTrainingArguments(
        output_dir="byt5_small/"+lang+"_13epochs",
        eval_strategy="epoch",
        learning_rate=5e-5,
        per_device_train_batch_size=16,
        per_device_eval_batch_size=16,
        weight_decay=0.01,
        save_total_limit=3,
        num_train_epochs=13,
        predict_with_generate=True,
        fp16=False,# did not work with True #change to bf16=True for XPU 
        #bf16 = True, # performance was best without setting fp16 or bf16 to true
        push_to_hub=True,
        warmup_steps = 500,
        save_strategy="epoch",
        load_best_model_at_end=True, # otherwise not model with minimum loss during training, like https://huggingface.co/docs/transformers/tasks/sequence_classification,
        greater_is_better=False,
        metric_for_best_model="eval_loss"
    )

    trainer = Seq2SeqTrainer(
        model=model,
        args=training_args,
        train_dataset=tokenized_dataset["train"],
        eval_dataset=tokenized_dataset["validation"],
        tokenizer=tokenizer,
        data_collator=data_collator,
        # compute_metrics=compute_metrics,
    )

    trainer.train()
    trainer.push_to_hub()
# Out:
# {'input': 'Navajo: Inflect náʼáłkad | V;IND;PFV;NOM(1,GRPL)', 'target': 'ńdaʼiilkad'}
# DatasetDict({
#     train: Dataset({
#         features: ['input', 'target', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 10000
#     })
#     validation: Dataset({
#         features: ['input', 'target', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 1000
#     })
# })
# [200, 135, 103, 100, 205, 191, 108, 108, 111, 110, 100, 103, 1]
# /tmp/ipykernel_3401446/2533773261.py:79: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(
#     <div>
#
#       <progress value='5061' max='8125' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5061/8125 25:54 < 15:41, 3.26 it/s, Epoch 8.10/13]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.696000</td>
#       <td>0.714211</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.782000</td>
#       <td>0.506161</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.568900</td>
#       <td>0.431394</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.412900</td>
#       <td>0.378233</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.362600</td>
#       <td>0.339201</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.323500</td>
#       <td>0.316904</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.289100</td>
#       <td>0.290162</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.246900</td>
#       <td>0.279335</td>
#     </tr>
#   </tbody>
# </table><p>

# %% [markdown]
# # Inference

# %%
# SETTINGS = ["grc","dan","fra","sme","deu","nav","jap","klr","eng","mul","deu_eng"] + ["mul_2","ote","pol","amh"] + ["mul-language-code","mul-language-word"]
SETTINGS = ["mul"]
SETTINGS = ["5lang-sample"]
BASE_TEST_LANGUAGES_OF_SETTING = {"slavic":["pol","ces","csb","dsb","slk"],"slavic-word":["pol","ces","csb","dsb","slk"],"slavic-family":["pol","ces","csb","dsb","slk"],"5lang-sample":["deu","nav","klr","amh","grc"],"5lang-sample_16epochs":["deu","nav","klr","amh","grc"],
                                 "sme-15ksamples":["sme"],"sme-20ksamples":["sme"],"klr-15ksamples":["klr"],"klr-20ksamples":["klr"],"slavic-distant-word": ["pol","ces","csb","dsb","slk","mkd","rus","bel"],"slavic-distant-word-or-family": ["pol","ces","csb","dsb","slk","mkd","rus","bel"],
                                  "csb-pol":["csb","pol"], "csb-pol-sent-pol": ["csb", "pol"], "csb-pol-sent-6epochs-pol": ["csb", "pol"],
                                  "csb-sent-6epochs-pol": ["csb", "pol"]
                                 }
CODES = {"slavic": "","slavic-word":["-lang-word"],"slavic-family":["-family","-lang-word","-word-or-family"],"5lang-sample":["-lang-word"],"5lang-sample_16epochs":["-lang-word"],"5lang-sample_13epochs":["-lang-word"],"sme-15ksamples":[""],"sme-20ksamples":[""],"klr-15ksamples":[""],"klr-20ksamples":[""],"slavic-distant-word":["-lang-word"],"slavic-distant-word-or-family":["-lang-word"],"csb-pol":[""],"csb-pol-sent-pol":[""],"csb-pol-sent-6epochs-pol": [""],"csb-sent-6epochs-pol": [""]}
SETTINGS = ["slavic","slavic-word"]
SETTINGS = ["sme-15ksamples","sme-20ksamples","klr-15ksamples","klr-20ksamples","5lang-sample_16epochs"]
SETTINGS = ["slavic-distant-word-or-family"]
SETTINGS = ["csb-sent-6epochs-pol"]

#TEST_LANGS_OLD = ["grc","dan","fra","sme","deu","nav","jap","klr","eng"] 
#TEST_LANGS = ["grc","dan","fra","sme","deu","nav","jap","klr","eng"] + ["ote","pol","amh","csb"]
#lang5_LANGS = ["deu","nav","klr","amh","grc"]
#lang_code = ""
for lang_setting in SETTINGS:
    test_langs = BASE_TEST_LANGUAGES_OF_SETTING[lang_setting]
    #if lang_setting == "mul": LANG_CODES = ["-language-word","-language-code",""] # test with no language code/word too
    #else: LANG_CODES = [""]
    #for lang_code in LANG_CODES:
        #if lang_setting in ( "deu_eng", "mul") and lang_code == "": test_langs = TEST_LANGS_OLD
        #elif lang_setting in ["mul_2","mul"]: test_langs = TEST_LANGS # test multilingual model on all languages it was trained on + Kashubian
        #elif lang_setting == "5lang-sample": test_langs = lang5_LANGS
        #elif lang_setting == "pol": test_langs = ["pol","csb"] # test Polish model on Kashubian also
        #else: 
    for lang_code in CODES[lang_setting]:
        for test_lang in test_langs:
            import torch
            from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
            PRETRAINED_MODEL = "google/byt5-small"
            FINETUNED_MODEL ="livles/"+lang_setting
            #FINETUNED_MODEL ="./byt5_small/"+lang_setting + lang_code
            MODEL = FINETUNED_MODEL
            print(MODEL)
            tokenizer = AutoTokenizer.from_pretrained(
                FINETUNED_MODEL,
            )
            model = AutoModelForSeq2SeqLM.from_pretrained(
                FINETUNED_MODEL,
            torch_dtype=torch.float16,
            device_map="auto"
            )
            from datasets import load_dataset
            OUT_DIR = "output_byt5_small/" + lang_setting + "/" 
            PATH_TO_JSON_TEST_FILE = "../preprocessing/preprocessing_to_json/data/" + test_lang + lang_code+ "_tst.json"
            print("test file: ",PATH_TO_JSON_TEST_FILE)
            PATH_TO_ORIG_TEST_FILE = "../2023InflectionST/part1/data/" + test_lang + ".tst"
            from pathlib import Path
            Path(OUT_DIR).mkdir(parents=True, exist_ok=True)
            with open (OUT_DIR + test_lang + lang_code + "_byt5-small.out","w") as out_file, open (PATH_TO_ORIG_TEST_FILE, "r") as test_file:
                dataset = load_dataset("json",data_files={"test":PATH_TO_JSON_TEST_FILE})
                covered_test_lines = dataset["test"]["input"]
                LEN = len(covered_test_lines)
                COUNTER = 0

                # preds = map (generate,covered_test_lines)
                for line in covered_test_lines:
                    input_ids = tokenizer(line, return_tensors="pt").to(model.device)
                    output = model.generate(
                        **input_ids,
                        max_new_tokens=50,
                        num_beams=4,
                        #early_stopping=True
                    )
                    output_string = (tokenizer.decode(output[0], skip_special_tokens=True))
                    lemma, features, ref = test_file.readline().strip().split("\t")

                    # evaluate
                    if (ref == output_string):
                        COUNTER += 1
                        print(ref,output_string)
                    else:
                        print("ref:",ref,"pred:",output_string)

                    # write
                    out_file.write(lemma + "\t" +features+ "\t" + output_string + "\n")
                    out_file.flush()

                accuracy = COUNTER / LEN
                out_file.write("accuracy:"+ str(accuracy)+"\n")
                print(accuracy)
# Out:
# livles/csb-sent-6epochs-pol
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json:   0%|          | 0.00/843 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.20G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/142 [00:00<?, ?B/s]
# test file:  ../preprocessing/preprocessing_to_json/data/csb_tst.json
# ref: narzãdzacze pred: narzódzócze
# ref: narzãdzaczom pred: narzãdzóczom
# ref: narzãdzaczu pred: narzãdzóczu
# ref: narzãdzaczama pred: narzódzóczami
# ref: narzãdzaczu pred: narzãdzóczu
# ref: narzãdzaczowi pred: narzãdzóczowi
# ref: narzãdzacza pred: narzãdzócza
# ref: narzãdzaczach pred: narzãdzóczach
# ref: narzãdzaczów pred: narzãdzóczów
# ref: narzãdzaczã pred: narzãdzôczem
# ref: narzãdzacze pred: narzódzócze
# ref: narzãdzacza pred: narzãdzócz
# ref: narzãdzôcz pred: narzódzócz
# ref: narzãdzacze pred: narzódzócze
# ref: Jastrë pred: Jastry
# Jastrach Jastrach
# ref: Jastróm pred: Jastrom
# Jastrów Jastrów
# ref: Jastrama pred: Jastry
# ref: Jastrë pred: Jastry
# ref: Jastrë pred: Jastry
# ref: pòniedzałczi pred: pòniedzółki
# ref: pòniedzałkóm pred: pòniedzôłkom
# ref: pòniedzałkù pred: pòniedzôłku
# ref: pòniedzałkama pred: pòniedzôłkami
# ref: pòniedzałkù pred: pòniedzôłcu
# ref: poniedzałkòwi pred: pòniedzôłce
# ref: pòniedzałkù pred: pòniedzôłka
# ref: pòniedzałkach pred: pòniedzôłkach
# ref: pòniedzałków pred: pòniedzôłków
# ref: pòniedzałkã pred: pòniedzôłkiem
# ref: pòniedzałczi pred: pòniedzôłki
# pòniedzôłk pòniedzôłk
# ref: pòniedzôłk pred: pòniedzółk
# ref: pòniedzałczi pred: pòniedzôłki
# ref: pùjczi pred: pùjki
# pùjkom pùjkom
# ref: pùjkù pred: pùjku
# ref: pùjkama pred: pùjkami
# ref: pùjkù pred: pùjku
# ref: pùjkòwi pred: pùjkowi
# ref: pùjka pred: pùjku
# pùjkach pùjkach
# pùjków pùjków
# ref: pùjkã pred: pùjkem
# ref: pùjczi pred: pùjki
# ref: pùjka pred: pùjk
# pùjk pùjk
# ref: pùjczi pred: pùjki
# ref: môlniczi pred: môlniki
# ref: môlnikòm pred: môlnikom
# ref: môlnikù pred: môlniku
# ref: môlnikama pred: môlnikami
# ref: môlnikù pred: môlniku
# ref: môlnikòwi pred: môlnikowi
# môlnika môlnika
# môlnikach môlnikach
# môlników môlników
# ref: môlnikã pred: môlnikiem
# ref: môlniczi pred: môlniki
# môlnik môlnik
# môlnik môlnik
# ref: môlniczi pred: môlniki
# ref: wòłiwaczë pred: wòłiwocze
# ref: wòłiwaczom pred: wòłiwoczom
# ref: wòłiwaczu pred: wòłiwoczu
# ref: wòłiwaczama pred: wòłiwoczami
# ref: wòłiwaczu pred: wòłiwoczu
# ref: wòłiwaczowi pred: wòłiwoczowi
# ref: wòłiwacza pred: wòłiwocza
# ref: wòłiwaczach pred: wòłiwoczach
# ref: wòłiwaczów pred: wòłiwoczów
# ref: wòłiwaczã pred: wòłiwoczem
# ref: wòłiwaczë pred: wòłiwocze
# ref: wòłiwacza pred: wòłiwocz
# ref: wòłiwôcz pred: wòłiwocz
# ref: wòłiwaczë pred: wòłiwocze
# ref: łżëkwiôtë pred: łżëkwióty
# ref: łżëkwiôtom pred: łżëkwiotom
# ref: łżëkwiôce pred: łżëkwiót
# ref: łżëkwiôtama pred: łżëkwiotami
# ref: łżëkwiôce pred: łżëkwiocie
# ref: łżëkwiôtowi pred: łżëkwiotowi
# ref: łżëkwiôta pred: łżëkwiota
# ref: łżëkwiôtach pred: łżëkwiotach
# ref: łżëkwiôtów pred: łżëkwiotów
# ref: łżëkwiôtã pred: łżëkwiotem
# ref: łżëkwiôtë pred: łżëkwioty
# ref: łżëkwiôta pred: łżëkwiot
# ref: łżëkwiôt pred: łżëkwiót
# ref: łżëkwiôtë pred: łżëkwioty
# ref: lëstopadniczi pred: lëstopadniki
# ref: lëstopadnikòm pred: lëstopadnikom
# ref: lëstopadnikù pred: lëstopadniku
# ref: lëstopadnikama pred: lëstopadnikami
# ref: lëstopadnikù pred: lëstopadniku
# ref: lëstopadnikòwi pred: lëstopadnikowi
# lëstopadnika lëstopadnika
# lëstopadnikach lëstopadnikach
# lëstopadników lëstopadników
# ref: lëstopadnikã pred: lëstopadnikiem
# ref: lëstopadniczi pred: lëstopadniki
# ref: lëstopadnika pred: lëstopadnik
# lëstopadnik lëstopadnik
# ref: lëstopadniczi pred: lëstopadniki
# ref: sobòtë pred: sobóty
# ref: sobòtóm pred: sobotom
# ref: sobòto pred: sobóto
# ref: sobòtama pred: sobótami
# ref: sobòce pred: sobocie
# ref: sobòce pred: sobótowi
# ref: sobòtë pred: sobóty
# ref: sobòtach pred: sobotach
# ref: sobòtów pred: sobotów
# ref: sobòtã pred: sobótą
# ref: sobòtë pred: sobóty
# ref: sobòtã pred: sobótę
# ref: sobòta pred: sobóta
# ref: sobòtë pred: sobóty
# ref: kònie pred: kóń
# ref: kòniom pred: końom
# ref: kòniu pred: koń
# ref: kòniama pred: kóńami
# ref: kòniu pred: koniu
# ref: kòniowi pred: koniowi
# ref: kònia pred: kóń
# ref: kòniach pred: końach
# ref: kòni pred: końów
# ref: kòniã pred: kóńem
# ref: kònie pred: kóń
# ref: kònia pred: kóń
# kóń kóń
# ref: kònie pred: kóń
# ref: nazéwacze pred: nazéwócze
# ref: nazéwaczom pred: nazéwôczom
# ref: nazéwaczu pred: nazéwoczu
# ref: nazéwaczama pred: nazéwôczami
# ref: nazéwaczu pred: nazéwoczu
# ref: nazéwaczowi pred: nazéwoczowi
# ref: nazéwacza pred: nazéwocza
# ref: nazéwaczach pred: nazéwôczach
# ref: nazéwaczów pred: nazéwoczów
# ref: nazéwaczã pred: nazéwôczem
# ref: nazéwacze pred: nazéwocze
# ref: nazéwacza pred: nazéwocz
# ref: nazéwôcz pred: nazéwócz
# ref: nazéwacze pred: nazéwôcze
# ref: piątczi pred: piątki
# ref: piątkóm pred: piątkom
# ref: piątkù pred: piątku
# ref: piątkama pred: piątkami
# ref: piątkù pred: piątku
# ref: piątkòwi pred: piątkowi
# ref: piątkù pred: piątka
# piątkach piątkach
# piątków piątków
# ref: piątkã pred: piątkiem
# ref: piątczi pred: piątki
# piątk piątk
# piątk piątk
# ref: piątczi pred: piątki
# ref: rënczi pred: rënki
# ref: rënkóm pred: rënkom
# ref: stolem pred: rënku
# ref: rënkama pred: rënkami
# ref: rënkù pred: rënku
# ref: rënkòwi pred: rënkowi
# ref: rënkù pred: rënku
# rënkach rënkach
# rënków rënków
# ref: rënkã pred: rënkem
# ref: rënczi pred: rënki
# rënk rënk
# rënk rënk
# ref: rënczi pred: rënki
# ref: wtórczi pred: wtórki
# ref: wtórkòm pred: wtórkom
# ref: wtórkù pred: wtórku
# ref: wtórkama pred: wtórkami
# ref: wtórkù pred: wtórce
# ref: wtórkòwi pred: wtórce
# wtórka wtórka
# wtórkach wtórkach
# wtórków wtórków
# ref: wtórkã pred: wtórkiem
# ref: wtórczi pred: wtórki
# wtórk wtórk
# wtórk wtórk
# ref: wtórczi pred: wtórki
# ref: winowacze pred: winowócze
# ref: winowaczom pred: winowoczom
# ref: winowaczu pred: winowoczu
# ref: winowaczama pred: winowôczami
# ref: winowaczu pred: winowoczu
# ref: winowaczowi pred: winowoczowi
# ref: winowacza pred: winowocza
# ref: winowaczach pred: winowoczach
# ref: winowaczów pred: winowoczów
# ref: winowaczã pred: winowôczem
# ref: winowacze pred: winowocze
# ref: winowacza pred: winowocz
# ref: winowôcz pred: winowócz
# ref: winowacze pred: winowócze
# ref: òjcowie pred: òjcy
# ref: òjcóm pred: òjcom
# ref: òjcze pred: òjcu
# ref: òjcama pred: òjcami
# òjcu òjcu
# ref: òjcu pred: òjcowi
# òjca òjca
# òjcach òjcach
# òjców òjców
# ref: òjcã pred: òjcem
# òjcem òjcem
# ref: òjców pred: òjcy
# ref: òjca pred: òjc
# òjc òjc
# ref: òjcowie pred: òjcy
# ref: latawiska pred: latawiski
# ref: latawiskóm pred: latawiskom
# ref: latawiskù pred: latawisko
# ref: latawiskama pred: latawiskami
# ref: latawiskù pred: latawisku
# ref: latawiskù pred: latawiskowi
# latawiska latawiska
# latawiskach latawiskach
# latawisków latawisków
# ref: latawiskã pred: latawiską
# ref: latawiska pred: latawisków
# ref: latawiskò pred: latawisko
# ref: latawiskò pred: latawisko
# latawiska latawiska
# ref: Jastra pred: Jastry
# Jastrach Jastrach
# ref: Jastróm pred: Jastrom
# Jastrów Jastrów
# ref: Jastrama pred: Jastry
# ref: Jastra pred: Jastry
# ref: Jastra pred: Jastry
# czerwińce czerwińce
# czerwińcom czerwińcom
# czerwińcu czerwińcu
# ref: czerwińcama pred: czerwińcami
# czerwińcu czerwińcu
# czerwińcowi czerwińcowi
# czerwińca czerwińca
# czerwińcach czerwińcach
# czerwińców czerwińców
# ref: czerwińcã pred: czerwińcem
# czerwińce czerwińce
# ref: czerwińca pred: czerwińc
# czerwińc czerwińc
# ref: czerwińc pred: czerwińcy
# ref: rujanë pred: rujany
# rujanom rujanom
# ref: rujanie pred: rujanu
# ref: rujanama pred: rujanami
# rujanie rujanie
# rujanowi rujanowi
# ref: rujana pred: rujanu
# rujanach rujanach
# rujanów rujanów
# ref: rujanã pred: rujanem
# ref: rujanë pred: rujany
# ref: rujana pred: rujan
# rujan rujan
# ref: rujanë pred: rujany
# ref: dôwacze pred: dôwócze
# ref: dôwaczom pred: dôwôczom
# ref: dôwaczu pred: dôwôczu
# ref: dôwaczama pred: dôwôczami
# ref: dôwaczu pred: dôwôczu
# ref: dôwaczowi pred: dôwôczowi
# dôwôcza dôwôcza
# ref: dôwaczach pred: dôwôczach
# ref: dôwaczów pred: dôwôczów
# ref: dôwaczã pred: dôwôczem
# ref: dôwacze pred: dôwôcze
# ref: dôwacza pred: dôwôcz
# ref: dôwôcz pred: dôwócz
# ref: dôwacze pred: dôwôcze
# ref: serca pred: serce
# ref: sercóm pred: sercom
# ref: serce pred: serco
# ref: sercama pred: sercami
# ref: sercu pred: sercie
# ref: serce pred: sercie
# ref: sercu pred: sercowi
# serca serca
# sercach sercach
# serców serców
# ref: serc pred: serców
# ref: sercã pred: sercą
# ref: sercem pred: sercą
# ref: serca pred: serce
# ref: serce pred: sercę
# serce serce
# ref: serca pred: serce
# lëpince lëpince
# lëpincom lëpincom
# lëpincu lëpincu
# ref: lëpincama pred: lëpincami
# lëpincu lëpincu
# lëpincowi lëpincowi
# lëpinca lëpinca
# lëpincach lëpincach
# lëpinców lëpinców
# ref: lëpincã pred: lëpincem
# lëpince lëpince
# lëpinc lëpinc
# lëpinc lëpinc
# ref: lëpince pred: lëpincy
# ref: séwniczi pred: séwniki
# ref: séwnikòm pred: séwnikom
# ref: séwnikù pred: séwniku
# ref: séwnikama pred: séwnikami
# ref: séwnikù pred: séwniku
# ref: séwnikòwi pred: séwnikowi
# séwnika séwnika
# séwnikach séwnikach
# séwników séwników
# ref: séwnikã pred: séwnikiem
# ref: séwniczi pred: séwniki
# ref: séwnika pred: séwnik
# séwnik séwnik
# ref: séwniczi pred: séwniki
# ref: zélniczi pred: zélniki
# ref: zélnikòm pred: zélnikom
# ref: zélnikù pred: zélniku
# ref: zélnikama pred: zélnikami
# ref: zélnikù pred: zélniku
# ref: zélnikòwi pred: zélnikowi
# zélnika zélnika
# zélnikach zélnikach
# zélników zélników
# ref: zélnikã pred: zélnikem
# ref: zélniczi pred: zélniki
# ref: zélnika pred: zélnik
# zélnik zélnik
# ref: zélniczi pred: zélniki
# ref: stëczniczi pred: stëczniki
# ref: stëcznikòm pred: stëcznikom
# ref: stëcznikù pred: stëczniku
# ref: stëcznikama pred: stëcznikami
# ref: stëcznikù pred: stëczniku
# ref: stëcznikòwi pred: stëcznikowi
# stëcznika stëcznika
# stëcznikach stëcznikach
# stëczników stëczników
# ref: stëcznikã pred: stëcznikiem
# ref: stëczniczi pred: stëczniki
# ref: stëcznika pred: stëcznik
# stëcznik stëcznik
# ref: stëczniczi pred: stëczniki
# ref: strzodë pred: strzody
# ref: strzodóm pred: strzodom
# ref: strzodo pred: strzodzie
# ref: strzodama pred: strzodami
# ref: strzodze pred: strzodzie
# ref: strzodze pred: strzodzie
# ref: strzodë pred: strzody
# strzodach strzodach
# strzodów strzodów
# ref: strzodã pred: strzodą
# ref: strzodë pred: strzody
# ref: strzodã pred: strzodę
# strzoda strzoda
# ref: strzodë pred: strzody
# ref: maje pred: moje
# ref: majom pred: mojom
# ref: maju pred: moju
# ref: majima pred: mojami
# ref: maju pred: moju
# ref: majowi pred: mojowi
# ref: maja pred: moja
# ref: majach pred: mojach
# ref: majów pred: mojów
# ref: majã pred: môjem
# ref: maje pred: moje
# ref: môj pred: moj
# ref: môj pred: moj
# ref: maje pred: moje
# ref: strumianniczi pred: strumianniki
# ref: strumiannikòm pred: strumiannikom
# ref: strumiannikù pred: strumianniku
# ref: strumiannikama pred: strumiannikami
# ref: strumiannikù pred: strumianniku
# ref: strumiannikòwi pred: strumiannikowi
# strumiannika strumiannika
# strumiannikach strumiannikach
# strumianników strumianników
# ref: strumiannikã pred: strumiannikiem
# ref: strumianniczi pred: strumianniki
# strumiannik strumiannik
# strumiannik strumiannik
# ref: strumianniczi pred: strumianniki
# ref: tidzénie pred: tidzóny
# ref: tidzénióm pred: tidzónom
# ref: tidzéniu pred: tidzeniu
# ref: tidzénama pred: tidzéniami
# ref: tidzéniu pred: tidzeniu
# ref: tidzéniowi pred: tidzónowi
# ref: tidzénia pred: tidzenia
# ref: tidzénach pred: tidzónach
# ref: tidzéniów pred: tidzónów
# ref: tidzénã pred: tidzéną
# ref: tidzénie pred: tidzóny
# ref: tidzéń pred: tidzónę
# ref: tidzéń pred: tidzón
# ref: tidzénie pred: tidzóny
# ref: czwôrtczi pred: czwórtki
# ref: czwôrtkóm pred: czwôrtkom
# ref: czwôrtkù pred: czwôrtku
# ref: czwôrtkama pred: czwôrtkami
# ref: czwôrtkù pred: czwôrtku
# ref: czwôrtkòwi pred: czwôrtkowi
# ref: czwôrtkù pred: czwôrtku
# czwôrtkach czwôrtkach
# czwôrtków czwôrtków
# ref: czwôrtkã pred: czwôrtkiem
# ref: czwôrtczi pred: czwôrtki
# ref: czwôrtk pred: czwôrtkę
# ref: czwôrtk pred: czwórtk
# ref: czwôrtczi pred: czwôrtki
# ref: kòtë pred: kóty
# ref: kòtom pred: kotom
# ref: kòce pred: kotu
# ref: kòtama pred: kòtami
# ref: kòce pred: kocie
# ref: kòtowi pred: kotowi
# ref: kòtu pred: kotowi
# ref: kòta pred: kotu
# ref: kòtach pred: kotach
# ref: kòtów pred: kotów
# ref: kòtã pred: kòtem
# ref: kòtë pred: kòty
# ref: kòta pred: kót
# ref: kòt pred: kót
# ref: kòtë pred: koty
# ref: gromiczniczi pred: gromiczniki
# ref: gromicznikòm pred: gromicznikom
# ref: gromicznikù pred: gromiczniku
# ref: gromicznikama pred: gromicznikami
# ref: gromicznikù pred: gromiczniku
# ref: gromicznikòwi pred: gromicznikowi
# gromicznika gromicznika
# gromicznikach gromicznikach
# gromiczników gromiczników
# ref: gromicznikã pred: gromicznikiem
# ref: gromiczniczi pred: gromiczniki
# ref: gromicznika pred: gromicznik
# gromicznik gromicznik
# ref: gromiczniczi pred: gromiczniki
# ref: rodzôcze pred: rodzócze
# ref: rodzôczom pred: rodzóczom
# ref: rodzôczu pred: rodzóczu
# ref: rodzôczama pred: rodzóczami
# ref: rodzôczu pred: rodzoczu
# ref: rodzôczowi pred: rodzóczowi
# ref: rodzôcza pred: rodzócza
# ref: rodzôczach pred: rodzóczach
# ref: rodzôczów pred: rodzóczów
# ref: rodzôczã pred: rodzôczem
# ref: rodzôcze pred: rodzócze
# ref: rodzôcza pred: rodzócz
# ref: rodzôcz pred: rodzócz
# ref: rodzôcze pred: rodzócze
# niedzele niedzele
# ref: niedzelóm pred: niedzelom
# niedzelo niedzelo
# ref: niedzelama pred: niedzelami
# niedzeli niedzeli
# niedzeli niedzeli
# ref: niedzeli pred: niedzely
# niedzelach niedzelach
# ref: niedzelów pred: niedzel
# ref: niedzelã pred: niedzelą
# niedzele niedzele
# ref: niedzelã pred: niedzelę
# niedzela niedzela
# niedzele niedzele
# ref: gòdniczi pred: gódniki
# ref: gòdnikòm pred: gódnikom
# ref: gòdnikù pred: gódniku
# ref: gòdnikama pred: gódnikami
# ref: gòdnikù pred: gódniku
# ref: gòdnikòwi pred: gódnikowi
# ref: gòdnika pred: gódnika
# ref: gòdnikach pred: gódnikach
# ref: gòdników pred: gódników
# ref: gòdnikã pred: gòdnikiem
# ref: gòdniczi pred: gódniki
# ref: gòdnika pred: gódnik
# ref: gòdnik pred: gódnik
# ref: gòdniczi pred: gódniki
# ref: stolemë pred: stolemy
# ref: stolemóm pred: stolemom
# ref: stolem pred: stolemu
# ref: stolemama pred: stolemami
# stolemie stolemie
# ref: stolemòwi pred: stolemowi
# ref: stolema pred: stolemu
# stolemach stolemach
# stolemów stolemów
# ref: stolemã pred: stolemem
# ref: stolemów pred: stolemy
# ref: stolema pred: stolem
# stolem stolem
# ref: stolemë pred: stolemy
# 0.2200392927308448
# livles/csb-sent-6epochs-pol
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# test file:  ../preprocessing/preprocessing_to_json/data/pol_tst.json
# bezgrzeszne bezgrzeszne
# bezgrzeszne bezgrzeszne
# bezgrzesznego bezgrzesznego
# bezgrzesznego bezgrzesznego
# bezgrzesznego bezgrzesznego
# bezgrzesznej bezgrzesznej
# ref: bezgrzesznej pred: bezgrzeszną
# bezgrzesznej bezgrzesznej
# bezgrzesznemu bezgrzesznemu
# bezgrzesznemu bezgrzesznemu
# ref: bezgrzeszny pred: bezgrzesznego
# bezgrzesznych bezgrzesznych
# bezgrzesznych bezgrzesznych
# bezgrzesznych bezgrzesznych
# bezgrzesznym bezgrzesznym
# bezgrzesznym bezgrzesznym
# bezgrzesznymi bezgrzesznymi
# uchwytami uchwytami
# uchwyt uchwyt
# uchwytom uchwytom
# ref: uchwytowi pred: uchwycie
# uchwytów uchwytów
# uchwyty uchwyty
# uchwyty uchwyty
# uchwyty uchwyty
# zdaniami podrzędnymi zdaniami podrzędnymi
# zdania podrzędnego zdania podrzędnego
# zdania podrzędne zdania podrzędne
# ref: zdania podrzędne pred: zdanie podrzędne
# zdaniem podrzędnym zdaniem podrzędnym
# zdanie podrzędne zdanie podrzędne
# ref: zdaniu podrzędnym pred: zdaniu podrzędnemu
# ref: zdań podrzędnych pred: zdania podrzędnych
# ref: będą nosili pred: będziemy nosili
# ref: będą nosiły pred: będziemy nosiły
# ref: będziecie nosili pred: będziemy nosili
# ref: będziecie nosiły pred: będziemy nosiły
# będzie nosiła będzie nosiła
# będzie nosił będzie nosił
# ref: będziesz nosiła pred: będzie nosiła
# ref: niech nosi pred: będziesz nosił
# ref: noście pred: będziemy nosili
# nosić nosić
# nosiłabym nosiłabym
# ref: nosiłabyś pred: nosiłabym
# ref: nosiłaby pred: nosiłabym
# ref: nosiłam pred: nosiłabym
# nosiłbym nosiłbym
# ref: nosiłbyś pred: nosiłbym
# ref: nosiłeś pred: nosiłbyś
# nosilibyście nosilibyście
# ref: nosilibyśmy pred: nosilibyście
# ref: nosiliby pred: nosilibyście
# ref: nosiliście pred: nosilibyście
# ref: nosiliśmy pred: nosilibyśmy
# ref: nosili pred: nosilibyście
# ref: nosiłoby pred: nosiłby
# nosił nosił
# ref: nosiłyście pred: nosiłyśmy
# ref: nosiły pred: nosiłyśmy
# ref: nosimy pred: nosiliśmy
# ref: nosisz pred: nosił
# ref: nośmy pred: będziemy nosili
# ref: nosząca pred: nosiłabym
# ref: noszące pred: nosilibyśmy
# ref: noszące pred: nosiłybyśmy
# ref: noszący pred: nosilibyście
# ref: noszą pred: nosiłyście
# ref: noszenie pred: nosić
# ref: noszeni pred: nosilibyśmy
# ref: noszę pred: nosiło
# ref: noszona pred: nosiłabym
# ref: noszone pred: nosilibyśmy
# ref: noszone pred: nosiłybyśmy
# ref: noszono pred: nosić
# kosmonaucie kosmonaucie
# kosmonaucie kosmonaucie
# ref: kosmonauci pred: kosmonauty
# kosmonautach kosmonautach
# kosmonautą kosmonautą
# kosmonauta kosmonauta
# kosmonautę kosmonautę
# ref: kosmonautów pred: kosmonauty
# kosmonautów kosmonautów
# kosmonauty kosmonauty
# łączach łączach
# łączami łączami
# ref: łącza pred: łącze
# ref: łącze pred: łączę
# łącze łącze
# ref: łącze pred: łączo
# ref: łączu pred: łączowi
# łączu łączu
# rosołach rosołach
# rosołami rosołami
# rosołem rosołem
# ref: rosole pred: rosołu
# ref: rosół pred: rosoł
# rosołów rosołów
# rosoły rosoły
# bękarcie bękarcie
# ref: bękarcie pred: bękartu
# bękartach bękartach
# bękartami bękartami
# bękartom bękartom
# ref: bękartowi pred: bękarcie
# bękartów bękartów
# naukowa naukowa
# naukowe naukowe
# naukowe naukowe
# naukowe naukowe
# naukowego naukowego
# naukowego naukowego
# naukowego naukowego
# naukowego naukowego
# naukowej naukowej
# naukowemu naukowemu
# naukowemu naukowemu
# naukowych naukowych
# naukowych naukowych
# naukowych naukowych
# naukowym naukowym
# naukowym naukowym
# naukowymi naukowymi
# szufladami szufladami
# szufladą szufladą
# szufladę szufladę
# ref: szuflado pred: szufladzie
# szuflady szuflady
# szuflady szuflady
# szuflady szuflady
# rzepikami rzepikami
# rzepikiem rzepikiem
# rzepiki rzepiki
# rzepik rzepik
# rzepik rzepik
# rzepików rzepików
# rzepiku rzepiku
# rzepiku rzepiku
# gnojach gnojach
# ref: gnojami pred: gnójami
# ref: gnojem pred: gnójem
# ref: gnoje pred: gnóje
# ref: gnoje pred: gnóje
# gnój gnój
# gnój gnój
# ref: gnojowi pred: gnójowi
# ref: gnoju pred: gnoji
# ref: gnoju pred: gnój
# winogronowe winogronowe
# winogronowe winogronowe
# winogronowe winogronowe
# winogronowego winogronowego
# winogronowego winogronowego
# winogronowej winogronowej
# winogronowej winogronowej
# winogronowej winogronowej
# winogronowemu winogronowemu
# winogronowemu winogronowemu
# winogronowy winogronowy
# winogronowym winogronowym
# winogronowym winogronowym
# ref: będą kleili pred: będziemy kleili
# ref: będą kleiły pred: będziemy kleiły
# ref: będę kleiła pred: będzie kleiła
# ref: będę kleił pred: będzie kleił
# ref: będziecie kleiły pred: będziemy kleiły
# ref: będzie kleiło pred: będziesz kleił
# będziemy kleili będziemy kleili
# ref: kleicie pred: kleją
# kleić kleić
# kleiłabym kleiłabym
# ref: kleiłabyś pred: kleiłabym
# ref: kleiłam pred: kleiłabym
# ref: kleiłby pred: kleiłbym
# ref: kleiłem pred: kleiłbyś
# ref: kleiłeś pred: kleiłbyś
# ref: kleilibyśmy pred: kleilibyście
# ref: kleiliście pred: kleilibyście
# ref: kleiliśmy pred: kleilibyśmy
# kleiło kleiło
# kleił kleił
# kleiłybyście kleiłybyście
# ref: kleiłyby pred: kleiłybyście
# kleiłyście kleiłyście
# kleiłyśmy kleiłyśmy
# ref: kleimy pred: kleją
# klejąca klejąca
# klejące klejące
# ref: klejący pred: kleilibyście
# klejący klejący
# kleją kleją
# ref: klejeni pred: kleilibyście
# ref: klejona pred: klejąca
# ref: klejono pred: klejący
# ref: klej pred: będziesz kleił
# uczuciach uczuciach
# uczuciami uczuciami
# uczucia uczucia
# uczucia uczucia
# uczucie uczucie
# uczuciu uczuciu
# edylach edylach
# edylami edylami
# ref: edyla pred: edylu
# ref: edyli pred: edyle
# edyl edyl
# edylom edylom
# ref: edylowie pred: edyle
# edylu edylu
# edylu edylu
# tłumaczeniach tłumaczeniach
# tłumaczenia tłumaczenia
# tłumaczenia tłumaczenia
# tłumaczeniem tłumaczeniem
# tłumaczenie tłumaczenie
# tłumaczenie tłumaczenie
# tłumaczeniu tłumaczeniu
# tłumaczeniu tłumaczeniu
# plombą plombą
# plomba plomba
# plombę plombę
# plombie plombie
# plombie plombie
# plomb plomb
# plombo plombo
# plomby plomby
# plomby plomby
# nieśmiertelną nieśmiertelną
# nieśmiertelną nieśmiertelną
# nieśmiertelnego nieśmiertelnego
# nieśmiertelnej nieśmiertelnej
# ref: nieśmiertelnej pred: nieśmiertelną
# nieśmiertelnej nieśmiertelnej
# nieśmiertelnemu nieśmiertelnemu
# nieśmiertelni nieśmiertelni
# nieśmiertelnych nieśmiertelnych
# nieśmiertelnych nieśmiertelnych
# nieśmiertelnym nieśmiertelnym
# kulach kulach
# kulą kulą
# kula kula
# kule kule
# ref: kule pred: kuly
# kuli kuli
# ref: kuli pred: kuly
# kul kul
# brzoskwiniową brzoskwiniową
# brzoskwiniowa brzoskwiniowa
# brzoskwiniowe brzoskwiniowe
# brzoskwiniowe brzoskwiniowe
# brzoskwiniowego brzoskwiniowego
# brzoskwiniowego brzoskwiniowego
# brzoskwiniowego brzoskwiniowego
# brzoskwiniowej brzoskwiniowej
# brzoskwiniowej brzoskwiniowej
# ref: brzoskwiniowi pred: brzoskwiniowy
# brzoskwiniowy brzoskwiniowy
# brzoskwiniowych brzoskwiniowych
# brzoskwiniowych brzoskwiniowych
# brzoskwiniowych brzoskwiniowych
# brzoskwiniowym brzoskwiniowym
# brzoskwiniowymi brzoskwiniowymi
# istnieniach istnieniach
# istnienia istnienia
# istnienia istnienia
# istnienia istnienia
# istnienie istnienie
# istnienie istnienie
# istnieniom istnieniom
# ref: istnień pred: istnienia
# martwą martwą
# martwa martwa
# martwe martwe
# martwe martwe
# martwego martwego
# martwego martwego
# martwemu martwemu
# martwemu martwemu
# ref: martwi pred: martwy
# ref: martwy pred: martwego
# martwy martwy
# martwych martwych
# martwych martwych
# martwym martwym
# martwym martwym
# martwym martwym
# martwym martwym
# martwymi martwymi
# napięciach napięciach
# napięcia napięcia
# napięcia napięcia
# napięcia napięcia
# napięcie napięcie
# napięciu napięciu
# ref: napięć pred: napięci
# dziwce dziwce
# dziwkami dziwkami
# dziwką dziwką
# dziwki dziwki
# dziwki dziwki
# dziwkom dziwkom
# dziwko dziwko
# kompromisem kompromisem
# kompromisie kompromisie
# ref: kompromisie pred: kompromisu
# kompromis kompromis
# kompromisom kompromisom
# kompromisowi kompromisowi
# kompromisów kompromisów
# kompromisu kompromisu
# kompromisy kompromisy
# klanami klanami
# klanem klanem
# klanie klanie
# klan klan
# klanom klanom
# klanowi klanowi
# klany klany
# klany klany
# klany klany
# polanach polanach
# polanami polanami
# polana polana
# polanę polanę
# polanie polanie
# polanie polanie
# polanom polanom
# polano polano
# polany polany
# polany polany
# ref: niech wyrządzą pred: będziemy wyrządzili
# ref: niech wyrządzę pred: będziesz wyrządził
# ref: wyrządzeni pred: wyrządzilibyśmy
# ref: wyrządzę pred: będziesz wyrządził
# wyrządziłabym wyrządziłabym
# ref: wyrządziłabyś pred: wyrządziłabym
# ref: wyrządziłaś pred: wyrządziłabym
# wyrządziła wyrządziła
# wyrządziłbym wyrządziłbym
# ref: wyrządziłbyś pred: wyrządziłbym
# ref: wyrządziłby pred: wyrządziłbym
# ref: wyrządziłeś pred: wyrządziłbyś
# wyrządzilibyście wyrządzilibyście
# ref: wyrządzilibyśmy pred: wyrządzilibyście
# ref: wyrządziliby pred: wyrządzilibyście
# ref: wyrządziliście pred: wyrządzilibyśmy
# ref: wyrządziliśmy pred: wyrządzilibyśmy
# ref: wyrządziłoby pred: wyrządziłby
# wyrządził wyrządził
# wyrządziłybyśmy wyrządziłybyśmy
# ref: wyrządziłyście pred: wyrządziłyśmy
# wyrządziłyśmy wyrządziłyśmy
# ref: wyrządziły pred: wyrządziłyśmy
# ref: wyrządzimy pred: będziemy wyrządziły
# wyrządzona wyrządzona
# wyrządzone wyrządzone
# ref: wyrządzono pred: wyrządzone
# ref: wyrządź pred: będzie wyrządził
# niższą niższą
# niższa niższa
# niższe niższe
# niższe niższe
# niższego niższego
# niższego niższego
# niższej niższej
# niższemu niższemu
# niższych niższych
# niższym niższym
# niższym niższym
# niższym niższym
# niższym niższym
# nastolatkach nastolatkach
# nastolatkami nastolatkami
# nastolatka nastolatka
# nastolatki nastolatki
# nastolatki nastolatki
# ref: nastolatków pred: nastolatki
# nastolatku nastolatku
# zbiegach zbiegach
# ref: zbiega pred: zbieg
# zbieg zbieg
# zbiegom zbiegom
# ref: zbiegowie pred: zbiegi
# ref: zbiegów pred: zbiegy
# zbiegu zbiegu
# ref: szkutnicy pred: szkutniki
# szkutnikach szkutnikach
# szkutnikami szkutnikami
# szkutnika szkutnika
# szkutnikom szkutnikom
# szkutników szkutników
# szkutniku szkutniku
# ref: samotniejsi pred: samotniejszy
# samotniejszą samotniejszą
# samotniejszą samotniejszą
# samotniejsza samotniejsza
# samotniejsze samotniejsze
# samotniejsze samotniejsze
# samotniejsze samotniejsze
# samotniejszego samotniejszego
# samotniejszego samotniejszego
# samotniejszej samotniejszej
# samotniejszej samotniejszej
# samotniejszemu samotniejszemu
# ref: samotniejszy pred: samotniejszego
# samotniejszy samotniejszy
# samotniejszych samotniejszych
# samotniejszych samotniejszych
# samotniejszym samotniejszym
# samotniejszym samotniejszym
# samotniejszymi samotniejszymi
# mitozach mitozach
# mitoza mitoza
# mitozę mitozę
# mitozie mitozie
# mitozom mitozom
# mitozy mitozy
# asemblerach asemblerach
# asemblerami asemblerami
# asemblera asemblera
# asemblerowi asemblerowi
# asemblerów asemblerów
# asemblery asemblery
# asemblery asemblery
# asemblerze asemblerze
# ref: asemblerze pred: asemblerowi
# ref: automacie pred: automatu
# automatami automatami
# automat automat
# ref: automatowi pred: automacie
# automaty automaty
# automaty automaty
# kasztanach kasztanach
# kasztanami kasztanami
# kasztan kasztan
# kasztan kasztan
# kasztany kasztany
# kasztany kasztany
# ref: śródmózgowiach pred: śródmózgowcach
# ref: śródmózgowiami pred: śródmózgowcami
# ref: śródmózgowia pred: śródmózgowie
# śródmózgowie śródmózgowie
# śródmózgowie śródmózgowie
# ref: śródmózgowi pred: śródmózgowców
# ref: śródmózgowiu pred: śródmózgowcu
# ref: śródmózgowiu pred: śródmózgowcu
# ref: lisiąt pred: lisionów
# ref: lisięciem pred: lisięmi
# ref: lisięciu pred: lisię
# ref: lisięciu pred: lisię
# lisię lisię
# lisię lisię
# ref: lisiętach pred: lisiach
# ref: lisiętami pred: lisięmi
# ref: lisięta pred: lisię
# ref: lisięta pred: lisięci
# ref: lisiętom pred: lisiom
# ref: graniach pred: granach
# ref: granią pred: graną
# ref: granie pred: grań
# granie granie
# ref: grani pred: grania
# grań grań
# basach basach
# basie basie
# ref: basie pred: basu
# bas bas
# bas bas
# basy basy
# woskowiną woskowiną
# woskowina woskowina
# ref: woskowino pred: woskowinie
# ref: zadadzą pred: będziemy zadały
# sinologia sinologia
# sinologię sinologię
# sinologii sinologii
# sinologii sinologii
# sinologii sinologii
# sinologio sinologio
# kurami kurami
# kur kur
# kurom kurom
# kurowi kurowi
# kurów kurów
# kurze kurze
# ref: kurze pred: kuru
# przysięgach przysięgach
# przysięgami przysięgami
# przysięga przysięga
# przysięgi przysięgi
# przysięgom przysięgom
# przysięgo przysięgo
# nonanem nonanem
# ref: nonanie pred: nonanu
# nonan nonan
# nonan nonan
# nonanów nonanów
# nonany nonany
# elektrowniami elektrowniami
# elektrownie elektrownie
# elektrownie elektrownie
# elektrownie elektrownie
# ref: elektrowni pred: elektrownią
# elektrowni elektrowni
# elektrowniom elektrowniom
# fotografach fotografach
# fotografami fotografami
# fotografem fotografem
# ref: fotografie pred: fotografu
# fotograf fotograf
# ref: fotografów pred: fotografy
# ref: będą machały pred: będziemy machały
# ref: będę machała pred: będzie machała
# ref: będę machał pred: będzie machał
# ref: będziecie machali pred: będziemy machali
# będzie machała będzie machała
# ref: będzie machało pred: będziesz machał
# będzie machał będzie machał
# będziemy machali będziemy machali
# ref: będziemy machały pred: będziemy machali
# ref: będziesz machała pred: będzie machała
# ref: będziesz machał pred: będzie machał
# ref: machający pred: machalibyście
# ref: machający pred: machane
# ref: machajcie pred: będziemy machali
# ref: machajmy pred: będziemy machali
# ref: machałaby pred: machałabym
# ref: machałam pred: machałabym
# ref: machałaś pred: machałabym
# machała machała
# machałbym machałbym
# ref: machałby pred: machałbym
# ref: machałem pred: machałbym
# machalibyście machalibyście
# ref: machalibyśmy pred: machalibyście
# ref: machaliśmy pred: machalibyśmy
# ref: machałoby pred: machałby
# machałybyśmy machałybyśmy
# ref: machałyby pred: machalibyśmy
# ref: machałyście pred: machałyśmy
# machałyśmy machałyśmy
# ref: machały pred: machałyśmy
# ref: macham pred: machało
# machane machane
# machanie machanie
# ref: machani pred: machalibyśmy
# machano machano
# ref: machasz pred: machało
# ref: niech macha pred: będziesz machał
# jonosferach jonosferach
# jonosfera jonosfera
# jonosferom jonosferom
# jonosfery jonosfery
# jonosfery jonosfery
# jonosfery jonosfery
# jonosferze jonosferze
# lodach lodach
# lodem lodem
# ref: lód pred: lod
# lodom lodom
# lodowi lodowi
# lodów lodów
# lodzie lodzie
# ref: będą siąknąły pred: będziemy siąknęły
# ref: będą siąknęli pred: będziemy siąknęli
# będziemy siąknęli będziemy siąknęli
# ref: będzie siąknąła pred: będzie siąknęła
# ref: będzie siąknąło pred: będzie siąknęło
# ref: będzie siąknął pred: będzie siąknęł
# ref: będziesz siąknąła pred: będzie siąknęła
# ref: będziesz siąknął pred: będzie siąknęł
# ref: niech siąkną pred: będziemy siąknęli
# ref: niech siąknie pred: będziesz siąknęł
# ref: siąknąca pred: siąknęłabym
# siąknące siąknące
# ref: siąknące pred: siąknęłybyśmy
# ref: siąknący pred: siąknęłybyśmy
# ref: siąknąłabyś pred: siąknęłabym
# ref: siąknąłaby pred: siąknęłabym
# ref: siąknąła pred: siąknęła
# ref: siąknąłbyś pred: siąknąłbym
# ref: siąknąłeś pred: siąknęło
# ref: siąknąłybyście pred: siąknąłybyśmy
# siąknąłybyśmy siąknąłybyśmy
# ref: siąknąłyby pred: siąknąłybyśmy
# siąknąłyśmy siąknąłyśmy
# siąkną siąkną
# ref: siąknęlibyście pred: siąknąlibyście
# ref: siąknęlibyśmy pred: siąknąlibyście
# ref: siąknęliście pred: siąknąliście
# ref: siąknęliśmy pred: siąknąlibyśmy
# ref: siąknę pred: siąknęło
# ref: siąkniemy pred: siąknąłyśmy
# ref: siąkniesz pred: siąknęło
# ref: siąknie pred: siąknęło
# ref: siąknijcie pred: będziemy siąknęli
# ref: siąknijmy pred: będziemy siąknęli
# ref: siąknij pred: będziesz siąknęł
# najdzikszą najdzikszą
# najdziksza najdziksza
# najdziksze najdziksze
# najdziksze najdziksze
# najdzikszego najdzikszego
# najdzikszej najdzikszej
# najdzikszej najdzikszej
# najdzikszej najdzikszej
# najdzikszemu najdzikszemu
# ref: najdzikszy pred: najdzikszego
# najdzikszy najdzikszy
# najdzikszych najdzikszych
# najdzikszych najdzikszych
# najdzikszym najdzikszym
# peronach peronach
# peronem peronem
# ref: peronie pred: peronu
# peronom peronom
# peronów peronów
# perony perony
# sygnałach sygnałach
# sygnałami sygnałami
# sygnał sygnał
# sygnałom sygnałom
# sygnały sygnały
# sygnały sygnały
# najlżejszą najlżejszą
# najlżejsza najlżejsza
# najlżejsze najlżejsze
# najlżejsze najlżejsze
# najlżejsze najlżejsze
# najlżejszego najlżejszego
# najlżejszego najlżejszego
# najlżejszej najlżejszej
# najlżejszemu najlżejszemu
# najlżejszy najlżejszy
# najlżejszych najlżejszych
# najlżejszych najlżejszych
# najlżejszym najlżejszym
# najlżejszymi najlżejszymi
# wybuchach wybuchach
# wybuchem wybuchem
# wybuch wybuch
# wybuch wybuch
# wybuchowi wybuchowi
# wybuchu wybuchu
# wybuchu wybuchu
# wybuchu wybuchu
# wybuchy wybuchy
# wybuchy wybuchy
# ref: sekście pred: sekstie
# ref: sekście pred: sekscie
# sekstą sekstą
# seksta seksta
# ref: sekst pred: sekstów
# sekstom sekstom
# seksto seksto
# seksty seksty
# seksty seksty
# seksty seksty
# bocianach bocianach
# bocianami bocianami
# bociana bociana
# bocianem bocianem
# bocianie bocianie
# bocian bocian
# bocianom bocianom
# bocianów bocianów
# bociany bociany
# bociany bociany
# trwania trwania
# trwanie trwanie
# trwanie trwanie
# trwaniu trwaniu
# trwaniu trwaniu
# ref: będę marła pred: będzie mrzeła
# ref: będziecie marli pred: będziemy mrzeli
# ref: będziecie marły pred: będziemy mrzeli
# ref: będzie marła pred: będzie mrzeła
# ref: będzie marło pred: będzie mrzeł
# ref: będzie marł pred: będzie mrzeł
# ref: będziemy marli pred: będziemy mrzeli
# ref: marcie pred: mrzenie
# ref: marłabyś pred: mrzełabym
# ref: marłam pred: mrzełabym
# ref: marłaś pred: mrzełaś
# ref: marła pred: mrzeła
# ref: marłbyś pred: mrzełbym
# ref: marłby pred: mrzełby
# ref: marłeś pred: mrzeł
# ref: marlibyście pred: mrzelibyście
# ref: marlibyśmy pred: mrzelibyście
# ref: marł pred: mrzeł
# ref: marłyby pred: mrzelibyście
# ref: marłyśmy pred: mrzeliśmy
# ref: marły pred: mrzeliśmy
# ref: mrące pred: mrzące
# ref: mrące pred: mrzenie
# ref: mrąc pred: mrzenie
# ref: mrący pred: mrzelibyście
# ref: mrący pred: mrzenie
# ref: mrzecie pred: mrzeliśmy
# ref: mrzeć pred: mrzące
# ref: mrzemy pred: mrzelibyśmy
# ref: mrze pred: mrzeł
# ref: mrzyjcie pred: będziemy mrzeli
# ref: mrzyj pred: będziesz mrzeł
# ref: niech mrą pred: będziemy mrzeli
# ref: niech mrze pred: będziesz mrzeł
# oczopląsach oczopląsach
# oczopląs oczopląs
# oczopląsowi oczopląsowi
# oczopląsy oczopląsy
# przewodniczącego przewodniczącego
# ref: przewodniczących pred: przewodniczące
# przewodniczących przewodniczących
# przewodniczącym przewodniczącym
# ref: przewodniczący pred: przewodniczące
# ref: przewodniczący pred: przewodniczące
# mięczakach mięczakach
# mięczakami mięczakami
# ref: mięczaka pred: mięczak
# mięczaka mięczaka
# mięczakiem mięczakiem
# mięczaki mięczaki
# mięczaki mięczaki
# mięczaki mięczaki
# mięczak mięczak
# mięczakowi mięczakowi
# mięczaków mięczaków
# nieodpowiedzialna nieodpowiedzialna
# nieodpowiedzialne nieodpowiedzialne
# nieodpowiedzialne nieodpowiedzialne
# nieodpowiedzialne nieodpowiedzialne
# nieodpowiedzialne nieodpowiedzialne
# nieodpowiedzialnego nieodpowiedzialnego
# nieodpowiedzialnego nieodpowiedzialnego
# nieodpowiedzialnego nieodpowiedzialnego
# nieodpowiedzialnemu nieodpowiedzialnemu
# nieodpowiedzialnemu nieodpowiedzialnemu
# nieodpowiedzialni nieodpowiedzialni
# nieodpowiedzialny nieodpowiedzialny
# nieodpowiedzialnych nieodpowiedzialnych
# nieodpowiedzialnym nieodpowiedzialnym
# nieodpowiedzialnym nieodpowiedzialnym
# nieodpowiedzialnymi nieodpowiedzialnymi
# ref: szalu pred: szaliwi
# cyrkami cyrkami
# cyrkiem cyrkiem
# cyrki cyrki
# cyrk cyrk
# cyrk cyrk
# cyrków cyrków
# cyrku cyrku
# cyrku cyrku
# cyrku cyrku
# ref: najjaśniejsi pred: najjaśniejszy
# najjaśniejszą najjaśniejszą
# najjaśniejsza najjaśniejsza
# najjaśniejsze najjaśniejsze
# najjaśniejsze najjaśniejsze
# najjaśniejszego najjaśniejszego
# najjaśniejszej najjaśniejszej
# najjaśniejszej najjaśniejszej
# najjaśniejszych najjaśniejszych
# najjaśniejszych najjaśniejszych
# najjaśniejszych najjaśniejszych
# najjaśniejszym najjaśniejszym
# najjaśniejszym najjaśniejszym
# żenecie żenecie
# żenetami żenetami
# żenetą żenetą
# żeneta żeneta
# żenetę żenetę
# żenet żenet
# żenetom żenetom
# żenety żenety
# żenety żenety
# żenety żenety
# waściach waściach
# waściami waściami
# waści waści
# waści waści
# waści waści
# waści waści
# waści waści
# waść waść
# ref: otwarci pred: otwarty
# otwartą otwartą
# otwarta otwarta
# otwarte otwarte
# otwarte otwarte
# otwartego otwartego
# otwartej otwartej
# otwartej otwartej
# otwartej otwartej
# otwartemu otwartemu
# otwartemu otwartemu
# ref: otwarty pred: otwartego
# ref: otwarty pred: otwarte
# otwartych otwartych
# otwartym otwartym
# otwartym otwartym
# otwartymi otwartymi
# ref: dłużnicy pred: dłużniki
# ref: dłużnicy pred: dłużniki
# dłużnikami dłużnikami
# dłużnika dłużnika
# dłużnik dłużnik
# dłużnikowi dłużnikowi
# ref: manicure'ami pred: manicurami
# ref: manicure'em pred: manicurą
# ref: manicure pred: manicurę
# ref: manicure'om pred: manicurom
# ref: manicure'y pred: manicury
# ref: manicure'y pred: manicury
# ref: manicure'y pred: manicury
# ref: manicurze pred: manicure
# sefardyjscy sefardyjscy
# ref: sefardyjski pred: sefardyjskiego
# sefardyjskich sefardyjskich
# sefardyjskie sefardyjskie
# sefardyjskiego sefardyjskiego
# sefardyjskiego sefardyjskiego
# ref: sefardyjskiej pred: sefardyjską
# sefardyjskiej sefardyjskiej
# sefardyjskiemu sefardyjskiemu
# sefardyjskim sefardyjskim
# sefardyjskim sefardyjskim
# sefardyjskim sefardyjskim
# sefardyjskimi sefardyjskimi
# szynce szynce
# szynce szynce
# ref: szynek pred: szynków
# szynkami szynkami
# szynkę szynkę
# szynki szynki
# szynkom szynkom
# szynko szynko
# częstokołach częstokołach
# częstokołami częstokołami
# ref: częstokole pred: częstokołu
# ref: częstokół pred: częstokoł
# tulem tulem
# tul tul
# tulowi tulowi
# tulu tulu
# tulu tulu
# ścianami ścianami
# ściana ściana
# ścianę ścianę
# ścianom ścianom
# ściano ściano
# ściany ściany
# ściany ściany
# ref: baracheł pred: barachłów
# barachłach barachłach
# barachła barachła
# barachła barachła
# barachła barachła
# barachło barachło
# barachło barachło
# ref: barachłu pred: barachłowi
# czczą czczą
# czcza czcza
# czcze czcze
# czcze czcze
# czcze czcze
# czczego czczego
# czczej czczej
# czczej czczej
# czczy czczy
# czczych czczych
# czczym czczym
# czczym czczym
# czczymi czczymi
# ref: Indianach pred: Indianinach
# ref: Indianie pred: Indianiny
# Indianinie Indianinie
# ref: Indianinie pred: Indianinu
# Indianin Indianin
# Indianinowi Indianinowi
# ref: Indian pred: Indianiny
# hodowlach hodowlach
# hodowlą hodowlą
# hodowla hodowla
# hodowle hodowle
# hodowli hodowli
# hodowli hodowli
# ref: hodowli pred: hodowly
# hodowlom hodowlom
# pacie pacie
# ref: pacie pred: patu
# patami patami
# ref: pata pred: pat
# pat pat
# patowi patowi
# patów patów
# paty paty
# ilustracjach ilustracjach
# ilustracje ilustracje
# ilustracje ilustracje
# ref: ilustracji pred: ilustracjów
# ilustracjom ilustracjom
# ref: ilustracjo pred: ilustracji
# rachunek rachunek
# rachunek rachunek
# rachunkach rachunkach
# rachunkiem rachunkiem
# rachunki rachunki
# rachunkowi rachunkowi
# rachunków rachunków
# rachunku rachunku
# rachunku rachunku
# zimową zimową
# zimową zimową
# zimowa zimowa
# zimowe zimowe
# zimowe zimowe
# zimowego zimowego
# zimowego zimowego
# zimowego zimowego
# zimowej zimowej
# zimowemu zimowemu
# ref: zimowy pred: zimowego
# zimowy zimowy
# zimowych zimowych
# zimowych zimowych
# zimowym zimowym
# zimowym zimowym
# zimowym zimowym
# rutenem rutenem
# ruten ruten
# chrabąszczach chrabąszczach
# chrabąszczami chrabąszczami
# ref: chrabąszcza pred: chrabąszcz
# chrabąszczem chrabąszczem
# chrabąszcze chrabąszcze
# chrabąszcze chrabąszcze
# chrabąszczom chrabąszczom
# chrabąszczowi chrabąszczowi
# ref: chrabąszczy pred: chrabąszczów
# miarami miarami
# miarę miarę
# miar miar
# miarom miarom
# miaro miaro
# miary miary
# miary miary
# ref: mierze pred: miarze
# dzieżach dzieżach
# dzieżami dzieżami
# dzieżą dzieżą
# ref: dzieże pred: dzieży
# ref: dzieże pred: dzieży
# dzieżom dzieżom
# dzieżo dzieżo
# ref: dzieży pred: dzieżą
# dzieży dzieży
# małpeczce małpeczce
# małpeczkach małpeczkach
# małpeczkami małpeczkami
# małpeczki małpeczki
# małpeczkom małpeczkom
# małpeczko małpeczko
# koronach koronach
# koroną koroną
# korona korona
# koronę koronę
# koronie koronie
# koronom koronom
# ref: korono pred: koronie
# korony korony
# korony korony
# korony korony
# ref: lipca pred: lipcu
# ref: lipce pred: lipiece
# ref: lipce pred: lipiece
# ref: lipce pred: lipcy
# lipcom lipcom
# lipców lipców
# lipiec lipiec
# lipiec lipiec
# zupami zupami
# zupą zupą
# zupa zupa
# zupie zupie
# ref: zup pred: zupów
# zupo zupo
# zupy zupy
# zupy zupy
# ref: miocie pred: miotu
# miotach miotach
# miotami miotami
# miot miot
# miotom miotom
# miotowi miotowi
# miotu miotu
# mioty mioty
# mioty mioty
# mioty mioty
# 0.705
