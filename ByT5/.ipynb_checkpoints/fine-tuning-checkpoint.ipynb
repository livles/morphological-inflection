# %% [markdown]
# # Setup

# %%
# %cd /dss/dsshome1/03/ge87wod2/morphological-inflection/ByT5/
# Out:
# /dss/dsshome1/03/ge87wod2/morphological-inflection/ByT5
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !pip install transformers torch datasets pip accelerate
# !pip install transformers --upgrade
# !pip install ipywidgets
# !pip install python-dotenv pickleshare
# Out:
# Collecting transformers
#   Using cached transformers-4.57.1-py3-none-any.whl.metadata (43 kB)
# Collecting torch
#   Downloading torch-2.9.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Collecting datasets
#   Downloading datasets-4.4.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (24.0)
# Collecting accelerate
#   Using cached accelerate-1.11.0-py3-none-any.whl.metadata (19 kB)
# Collecting filelock (from transformers)
#   Using cached filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting huggingface-hub<1.0,>=0.34.0 (from transformers)
#   Using cached huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading regex-2025.11.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Using cached tokenizers-0.22.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Using cached safetensors-0.6.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting tqdm>=4.27 (from transformers)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.0)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.10/dist-packages (from torch) (2024.5.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch)
#   Using cached nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch)
#   Using cached nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch)
#   Using cached nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch)
#   Using cached nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch)
#   Using cached nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch)
#   Using cached nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch)
#   Using cached nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting nvidia-nccl-cu12==2.27.5 (from torch)
#   Using cached nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvshmem-cu12==3.3.20 (from torch)
#   Using cached nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch)
#   Using cached nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch)
#   Using cached nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch)
#   Using cached nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.5.1 (from torch)
#   Downloading triton-3.5.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Collecting pyarrow>=21.0.0 (from datasets)
#   Using cached pyarrow-22.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.2 kB)
# Collecting dill<0.4.1,>=0.3.0 (from datasets)
#   Using cached dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.1)
# Collecting httpx<1.0.0 (from datasets)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting xxhash (from datasets)
#   Using cached xxhash-3.6.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.19 (from datasets)
#   Downloading multiprocess-0.70.18-py310-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.8)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.9.5)
# Collecting anyio (from httpx<1.0.0->datasets)
#   Using cached anyio-4.11.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1.0.0->datasets) (2024.6.2)
# Collecting httpcore==1.* (from httpx<1.0.0->datasets)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<1.0.0->datasets) (3.7)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1.0.0->datasets)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub<1.0,>=0.34.0->transformers)
#   Using cached hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (4.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1.0.0->datasets) (1.2.1)
# Collecting sniffio>=1.1 (from anyio->httpx<1.0.0->datasets)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Using cached transformers-4.57.1-py3-none-any.whl (12.0 MB)
# Downloading torch-2.9.1-cp310-cp310-manylinux_2_28_x86_64.whl (899.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.8/899.8 MB 11.4 MB/s eta 0:00:0000:0100:01
# Using cached nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
# Using cached nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
# Using cached nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
# Using cached nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
# Using cached nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
# Using cached nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
# Using cached nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
# Using cached nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
# Using cached nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
# Using cached nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
# Using cached nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.3 MB)
# Using cached nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
# Using cached nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (124.7 MB)
# Using cached nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading triton-3.5.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (170.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.3/170.3 MB 32.4 MB/s eta 0:00:0000:0100:01
# Downloading datasets-4.4.1-py3-none-any.whl (511 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.6/511.6 kB 5.8 MB/s eta 0:00:00:00:01
# Using cached accelerate-1.11.0-py3-none-any.whl (375 kB)
# Using cached dill-0.4.0-py3-none-any.whl (119 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
# Downloading multiprocess-0.70.18-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.9/134.9 kB 17.3 MB/s eta 0:00:00
# Using cached pyarrow-22.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (47.6 MB)
# Downloading regex-2025.11.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (791 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 791.7/791.7 kB 11.0 MB/s eta 0:00:0000:01
# Using cached safetensors-0.6.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (485 kB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached tokenizers-0.22.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached filelock-3.20.0-py3-none-any.whl (16 kB)
# Using cached xxhash-3.6.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (193 kB)
# Using cached hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached anyio-4.11.0-py3-none-any.whl (109 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, xxhash, triton, tqdm, sympy, sniffio, safetensors, regex, pyarrow, nvidia-nvtx-cu12, nvidia-nvshmem-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, hf-xet, h11, filelock, dill, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, multiprocess, huggingface-hub, httpcore, anyio, tokenizers, nvidia-cusolver-cu12, httpx, transformers, torch, datasets, accelerate
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 14.0.2
#     Uninstalling pyarrow-14.0.2:
#       Successfully uninstalled pyarrow-14.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 24.4.0 requires pyarrow<15.0.0a0,>=14.0.1, but you have pyarrow 22.0.0 which is incompatible.
# Successfully installed accelerate-1.11.0 anyio-4.11.0 datasets-4.4.1 dill-0.4.0 filelock-3.20.0 h11-0.16.0 hf-xet-1.2.0 httpcore-1.0.9 httpx-0.28.1 huggingface-hub-0.36.0 mpmath-1.3.0 multiprocess-0.70.18 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.5 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvshmem-cu12-3.3.20 nvidia-nvtx-cu12-12.8.90 pyarrow-22.0.0 regex-2025.11.3 safetensors-0.6.2 sniffio-1.3.1 sympy-1.14.0 tokenizers-0.22.1 torch-2.9.1 tqdm-4.67.1 transformers-4.57.1 triton-3.5.1 xxhash-3.6.0
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.57.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2024.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.6.2)
# Collecting ipywidgets
#   Using cached ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (8.21.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (5.9.0)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets)
#   Using cached widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets)
#   Using cached jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (3.0.46)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (1.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (4.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Using cached ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Using cached jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
# Using cached widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
# Installing collected packages: widgetsnbextension, jupyterlab_widgets, ipywidgets
# Successfully installed ipywidgets-8.1.8 jupyterlab_widgets-3.0.16 widgetsnbextension-4.0.15
# Collecting python-dotenv
#   Using cached python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Collecting pickleshare
#   Using cached pickleshare-0.7.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Using cached python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Using cached pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Installing collected packages: pickleshare, python-dotenv
# Successfully installed pickleshare-0.7.5 python-dotenv-1.2.1

# %% [markdown]
# # Training small pre-trained ByT5 model using dataset

# %%
LANGS = ["grc","dan","fra","sme","deu","nav","jap","klr","eng","mul","deu_eng"]
LANGS = LANGS[-2:]
LANGS = ["mul_2","amh","pol","ote"]
LANGS = ["mul_2","amh","pol","ote"]
LANGS = ["mul-language-code","mul-language-word"]
LANGS = ["mul-language-code"]
LANGS = ["5lang-sample"]
#LANGS = ["slavic-family"]
LANGS = ["klr-20ksamples"]

PATH_JSON_DATA = "../preprocessing/preprocessing_to_json/data/"

for lang in LANGS:
    from datasets import load_dataset
    dataset = load_dataset("json", data_files={"train": PATH_JSON_DATA + lang + "_trn.json", "validation": PATH_JSON_DATA + lang.split("-")[0] + "_eval.json"})

    print(dataset["train"][0])

    from transformers import AutoTokenizer

    checkpoint = "google/byt5-small"
    tokenizer = AutoTokenizer.from_pretrained(checkpoint)
    # -

    import torch

    from transformers import (
        AutoTokenizer,
        TrainingArguments,
        Trainer,
        AutoModelForSeq2SeqLM,
        Seq2SeqTrainingArguments,
        Seq2SeqTrainer
    )
    from datasets import load_dataset

    def preprocess_function(examples):
        # inputs = [prefix + doc for doc in examples["text"]]
        inputs = examples["input"]
        model_inputs = tokenizer(inputs)

        labels = tokenizer(text_target=examples["target"]) # same length irrelevant here, so no truncation or padding

        model_inputs["labels"] = labels["input_ids"]
        return model_inputs


    tokenized_dataset = dataset.map(preprocess_function, batched=True)
    print(tokenized_dataset)
    sample = tokenized_dataset["train"][0]
    print(sample["labels"])

    from transformers import DataCollatorForSeq2Seq

    data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=checkpoint)

    from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer

    model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    training_args = Seq2SeqTrainingArguments(
        output_dir="byt5_small/"+lang,
        eval_strategy="epoch",
        learning_rate=5e-5,
        per_device_train_batch_size=16,
        per_device_eval_batch_size=16,
        weight_decay=0.01,
        save_total_limit=3,
        num_train_epochs=4,
        predict_with_generate=True,
        # save_strategy="epoch",
        fp16=False,# did not work with True #change to bf16=True for XPU 
        #bf16 = True, # performance was best without setting fp16 or bf16 to true
        push_to_hub=True,
        warmup_steps = 500,
        # load_best_model_at_end=True, # otherwise not model with minimum loss during training, like https://huggingface.co/docs/transformers/tasks/sequence_classification
    )

    trainer = Seq2SeqTrainer(
        model=model,
        args=training_args,
        train_dataset=tokenized_dataset["train"],
        eval_dataset=tokenized_dataset["validation"],
        tokenizer=tokenizer,
        data_collator=data_collator,
        # compute_metrics=compute_metrics,
    )

    trainer.train()
    trainer.push_to_hub()
# Out:
# {'input': 'Inflect bekt | V;IMP;NEG;TR;ABS(2,DU);ERG(1,EXCL,DU)', 'target': 'mubekuje'}
# DatasetDict({
#     train: Dataset({
#         features: ['input', 'target', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 20000
#     })
#     validation: Dataset({
#         features: ['input', 'target', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 1000
#     })
# })
# [112, 120, 101, 104, 110, 120, 109, 104, 1]
# /tmp/ipykernel_888465/884237083.py:81: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(
#     <div>
#
#       <progress value='5000' max='5000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5000/5000 22:14, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.645000</td>
#       <td>0.285506</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.190800</td>
#       <td>0.132391</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.122300</td>
#       <td>0.107730</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.091800</td>
#       <td>0.105346</td>
#     </tr>
#   </tbody>
# </table><p>
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B

# %% [markdown]
# # Train with more epochs

# %%
LANGS = ["5lang-sample"]
#LANGS = ["slavic-family"]



PATH_JSON_DATA = "../preprocessing/preprocessing_to_json/data/"

for lang in LANGS:
    from datasets import load_dataset
    dataset = load_dataset("json", data_files={"train": PATH_JSON_DATA + lang + "_trn.json", "validation": PATH_JSON_DATA + lang + "_dev.json"})

    print(dataset["train"][0])

    from transformers import AutoTokenizer

    checkpoint = "google/byt5-small"
    tokenizer = AutoTokenizer.from_pretrained(checkpoint)
    # 

    import torch

    from transformers import (
        AutoTokenizer,
        TrainingArguments,
        Trainer,
        AutoModelForSeq2SeqLM,
        Seq2SeqTrainingArguments,
        Seq2SeqTrainer
    )
    from datasets import load_dataset

    def preprocess_function(examples):
        # inputs = [prefix + doc for doc in examples["text"]]
        inputs = examples["input"]
        model_inputs = tokenizer(inputs)

        labels = tokenizer(text_target=examples["target"]) # same length irrelevant here, so no truncation or padding

        model_inputs["labels"] = labels["input_ids"]
        return model_inputs


    tokenized_dataset = dataset.map(preprocess_function, batched=True)
    print(tokenized_dataset)
    sample = tokenized_dataset["train"][0]
    print(sample["labels"])

    from transformers import DataCollatorForSeq2Seq

    data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=checkpoint)

    from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer

    model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    training_args = Seq2SeqTrainingArguments(
        output_dir="byt5_small/"+lang+"_16epochs",
        eval_strategy="epoch",
        learning_rate=5e-5,
        per_device_train_batch_size=16,
        per_device_eval_batch_size=16,
        weight_decay=0.01,
        save_total_limit=3,
        num_train_epochs=16,
        predict_with_generate=True,
        # save_strategy="epoch",
        fp16=False,# did not work with True #change to bf16=True for XPU 
        #bf16 = True, # performance was best without setting fp16 or bf16 to true
        push_to_hub=True,
        warmup_steps = 500,
        load_best_model_at_end=True, # otherwise not model with minimum loss during training, like https://huggingface.co/docs/transformers/tasks/sequence_classification,
    )

    trainer = Seq2SeqTrainer(
        model=model,
        args=training_args,
        train_dataset=tokenized_dataset["train"],
        eval_dataset=tokenized_dataset["validation"],
        tokenizer=tokenizer,
        data_collator=data_collator,
        # compute_metrics=compute_metrics,
    )

    trainer.train()
    trainer.push_to_hub()

# %% [markdown]
# # Testing models
# + [ ] TODO: finetune all slavic models and test them on the specific dataset
# + [ ] TODO: test 5lang-sample model on the dataset with prefixes

# %%
# SETTINGS = ["grc","dan","fra","sme","deu","nav","jap","klr","eng","mul","deu_eng"] + ["mul_2","ote","pol","amh"] + ["mul-language-code","mul-language-word"]
SETTINGS = ["mul"]
SETTINGS = ["5lang-sample"]
BASE_TEST_LANGUAGES_OF_SETTING = {"slavic":["pol","ces","csb","dsb","slk"],"slavic-word":["pol","ces","csb","dsb","slk"],"slavic-family":["pol","ces","csb","dsb","slk"],"5lang-sample":["deu","nav","klr","amh","grc"],"5lang-sample_16epochs":["deu","nav","klr","amh","grc"],
                                 "sme-15ksamples":["sme"],"sme-20ksamples":["sme"],"klr-15ksamples":["klr"],"klr-20ksamples":["klr"]
                                 }
CODES = {"slavic": "","slavic-word":["-lang-word"],"slavic-family":["-family","-lang-word","-word-or-family"],"5lang-sample":["-lang-word"],"5lang-sample_16epochs":["-lang-word"],"sme-15ksamples":[""],"sme-20ksamples":[""],"klr-15ksamples":[""],"klr-20ksamples":[""]}
SETTINGS = ["slavic","slavic-word"]
SETTINGS = ["5lang-sample_16epochs"]
SETTINGS = ["sme-15ksamples","sme-20ksamples","klr-15ksamples","klr-20ksamples","5lang-sample_16epochs"]
#TEST_LANGS_OLD = ["grc","dan","fra","sme","deu","nav","jap","klr","eng"] 
#TEST_LANGS = ["grc","dan","fra","sme","deu","nav","jap","klr","eng"] + ["ote","pol","amh","csb"]
#lang5_LANGS = ["deu","nav","klr","amh","grc"]
#lang_code = ""
for lang_setting in SETTINGS:
    test_langs = BASE_TEST_LANGUAGES_OF_SETTING[lang_setting]
    #if lang_setting == "mul": LANG_CODES = ["-language-word","-language-code",""] # test with no language code/word too
    #else: LANG_CODES = [""]
    #for lang_code in LANG_CODES:
        #if lang_setting in ( "deu_eng", "mul") and lang_code == "": test_langs = TEST_LANGS_OLD
        #elif lang_setting in ["mul_2","mul"]: test_langs = TEST_LANGS # test multilingual model on all languages it was trained on + Kashubian
        #elif lang_setting == "5lang-sample": test_langs = lang5_LANGS
        #elif lang_setting == "pol": test_langs = ["pol","csb"] # test Polish model on Kashubian also
        #else: 
    for lang_code in CODES[lang_setting]:
        for test_lang in test_langs:
            import torch
            from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
            PRETRAINED_MODEL = "google/byt5-small"
            FINETUNED_MODEL ="livles/"+lang_setting
            #FINETUNED_MODEL ="./byt5_small/"+lang_setting + lang_code
            MODEL = FINETUNED_MODEL
            print(MODEL)
            tokenizer = AutoTokenizer.from_pretrained(
                FINETUNED_MODEL,
            )
            model = AutoModelForSeq2SeqLM.from_pretrained(
                FINETUNED_MODEL,
            dtype=torch.float16,
            device_map="auto"
            )
            from datasets import load_dataset
            OUT_DIR = "output_byt5_small/" + lang_setting + "/" 
            PATH_TO_JSON_TEST_FILE = "../preprocessing/preprocessing_to_json/data/" + test_lang + lang_code+ "_test.json"
            print("test file: ",PATH_TO_JSON_TEST_FILE)
            PATH_TO_ORIG_TEST_FILE = "../2023InflectionST/part1/data/" + test_lang + ".tst"
            from pathlib import Path
            Path(OUT_DIR).mkdir(parents=True, exist_ok=True)
            with open (OUT_DIR + test_lang + lang_code + "_byt5-small.out","w") as out_file, open (PATH_TO_ORIG_TEST_FILE, "r") as test_file:
                dataset = load_dataset("json",data_files={"test":PATH_TO_JSON_TEST_FILE})
                covered_test_lines = dataset["test"]["input"]
                LEN = len(covered_test_lines)
                COUNTER = 0

                # preds = map (generate,covered_test_lines)
                for line in covered_test_lines:
                    input_ids = tokenizer(line, return_tensors="pt").to(model.device)
                    output = model.generate(
                        **input_ids,
                        max_new_tokens=50,
                        num_beams=4,
                        #early_stopping=True
                    )
                    output_string = (tokenizer.decode(output[0], skip_special_tokens=True))
                    lemma, features, ref = test_file.readline().strip().split("\t")

                    # evaluate
                    if (ref == output_string):
                        COUNTER += 1
                        print(ref,output_string)
                    else:
                        print("ref:",ref,"pred:",output_string)

                    # write
                    out_file.write(lemma + "\t" +features+ "\t" + output_string + "\n")
                    out_file.flush()

                accuracy = COUNTER / LEN
                out_file.write("accuracy:"+ str(accuracy)+"\n")
                print(accuracy)
# Out:
# livles/sme-15ksamples
# test file:  ../preprocessing/preprocessing_to_json/data/sme_test.json
# Generating test split: 0 examples [00:00, ? examples/s]
# abstrávttaid abstrávttaid
# abstrávtta abstrávtta
# abstrávttaiguin abstrávttaiguin
# abstrávttain abstrávttain
# ref: abstráktan pred: abstrávttan
# abstrávttaid abstrávttaid
# abstrávtta abstrávtta
# abstrávttaide abstrávttaide
# ref: abstráktii pred: abstrávttai
# abstrávttat abstrávttat
# ref: abstrákta pred: abstrávtta
# abstrávttain abstrávttain
# abstrávttas abstrávttas
# ref: almmáskivččiime pred: almmáskkášeimme
# ref: almmáskivččiimet pred: almmáskkášeimmet
# ref: almmáskivččen pred: almmáskkášin
# ref: almmáskivččiide pred: almmáskkášeidde
# ref: almmáskivččiidet pred: almmáskkášeiddet
# ref: almmáskivččiiga pred: almmáskkášeigga
# ref: almmáskivččii pred: almmáskkášii
# ref: almmáskehkot pred: almmáskot
# ref: almmáskeahkki pred: almmásko
# ref: almmás pred: almmásko
# ref: almmáskehkoset pred: almmáskoset
# ref: almmáskehkos pred: almmáskos
# ref: almmáskežže pred: almmáskkežetne
# ref: almmáskeažžat pred: almmáskkežit
# ref: almmáskeažžabeahtti pred: almmáskkežeahppi
# ref: almmáskeažžabehtet pred: almmáskkežehpet
# ref: almmáskeaččat pred: almmáskkežat
# ref: almmáskežžet pred: almmáskkežit
# ref: almmáskeš pred: almmáskkeža
# ref: almmásketne pred: almmáske
# almmáskit almmáskit
# ref: almmáskan pred: almmáskin
# ref: almmáskeahppi pred: almmáskibeahtti
# ref: almmáskehpet pred: almmáskibehtet
# ref: almmáskat pred: almmáskit
# ref: almmáskeaba pred: almmáskiba
# ref: almmáska pred: almmáski
# almmáskeimme almmáskeimme
# ref: almmáskin pred: almmásken
# almmáskeidde almmáskeidde
# almmáskeigga almmáskeigga
# almmáske almmáske
# ref: apmasiid pred: amasiid
# ref: apmasa pred: amasa
# ref: apmasiiguin pred: amasiiguin
# ref: apmasiin pred: amasiin
# amasin amasin
# ref: apmasiid pred: amasiid
# ref: apmasa pred: amas
# ref: apmasiidda pred: amasiidda
# ref: apmasii pred: amasii
# ref: apmasat pred: amasat
# amas amas
# ref: apmasiin pred: amasiin
# ref: apmasis pred: amasis
# atomaid atomaid
# atoma atoma
# atomaiguin atomaiguin
# atomain atomain
# atoman atoman
# atomaid atomaid
# atoma atoma
# atomaide atomaide
# ref: atomii pred: atomai
# atomat atomat
# atoma atoma
# atomain atomain
# atomas atomas
# bieđgáleimmet bieđgáleimmet
# bieđgálin bieđgálin
# bieđgáleidde bieđgáleidde
# bieđgálit bieđgálit
# bieđgáleigga bieđgáleigga
# bieđgále bieđgále
# bieđgálii bieđgálii
# bieđgášeimme bieđgášeimme
# bieđgášeimmet bieđgášeimmet
# bieđgášeiddet bieđgášeiddet
# bieđgášit bieđgášit
# bieđgájehkon bieđgájehkon
# bieđgájeahkki bieđgájeahkki
# bieđgájehket bieđgájehket
# bieđgá bieđgá
# bieđgájehkoska bieđgájehkoska
# bieđgážetne bieđgážetne
# bieđgážit bieđgážit
# bieđgážan bieđgážan
# bieđgážeahppi bieđgážeahppi
# bieđgážehpet bieđgážehpet
# bieđgážeaba bieđgážeaba
# bieđgájetne bieđgájetne
# bieđgát bieđgát
# bieđgán bieđgán
# bieđgábeahtti bieđgábeahtti
# bieđgábehtet bieđgábehtet
# ref: bieđgájit pred: bieđgát
# bieđgáimet bieđgáimet
# bieđgájin bieđgájin
# bieđgáidet bieđgáidet
# ref: bieđgájedje pred: bieđgáiga
# ref: buddeleimme pred: butteleimme
# buddelin buddelin
# buddeleiddet buddeleiddet
# buddelit buddelit
# ref: buddeleigga pred: butteleigga
# ref: buddele pred: buttele
# ref: buddelii pred: buttelii
# ref: buddešeimmet pred: buttešeimmet
# ref: buddešin pred: buttešin
# ref: buddešeidde pred: buttešeidde
# ref: buddešit pred: buttešit
# ref: buddešeigga pred: buttešeigga
# ref: buddeše pred: butteše
# ref: buddejetnot pred: buddot
# ref: buddejehkon pred: buddon
# ref: buddejehket pred: buddet
# budde budde
# ref: buddejehkoset pred: buddoset
# ref: buddežeahppi pred: buttežeahppi
# ref: buddežehpet pred: buttežehpet
# ref: buddežat pred: buttežat
# ref: buddežeaba pred: buttežeaba
# buddet buddet
# budden budden
# buddebeahtti buddebeahtti
# buddebehtet buddebehtet
# ref: buddejit pred: buddet
# ref: buddiime pred: buddeimme
# ref: buddejin pred: budden
# ref: buddiiga pred: buddeigga
# ref: buddejedje pred: buddeigga
# báisttáleimmet báisttáleimmet
# báisttálin báisttálin
# báisttáleidde báisttáleidde
# báisttáleiddet báisttáleiddet
# báisttálit báisttálit
# báisttáleigga báisttáleigga
# báisttále báisttále
# báisttálii báisttálii
# báisttášeimme báisttášeimme
# báisttášin báisttášin
# báisttášeidde báisttášeidde
# báisttášeigga báisttášeigga
# báisttáše báisttáše
# báisttášii báisttášii
# ref: báistu pred: báisto
# báistot báistot
# ref: báistet pred: báistot
# báisttežan báisttežan
# báisttežehpet báisttežehpet
# báisttežeaba báisttežeaba
# báisttežit báisttežit
# báistteža báistteža
# báiste báiste
# báistibehtet báistibehtet
# báistá báistá
# báisttiime báisttiime
# ref: báisttiimet pred: báistiimet
# ref: báisten pred: báisttin
# ref: báisttiidet pred: báistiidet
# ref: báisttiiga pred: báistiiga
# ref: báiste pred: báistiiga
# ref: báisttii pred: báistii
# ref: bálgáidan pred: bálgániid
# bálgán bálgán
# ref: bálgáidanguin pred: bálgániiguin
# ref: bálgáinan pred: bálgániin
# ref: bálggisinin pred: bálgánin
# ref: bálgáidan pred: bálgániid
# bálgán bálgán
# ref: bálgáidasan pred: bálgáide
# ref: bálgásan pred: bálgánii
# bálgán bálgán
# ref: bálgáinan pred: bálgániin
# ref: bálgástan pred: bálgán
# báralaččaid báralaččaid
# báralačča báralačča
# báralaččaiguin báralaččaiguin
# báralaččain báralaččain
# ref: báralažžan pred: báralaččan
# báralaččaid báralaččaid
# báralačča báralačča
# báralaččaide báralaččaide
# ref: báralažžii pred: báralaččai
# báralaččat báralaččat
# ref: báralaš pred: báralačča
# báralaččain báralaččain
# báralaččas báralaččas
# ref: bártnaleimme pred: bárnnaleimme
# ref: bártnaleimmet pred: bárnnaleimmet
# ref: bártnaleidde pred: bárnnaleidde
# ref: bártnaleiddet pred: bárnnaleiddet
# ref: bártnalit pred: bárnnalit
# ref: bártnaleigga pred: bárnnaleigga
# ref: bártnalii pred: bárnnalii
# ref: bártnašeimme pred: bárnnašeimme
# ref: bártnašeimmet pred: bárnnašeimmet
# ref: bártnašeidde pred: bárnnašeidde
# ref: bártnašit pred: bárnnašit
# bárdnon bárdnon
# ref: bárdni pred: bárdno
# ref: bártna pred: bárdno
# bárdnoska bárdnoska
# bárdnoset bárdnoset
# bárdnos bárdnos
# ref: bártnažetne pred: bárnnažetne
# ref: bártnažit pred: bárnnažit
# ref: bártnažehpet pred: bárnnažehpet
# ref: bártnažeaba pred: bárnnažeaba
# ref: bártnaža pred: bárnnaža
# ref: bárdne pred: bárdnabu
# bárdnat bárdnat
# ref: bártnan pred: bárdnan
# bárdnabehtet bárdnabehtet
# bárdnaba bárdnaba
# ref: bárdná pred: bárdna
# ref: bártnaime pred: bárdnaime
# ref: bártnaide pred: bárdnaide
# ref: bárdne pred: bárdnaiga
# ref: bártnai pred: bárdnai
# ceggosepmosiid ceggosepmosiid
# ceggosepmosa ceggosepmosa
# ceggosepmosiiguin ceggosepmosiiguin
# ceggosepmosiin ceggosepmosiin
# ref: ceggoseamosin pred: ceggosepmosin
# ceggosepmosiid ceggosepmosiid
# ceggosepmosa ceggosepmosa
# ceggosepmosiidda ceggosepmosiidda
# ceggosepmosii ceggosepmosii
# ceggosepmosat ceggosepmosat
# ref: ceggoseamos pred: ceggosepmos
# ceggosepmosiin ceggosepmosiin
# ceggosepmosis ceggosepmosis
# cuoŋománuid cuoŋománuid
# cuoŋománu cuoŋománu
# cuoŋománuiguin cuoŋománuiguin
# cuoŋománuin cuoŋománuin
# ref: cuoŋománnun pred: cuoŋománun
# cuoŋománuid cuoŋománuid
# cuoŋománu cuoŋománu
# cuoŋománuide cuoŋománuide
# ref: cuoŋománnui pred: cuoŋománui
# cuoŋománut cuoŋománut
# ref: cuoŋománnu pred: cuoŋománu
# cuoŋománuin cuoŋománuin
# cuoŋománus cuoŋománus
# ref: deaivvaleidde pred: deivvaleidde
# ref: deaivvaleiddet pred: deivvaleiddet
# ref: deaivvalit pred: deivvalit
# ref: deaivvaleigga pred: deivvaleigga
# ref: deaivvale pred: deivvale
# ref: deaivvalii pred: deivvalii
# deaivvašeimme deaivvašeimme
# deaivvašeidde deaivvašeidde
# ref: deaivvašeiddet pred: deivvašeiddet
# ref: deaivvašeigga pred: deivvašeigga
# ref: deaivvaše pred: deivvaše
# ref: deaivvašii pred: deivvašii
# ref: deaivu pred: deivo
# ref: deaivi pred: deivo
# ref: deivet pred: deivot
# ref: deaivva pred: deivo
# deivoska deivoska
# deivoset deivoset
# ref: deaivvažit pred: deivvažit
# ref: deaivvažan pred: deivvažan
# ref: deaivvažehpet pred: deivvažehpet
# ref: deaivvažat pred: deivvažat
# ref: deaivvažeaba pred: deivvažeaba
# ref: deive pred: deaiva
# ref: deaivvat pred: deaivat
# ref: deivet pred: deaivat
# ref: deaivvaime pred: deivviime
# ref: deaivvaimet pred: deivviimet
# ref: deiven pred: deivven
# ref: deivet pred: deivvet
# ref: deaivvaiga pred: deivviiga
# ref: deive pred: deivve
# ref: dievalin pred: dievvalin
# ref: dievaleiddet pred: dievvaleiddet
# ref: dievalit pred: dievvalit
# ref: dievale pred: dievvale
# ref: dievalii pred: dievvalii
# ref: dievašeimmet pred: dievvašeimmet
# ref: dievašeidde pred: dievvašeidde
# ref: dievašit pred: dievvašit
# ref: dievašeigga pred: dievvašeigga
# ref: dievaše pred: dievvaše
# ref: dievašii pred: dievvašii
# divvon divvon
# ref: divvet pred: divvot
# ref: dieva pred: divvo
# divvoska divvoska
# divvos divvos
# ref: dievažan pred: dievvažan
# ref: dievažeahppi pred: dievvažeahppi
# ref: dievažehpet pred: dievvažehpet
# ref: dievažat pred: dievvažat
# ref: dievažeaba pred: dievvažeaba
# ref: dievažit pred: dievvažit
# ref: divve pred: dievva
# ref: dievat pred: dievvat
# ref: dievvá pred: dievva
# ref: dievaimet pred: dievvaimet
# ref: divven pred: dievven
# ref: dievaide pred: dievvaide
# ref: dievaidet pred: dievvaidet
# ref: dievaiga pred: dievvaiga
# ref: divve pred: dievvaiga
# ref: dievai pred: dievvai
# dorvvuid dorvvuid
# dorvvu dorvvu
# dorvvuiguin dorvvuiguin
# dorvvuin dorvvuin
# ref: dorvun pred: dorvvun
# dorvvuid dorvvuid
# dorvvu dorvvu
# dorvvuide dorvvuide
# ref: dorvui pred: dorvvui
# dorvvut dorvvut
# ref: dorvu pred: dorvvu
# dorvvuin dorvvuin
# dorvvus dorvvus
# dorvvastivččiime dorvvastivččiime
# dorvvastivččiimet dorvvastivččiimet
# ref: dorvvastivččen pred: dorvvastivččiin
# dorvvastivččiide dorvvastivččiide
# dorvvastivččiidet dorvvastivččiidet
# ref: dorvvastivččet pred: dorvvastivččiit
# dorvvastivččiiga dorvvastivččiiga
# ref: dorvvastivčče pred: dorvvastivččiiga
# dorvvastivččii dorvvastivččii
# dorvvastehkon dorvvastehkon
# dorvvastehket dorvvastehket
# ref: dorvvas pred: dorvvastehket
# dorvvastehkoska dorvvastehkoska
# dorvvastehkoset dorvvastehkoset
# dorvvastehkos dorvvastehkos
# ref: dorvvastežže pred: dorvvasteažžabeahtti
# dorvvasteaččan dorvvasteaččan
# dorvvasteažžabeahtti dorvvasteažžabeahtti
# dorvvasteažžabehtet dorvvasteažžabehtet
# ref: dorvvastežžet pred: dorvvasteažžaba
# ref: dorvvasteš pred: dorvvasteažža
# dorvvastetne dorvvastetne
# dorvvastit dorvvastit
# ref: dorvvastan pred: dorvvastin
# dorvvasteahppi dorvvasteahppi
# dorvvasteaba dorvvasteaba
# dorvvasteimme dorvvasteimme
# dorvvasteiddet dorvvasteiddet
# ref: dorvvastit pred: dorvvastiit
# dorvvasteigga dorvvasteigga
# ref: dorvvaste pred: dorvvasteigga
# dorvvastii dorvvastii
# ref: dorvvolaččabuid pred: dorvvolaččadiid
# ref: dorvvolaččabu pred: dorvvolaččada
# ref: dorvvolaččabuiguin pred: dorvvolaččadiiguin
# ref: dorvvolaččabuin pred: dorvvolaččadiin
# ref: dorvvolaččabun pred: dorvvolaččadin
# ref: dorvvolaččabuid pred: dorvvolaččadiid
# ref: dorvvolaččabu pred: dorvvolaččada
# ref: dorvvolaččabuidda pred: dorvvolaččadiidda
# ref: dorvvolaččabui pred: dorvvolaččadii
# ref: dorvvolaččabut pred: dorvvolaččadat
# ref: dorvvolaččat pred: dorvvolaččabu
# ref: dorvvolaččabuin pred: dorvvolaččadiin
# ref: dorvvolaččabus pred: dorvvolaččadis
# ref: dámaleimme pred: dápmaleimme
# ref: dámalit pred: dápmalit
# ref: dámalii pred: dápmalii
# ref: dámašeimme pred: dápmašeimme
# ref: dámašit pred: dápmašit
# ref: dámašeigga pred: dápmašeigga
# ref: dámaše pred: dápmaše
# ref: dámašii pred: dápmašii
# dápmot dápmot
# dápmon dápmon
# ref: dábmi pred: dápmo
# dápmoset dápmoset
# ref: dámažetne pred: dápmažetne
# ref: dámažeahppi pred: dápmažeahppi
# ref: dámažat pred: dápmažat
# ref: dámažeaba pred: dápmažeaba
# ref: dámažit pred: dápmažit
# ref: dápme pred: dápmabu
# dápmat dápmat
# dápmabeahtti dápmabeahtti
# ref: dámat pred: dápmat
# dápmaba dápmaba
# ref: dápmet pred: dápmat
# ref: dápmá pred: dápma
# ref: dámaime pred: dápmaime
# ref: dámaimet pred: dápmaimet
# ref: dápmen pred: dápman
# ref: dámaide pred: dápmaide
# ref: dámaidet pred: dápmaidet
# ref: dámaiga pred: dápmaiga
# ref: dámai pred: dápmai
# ref: fuoikkáleimme pred: fuikkáleimme
# ref: fuoikkáleimmet pred: fuikkáleimmet
# ref: fuoikkálin pred: fuikkálin
# ref: fuoikkáleidde pred: fuikkáleidde
# ref: fuoikkáleiddet pred: fuikkáleiddet
# ref: fuoikkále pred: fuikkále
# ref: fuoikkálii pred: fuikkálii
# ref: fuoikkášeimme pred: fuikkášeimme
# ref: fuoikkášeiddet pred: fuikkášeiddet
# ref: fuoikkášit pred: fuikkášit
# ref: fuoikkášeigga pred: fuikkášeigga
# ref: fuoikkášii pred: fuikkášii
# ref: fuoiku pred: fuiko
# fuikot fuikot
# fuikon fuikon
# ref: fuoiki pred: fuiko
# ref: fuiket pred: fuikot
# ref: fuoikke pred: fuiko
# fuikoska fuikoska
# fuikkežit fuikkežit
# fuikkežan fuikkežan
# fuikkežat fuikkežat
# fuikkežeaba fuikkežeaba
# fuikkeža fuikkeža
# fuoikit fuoikit
# ref: fuoikkán pred: fuoikin
# fuoikibehtet fuoikibehtet
# ref: fuiken pred: fuikkin
# fuiket fuiket
# fuikkiiga fuikkiiga
# fuikkii fuikkii
# ref: geahppáidan pred: geahppániid
# geahppán geahppán
# ref: geahppáidanguin pred: geahppámiiguin
# ref: geahppáinan pred: geahppániin
# ref: geahpisinin pred: geahppánin
# ref: geahppáidan pred: geahppámiid
# geahppán geahppán
# ref: geahppáidasan pred: geahppáide
# ref: geahppásan pred: geahppánii
# geahppán geahppán
# ref: geahppáinan pred: geahppániin
# ref: geahppástan pred: geahppán
# guoggáleimme guoggáleimme
# guoggálit guoggálit
# guoggáleigga guoggáleigga
# ref: guoggále pred: guokkále
# guoggálii guoggálii
# guoggášeimme guoggášeimme
# guoggášin guoggášin
# guoggášeidde guoggášeidde
# guoggášeiddet guoggášeiddet
# guoggášeigga guoggášeigga
# guoggášii guoggášii
# guoggájeadnu guoggájeadnu
# guoggájehkon guoggájehkon
# guoggá guoggá
# guoggájehkoska guoggájehkoska
# guoggájehkos guoggájehkos
# guoggážetne guoggážetne
# guoggážehpet guoggážehpet
# guoggážat guoggážat
# guoggážit guoggážit
# guoggájetne guoggájetne
# guoggát guoggát
# guoggán guoggán
# guoggábehtet guoggábehtet
# guoggát guoggát
# guoggá guoggá
# guoggáime guoggáime
# guoggáimet guoggáimet
# guoggájin guoggájin
# guoggáide guoggáide
# guoggájit guoggájit
# ref: guoggájedje pred: guoggáiga
# guoktelogigoalmmádiid guoktelogigoalmmádiid
# guoktelogigoalmmáda guoktelogigoalmmáda
# guoktelogigoalmmádiiguin guoktelogigoalmmádiiguin
# guoktelogigoalmmádiin guoktelogigoalmmádiin
# guoktelogigoalmmádin guoktelogigoalmmádin
# guoktelogigoalmmádiid guoktelogigoalmmádiid
# guoktelogigoalmmáda guoktelogigoalmmáda
# guoktelogigoalmmádiidda guoktelogigoalmmádiidda
# guoktelogigoalmmádii guoktelogigoalmmádii
# guoktelogigoalmmádat guoktelogigoalmmádat
# ref: guoktelogigoalmmát pred: guoktelogigoalmmád
# guoktelogigoalmmádiin guoktelogigoalmmádiin
# guoktelogigoalmmádis guoktelogigoalmmádis
# guolástivččiimet guolástivččiimet
# ref: guolástivččen pred: guolástivččiin
# guolástivččiide guolástivččiide
# ref: guolástivččet pred: guolástivččiit
# guolástivččiiga guolástivččiiga
# guolástivččii guolástivččii
# ref: guolásteadnu pred: guolástehko
# ref: guolástehkon pred: guoláston
# guolásteahkki guolásteahkki
# guolástehket guolástehket
# ref: guolás pred: guolástehket
# guolástehkoska guolástehkoska
# guolástehkos guolástehkos
# ref: guolástežže pred: guolásteažžabeahtti
# guolásteažžat guolásteažžat
# guolásteažžabehtet guolásteažžabehtet
# guolásteažžaba guolásteažžaba
# ref: guolástežžet pred: guolásteažžaba
# ref: guolásteš pred: guolásteažža
# ref: guolástetne pred: guoláste
# ref: guolástan pred: guolástin
# ref: guolástehpet pred: guolástibehtet
# ref: guolástat pred: guolástit
# guolástit guolástit
# guolásteimme guolásteimme
# guolásteimmet guolásteimmet
# guolástin guolástin
# guolásteidde guolásteidde
# guolásteiddet guolásteiddet
# ref: guolástit pred: guolástiit
# guolástii guolástii
# guvráleimmet guvráleimmet
# guvrálin guvrálin
# guvráleidde guvráleidde
# guvráleigga guvráleigga
# guvrálii guvrálii
# guvrášeimmet guvrášeimmet
# guvrášin guvrášin
# guvrášeidde guvrášeidde
# guvrášeiddet guvrášeiddet
# guvrájeadnu guvrájeadnu
# guvrájeahkki guvrájeahkki
# guvrájehket guvrájehket
# guvrájehkoset guvrájehkoset
# guvrájehkos guvrájehkos
# guvrážetne guvrážetne
# guvrážit guvrážit
# guvrážehpet guvrážehpet
# guvrážat guvrážat
# guvrážeaba guvrážeaba
# guvrážit guvrážit
# guvráža guvráža
# ref: guvrájetne pred: guvrábu
# guvrán guvrán
# guvrábehtet guvrábehtet
# guvrát guvrát
# ref: guvrájit pred: guvrát
# guvrá guvrá
# guvráide guvráide
# guvrájit guvrájit
# guvráiga guvráiga
# ref: guvrájedje pred: guvráiga
# guvrái guvrái
# guđadiid guđadiid
# guđada guđada
# guđadiiguin guđadiiguin
# guđadiin guđadiin
# guđadin guđadin
# guđadiid guđadiid
# guđada guđada
# guđadiidda guđadiidda
# guđadii guđadii
# guđadat guđadat
# guđat guđat
# guđadis guđadis
# ref: gáissiid pred: gáisiid
# ref: gáissi pred: gáisi
# ref: gáissiiguin pred: gáisiiguin
# ref: gáissiin pred: gáisiin
# gáisin gáisin
# ref: gáissiid pred: gáisiid
# ref: gáissi pred: gáisi
# ref: gáissiide pred: gáisiide
# ref: gáisái pred: gáisii
# ref: gáissit pred: gáisit
# gáisi gáisi
# ref: gáissiin pred: gáisiin
# ref: gáissis pred: gáisis
# ref: gáranasaid pred: gáranasiid
# gáranasa gáranasa
# ref: gáranasaiguin pred: gáranasiiguin
# ref: gáranasain pred: gáranasiin
# ref: gáranassan pred: gáranasin
# ref: gáranasaid pred: gáranasiid
# ref: gáranasa pred: gáranas
# ref: gáranasaide pred: gáranasiidda
# ref: gáranassii pred: gáranasii
# gáranasat gáranasat
# gáranas gáranas
# ref: gáranasain pred: gáranasiin
# ref: gáranasas pred: gáranasis
# gávrroleimmet gávrroleimmet
# gávrroleiddet gávrroleiddet
# gávrrole gávrrole
# gávrrolii gávrrolii
# gávrrošeimmet gávrrošeimmet
# gávrrošin gávrrošin
# gávrrošeidde gávrrošeidde
# gávrrošeiddet gávrrošeiddet
# gávrroše gávrroše
# gávrrošii gávrrošii
# ref: gávru pred: gávro
# gávrot gávrot
# ref: gávrro pred: gávro
# gávroska gávroska
# gávroset gávroset
# gávrrožetne gávrrožetne
# gávrrožit gávrrožit
# gávrrožeahppi gávrrožeahppi
# gávrrožehpet gávrrožehpet
# gávrrožat gávrrožat
# gávrrožeaba gávrrožeaba
# gávrroža gávrroža
# ref: gávrrun pred: gávrun
# gávrubeahtti gávrubeahtti
# ref: gávrrut pred: gávrut
# ref: gávrot pred: gávrut
# gávrruime gávrruime
# gávrruimet gávrruimet
# gávrruide gávrruide
# ref: gávrot pred: gávrruit
# gávrruiga gávrruiga
# ref: gávro pred: gávrruiga
# ref: jiehtanasaid pred: jiehtanasiid
# jiehtanasa jiehtanasa
# ref: jiehtanasaiguin pred: jiehtanasiiguin
# ref: jiehtanassan pred: jiehtanasin
# ref: jiehtanasaid pred: jiehtanasiid
# ref: jiehtanasa pred: jiehtanas
# ref: jiehtanasaide pred: jiehtanasiidda
# ref: jiehtanassii pred: jiehtanasii
# jiehtanasat jiehtanasat
# jiehtanas jiehtanas
# ref: jiehtanasain pred: jiehtanasiin
# ref: jiehtanasas pred: jiehtanasis
# ref: jorbasiid pred: jorbbasiid
# ref: jorbasa pred: jorbbas
# ref: jorbasiiguin pred: jorbbasiiguin
# ref: jorbasiin pred: jorbbasiin
# jorbbasin jorbbasin
# ref: jorbasiid pred: jorbbasiid
# ref: jorbasa pred: jorbbas
# ref: jorbasiidda pred: jorbbasiidda
# ref: jorbasii pred: jorbbasii
# ref: jorbasat pred: jorbbasat
# jorbbas jorbbas
# ref: jorbasiin pred: jorbbasiin
# ref: jorbasis pred: jorbbas
# lasttaid lasttaid
# lastta lastta
# lasttaiguin lasttaiguin
# lasttain lasttain
# lastan lastan
# lasttaid lasttaid
# lastta lastta
# lasttaide lasttaide
# ref: lastii pred: lasttai
# lasttat lasttat
# lasta lasta
# lasttain lasttain
# ref: lasttas pred: lastas
# loahpaleimme loahpaleimme
# loahpaleidde loahpaleidde
# loahpalit loahpalit
# loahpalii loahpalii
# loahpašeimmet loahpašeimmet
# loahpašin loahpašin
# loahpašeidde loahpašeidde
# loahpašit loahpašit
# ref: loahppu pred: loahppo
# ref: lohppon pred: loahppon
# ref: loahppi pred: loahppo
# ref: lohpposka pred: loahpposka
# ref: lohpposet pred: loahpposet
# ref: lohppos pred: loahppos
# loahpažetne loahpažetne
# loahpažit loahpažit
# loahpažan loahpažan
# loahpažeahppi loahpažeahppi
# loahpažehpet loahpažehpet
# loahpažat loahpažat
# loahpažit loahpažit
# loahpaža loahpaža
# ref: lohppe pred: loahppabu
# loahppabehtet loahppabehtet
# ref: lohppet pred: loahppat
# ref: loahppá pred: loahppa
# ref: lohppen pred: loahppin
# ref: loahpaide pred: loahppiide
# ref: loahpaidet pred: loahppiidet
# ref: lohppet pred: loahppit
# ref: loahpaiga pred: loahppiiga
# lávccaid lávccaid
# lávcca lávcca
# lávccaiguin lávccaiguin
# lávccain lávccain
# ref: lákcan pred: lávccan
# lávccaid lávccaid
# lávcca lávcca
# lávccaide lávccaide
# ref: lákcii pred: lávccai
# lávccat lávccat
# ref: lákca pred: lávcca
# lávccain lávccain
# lávccas lávccas
# mohkkámusaid mohkkámusaid
# mohkkámusa mohkkámusa
# mohkkámusaiguin mohkkámusaiguin
# mohkkámusain mohkkámusain
# ref: mohkkámussan pred: mohkkámusan
# mohkkámusaid mohkkámusaid
# mohkkámusa mohkkámusa
# ref: mohkkámusaide pred: mohkkámusiidda
# ref: mohkkámussii pred: mohkkámusai
# mohkkámusat mohkkámusat
# ref: mohkkámus pred: mohkkámusa
# mohkkámusain mohkkámusain
# mohkkámusas mohkkámusas
# positiivvaid positiivvaid
# positiivva positiivva
# positiivvaiguin positiivvaiguin
# positiivvain positiivvain
# ref: positiivan pred: positiivvan
# positiivvaid positiivvaid
# positiivva positiivva
# positiivvaide positiivvaide
# ref: positiivii pred: positiivvai
# positiivvat positiivvat
# ref: positiiva pred: positiivva
# positiivvain positiivvain
# positiivvas positiivvas
# ref: ruđaid pred: ruhtaid
# ref: ruđa pred: ruhta
# ref: ruđaiguin pred: ruhtaiguin
# ref: ruđain pred: ruhtain
# ruhtan ruhtan
# ref: ruđaid pred: ruhtaid
# ref: ruđa pred: ruhta
# ref: ruđaide pred: ruhtaide
# ref: ruđat pred: ruhtat
# ruhta ruhta
# ref: ruđain pred: ruhtain
# ref: ruđas pred: ruhtas
# rusaleimme rusaleimme
# rusaleimmet rusaleimmet
# rusaleidde rusaleidde
# rusalit rusalit
# rusalii rusalii
# rusašeimme rusašeimme
# rusašeimmet rusašeimmet
# rusašin rusašin
# rusašeiddet rusašeiddet
# rusašit rusašit
# rusašii rusašii
# russot russot
# russon russon
# ref: rusa pred: russo
# russoska russoska
# rusažetne rusažetne
# rusažit rusažit
# rusažeahppi rusažeahppi
# rusažeaba rusažeaba
# russat russat
# ref: rusan pred: russan
# russabehtet russabehtet
# ref: rusat pred: russat
# ref: russet pred: russat
# ref: rusaime pred: russeimme
# ref: rusaimet pred: russiimet
# russen russen
# ref: rusaide pred: russeidde
# ref: rusaidet pred: russiidet
# russet russet
# russe russe
# ref: rusai pred: russii
# ref: ráhkkásiid pred: rágisiid
# ref: ráhkkása pred: ráhkis
# ref: ráhkkásiiguin pred: rágisiiguin
# ref: ráhkkásiin pred: ráhkisiin
# ráhkisin ráhkisin
# ref: ráhkkásiid pred: rágisiid
# ref: ráhkkása pred: ráhkis
# ref: ráhkkásiidda pred: rágisiidda
# ref: ráhkkásii pred: ráhkisii
# ref: ráhkkásat pred: ráhkisat
# ráhkis ráhkis
# ref: ráhkkásiin pred: ráhkisiin
# ref: ráhkkásis pred: ráhkis
# ref: skeaikkáleimme pred: skeikkáleimme
# ref: skeaikkálin pred: skeikkálin
# ref: skeaikkáleidde pred: skeikkáleidde
# ref: skeaikkáleiddet pred: skeikkáleiddet
# ref: skeaikkálit pred: skeikkálit
# ref: skeaikkále pred: skeikkále
# ref: skeaikkášeidde pred: skeikkášeidde
# ref: skeaikkášit pred: skeikkášit
# ref: skeaikkášeigga pred: skeikkášeigga
# skeikot skeikot
# ref: skeaiki pred: skeiko
# ref: skeaikke pred: skeiko
# skeikos skeikos
# skeikkežetne skeikkežetne
# skeikkežit skeikkežit
# skeikkežan skeikkežan
# skeikkežeahppi skeikkežeahppi
# skeikkežehpet skeikkežehpet
# skeikkežat skeikkežat
# skeikkežeaba skeikkežeaba
# skeikkežit skeikkežit
# skeikkeža skeikkeža
# ref: skeaikkán pred: skeaikán
# ref: skeaikibeahtti pred: skeaikebeahtti
# skeaikibehtet skeaikibehtet
# ref: skeaikiba pred: skeaikeba
# ref: skeiket pred: skeaiket
# skeikkiide skeikkiide
# ref: skeikkiidet pred: skeikeiddet
# skeiket skeiket
# skeikkiiga skeikkiiga
# ref: skeike pred: skeikkiiga
# ref: stoarpmaid pred: stoarbmaid
# ref: stoarpma pred: stoarbma
# ref: stoarpmaiguin pred: stoarbmaiguin
# ref: stoarpmain pred: stoarbmain
# stoarbman stoarbman
# ref: stoarpmaid pred: stoarbmaid
# ref: stoarpma pred: stoarbma
# ref: stoarpmaide pred: stoarbmaide
# ref: storbmii pred: stoarbmai
# ref: stoarpmat pred: stoarbmat
# stoarbma stoarbma
# ref: stoarpmain pred: stoarbmain
# ref: stoarpmas pred: stoarbmas
# ref: stuorábuid pred: stuorádiid
# ref: stuorábu pred: stuoráda
# ref: stuorábuiguin pred: stuorádiiguin
# ref: stuorábuin pred: stuorádiin
# ref: stuorábun pred: stuorádin
# ref: stuorábuid pred: stuorádiid
# ref: stuorábu pred: stuoráda
# ref: stuorábuidda pred: stuorádiidda
# ref: stuorábui pred: stuorádii
# ref: stuorábut pred: stuorádat
# ref: stuorát pred: stuoráda
# ref: stuorábuin pred: stuorádiin
# ref: stuorábus pred: stuorádis
# sávaleimme sávaleimme
# sávaleimmet sávaleimmet
# sávalin sávalin
# sávalit sávalit
# sávaleigga sávaleigga
# sávašeimmet sávašeimmet
# sávašeidde sávašeidde
# sávašeiddet sávašeiddet
# sávašit sávašit
# sávaše sávaše
# sávašii sávašii
# sávvot sávvot
# sávvon sávvon
# ref: sáv'vi pred: sávvo
# ref: sávvet pred: sávvot
# ref: sáva pred: sávvo
# sávvoset sávvoset
# sávažit sávažit
# sávažan sávažan
# sávažat sávažat
# sávažit sávažit
# ref: sávve pred: sávvabu
# sávvat sávvat
# ref: sávan pred: sávvan
# sávvabeahtti sávvabeahtti
# sávvabehtet sávvabehtet
# ref: sávat pred: sávvat
# sávvaba sávvaba
# ref: sávvet pred: sávvat
# sávaide sávaide
# sávaidet sávaidet
# ref: sávvet pred: sávait
# višuvnnaid višuvnnaid
# višuvnna višuvnna
# višuvnnaiguin višuvnnaiguin
# višuvnnain višuvnnain
# ref: višuvdnan pred: višuvnnan
# višuvnnaid višuvnnaid
# višuvnna višuvnna
# višuvnnaide višuvnnaide
# ref: višuvdnii pred: višuvnnai
# višuvnnat višuvnnat
# ref: višuvdna pred: višuvnna
# višuvnnain višuvnnain
# višuvnnas višuvnnas
# árggiid árggiid
# árggi árggi
# árggiiguin árggiiguin
# árggiin árggiin
# ref: árgin pred: árggin
# árggiid árggiid
# árggi árggi
# árggiide árggiide
# ref: árgái pred: árggii
# árggit árggit
# ref: árgi pred: árggi
# árggiin árggiin
# árggis árggis
# čalmmehepmosiid čalmmehepmosiid
# čalmmehepmosa čalmmehepmosa
# čalmmehepmosiiguin čalmmehepmosiiguin
# čalmmehepmosiin čalmmehepmosiin
# ref: čalmmeheamosin pred: čalmmehepmosin
# čalmmehepmosiid čalmmehepmosiid
# čalmmehepmosa čalmmehepmosa
# čalmmehepmosiidda čalmmehepmosiidda
# čalmmehepmosii čalmmehepmosii
# čalmmehepmosat čalmmehepmosat
# ref: čalmmeheamos pred: čalmmehepmos
# čalmmehepmosiin čalmmehepmosiin
# čalmmehepmosis čalmmehepmosis
# ref: čavgadiid pred: čavggadiid
# ref: čavgada pred: čavggabu
# ref: čavgadiiguin pred: čavggadiiguin
# ref: čavgadiin pred: čavggabuin
# čavgadin čavgadin
# ref: čavgadiid pred: čavggadiid
# ref: čavgada pred: čavggabu
# ref: čavgadiidda pred: čavggadiidda
# ref: čavgadii pred: čavggadii
# ref: čavgadat pred: čavggabut
# ref: čavgat pred: čavgada
# ref: čavgadiin pred: čavggabuin
# ref: čavgadis pred: čavggabus
# ref: čiroleimme pred: čierroleimme
# ref: čirolin pred: čierrolin
# ref: čiroleidde pred: čierroleidde
# ref: čirolii pred: čierrolii
# ref: čirošeimme pred: čierrošeimme
# ref: čirošin pred: čierrošin
# ref: čirošeidde pred: čierrošeidde
# ref: čirošit pred: čierrošit
# ref: čirošeigga pred: čierrošeigga
# ref: čiroše pred: čierroše
# ref: čirošii pred: čierrošii
# ref: čier'ru pred: čirro
# čirrot čirrot
# čirron čirron
# ref: čier'ru pred: čirro
# čirrot čirrot
# ref: čiero pred: čirro
# čirroska čirroska
# čirros čirros
# ref: čirožeahppi pred: čierrožeahppi
# ref: čirožehpet pred: čierrožehpet
# ref: čirožat pred: čierrožat
# ref: čirožeaba pred: čierrožeaba
# ref: čirro pred: čierru
# čierrut čierrut
# čierrubehtet čierrubehtet
# ref: čirrot pred: čierrut
# ref: čiruime pred: čierruime
# ref: čirron pred: čirrun
# ref: čiruidet pred: čirruidet
# ref: čirrot pred: čirruit
# ref: čirui pred: čirrui
# čuovgadiid čuovgadiid
# čuovgada čuovgada
# čuovgadiiguin čuovgadiiguin
# čuovgadiin čuovgadiin
# čuovgadin čuovgadin
# čuovgadiid čuovgadiid
# čuovgada čuovgada
# ref: čuovgadiidda pred: čuovggadiidda
# čuovgadii čuovgadii
# čuovgadat čuovgadat
# ref: čuovgat pred: čuovgada
# čuovgadiin čuovgadiin
# čuovgadis čuovgadis
# čábbásepmosiid čábbásepmosiid
# čábbásepmosa čábbásepmosa
# čábbásepmosiiguin čábbásepmosiiguin
# čábbásepmosiin čábbásepmosiin
# ref: čábbáseamosin pred: čábbásepmosin
# čábbásepmosiid čábbásepmosiid
# čábbásepmosa čábbásepmosa
# čábbásepmosiidda čábbásepmosiidda
# čábbásepmosii čábbásepmosii
# čábbásepmosat čábbásepmosat
# ref: čábbáseamos pred: čábbásepmos
# čábbásepmosiin čábbásepmosiin
# čábbásepmosis čábbásepmosis
# ref: čábbáid pred: čápadiid
# ref: čábbá pred: čáppabu
# ref: čábbáiguin pred: čábadiiguin
# ref: čáppahin pred: čáppabun
# ref: čábbáid pred: čáppabuid
# ref: čábbá pred: čáppabu
# ref: čábbáide pred: čáppadiidda
# ref: čábbái pred: čáppadii
# ref: čábbát pred: čáppabut
# ref: čáppat pred: čáppabu
# ref: čábbáin pred: čáppabusingiin
# ref: čábbás pred: čáppabus
# 0.515
# livles/sme-20ksamples
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# config.json:   0%|          | 0.00/791 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.20G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/152 [00:00<?, ?B/s]
# test file:  ../preprocessing/preprocessing_to_json/data/sme_test.json
# abstrávttaid abstrávttaid
# abstrávtta abstrávtta
# abstrávttaiguin abstrávttaiguin
# abstrávttain abstrávttain
# abstráktan abstráktan
# abstrávttaid abstrávttaid
# abstrávtta abstrávtta
# abstrávttaide abstrávttaide
# ref: abstráktii pred: abstrávttai
# abstrávttat abstrávttat
# abstrákta abstrákta
# abstrávttain abstrávttain
# abstrávttas abstrávttas
# ref: almmáskivččiime pred: almmáskkášeimme
# ref: almmáskivččiimet pred: almmáskkášeimmet
# ref: almmáskivččen pred: almmáskkášin
# ref: almmáskivččiide pred: almmáskkášeidde
# ref: almmáskivččiidet pred: almmáskkášeiddet
# ref: almmáskivččiiga pred: almmáskkášeigga
# ref: almmáskivččii pred: almmáskkášii
# ref: almmáskehkot pred: almmáskot
# ref: almmáskeahkki pred: almmáske
# ref: almmás pred: almmáske
# ref: almmáskehkoset pred: almmáskoset
# ref: almmáskehkos pred: almmáskos
# ref: almmáskežže pred: almmáskkežetne
# ref: almmáskeažžat pred: almmáskkežit
# ref: almmáskeažžabeahtti pred: almmáskkežeahppi
# ref: almmáskeažžabehtet pred: almmáskkežehpet
# ref: almmáskeaččat pred: almmáskkežat
# ref: almmáskežžet pred: almmáskkežit
# ref: almmáskeš pred: almmáskkeža
# ref: almmásketne pred: almmáske
# almmáskit almmáskit
# ref: almmáskan pred: almmáskán
# ref: almmáskeahppi pred: almmáskibeahtti
# ref: almmáskehpet pred: almmáskibehtet
# ref: almmáskat pred: almmáskát
# ref: almmáskeaba pred: almmáskiba
# ref: almmáska pred: almmáská
# ref: almmáskeimme pred: almmáskiime
# ref: almmáskin pred: almmásken
# ref: almmáskeidde pred: almmáskiide
# ref: almmáskeigga pred: almmáskiiga
# almmáske almmáske
# ref: apmasiid pred: amas usingiid
# ref: apmasa pred: amas usinga
# ref: apmasiiguin pred: amasingiiguin
# ref: apmasiin pred: amas usingiin
# ref: amasin pred: amas usingin
# ref: apmasiid pred: amasingiid
# ref: apmasa pred: amas usinga
# ref: apmasiidda pred: amasiidda
# ref: apmasii pred: amas usingii
# ref: apmasat pred: amas usingat
# ref: amas pred: amas using
# ref: apmasiin pred: amas usingiin
# ref: apmasis pred: amas usingis
# atomaid atomaid
# atoma atoma
# atomaiguin atomaiguin
# ref: atomain pred: atoma usingiin
# ref: atoman pred: atoma usingin
# atomaid atomaid
# atoma atoma
# atomaide atomaide
# ref: atomii pred: atomai
# atomat atomat
# ref: atoma pred: atoma using
# ref: atomain pred: atomaingiin
# ref: atomas pred: atomasingis
# bieđgáleimmet bieđgáleimmet
# bieđgálin bieđgálin
# bieđgáleidde bieđgáleidde
# bieđgálit bieđgálit
# bieđgáleigga bieđgáleigga
# bieđgále bieđgále
# bieđgálii bieđgálii
# bieđgášeimme bieđgášeimme
# bieđgášeimmet bieđgášeimmet
# bieđgášeiddet bieđgášeiddet
# bieđgášit bieđgášit
# bieđgájehkon bieđgájehkon
# bieđgájeahkki bieđgájeahkki
# bieđgájehket bieđgájehket
# bieđgá bieđgá
# bieđgájehkoska bieđgájehkoska
# bieđgážetne bieđgážetne
# bieđgážit bieđgážit
# bieđgážan bieđgážan
# bieđgážeahppi bieđgážeahppi
# bieđgážehpet bieđgážehpet
# bieđgážeaba bieđgážeaba
# bieđgájetne bieđgájetne
# bieđgát bieđgát
# bieđgán bieđgán
# bieđgábeahtti bieđgábeahtti
# bieđgábehtet bieđgábehtet
# ref: bieđgájit pred: bieđgát
# bieđgáimet bieđgáimet
# bieđgájin bieđgájin
# bieđgáidet bieđgáidet
# ref: bieđgájedje pred: bieđgáiga
# buddeleimme buddeleimme
# buddelin buddelin
# buddeleiddet buddeleiddet
# buddelit buddelit
# buddeleigga buddeleigga
# buddele buddele
# buddelii buddelii
# buddešeimmet buddešeimmet
# buddešin buddešin
# buddešeidde buddešeidde
# buddešit buddešit
# buddešeigga buddešeigga
# buddeše buddeše
# buddejetnot buddejetnot
# buddejehkon buddejehkon
# buddejehket buddejehket
# budde budde
# ref: buddejehkoset pred: buddoset
# buddežeahppi buddežeahppi
# buddežehpet buddežehpet
# buddežat buddežat
# buddežeaba buddežeaba
# buddet buddet
# budden budden
# buddebeahtti buddebeahtti
# buddebehtet buddebehtet
# ref: buddejit pred: buddet
# ref: buddiime pred: buddeimme
# ref: buddejin pred: budden
# ref: buddiiga pred: buddeigga
# ref: buddejedje pred: budde
# báisttáleimmet báisttáleimmet
# báisttálin báisttálin
# báisttáleidde báisttáleidde
# báisttáleiddet báisttáleiddet
# báisttálit báisttálit
# báisttáleigga báisttáleigga
# báisttále báisttále
# báisttálii báisttálii
# báisttášeimme báisttášeimme
# báisttášin báisttášin
# báisttášeidde báisttášeidde
# báisttášeigga báisttášeigga
# báisttáše báisttáše
# báisttášii báisttášii
# ref: báistu pred: báiste
# báistot báistot
# báistet báistet
# báisttežan báisttežan
# báisttežehpet báisttežehpet
# báisttežeaba báisttežeaba
# báisttežit báisttežit
# báistteža báistteža
# ref: báiste pred: báistibeadnu
# báistibehtet báistibehtet
# báistá báistá
# báisttiime báisttiime
# báisttiimet báisttiimet
# ref: báisten pred: báisttin
# báisttiidet báisttiidet
# báisttiiga báisttiiga
# ref: báiste pred: báisttiiga
# báisttii báisttii
# ref: bálgáidan pred: bálgámiid
# bálgán bálgán
# ref: bálgáidanguin pred: bálgámiiguin
# ref: bálgáinan pred: bálgániin
# ref: bálggisinin pred: bálgán
# ref: bálgáidan pred: bálgámiid
# bálgán bálgán
# ref: bálgáidasan pred: bálgámiidda
# ref: bálgásan pred: bálgánii
# bálgán bálgán
# ref: bálgáinan pred: bálgámiin
# ref: bálgástan pred: bálgán
# báralaččaid báralaččaid
# báralačča báralačča
# báralaččaiguin báralaččaiguin
# báralaččain báralaččain
# ref: báralažžan pred: báralaččan
# báralaččaid báralaččaid
# báralačča báralačča
# báralaččaide báralaččaide
# ref: báralažžii pred: báralaččai
# báralaččat báralaččat
# ref: báralaš pred: báralačča
# báralaččain báralaččain
# báralaččas báralaččas
# bártnaleimme bártnaleimme
# bártnaleimmet bártnaleimmet
# bártnaleidde bártnaleidde
# bártnaleiddet bártnaleiddet
# bártnalit bártnalit
# bártnaleigga bártnaleigga
# bártnalii bártnalii
# bártnašeimme bártnašeimme
# bártnašeimmet bártnašeimmet
# bártnašeidde bártnašeidde
# bártnašit bártnašit
# bárdnon bárdnon
# ref: bárdni pred: bárdna
# ref: bártna pred: bártne
# bárdnoska bárdnoska
# bárdnoset bárdnoset
# bárdnos bárdnos
# bártnažetne bártnažetne
# bártnažit bártnažit
# bártnažehpet bártnažehpet
# bártnažeaba bártnažeaba
# bártnaža bártnaža
# ref: bárdne pred: bárdnabeadnu
# bárdnat bárdnat
# ref: bártnan pred: bártnán
# bárdnabehtet bárdnabehtet
# bárdnaba bárdnaba
# ref: bárdná pred: bártná
# bártnaime bártnaime
# bártnaide bártnaide
# ref: bárdne pred: bártne
# ref: bártnai pred: bártne
# ceggosepmosiid ceggosepmosiid
# ceggosepmosa ceggosepmosa
# ceggosepmosiiguin ceggosepmosiiguin
# ceggosepmosiin ceggosepmosiin
# ref: ceggoseamosin pred: ceggosepmosin
# ceggosepmosiid ceggosepmosiid
# ceggosepmosa ceggosepmosa
# ceggosepmosiidda ceggosepmosiidda
# ceggosepmosii ceggosepmosii
# ceggosepmosat ceggosepmosat
# ref: ceggoseamos pred: ceggosepmos
# ceggosepmosiin ceggosepmosiin
# ceggosepmosis ceggosepmosis
# cuoŋománuid cuoŋománuid
# cuoŋománu cuoŋománu
# cuoŋománuiguin cuoŋománuiguin
# cuoŋománuin cuoŋománuin
# ref: cuoŋománnun pred: cuoŋománun
# cuoŋománuid cuoŋománuid
# cuoŋománu cuoŋománu
# cuoŋománuide cuoŋománuide
# ref: cuoŋománnui pred: cuoŋománui
# cuoŋománut cuoŋománut
# ref: cuoŋománnu pred: cuoŋománu
# cuoŋománuin cuoŋománuin
# cuoŋománus cuoŋománus
# deaivvaleidde deaivvaleidde
# deaivvaleiddet deaivvaleiddet
# deaivvalit deaivvalit
# deaivvaleigga deaivvaleigga
# deaivvale deaivvale
# deaivvalii deaivvalii
# deaivvašeimme deaivvašeimme
# deaivvašeidde deaivvašeidde
# deaivvašeiddet deaivvašeiddet
# deaivvašeigga deaivvašeigga
# deaivvaše deaivvaše
# deaivvašii deaivvašii
# ref: deaivu pred: deivo
# ref: deaivi pred: deiva
# ref: deivet pred: deivot
# ref: deaivva pred: deivo
# deivoska deivoska
# deivoset deivoset
# ref: deaivvažit pred: deivvažit
# ref: deaivvažan pred: deivvažan
# ref: deaivvažehpet pred: deivvažehpet
# ref: deaivvažat pred: deivvažat
# ref: deaivvažeaba pred: deivvažeaba
# ref: deive pred: deaiva
# ref: deaivvat pred: deaivat
# ref: deivet pred: deaivat
# ref: deaivvaime pred: deivve
# ref: deaivvaimet pred: deivvet
# ref: deiven pred: deivven
# ref: deivet pred: deivvet
# ref: deaivvaiga pred: deivviiga
# ref: deive pred: deivve
# dievalin dievalin
# dievaleiddet dievaleiddet
# dievalit dievalit
# dievale dievale
# dievalii dievalii
# dievašeimmet dievašeimmet
# dievašeidde dievašeidde
# dievašit dievašit
# dievašeigga dievašeigga
# dievaše dievaše
# dievašii dievašii
# divvon divvon
# ref: divvet pred: divvot
# ref: dieva pred: divvo
# divvoska divvoska
# divvos divvos
# dievažan dievažan
# dievažeahppi dievažeahppi
# dievažehpet dievažehpet
# dievažat dievažat
# dievažeaba dievažeaba
# dievažit dievažit
# ref: divve pred: dievva
# ref: dievat pred: dievvát
# dievvá dievvá
# ref: dievaimet pred: divvet
# divven divven
# ref: dievaide pred: divveidde
# ref: dievaidet pred: divvet
# ref: dievaiga pred: divveigga
# divve divve
# ref: dievai pred: divve
# dorvvuid dorvvuid
# dorvvu dorvvu
# dorvvuiguin dorvvuiguin
# ref: dorvvuin pred: dorvvuingiin
# ref: dorvun pred: dorvu usingin
# dorvvuid dorvvuid
# ref: dorvvu pred: dorvu
# dorvvuide dorvvuide
# dorvui dorvui
# dorvvut dorvvut
# dorvu dorvu
# ref: dorvvuin pred: dorvvuingiin
# ref: dorvvus pred: dorvusingis
# dorvvastivččiime dorvvastivččiime
# dorvvastivččiimet dorvvastivččiimet
# ref: dorvvastivččen pred: dorvvastivččin
# dorvvastivččiide dorvvastivččiide
# dorvvastivččiidet dorvvastivččiidet
# ref: dorvvastivččet pred: dorvvastivččit
# dorvvastivččiiga dorvvastivččiiga
# ref: dorvvastivčče pred: dorvvastivččiiga
# dorvvastivččii dorvvastivččii
# dorvvastehkon dorvvastehkon
# dorvvastehket dorvvastehket
# ref: dorvvas pred: dorvvastehke
# dorvvastehkoska dorvvastehkoska
# dorvvastehkoset dorvvastehkoset
# dorvvastehkos dorvvastehkos
# ref: dorvvastežže pred: dorvvasteažžabeahtti
# dorvvasteaččan dorvvasteaččan
# dorvvasteažžabeahtti dorvvasteažžabeahtti
# dorvvasteažžabehtet dorvvasteažžabehtet
# ref: dorvvastežžet pred: dorvvasteažžat
# ref: dorvvasteš pred: dorvvasteažža
# ref: dorvvastetne pred: dorvvasteadnu
# dorvvastit dorvvastit
# dorvvastan dorvvastan
# ref: dorvvasteahppi pred: dorvvastibeahtti
# dorvvasteaba dorvvasteaba
# dorvvasteimme dorvvasteimme
# dorvvasteiddet dorvvasteiddet
# ref: dorvvastit pred: dorvvastet
# dorvvasteigga dorvvasteigga
# dorvvaste dorvvaste
# ref: dorvvastii pred: dorvvaste
# ref: dorvvolaččabuid pred: dorvvolaččadiid
# dorvvolaččabu dorvvolaččabu
# dorvvolaččabuiguin dorvvolaččabuiguin
# dorvvolaččabuin dorvvolaččabuin
# dorvvolaččabun dorvvolaččabun
# dorvvolaččabuid dorvvolaččabuid
# dorvvolaččabu dorvvolaččabu
# dorvvolaččabuidda dorvvolaččabuidda
# dorvvolaččabui dorvvolaččabui
# dorvvolaččabut dorvvolaččabut
# dorvvolaččat dorvvolaččat
# dorvvolaččabuin dorvvolaččabuin
# dorvvolaččabus dorvvolaččabus
# dámaleimme dámaleimme
# dámalit dámalit
# dámalii dámalii
# dámašeimme dámašeimme
# dámašit dámašit
# dámašeigga dámašeigga
# dámaše dámaše
# dámašii dámašii
# dápmot dápmot
# dápmon dápmon
# ref: dábmi pred: dápma
# dápmoset dápmoset
# dámažetne dámažetne
# dámažeahppi dámažeahppi
# dámažat dámažat
# dámažeaba dámažeaba
# dámažit dámažit
# ref: dápme pred: dápmabeadnu
# dápmat dápmat
# dápmabeahtti dápmabeahtti
# ref: dámat pred: dápmat
# dápmaba dápmaba
# ref: dápmet pred: dápmat
# dápmá dápmá
# dámaime dámaime
# dámaimet dámaimet
# ref: dápmen pred: dáman
# dámaide dámaide
# dámaidet dámaidet
# dámaiga dámaiga
# dámai dámai
# fuoikkáleimme fuoikkáleimme
# fuoikkáleimmet fuoikkáleimmet
# fuoikkálin fuoikkálin
# fuoikkáleidde fuoikkáleidde
# fuoikkáleiddet fuoikkáleiddet
# fuoikkále fuoikkále
# fuoikkálii fuoikkálii
# fuoikkášeimme fuoikkášeimme
# fuoikkášeiddet fuoikkášeiddet
# fuoikkášit fuoikkášit
# fuoikkášeigga fuoikkášeigga
# fuoikkášii fuoikkášii
# ref: fuoiku pred: fuiko
# fuikot fuikot
# fuikon fuikon
# ref: fuoiki pred: fuike
# fuiket fuiket
# ref: fuoikke pred: fuiko
# fuikoska fuikoska
# fuikkežit fuikkežit
# fuikkežan fuikkežan
# fuikkežat fuikkežat
# fuikkežeaba fuikkežeaba
# fuikkeža fuikkeža
# fuoikit fuoikit
# ref: fuoikkán pred: fuikán
# fuoikibehtet fuoikibehtet
# fuiken fuiken
# fuiket fuiket
# fuikkiiga fuikkiiga
# ref: fuikkii pred: fuike
# ref: geahppáidan pred: geahppámusimiid
# geahppán geahppán
# ref: geahppáidanguin pred: geahppámiiguin
# ref: geahppáinan pred: geahppániin
# ref: geahpisinin pred: geahppán
# ref: geahppáidan pred: geahppámiid
# geahppán geahppán
# ref: geahppáidasan pred: geahppáide
# ref: geahppásan pred: geahppán
# geahppán geahppán
# ref: geahppáinan pred: geahppániin
# ref: geahppástan pred: geahppán
# guoggáleimme guoggáleimme
# guoggálit guoggálit
# guoggáleigga guoggáleigga
# guoggále guoggále
# guoggálii guoggálii
# guoggášeimme guoggášeimme
# guoggášin guoggášin
# guoggášeidde guoggášeidde
# guoggášeiddet guoggášeiddet
# guoggášeigga guoggášeigga
# guoggášii guoggášii
# guoggájeadnu guoggájeadnu
# guoggájehkon guoggájehkon
# guoggá guoggá
# guoggájehkoska guoggájehkoska
# guoggájehkos guoggájehkos
# guoggážetne guoggážetne
# guoggážehpet guoggážehpet
# guoggážat guoggážat
# guoggážit guoggážit
# guoggájetne guoggájetne
# guoggát guoggát
# guoggán guoggán
# guoggábehtet guoggábehtet
# guoggát guoggát
# guoggá guoggá
# guoggáime guoggáime
# guoggáimet guoggáimet
# guoggájin guoggájin
# guoggáide guoggáide
# guoggájit guoggájit
# ref: guoggájedje pred: guoggáiga
# guoktelogigoalmmádiid guoktelogigoalmmádiid
# ref: guoktelogigoalmmáda pred: guoktelogigoalmmá
# guoktelogigoalmmádiiguin guoktelogigoalmmádiiguin
# guoktelogigoalmmádiin guoktelogigoalmmádiin
# guoktelogigoalmmádin guoktelogigoalmmádin
# guoktelogigoalmmádiid guoktelogigoalmmádiid
# guoktelogigoalmmáda guoktelogigoalmmáda
# guoktelogigoalmmádiidda guoktelogigoalmmádiidda
# guoktelogigoalmmádii guoktelogigoalmmádii
# ref: guoktelogigoalmmádat pred: guoktelogigoalmmábut
# guoktelogigoalmmát guoktelogigoalmmát
# ref: guoktelogigoalmmádiin pred: guoktelogigoalmmábuin
# ref: guoktelogigoalmmádis pred: guoktelogigoalmmábus
# guolástivččiimet guolástivččiimet
# ref: guolástivččen pred: guolástivččin
# guolástivččiide guolástivččiide
# ref: guolástivččet pred: guolástivččit
# guolástivččiiga guolástivččiiga
# guolástivččii guolástivččii
# ref: guolásteadnu pred: guolástehko
# ref: guolástehkon pred: guoláston
# guolásteahkki guolásteahkki
# guolástehket guolástehket
# ref: guolás pred: guolástehke
# guolástehkoska guolástehkoska
# ref: guolástehkos pred: guolástos
# ref: guolástežže pred: guolásteažžabeadnu
# guolásteažžat guolásteažžat
# guolásteažžabehtet guolásteažžabehtet
# guolásteažžaba guolásteažžaba
# ref: guolástežžet pred: guolásteažžat
# ref: guolásteš pred: guolásteažža
# ref: guolástetne pred: guolástibeadnu
# ref: guolástan pred: guolástán
# ref: guolástehpet pred: guolástibehtet
# guolástat guolástat
# guolástit guolástit
# ref: guolásteimme pred: guolástiime
# ref: guolásteimmet pred: guolástiimet
# ref: guolástin pred: guolásten
# ref: guolásteidde pred: guolástiide
# guolásteiddet guolásteiddet
# guolástit guolástit
# guolástii guolástii
# guvráleimmet guvráleimmet
# guvrálin guvrálin
# guvráleidde guvráleidde
# guvráleigga guvráleigga
# guvrálii guvrálii
# guvrášeimmet guvrášeimmet
# guvrášin guvrášin
# guvrášeidde guvrášeidde
# guvrášeiddet guvrášeiddet
# guvrájeadnu guvrájeadnu
# guvrájeahkki guvrájeahkki
# guvrájehket guvrájehket
# guvrájehkoset guvrájehkoset
# guvrájehkos guvrájehkos
# guvrážetne guvrážetne
# guvrážit guvrážit
# guvrážehpet guvrážehpet
# guvrážat guvrážat
# guvrážeaba guvrážeaba
# guvrážit guvrážit
# guvráža guvráža
# ref: guvrájetne pred: guvrábeadnu
# guvrán guvrán
# guvrábehtet guvrábehtet
# guvrát guvrát
# ref: guvrájit pred: guvrát
# guvrá guvrá
# guvráide guvráide
# guvrájit guvrájit
# guvráiga guvráiga
# ref: guvrájedje pred: guvráiga
# guvrái guvrái
# guđadiid guđadiid
# guđada guđada
# guđadiiguin guđadiiguin
# guđadiin guđadiin
# ref: guđadin pred: guđat
# guđadiid guđadiid
# ref: guđada pred: guđat
# guđadiidda guđadiidda
# guđadii guđadii
# guđadat guđadat
# guđat guđat
# guđadis guđadis
# ref: gáissiid pred: gáisiisingiid
# ref: gáissi pred: gáisinga
# ref: gáissiiguin pred: gáisiinniiguin
# ref: gáissiin pred: gáisingiin
# ref: gáisin pred: gáisingin
# ref: gáissiid pred: gáisiingiid
# ref: gáissi pred: gáisi usinga
# ref: gáissiide pred: gáissiidda
# ref: gáisái pred: gáisii
# ref: gáissit pred: gáisi usingat
# ref: gáisi pred: gáisi using
# ref: gáissiin pred: gáisingiin
# ref: gáissis pred: gáisisingis
# gáranasaid gáranasaid
# gáranasa gáranasa
# ref: gáranasaiguin pred: gáranasiiguin
# ref: gáranasain pred: gáranasingiin
# ref: gáranassan pred: gáranas usingin
# gáranasaid gáranasaid
# gáranasa gáranasa
# ref: gáranasaide pred: gáranasiidda
# ref: gáranassii pred: gáranasii
# gáranasat gáranasat
# ref: gáranas pred: gáranas using
# ref: gáranasain pred: gáranasingiin
# gáranasas gáranasas
# ref: gávrroleimmet pred: gávroleimmet
# ref: gávrroleiddet pred: gávroleiddet
# ref: gávrrole pred: gávrole
# ref: gávrrolii pred: gávrolii
# ref: gávrrošeimmet pred: gávrošeimmet
# ref: gávrrošin pred: gávrošin
# ref: gávrrošeidde pred: gávrošeidde
# ref: gávrrošeiddet pred: gávrošeiddet
# ref: gávrroše pred: gávroše
# ref: gávrrošii pred: gávrošii
# ref: gávru pred: gávro
# gávrot gávrot
# ref: gávrro pred: gávro
# gávroska gávroska
# gávroset gávroset
# ref: gávrrožetne pred: gávrožetne
# ref: gávrrožit pred: gávrožit
# ref: gávrrožeahppi pred: gávrožeahppi
# ref: gávrrožehpet pred: gávrožehpet
# ref: gávrrožat pred: gávrožat
# ref: gávrrožeaba pred: gávrožeaba
# ref: gávrroža pred: gávroža
# ref: gávrrun pred: gávrun
# gávrubeahtti gávrubeahtti
# ref: gávrrut pred: gávrut
# ref: gávrot pred: gávrut
# gávrruime gávrruime
# ref: gávrruimet pred: gávruimet
# gávrruide gávrruide
# gávrot gávrot
# gávrruiga gávrruiga
# gávro gávro
# jiehtanasaid jiehtanasaid
# ref: jiehtanasa pred: jiehtanas
# ref: jiehtanasaiguin pred: jiehtanasiiguin
# ref: jiehtanassan pred: jiehtanas usingin
# jiehtanasaid jiehtanasaid
# ref: jiehtanasa pred: jiehtanas
# ref: jiehtanasaide pred: jiehtanasiidda
# ref: jiehtanassii pred: jiehtanasii
# jiehtanasat jiehtanasat
# jiehtanas jiehtanas
# ref: jiehtanasain pred: jiehtanasingiin
# jiehtanasas jiehtanasas
# ref: jorbasiid pred: jorbbasaid
# ref: jorbasa pred: jorbbas
# ref: jorbasiiguin pred: jorbbasiiguin
# ref: jorbasiin pred: jorbbasingiin
# ref: jorbbasin pred: jorbbas usingin
# ref: jorbasiid pred: jorbbasingiid
# ref: jorbasa pred: jorbbas
# ref: jorbasiidda pred: jorbbasiidda
# ref: jorbasii pred: jorbbasii
# ref: jorbasat pred: jorbbasat
# jorbbas jorbbas
# ref: jorbasiin pred: jorbbasingiin
# ref: jorbasis pred: jorbbas
# lasttaid lasttaid
# lastta lastta
# lasttaiguin lasttaiguin
# ref: lasttain pred: lasta usingiin
# ref: lastan pred: lasta usingin
# lasttaid lasttaid
# ref: lastta pred: lasta
# lasttaide lasttaide
# ref: lastii pred: lastai
# lasttat lasttat
# ref: lasta pred: lasta using
# lasttain lasttain
# ref: lasttas pred: lastasingis
# loahpaleimme loahpaleimme
# loahpaleidde loahpaleidde
# loahpalit loahpalit
# loahpalii loahpalii
# loahpašeimmet loahpašeimmet
# loahpašin loahpašin
# loahpašeidde loahpašeidde
# loahpašit loahpašit
# loahppu loahppu
# lohppon lohppon
# ref: loahppi pred: loahppu
# lohpposka lohpposka
# lohpposet lohpposet
# lohppos lohppos
# loahpažetne loahpažetne
# loahpažit loahpažit
# loahpažan loahpažan
# loahpažeahppi loahpažeahppi
# loahpažehpet loahpažehpet
# loahpažat loahpažat
# loahpažit loahpažit
# loahpaža loahpaža
# ref: lohppe pred: loahppabeadnu
# loahppabehtet loahppabehtet
# ref: lohppet pred: loahppat
# ref: loahppá pred: loahpá
# ref: lohppen pred: loahppen
# loahpaide loahpaide
# loahpaidet loahpaidet
# ref: lohppet pred: loahppet
# loahpaiga loahpaiga
# lávccaid lávccaid
# lávcca lávcca
# lávccaiguin lávccaiguin
# lávccain lávccain
# lákcan lákcan
# lávccaid lávccaid
# lávcca lávcca
# lávccaide lávccaide
# ref: lákcii pred: lávccai
# lávccat lávccat
# lákca lákca
# lávccain lávccain
# lávccas lávccas
# mohkkámusaid mohkkámusaid
# mohkkámusa mohkkámusa
# mohkkámusaiguin mohkkámusaiguin
# mohkkámusain mohkkámusain
# ref: mohkkámussan pred: mohkkámus usingin
# mohkkámusaid mohkkámusaid
# mohkkámusa mohkkámusa
# mohkkámusaide mohkkámusaide
# ref: mohkkámussii pred: mohkkámusai
# mohkkámusat mohkkámusat
# mohkkámus mohkkámus
# mohkkámusain mohkkámusain
# mohkkámusas mohkkámusas
# positiivvaid positiivvaid
# positiivva positiivva
# positiivvaiguin positiivvaiguin
# positiivvain positiivvain
# positiivan positiivan
# positiivvaid positiivvaid
# ref: positiivva pred: positiiva
# positiivvaide positiivvaide
# ref: positiivii pred: positiivvai
# positiivvat positiivvat
# positiiva positiiva
# positiivvain positiivvain
# ref: positiivvas pred: positiivas
# ref: ruđaid pred: ruhtaid
# ref: ruđa pred: ruhta
# ref: ruđaiguin pred: ruhtaiguin
# ref: ruđain pred: ruhta usingiin
# ref: ruhtan pred: ruhta usingin
# ref: ruđaid pred: ruhtaid
# ref: ruđa pred: ruhta
# ref: ruđaide pred: ruhtaide
# ref: ruđat pred: ruhtat
# ref: ruhta pred: ruhta using
# ref: ruđain pred: ruhtain
# ref: ruđas pred: ruhtasingis
# ref: rusaleimme pred: russaleimme
# ref: rusaleimmet pred: russaleimmet
# ref: rusaleidde pred: russaleidde
# ref: rusalit pred: russalit
# ref: rusalii pred: russalii
# ref: rusašeimme pred: russašeimme
# ref: rusašeimmet pred: russašeimmet
# ref: rusašin pred: russašin
# ref: rusašeiddet pred: russašeiddet
# ref: rusašit pred: russašit
# ref: rusašii pred: russašii
# russot russot
# russon russon
# ref: rusa pred: russo
# russoska russoska
# ref: rusažetne pred: russažetne
# ref: rusažit pred: russažit
# ref: rusažeahppi pred: russažeahppi
# ref: rusažeaba pred: russažeaba
# russat russat
# ref: rusan pred: russán
# russabehtet russabehtet
# ref: rusat pred: russát
# ref: russet pred: russat
# ref: rusaime pred: russeimme
# ref: rusaimet pred: russet
# russen russen
# ref: rusaide pred: russeidde
# ref: rusaidet pred: russeiddet
# russet russet
# russe russe
# ref: rusai pred: russe
# ref: ráhkkásiid pred: ráhkisinguid
# ref: ráhkkása pred: ráhkis
# ref: ráhkkásiiguin pred: ráhkisingiiguin
# ref: ráhkkásiin pred: ráhkis usingiin
# ref: ráhkisin pred: ráhkis usingin
# ref: ráhkkásiid pred: ráhkisingiid
# ref: ráhkkása pred: ráhkis
# ref: ráhkkásiidda pred: ráhkisiidda
# ref: ráhkkásii pred: ráhkis usingii
# ...
# ref: pʌŋiti pred: pʉŋiti
# ref: pʌ̂ŋtɛnu pred: pʌŋtɛnu
# ref: mupʰaŋnuje pred: mupʰʌŋnuje
# mupʰʌŋʌje mupʰʌŋʌje
# ref: mʌpʰaːni pred: mʌpʰânni
# mupʰaŋki mupʰaŋki
# mʌpʰaŋkʌ mʌpʰaŋkʌ
# mʌpʰaŋ mʌpʰaŋ
# pʰaŋkʌ pʰaŋkʌ
# ref: ʔipʰʌŋu pred: ʔipʰʉŋu
# ʔipʰaŋkʌ ʔipʰaŋkʌ
# ʔipʰʌŋi ʔipʰʌŋi
# ʔipʰaŋki ʔipʰaŋki
# ʔipʰaŋ ʔipʰaŋ
# pʰânsu pʰânsu
# mupʰaŋwʌkʌ mupʰaŋwʌkʌ
# ref: mupʰanwʌsu pred: mupʰaŋwʌsu
# ref: mʌpʰʌŋiwi pred: mʌpʰʉŋiwi
# ref: mʌpʰʌŋiwi pred: mʌpʰʉŋiwi
# ref: ʔipʰântɛ pred: ʔipʰʌ̂ntɛ
# ref: ʔipʰʌŋiti pred: ʔipʰʉŋiti
# ʔipʰaŋtiki ʔipʰaŋtiki
# mupʰernuje mupʰernuje
# pʰerije pʰerije
# pʰernuje pʰernuje
# mupʰer mupʰer
# mupʰerkʌ mupʰerkʌ
# mʌpʰeri mʌpʰeri
# mʌpʰerni mʌpʰerni
# pʰeru pʰeru
# pʰêrnu pʰêrnu
# mʌpʰeruwu mʌpʰeruwu
# mʌpʰeriwi mʌpʰeriwi
# mʌpʰerʌwʌnu mʌpʰerʌwʌnu
# mupʰêrwɛnu mupʰêrwɛnu
# mupʰêrwɛ mupʰêrwɛ
# pʰeriti pʰeriti
# pʰertiki pʰertiki
# ref: ʔipʰêrtɛnu pred: ʔipʰertɛnu
# ʔipʰerʌtʌnu ʔipʰerʌtʌnu
# pʰêrtɛnu pʰêrtɛnu
# ʔipʰerʌtʌ ʔipʰerʌtʌ
# mupʰrɛpnuje mupʰrɛpnuje
# pʰrɛpkʌje pʰrɛpkʌje
# mʌpʰrɛ̂mni mʌpʰrɛ̂mni
# mupʰrɛpi mupʰrɛpi
# mʌpʰrɛpkʌ mʌpʰrɛpkʌ
# mʌpʰrɛ̂mni mʌpʰrɛ̂mni
# mʌpʰrɛpi mʌpʰrɛpi
# ref: mʌpʰrɛ̂mni pred: mʌpʰrɛpni
# mʌpʰrɛpu mʌpʰrɛpu
# ref: mʌpʰrɛ̂mni pred: mʌpʰrɛpni
# pʰrɛpkʌ pʰrɛpkʌ
# pʰrɛpi pʰrɛpi
# ʔipʰrɛpi ʔipʰrɛpi
# ʔipʰrɛ̂mŋʌnu ʔipʰrɛ̂mŋʌnu
# ʔipʰrɛ̂mni ʔipʰrɛ̂mni
# ʔipʰrɛpkʌ ʔipʰrɛpkʌ
# ʔipʰrɛ̂mŋʌsu ʔipʰrɛ̂mŋʌsu
# mʌpʰrɛpiwi mʌpʰrɛpiwi
# ʔipʰrɛptɛ ʔipʰrɛptɛ
# pʰrɛptɛsu pʰrɛptɛsu
# mupʰɛmnuje mupʰɛmnuje
# pʰɛme pʰɛme
# mupʰɛmu mupʰɛmu
# mupʰɛmkʌ mupʰɛmkʌ
# mupʰɛmŋʌ mupʰɛmŋʌ
# mʌpʰɛmi mʌpʰɛmi
# mʌpʰɛm mʌpʰɛm
# pʰɛmkʌ pʰɛmkʌ
# ʔipʰɛmi ʔipʰɛmi
# mupʰɛmwʌkʌ mupʰɛmwʌkʌ
# mupʰɛmʌwʌ mupʰɛmʌwʌ
# mʌpʰɛmiwi mʌpʰɛmiwi
# mʌpʰɛ̂mwɛnu mʌpʰɛ̂mwɛnu
# mupʰɛmiwi mupʰɛmiwi
# mupʰɛ̂mwɛnu mupʰɛ̂mwɛnu
# mupʰɛ̂mwɛ mupʰɛ̂mwɛ
# pʰɛmiti pʰɛmiti
# ʔipʰɛmiti ʔipʰɛmiti
# ʔipʰɛ̂mtɛ ʔipʰɛ̂mtɛ
# pʰɛ̂mtɛ pʰɛ̂mtɛ
# murekuje murekuje
# murekte murekte
# reknuje reknuje
# rekte rekte
# murekkʌ murekkʌ
# mʌrekkʌ mʌrekkʌ
# mʌrekki mʌrekki
# mʌrekkʌ mʌrekkʌ
# reku reku
# ʔireki ʔireki
# ʔireki ʔireki
# murekwɛsu murekwɛsu
# mʌrekiwi mʌrekiwi
# mʌrekwɛnu mʌrekwɛnu
# murekwɛnu murekwɛnu
# murekwɛnu murekwɛnu
# mʌrekwɛ mʌrekwɛ
# ref: rêːtɛnnu pred: rêːktɛnnu
# ʔirekutu ʔirekutu
# ʔirektʌkʌ ʔirektʌkʌ
# mureŋije mureŋije
# reŋnuje reŋnuje
# mureŋu mureŋu
# mʌreŋu mʌreŋu
# mʌreŋŋʌsu mʌreŋŋʌsu
# mʌreŋki mʌreŋki
# mʌreŋ mʌreŋ
# ref: ʔireːni pred: ʔireŋni
# ʔireŋu ʔireŋu
# ʔireŋki ʔireŋki
# ʔireŋŋʌsu ʔireŋŋʌsu
# ʔireŋŋʌnu ʔireŋŋʌnu
# mʌreŋwʌkʌ mʌreŋwʌkʌ
# mʌrêŋwɛnu mʌrêŋwɛnu
# murênwɛsu murênwɛsu
# mʌreŋʌwʌ mʌreŋʌwʌ
# ʔirêŋtɛnu ʔirêŋtɛnu
# ref: rentʌ pred: reŋtʌ
# ʔirêŋtɛ ʔirêŋtɛ
# ʔireŋutu ʔireŋutu
# muriʦʌsuje muriʦʌsuje
# muriʦʌje muriʦʌje
# riʦije riʦije
# muriʦu muriʦu
# mʌrʌçkʌ mʌrʌçkʌ
# mʌrʌ̂nni mʌrʌ̂nni
# ʔirʌ̂nni ʔirʌ̂nni
# rʌttu rʌttu
# ʔirʌ̂nni ʔirʌ̂nni
# ref: ʔirʌtsu pred: ʔirʌttusu
# ʔirʌ̂j ʔirʌ̂j
# ref: muriswi pred: murisiiwi
# murʌçwiki murʌçwiki
# murʌtwʌnu murʌtwʌnu
# ref: mʌriswu pred: mʌrisiuwu
# mʌrʌtwɛ mʌrʌtwɛ
# ref: ʔiristi pred: ʔirisiiti
# ʔirʌçtʌkʌ ʔirʌçtʌkʌ
# ʔiristu ʔiristu
# ʔirʌçtʌkʌ ʔirʌçtʌkʌ
# murɵlnuje murɵlnuje
# murɵlije murɵlije
# rɵluje rɵluje
# murɵlu murɵlu
# murolusu murolusu
# mʌroɔlkʌ mʌroɔlkʌ
# rɵli rɵli
# ʔirɵlu ʔirɵlu
# ref: rɵ̂lnu pred: roɔ̂lnu
# mʌrɵ̂lwɛ mʌrɵ̂lwɛ
# murɵliwi murɵliwi
# muroluwʌnu muroluwʌnu
# mʌroɔlwʌkʌ mʌroɔlwʌkʌ
# mʌrɵ̂lwɛ mʌrɵ̂lwɛ
# mʌroɔlwiki mʌroɔlwiki
# murɵ̂lwɛnu murɵ̂lwɛnu
# mʌrɵ̂lwɛ mʌrɵ̂lwɛ
# roɔ̂ltɛnnu roɔ̂ltɛnnu
# ʔirɵliti ʔirɵliti
# ʔirɵ̂ltɛnu ʔirɵ̂ltɛnu
# roɔçkʌje roɔçkʌje
# muroɔ̂nsu muroɔ̂nsu
# mʌrɵʦu mʌrɵʦu
# mʌrɵʦi mʌrɵʦi
# mʌrɵʦi mʌrɵʦi
# mʌroɔ̂nni mʌroɔ̂nni
# ʔiroɔçkʌ ʔiroɔçkʌ
# ref: rɵ̂ːtsu pred: roɔ̂nsu
# muroɔçwʌkʌ muroɔçwʌkʌ
# ref: mʌrɵswu pred: mʌrɵsiuwu
# mʌrɵswɛnu mʌrɵswɛnu
# ref: murɵ̂ːtwɛnu pred: muroɔ̂nwɛnu
# ʔirɵsti ʔirɵsti
# ref: rɵsti pred: rɵsîjtu
# ref: rɵsti pred: rɵsîjtu
# roɔçtiki roɔçtiki
# ref: ʔirɵsti pred: ʔirɵsiiti
# ʔiroɔçtʌkʌ ʔiroɔçtʌkʌ
# rɵ̂ːtɛnu rɵ̂ːtɛnu
# ʔiroɔçtiki ʔiroɔçtiki
# museʦuje museʦuje
# seʦije seʦije
# ref: seːde pred: sesije
# museʦi museʦi
# mʌseʦi mʌseʦi
# mʌsêːtnu mʌsêːtnu
# mʌseʦi mʌseʦi
# ʔisêj ʔisêj
# seʦi seʦi
# sênnɛ sênnɛ
# mʌseswɛ mʌseswɛ
# ref: museswi pred: musesiiwi
# sesti sesti
# ʔisestɛnu ʔisestɛnu
# ref: ʔisêːtɛ pred: ʔisettɛ
# ʔiseçtʌkʌ ʔiseçtʌkʌ
# ref: sêːtɛsu pred: settɛsu
# ʔisestu ʔisestu
# ʔisesti ʔisesti
# ʔisestɛnu ʔisestɛnu
# musisnuje musisnuje
# ref: sisnuje pred: siʦnuje
# mʌsʌ̂j mʌsʌ̂j
# musiʦu musiʦu
# mʌsiʦi mʌsiʦi
# mʌsʌçkʌ mʌsʌçkʌ
# mʌsiʦu mʌsiʦu
# ref: musîːtsu pred: musʌ̂nsu
# mʌsiʦi mʌsiʦi
# ʔisʌ̂nni ʔisʌ̂nni
# ref: ʔisiːdʉ pred: ʔisʌttʉ
# mʌsiswɛ mʌsiswɛ
# musʌçwʌkʌ musʌçwʌkʌ
# ref: mʌsiswu pred: mʌsisuwu
# mʌsiswi mʌsiswi
# mʌsiswɛnu mʌsiswɛnu
# ref: mʌsiswu pred: mʌsisuwu
# mʌsʌçwʌkʌ mʌsʌçwʌkʌ
# ref: musîːtwɛnu pred: musʌ̂nwɛnu
# ʔisistɛnu ʔisistɛnu
# mʌtɛm mʌtɛm
# mʌtɛmu mʌtɛmu
# mʌtɛmi mʌtɛmi
# mʌtɛmu mʌtɛmu
# mʌtɛmni mʌtɛmni
# mʌtɛmki mʌtɛmki
# mʌtɛmi mʌtɛmi
# ʔitɛmi ʔitɛmi
# tɛmkʌ tɛmkʌ
# ʔitɛmŋʌnu ʔitɛmŋʌnu
# ʔitɛmni ʔitɛmni
# ref: ʔitɛ̂mnu pred: ʔitɛ̂mni
# tɛ̂msu tɛ̂msu
# mutɛ̂mwɛnu mutɛ̂mwɛnu
# ref: mʌtɛ̂mwɛ pred: mʌtɛmwɛ
# ʔitɛ̂mtɛnu ʔitɛ̂mtɛnu
# tɛmiti tɛmiti
# tɛmtiki tɛmtiki
# ʔitɛmiti ʔitɛmiti
# ʔitɛ̂mtɛnu ʔitɛ̂mtɛnu
# mutʰiːʦuje mutʰiːʦuje
# mutʰiːʦije mutʰiːʦije
# mutʰiːsnuje mutʰiːsnuje
# mutʰiːsnuje mutʰiːsnuje
# ref: mutʰʌnde pred: mutʰiːsije
# mutʰʌndusu mutʰʌndusu
# mutʰʌndu mutʰʌndu
# mʌtʰʌjki mʌtʰʌjki
# mʌtʰiːʦi mʌtʰiːʦi
# mutʰʌ̂nnu mutʰʌ̂nnu
# mutʰʌ̂nsu mutʰʌ̂nsu
# tʰʌjkʌ tʰʌjkʌ
# tʰʌjki tʰʌjki
# tʰʌndu tʰʌndu
# mʌtʰîːswɛnu mʌtʰîːswɛnu
# mʌtʰiːswi mʌtʰiːswi
# ʔitʰiːsti ʔitʰiːsti
# ʔitʰiːstu ʔitʰiːstu
# ʔitʰîːstɛ ʔitʰîːstɛ
# tʰʌ̂ntɛnu tʰʌ̂ntɛnu
# mutʰɵluje mutʰɵluje
# mutʰɵlnuje mutʰɵlnuje
# mutʰɵlu mutʰɵlu
# mutʰolu mutʰolu
# mʌtʰɵlu mʌtʰɵlu
# tʰɵlu tʰɵlu
# tʰɵli tʰɵli
# tʰɵli tʰɵli
# tʰolunu tʰolunu
# ref: tʰɵ̂lsu pred: tʰoɔ̂lsu
# ʔitʰɵli ʔitʰɵli
# mutʰɵliwi mutʰɵliwi
# mʌtʰɵluwu mʌtʰɵluwu
# mʌtʰɵliwi mʌtʰɵliwi
# mʌtʰɵ̂lwɛnu mʌtʰɵ̂lwɛnu
# ʔitʰɵliti ʔitʰɵliti
# tʰoɔltiki tʰoɔltiki
# ʔitʰɵ̂ltɛnu ʔitʰɵ̂ltɛnu
# ʔitʰoɔltiki ʔitʰoɔltiki
# ʔitʰɵlʌtʌsu ʔitʰɵlʌtʌsu
# tʰɛpije tʰɛpije
# ref: mʌtʰɛ̂mni pred: mʌtʰɛpni
# mʌtʰɛpki mʌtʰɛpki
# mʌtʰɛpi mʌtʰɛpi
# tʰɛpkʌ tʰɛpkʌ
# ref: ʔitʰɛ̂mŋʌsu pred: ʔitʰɛpŋʌsu
# ref: ʔitʰɛ̂mni pred: ʔitʰɛpni
# ʔitʰɛpki ʔitʰɛpki
# ʔitʰɛpkʌ ʔitʰɛpkʌ
# ʔitʰɛpi ʔitʰɛpi
# mutʰɛpiwi mutʰɛpiwi
# mutʰɛpiwi mutʰɛpiwi
# mʌtʰɛpwɛ mʌtʰɛpwɛ
# tʰɛpiti tʰɛpiti
# tʰɛptʌsu tʰɛptʌsu
# ʔitʰɛptɛnu ʔitʰɛptɛnu
# tʰɛptɛsu tʰɛptɛsu
# ʔitʰɛputu ʔitʰɛputu
# ʔitʰɛptɛ ʔitʰɛptɛ
# ʔitʰɛptʌkʌ ʔitʰɛptʌkʌ
# muwɛːʦe muwɛːʦe
# wɛːʦije wɛːʦije
# ref: wɛjnɛ pred: wɛ̂ːsnɛ
# muwɛːʦu muwɛːʦu
# muwɛjkʌ muwɛjkʌ
# muwɛːʦi muwɛːʦi
# mʌwɛj mʌwɛj
# muwɛːʦi muwɛːʦi
# wɛjkʌ wɛjkʌ
# wɛjki wɛjki
# wɛːʦi wɛːʦi
# wɛjnu wɛjnu
# ref: muwɛːswi pred: muwɛːsiiwi
# mʌwɛ̂ːswɛ mʌwɛ̂ːswɛ
# wɛːsti wɛːsti
# wɛːstʌ wɛːstʌ
# ʔiwɛ̂ːstɛnu ʔiwɛ̂ːstɛnu
# ʔiwɛ̂ːstɛ ʔiwɛ̂ːstɛ
# wɛːsti wɛːsti
# wɛ̂ːstɛ wɛ̂ːstɛ
# muɦipuje muɦipuje
# ɦipije ɦipije
# muɦʌ̂mnɛ muɦʌ̂mnɛ
# mʌɦipu mʌɦipu
# mʌɦipi mʌɦipi
# ref: muɦiːbʉ pred: muɦʌ̂msu
# ʔiɦipi ʔiɦipi
# ʔiɦipi ʔiɦipi
# ref: ʔiɦʌ̂mŋʌsu pred: ʔiɦʌpŋʌsu
# muɦʌpwiki muɦʌpwiki
# ref: muɦibuwʌsu pred: muɦʌpwʌsu
# ref: mʌɦîːpwɛnu pred: mʌɦʌ̂mwɛnu
# ref: muɦîːpwɛsu pred: muɦʌ̂mwɛsu
# ref: muɦîːpwɛnu pred: muɦʌ̂mwɛnu
# mʌɦipuwu mʌɦipuwu
# mʌɦipiwi mʌɦipiwi
# ɦipiti ɦipiti
# ʔiɦipiti ʔiɦipiti
# ɦʌptʌkʌ ɦʌptʌkʌ
# ʔiɦiptɛnu ʔiɦiptɛnu
# ref: ɦoɔnde pred: ɦɵːʦe
# mʌɦɵːʦi mʌɦɵːʦi
# ref: muɦoɔ̂jsu pred: muɦoɔ̂nsu
# mʌɦoɔndʉ mʌɦoɔndʉ
# mʌɦɵːʦu mʌɦɵːʦu
# mʌɦɵːʦi mʌɦɵːʦi
# mʌɦoɔj mʌɦoɔj
# mʌɦoɔjŋʌ mʌɦoɔjŋʌ
# ʔiɦɵːʦi ʔiɦɵːʦi
# ʔiɦɵːʦu ʔiɦɵːʦu
# ʔiɦoɔjni ʔiɦoɔjni
# ʔiɦoɔjkʌ ʔiɦoɔjkʌ
# ref: ʔiɦoɔ̂nsu pred: ʔiɦoɔjsu
# ʔiɦɵːʦi ʔiɦɵːʦi
# mʌɦɵ̂ːswɛnu mʌɦɵ̂ːswɛnu
# mʌɦoɔjwʌkʌ mʌɦoɔjwʌkʌ
# mʌɦoɔjwʌkʌ mʌɦoɔjwʌkʌ
# ʔiɦɵːstu ʔiɦɵːstu
# ʔiɦɵ̂ːstɛnu ʔiɦɵ̂ːstɛnu
# ɦoɔ̂ntɛ ɦoɔ̂ntɛ
# muɦɛmuje muɦɛmuje
# ref: muɦɛːme pred: muɦɛme
# ɦɛmnuje ɦɛmnuje
# muɦɛmu muɦɛmu
# ref: muɦɛmnɛ pred: muɦɛ̂mnɛ
# mʌɦɛmkʌ mʌɦɛmkʌ
# mʌɦɛmu mʌɦɛmu
# mʌɦɛmkʌ mʌɦɛmkʌ
# mʌɦɛmi mʌɦɛmi
# mʌɦɛm mʌɦɛm
# ɦɛ̂mnu ɦɛ̂mnu
# ʔiɦɛmni ʔiɦɛmni
# muɦɛmwiki muɦɛmwiki
# muɦɛmuwʌsu muɦɛmuwʌsu
# mʌɦɛmiwi mʌɦɛmiwi
# mʌɦɛmuwu mʌɦɛmuwu
# ʔiɦɛmiti ʔiɦɛmiti
# ɦɛmiti ɦɛmiti
# ʔiɦɛmtʌkʌ ʔiɦɛmtʌkʌ
# ʔiɦɛ̂mtɛnu ʔiɦɛ̂mtɛnu
# ref: muʔûnje pred: muʔiːsnuje
# ref: muʔuːje pred: muʔiʔije
# ref: ʔîjje pred: ʔiʔiːʦije
# ref: ʔuːje pred: ʔiʔije
# ref: ʔinɛ pred: ʔʌ̂nnɛ
# ref: muʔikʌ pred: muʔʌjkʌ
# ref: muʔiji pred: muʔiʔiji
# ref: muʔiki pred: muʔʌjki
# ref: mʌʔi pred: mʌʔʌj
# ref: muʔinu pred: muʔʌnu
# ref: ʔikʌ pred: ʔʌjkʌ
# ref: ʔiji pred: ʔiʔiji
# ref: ʔiʔini pred: ʔiʔʌjni
# ref: ʔiʔi pred: ʔiʔʌj
# ref: ʔinu pred: ʔiʔʌnnu
# ref: muʔikwʌkʌ pred: muʔʌjwʌkʌ
# ref: muʔuːwɛ pred: muʔiʔiːswɛ
# ref: ʔiktʌkʌ pred: ʔʌjtʌkʌ
# ref: ʔiŋʌtʌ pred: ʔiʔiʔisiŋʌtʌ
# ref: ʔiʔîjti pred: ʔiʔiʔiʔiːsiiti
# muʔɵke muʔɵke
# ʔôːnɛ ʔôːnɛ
# muʔokki muʔokki
# mʌʔɵki mʌʔɵki
# mʌʔôːni mʌʔôːni
# mʌʔôː mʌʔôː
# muʔɵki muʔɵki
# ʔɵki ʔɵki
# ʔokki ʔokki
# ʔiʔɵki ʔiʔɵki
# ʔôːnu ʔôːnu
# ʔôː ʔôː
# muʔokwiki muʔokwiki
# mʌʔɵkiwi mʌʔɵkiwi
# mʌʔɵkwɛnu mʌʔɵkwɛnu
# ʔɵkutu ʔɵkutu
# ʔɵkʌtʌ ʔɵkʌtʌ
# ʔiʔɵktɛnu ʔiʔɵktɛnu
# ʔɵkiti ʔɵkiti
# ʔɵktɛ ʔɵktɛ
# muʔoɔjkʌje muʔoɔjkʌje
# ʔoɔjkʌje ʔoɔjkʌje
# ʔɵːsnuje ʔɵːsnuje
# ref: ʔoɔnde pred: ʔɵːsije
# mʌʔoɔndʉ mʌʔoɔndʉ
# mʌʔoɔjkʌ mʌʔoɔjkʌ
# mʌʔɵːʦi mʌʔɵːʦi
# muʔoɔ̂nnu muʔoɔ̂nnu
# muʔoɔndʉ muʔoɔndʉ
# ʔiʔɵːʦi ʔiʔɵːʦi
# ʔiʔoɔjni ʔiʔoɔjni
# ref: ʔoɔ̂jnu pred: ʔoɔ̂nnu
# ʔoɔndusu ʔoɔndusu
# ʔoɔ̂nsu ʔoɔ̂nsu
# ʔiʔɵːʦu ʔiʔɵːʦu
# mʌʔɵːswi mʌʔɵːswi
# ref: muʔoɔ̂jwɛnnu pred: muʔoɔ̂nwɛnnu
# mʌʔɵ̂ːswɛnu mʌʔɵ̂ːswɛnu
# ref: ʔiʔoɔ̂ntɛ pred: ʔiʔɵ̂ːstɛ
# ʔiʔɵ̂ːstɛ ʔiʔɵ̂ːstɛ
# muʦiknuje muʦiknuje
# ref: ʦûːnɛ pred: ʦîːnɛ
# muʦakkʌ muʦakkʌ
# ref: muʦûːŋʌ pred: muʦikŋʌ
# mʌʦiki mʌʦiki
# ref: mʌʦûː pred: mʌʦâː
# muʦiki muʦiki
# ʦiku ʦiku
# ʦakkʌ ʦakkʌ
# ʦakki ʦakki
# ref: ʔiʦûː pred: ʔiʦâː
# ʦiki ʦiki
# ref: ʦûː pred: ʦâː
# muʦikuwu muʦikuwu
# muʦikiwi muʦikiwi
# muʦakwiki muʦakwiki
# mʌʦikwɛnu mʌʦikwɛnu
# mʌʦikwɛ mʌʦikwɛ
# ʦaktʌkʌ ʦaktʌkʌ
# ref: ʦiktɛnu pred: ʦʌktɛnu
# muʦirnuje muʦirnuje
# ref: muʦirsiju pred: muʦirsijsiju
# ref: muʦʌrsikʌ pred: muʦʌrsiksikʌ
# muʦirsiji muʦirsiji
# mʌʦʌrni mʌʦʌrni
# ref: muʦîrnu pred: muʦʌ̂rnu
# ʔiʦʌrni ʔiʦʌrni
# ʔiʦiru ʔiʦiru
# ʔiʦiru ʔiʦiru
# ʔiʦʌrki ʔiʦʌrki
# ʔiʦʌrkʌ ʔiʦʌrkʌ
# ref: ʦîrnu pred: ʦʌ̂rnu
# mʌʦiriwi mʌʦiriwi
# ref: muʦîrwɛsu pred: muʦʌ̂rwɛsu
# ref: muʦîrwɛnu pred: muʦʌ̂rwɛnu
# ʦiriti ʦiriti
# ʦʌrtiki ʦʌrtiki
# ʦʌ̂rtɛnnu ʦʌ̂rtɛnnu
# ref: ʦirutʌnu pred: ʦʌrtʌnu
# ʔiʦʌrtʌkʌ ʔiʦʌrtʌkʌ
# muʦʰɵpije muʦʰɵpije
# muʦʰɵpu muʦʰɵpu
# mʌʦʰɵpu mʌʦʰɵpu
# mʌʦʰoɔpkʌ mʌʦʰoɔpkʌ
# ref: mʌʦʰoɔp pred: mʌʦʰoɔ̂m
# ref: muʦʰɵ̂ːpnu pred: muʦʰoɔ̂mnu
# ʔiʦʰɵpi ʔiʦʰɵpi
# ʔiʦʰoɔ̂mni ʔiʦʰoɔ̂mni
# ʦʰoɔpki ʦʰoɔpki
# ref: ʦʰɵ̂ːpnu pred: ʦʰoɔ̂mnu
# ʔiʦʰoɔpki ʔiʦʰoɔpki
# ʔiʦʰoɔpki ʔiʦʰoɔpki
# ref: ʦʰɵːbʉ pred: ʦʰoɔ̂m
# mʌʦʰɵpwɛ mʌʦʰɵpwɛ
# mʌʦʰɵpiwi mʌʦʰɵpiwi
# muʦʰɵ̂ːpwɛnu muʦʰɵ̂ːpwɛnu
# mʌʦʰɵpʌwʌnu mʌʦʰɵpʌwʌnu
# ʦʰoɔptʌkʌ ʦʰoɔptʌkʌ
# ʦʰoɔ̂mtɛnnu ʦʰoɔ̂mtɛnnu
# ʦʰɵ̂ːptɛnu ʦʰɵ̂ːptɛnu
# ref: muʦʰɛ̂nnuje pred: muʦʰɛsnuje
# ʦʰɛçkʌje ʦʰɛçkʌje
# ʦʰɛʦʌnuje ʦʰɛʦʌnuje
# muʦʰɛçkʌ muʦʰɛçkʌ
# ʦʰɛçkʌ ʦʰɛçkʌ
# ʦʰɛçki ʦʰɛçki
# ʔiʦʰɛçkʌ ʔiʦʰɛçkʌ
# ʔiʦʰɛtsu ʔiʦʰɛtsu
# ʔiʦʰɛ̂nni ʔiʦʰɛ̂nni
# ʦʰɛtnu ʦʰɛtnu
# muʦʰɛçwiki muʦʰɛçwiki
# muʦʰɛtwɛsu muʦʰɛtwɛsu
# ref: ʦʰɛssiktʌkʌ pred: ʦʰɛçtʌkʌ
# ʔiʦʰɛstɛnu ʔiʦʰɛstɛnu
# ʔiʦʰɛstɛ ʔiʦʰɛstɛ
# ʦʰɛ̂ntɛnnu ʦʰɛ̂ntɛnnu
# ʔiʦʰɛstɛnu ʔiʦʰɛstɛnu
# ʦʰɛttɛnu ʦʰɛttɛnu
# ʔiʦʰɛstu ʔiʦʰɛstu
# ʔiʦʰɛçtiki ʔiʦʰɛçtiki
# 0.77
# livles/5lang-sample_16epochs
# test file:  ../preprocessing/preprocessing_to_json/data/deu-lang-word_test.json
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 50
#      48 Path(OUT_DIR).mkdir(parents=True, exist_ok=True)
#      49 with open (OUT_DIR + test_lang + lang_code + "_byt5-small.out","w") as out_file, open (PATH_TO_ORIG_TEST_FILE, "r") as test_file:
# ---> 50     dataset = load_dataset("json",data_files={"test":PATH_TO_JSON_TEST_FILE})
#      51     covered_test_lines = dataset["test"]["input"]
#      52     LEN = len(covered_test_lines)
#
# File /usr/local/lib/python3.10/dist-packages/datasets/load.py:1397, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1392 verification_mode = VerificationMode(
#    1393     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    1394 )
#    1396 # Create a dataset builder
# -> 1397 builder_instance = load_dataset_builder(
#    1398     path=path,
#    1399     name=name,
#    1400     data_dir=data_dir,
#    1401     data_files=data_files,
#    1402     cache_dir=cache_dir,
#    1403     features=features,
#    1404     download_config=download_config,
#    1405     download_mode=download_mode,
#    1406     revision=revision,
#    1407     token=token,
#    1408     storage_options=storage_options,
#    1409     **config_kwargs,
#    1410 )
#    1412 # Return iterable dataset in case of streaming
#    1413 if streaming:
#
# File /usr/local/lib/python3.10/dist-packages/datasets/load.py:1137, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, **config_kwargs)
#    1135 if features is not None:
#    1136     features = _fix_for_backward_compatible_features(features)
# -> 1137 dataset_module = dataset_module_factory(
#    1138     path,
#    1139     revision=revision,
#    1140     download_config=download_config,
#    1141     download_mode=download_mode,
#    1142     data_dir=data_dir,
#    1143     data_files=data_files,
#    1144     cache_dir=cache_dir,
#    1145 )
#    1146 # Get dataset builder class
#    1147 builder_kwargs = dataset_module.builder_kwargs
#
# File /usr/local/lib/python3.10/dist-packages/datasets/load.py:913, in dataset_module_factory(path, revision, download_config, download_mode, data_dir, data_files, cache_dir, **download_kwargs)
#     890 # We have several ways to get a dataset builder:
#     891 #
#     892 # - if path is the name of a packaged dataset module
#    (...)
#     904
#     905 # Try packaged
#     906 if path in _PACKAGED_DATASETS_MODULES:
#     907     return PackagedDatasetModuleFactory(
#     908         path,
#     909         data_dir=data_dir,
#     910         data_files=data_files,
#     911         download_config=download_config,
#     912         download_mode=download_mode,
# --> 913     ).get_module()
#     914 # Try locally
#     915 elif path.endswith(filename):
#
# File /usr/local/lib/python3.10/dist-packages/datasets/load.py:527, in PackagedDatasetModuleFactory.get_module(self)
#     521 base_path = Path(self.data_dir or "").expanduser().resolve().as_posix()
#     522 patterns = (
#     523     sanitize_patterns(self.data_files)
#     524     if self.data_files is not None
#     525     else get_data_patterns(base_path, download_config=self.download_config)
#     526 )
# --> 527 data_files = DataFilesDict.from_patterns(
#     528     patterns,
#     529     download_config=self.download_config,
#     530     base_path=base_path,
#     531 )
#     533 module_path, hash = _PACKAGED_DATASETS_MODULES[self.name]
#     535 builder_kwargs = {
#     536     "data_files": data_files,
#     537     "dataset_name": self.name,
#     538 }
#
# File /usr/local/lib/python3.10/dist-packages/datasets/data_files.py:705, in DataFilesDict.from_patterns(cls, patterns, base_path, allowed_extensions, download_config)
#     700 out = cls()
#     701 for key, patterns_for_key in patterns.items():
#     702     out[key] = (
#     703         patterns_for_key
#     704         if isinstance(patterns_for_key, DataFilesList)
# --> 705         else DataFilesList.from_patterns(
#     706             patterns_for_key,
#     707             base_path=base_path,
#     708             allowed_extensions=allowed_extensions,
#     709             download_config=download_config,
#     710         )
#     711     )
#     712 return out
#
# File /usr/local/lib/python3.10/dist-packages/datasets/data_files.py:598, in DataFilesList.from_patterns(cls, patterns, base_path, allowed_extensions, download_config)
#     595 for pattern in patterns:
#     596     try:
#     597         data_files.extend(
# --> 598             resolve_pattern(
#     599                 pattern,
#     600                 base_path=base_path,
#     601                 allowed_extensions=allowed_extensions,
#     602                 download_config=download_config,
#     603             )
#     604         )
#     605     except FileNotFoundError:
#     606         if not has_magic(pattern):
#
# File /usr/local/lib/python3.10/dist-packages/datasets/data_files.py:387, in resolve_pattern(pattern, base_path, allowed_extensions, download_config)
#     385     if allowed_extensions is not None:
#     386         error_msg += f" with any supported extension {list(allowed_extensions)}"
# --> 387     raise FileNotFoundError(error_msg)
#     388 return out
#
# FileNotFoundError: Unable to find '/dss/dsshome1/03/ge87wod2/morphological-inflection/ByT5/../preprocessing/preprocessing_to_json/data/deu-lang-word_test.json'
