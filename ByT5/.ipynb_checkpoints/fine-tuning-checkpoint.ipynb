# %% [markdown]
# # Setup

# %%
# !pip install transformers torch datasets pip accelerate
# !pip install transformers --upgrade
# !pip install ipywidgets
# !pip install python-dotenv pickleshare
# Out:
# Collecting transformers
#   Using cached transformers-4.57.1-py3-none-any.whl.metadata (43 kB)
# Collecting torch
#   Using cached torch-2.9.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Collecting datasets
#   Using cached datasets-4.3.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (24.2)
# Collecting accelerate
#   Using cached accelerate-1.11.0-py3-none-any.whl.metadata (19 kB)
# Collecting filelock (from transformers)
#   Using cached filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting huggingface-hub<1.0,>=0.34.0 (from transformers)
#   Using cached huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Collecting regex!=2019.12.17 (from transformers)
#   Using cached regex-2025.10.23-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Using cached tokenizers-0.22.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Using cached safetensors-0.6.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting tqdm>=4.27 (from transformers)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Collecting sympy>=1.13.3 (from torch)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch)
#   Using cached nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch)
#   Using cached nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch)
#   Using cached nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch)
#   Using cached nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch)
#   Using cached nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch)
#   Using cached nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch)
#   Using cached nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting nvidia-nccl-cu12==2.27.5 (from torch)
#   Using cached nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvshmem-cu12==3.3.20 (from torch)
#   Using cached nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch)
#   Using cached nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch)
#   Using cached nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch)
#   Using cached nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.5.0 (from torch)
#   Using cached triton-3.5.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Collecting pyarrow>=21.0.0 (from datasets)
#   Using cached pyarrow-22.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.2 kB)
# Collecting dill<0.4.1,>=0.3.0 (from datasets)
#   Using cached dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.27.0)
# Collecting xxhash (from datasets)
#   Using cached xxhash-3.6.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Using cached multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (3.10.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1.0.0->datasets) (4.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1.0.0->datasets) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1.0.0->datasets) (1.0.5)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<1.0.0->datasets) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1.0.0->datasets) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.14.0)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub<1.0,>=0.34.0->transformers)
#   Using cached hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (2.3.5)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets) (4.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1.0.0->datasets) (1.2.2)
# Using cached transformers-4.57.1-py3-none-any.whl (12.0 MB)
# Using cached torch-2.9.0-cp310-cp310-manylinux_2_28_x86_64.whl (899.8 MB)
# Using cached nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
# Using cached nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
# Using cached nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
# Using cached nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
# Using cached nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
# Using cached nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
# Using cached nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
# Using cached nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
# Using cached nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
# Using cached nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
# Using cached nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.3 MB)
# Using cached nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
# Using cached nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (124.7 MB)
# Using cached nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Using cached triton-3.5.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (170.3 MB)
# Using cached datasets-4.3.0-py3-none-any.whl (506 kB)
# Using cached accelerate-1.11.0-py3-none-any.whl (375 kB)
# Using cached dill-0.4.0-py3-none-any.whl (119 kB)
# Using cached huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
# Using cached multiprocess-0.70.16-py310-none-any.whl (134 kB)
# Using cached pyarrow-22.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (47.6 MB)
# Using cached regex-2025.10.23-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (791 kB)
# Using cached safetensors-0.6.2-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (485 kB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached tokenizers-0.22.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached filelock-3.20.0-py3-none-any.whl (16 kB)
# Using cached xxhash-3.6.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (193 kB)
# Using cached hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, xxhash, triton, tqdm, sympy, safetensors, regex, pyarrow, nvidia-nvtx-cu12, nvidia-nvshmem-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, hf-xet, filelock, dill, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, multiprocess, huggingface-hub, tokenizers, nvidia-cusolver-cu12, transformers, torch, datasets, accelerate
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 16.1.0
#     Uninstalling pyarrow-16.1.0:
#       Successfully uninstalled pyarrow-16.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 24.6.0 requires pyarrow<16.2.0a0,>=16.1.0, but you have pyarrow 22.0.0 which is incompatible.
# Successfully installed accelerate-1.11.0 datasets-4.3.0 dill-0.4.0 filelock-3.20.0 hf-xet-1.2.0 huggingface-hub-0.36.0 mpmath-1.3.0 multiprocess-0.70.16 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.5 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvshmem-cu12-3.3.20 nvidia-nvtx-cu12-12.8.90 pyarrow-22.0.0 regex-2025.10.23 safetensors-0.6.2 sympy-1.14.0 tokenizers-0.22.1 torch-2.9.0 tqdm-4.67.1 transformers-4.57.1 triton-3.5.0 xxhash-3.6.0
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.57.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.20.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.36.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2025.10.23)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.12.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.7.4)
# Collecting ipywidgets
#   Using cached ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (8.26.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets)
#   Using cached widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets)
#   Using cached jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (2.18.0)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (1.2.2)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (4.12.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets) (4.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.4.1)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.10/dist-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)
# Using cached ipywidgets-8.1.7-py3-none-any.whl (139 kB)
# Using cached jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
# Using cached widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
# Installing collected packages: widgetsnbextension, jupyterlab_widgets, ipywidgets
# Successfully installed ipywidgets-8.1.7 jupyterlab_widgets-3.0.15 widgetsnbextension-4.0.14
# Collecting python-dotenv
#   Using cached python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Collecting pickleshare
#   Using cached pickleshare-0.7.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Using cached python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Using cached pickleshare-0.7.5-py2.py3-none-any.whl (6.9 kB)
# Installing collected packages: pickleshare, python-dotenv
# Successfully installed pickleshare-0.7.5 python-dotenv-1.2.1

# %% [markdown]
# # Training small pre-trained ByT5 model using dataset

# %%
# from dotenv import load_dotenv
# import os

# load_dotenv()

# HF_TOKEN = os.getenv("HF_TOKEN")

# # print("HF_TOKEN: ", HF_TOKEN)

# # source: https://huggingface.co/docs/transformers/v4.28.1/tasks/summarization
# from huggingface_hub import login

# login(HF_TOKEN)
LANGS = ["grc","dan","fra","sme","deu","nav","jap","klr","eng","mul","deu_eng"]
LANGS = LANGS[-2:]
LANGS = ["mul_2","amh","pol","ote"]
LANGS = ["mul_2","amh","pol","ote"]
LANGS = ["mul-language-code","mul-language-word"]
LANGS = ["mul-language-code"]
LANGS = ["5lang-sample"]


PATH_JSON_DATA = "../preprocessing/preprocessing_to_json/data/"

for lang in LANGS:
    from datasets import load_dataset
    # dataset= dataset.train_test_split(test_size=0.2) #train_size=10000,
    dataset = load_dataset("json", data_files={"train": PATH_JSON_DATA + lang + "_trn.json", "validation": PATH_JSON_DATA + lang + "_dev.json"})

    print(dataset["train"][0])

    from transformers import AutoTokenizer

    checkpoint = "google/byt5-small"
    tokenizer = AutoTokenizer.from_pretrained(checkpoint)
    # -

    import torch

    from transformers import (
        AutoTokenizer,
        TrainingArguments,
        Trainer,
        AutoModelForSeq2SeqLM,
        Seq2SeqTrainingArguments,
        Seq2SeqTrainer
    )
    from datasets import load_dataset

    def preprocess_function(examples):
        # inputs = [prefix + doc for doc in examples["text"]]
        inputs = examples["input"]
        model_inputs = tokenizer(inputs)

        labels = tokenizer(text_target=examples["target"]) # same length irrelevant here, so no truncation or padding

        model_inputs["labels"] = labels["input_ids"]
        return model_inputs


    tokenized_dataset = dataset.map(preprocess_function, batched=True)
    print(tokenized_dataset)
    sample = tokenized_dataset["train"][0]
    print(sample["labels"])

    from transformers import DataCollatorForSeq2Seq

    data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=checkpoint)

    # import evaluate

    # rouge = evaluate.load("rouge")

    # import numpy as np


    # def compute_metrics(eval_pred):
    #     predictions, labels = eval_pred
    #     decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    #     labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    #     decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)

    #     result = rouge.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)

    #     prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions]
    #     result["gen_len"] = np.mean(prediction_lens)

    #     return {k: round(v, 4) for k, v in result.items()}

    # import numpy as np
    # import evaluate

    # metric = evaluate.load("accuracy")

    # def compute_metrics(eval_pred):
    #     predictions, labels = eval_pred # TODO: labels vs title?

    #     decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)

    #     labels = np.where(labels != -100, labels, tokenizer.pad_token_id) # TODO: correct?

    #     decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    #     return metric.compute(predictions=predictions, references=labels)

    from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer

    model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    training_args = Seq2SeqTrainingArguments(
        output_dir="byt5_small/"+lang,
        eval_strategy="epoch",
        learning_rate=5e-5,
        per_device_train_batch_size=16,
        per_device_eval_batch_size=16,
        weight_decay=0.01,
        save_total_limit=3,
        num_train_epochs=4,
        predict_with_generate=True,
        # save_strategy="epoch",
        fp16=False,# did not work with True #change to bf16=True for XPU 
        #bf16 = True, # performance was best without setting fp16 or bf16 to true
        push_to_hub=True,
        warmup_steps = 500,
        # load_best_model_at_end=True, # otherwise not model with minimum loss during training, like https://huggingface.co/docs/transformers/tasks/sequence_classification
    )

    trainer = Seq2SeqTrainer(
        model=model,
        args=training_args,
        train_dataset=tokenized_dataset["train"],
        eval_dataset=tokenized_dataset["validation"],
        tokenizer=tokenizer,
        data_collator=data_collator,
        # compute_metrics=compute_metrics,
    )

    trainer.train()
    trainer.push_to_hub()
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# {'input': 'Navajo: Inflect náʼáłkad | V;IND;PFV;NOM(1,GRPL)', 'target': 'ńdaʼiilkad'}
# 2025-11-01 16:16:20.882874: I tensorflow/core/platform/cpu_feature_guard.cc:211] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Map:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['input', 'target', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 10000
#     })
#     validation: Dataset({
#         features: ['input', 'target', 'input_ids', 'attention_mask', 'labels'],
#         num_rows: 1000
#     })
# })
# [200, 135, 103, 100, 205, 191, 108, 108, 111, 110, 100, 103, 1]
# /tmp/ipykernel_301522/2453831306.py:129: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(
#     <div>
#
#       <progress value='2500' max='2500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2500/2500 12:57, Epoch 4/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.696000</td>
#       <td>0.715448</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.788000</td>
#       <td>0.518034</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.591400</td>
#       <td>0.467004</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.488600</td>
#       <td>0.454720</td>
#     </tr>
#   </tbody>
# </table><p>
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B

# %% [markdown]
# # Testing models

# %%
# SETTINGS = ["grc","dan","fra","sme","deu","nav","jap","klr","eng","mul","deu_eng"] + ["mul_2","ote","pol","amh"] + ["mul-language-code","mul-language-word"]
SETTINGS = ["mul"]
SETTINGS = ["5lang-sample"]
TEST_LANGS_OLD = ["grc","dan","fra","sme","deu","nav","jap","klr","eng"] 
TEST_LANGS = ["grc","dan","fra","sme","deu","nav","jap","klr","eng"] + ["ote","pol","amh","csb"]
lang5_LANGS = ["deu","nav","klr","amh","grc"]
lang_code = ""
for lang_setting in SETTINGS:
    if lang_setting == "mul": LANG_CODES = ["-language-word","-language-code",""] # test with no language code/word too
    else: LANG_CODES = [""]
    for lang_code in LANG_CODES:
        if lang_setting in ( "deu_eng", "mul") and lang_code == "": test_langs = TEST_LANGS_OLD
        elif lang_setting in ["mul_2","mul"]: test_langs = TEST_LANGS # test multilingual model on all languages it was trained on + Kashubian
        elif lang_setting == "5lang-sample": test_langs = lang5_LANGS
        elif lang_setting == "pol": test_langs = ["pol","csb"] # test Polish model on Kashubian also
        else: test_langs = [lang_setting]
        for test_lang in test_langs:
            import torch
            from transformers import AutoModelForSeq2SeqLM, AutoTokenizer
            PRETRAINED_MODEL = "google/byt5-small"
            FINETUNED_MODEL ="livles/"+lang_setting + lang_code
            #FINETUNED_MODEL ="./byt5_small/"+lang_setting + "-" + lang_code
            MODEL = FINETUNED_MODEL
            print(MODEL)
            tokenizer = AutoTokenizer.from_pretrained(
                FINETUNED_MODEL,
            )
            model = AutoModelForSeq2SeqLM.from_pretrained(
                FINETUNED_MODEL,
            dtype=torch.float16,
            device_map="auto"
            )

            from datasets import load_dataset
            OUT_DIR = "output_byt5_small/" + lang_setting + lang_code+ "/" 
            PATH_TO_JSON_TEST_FILE = "../preprocessing/preprocessing_to_json/data/" + test_lang + lang_code+ "_test.json"
            PATH_TO_ORIG_TEST_FILE = "../2023InflectionST/part1/data/" + test_lang + ".tst"
            with open (OUT_DIR + test_lang + lang_code + "_byt5-small.out","w") as out_file, open (PATH_TO_ORIG_TEST_FILE, "r") as test_file:
                COUNTER = 0
                dataset = load_dataset("json",data_files={"test":PATH_TO_JSON_TEST_FILE})
                covered_test_lines = dataset["test"]["input"]
                LEN = len(covered_test_lines)


                # preds = map (generate,covered_test_lines)
                for line in covered_test_lines:
                    input_ids = tokenizer(line, return_tensors="pt").to(model.device)
                    output = model.generate(
                        **input_ids,
                        max_new_tokens=50,
                        num_beams=4,
                        #early_stopping=True
                    )
                    output_string = (tokenizer.decode(output[0], skip_special_tokens=True))
                    lemma, features, ref = test_file.readline().strip().split("\t")

                    # evaluate
                    if (ref == output_string):
                        COUNTER += 1
                        print(ref,output_string)
                    else:
                        print("ref:",ref,"pred:",output_string)
                    
                    # write
                    out_file.write(lemma + "\t" +features+ "\t" + output_string + "\n")
                    out_file.flush()

                accuracy = COUNTER / LEN
                out_file.write("accuracy:"+ str(accuracy))
                print(accuracy)
# Out:
# livles/5lang-sample
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 38
#      36 with open (OUT_DIR + test_lang + lang_code + "_byt5-small.out","w") as out_file, open (PATH_TO_ORIG_TEST_FILE, "r") as test_file:
#      37     COUNTER = 0
# ---> 38     dataset = load_dataset("json",data_files={"test":PATH_TO_JSON_TEST_FILE})
#      39     covered_test_lines = dataset["test"]["input"]
#      40     LEN = len(covered_test_lines)
#
# File /usr/local/lib/python3.10/dist-packages/datasets/load.py:1397, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, **config_kwargs)
#    1392 verification_mode = VerificationMode(
#    1393     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    1394 )
#    1396 # Create a dataset builder
# -> 1397 builder_instance = load_dataset_builder(
#    1398     path=path,
#    1399     name=name,
#    1400     data_dir=data_dir,
#    1401     data_files=data_files,
#    1402     cache_dir=cache_dir,
#    1403     features=features,
#    1404     download_config=download_config,
#    1405     download_mode=download_mode,
#    1406     revision=revision,
#    1407     token=token,
#    1408     storage_options=storage_options,
#    1409     **config_kwargs,
#    1410 )
#    1412 # Return iterable dataset in case of streaming
#    1413 if streaming:
#
# File /usr/local/lib/python3.10/dist-packages/datasets/load.py:1137, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, **config_kwargs)
#    1135 if features is not None:
#    1136     features = _fix_for_backward_compatible_features(features)
# -> 1137 dataset_module = dataset_module_factory(
#    1138     path,
#    1139     revision=revision,
#    1140     download_config=download_config,
#    1141     download_mode=download_mode,
#    1142     data_dir=data_dir,
#    1143     data_files=data_files,
#    1144     cache_dir=cache_dir,
#    1145 )
#    1146 # Get dataset builder class
#    1147 builder_kwargs = dataset_module.builder_kwargs
#
# File /usr/local/lib/python3.10/dist-packages/datasets/load.py:913, in dataset_module_factory(path, revision, download_config, download_mode, data_dir, data_files, cache_dir, **download_kwargs)
#     890 # We have several ways to get a dataset builder:
#     891 #
#     892 # - if path is the name of a packaged dataset module
#    (...)
#     904
#     905 # Try packaged
#     906 if path in _PACKAGED_DATASETS_MODULES:
#     907     return PackagedDatasetModuleFactory(
#     908         path,
#     909         data_dir=data_dir,
#     910         data_files=data_files,
#     911         download_config=download_config,
#     912         download_mode=download_mode,
# --> 913     ).get_module()
#     914 # Try locally
#     915 elif path.endswith(filename):
#
# File /usr/local/lib/python3.10/dist-packages/datasets/load.py:527, in PackagedDatasetModuleFactory.get_module(self)
#     521 base_path = Path(self.data_dir or "").expanduser().resolve().as_posix()
#     522 patterns = (
#     523     sanitize_patterns(self.data_files)
#     524     if self.data_files is not None
#     525     else get_data_patterns(base_path, download_config=self.download_config)
#     526 )
# --> 527 data_files = DataFilesDict.from_patterns(
#     528     patterns,
#     529     download_config=self.download_config,
#     530     base_path=base_path,
#     531 )
#     533 module_path, hash = _PACKAGED_DATASETS_MODULES[self.name]
#     535 builder_kwargs = {
#     536     "data_files": data_files,
#     537     "dataset_name": self.name,
#     538 }
#
# File /usr/local/lib/python3.10/dist-packages/datasets/data_files.py:701, in DataFilesDict.from_patterns(cls, patterns, base_path, allowed_extensions, download_config)
#     696 out = cls()
#     697 for key, patterns_for_key in patterns.items():
#     698     out[key] = (
#     699         patterns_for_key
#     700         if isinstance(patterns_for_key, DataFilesList)
# --> 701         else DataFilesList.from_patterns(
#     702             patterns_for_key,
#     703             base_path=base_path,
#     704             allowed_extensions=allowed_extensions,
#     705             download_config=download_config,
#     706         )
#     707     )
#     708 return out
#
# File /usr/local/lib/python3.10/dist-packages/datasets/data_files.py:594, in DataFilesList.from_patterns(cls, patterns, base_path, allowed_extensions, download_config)
#     591 for pattern in patterns:
#     592     try:
#     593         data_files.extend(
# --> 594             resolve_pattern(
#     595                 pattern,
#     596                 base_path=base_path,
#     597                 allowed_extensions=allowed_extensions,
#     598                 download_config=download_config,
#     599             )
#     600         )
#     601     except FileNotFoundError:
#     602         if not has_magic(pattern):
#
# File /usr/local/lib/python3.10/dist-packages/datasets/data_files.py:383, in resolve_pattern(pattern, base_path, allowed_extensions, download_config)
#     381     if allowed_extensions is not None:
#     382         error_msg += f" with any supported extension {list(allowed_extensions)}"
# --> 383     raise FileNotFoundError(error_msg)
#     384 return out
#
# FileNotFoundError: Unable to find '/dss/dsshome1/03/ge87wod2/morphological-inflection/ByT5/../preprocessing/preprocessing_to_json/data/grc_tst.json'
# kalkstens kalkstens
# kalkstens kalkstens
# ref: kalkstenenes pred: kalkstenernes
# ref: kalkstenens pred: kalkstenets
# ref: kalksten pred: kalkstene
# kalksten kalksten
# kasketters kasketters
# kaskets kaskets
# kasketternes kasketternes
# kaskettens kaskettens
# kasketter kasketter
# kasket kasket
# kejthåndede kejthåndede
# kejthåndet kejthåndet
# kejthåndet kejthåndet
# kejthåndede kejthåndede
# kierkegårdske kierkegårdske
# kierkegårdsk kierkegårdsk
# kierkegårdsk kierkegårdsk
# kierkegårdske kierkegårdske
# kioskers kioskers
# kiosks kiosks
# kioskernes kioskernes
# kioskens kioskens
# ref: kiosker pred: kioske
# kiosk kiosk
# knappe knappe
# knap knap
# knapt knapt
# ref: knappe pred: knape
# knapper knapper
# kokkepigers kokkepigers
# kokkepiges kokkepiges
# kokkepigernes kokkepigernes
# kokkepigens kokkepigens
# kokkepiger kokkepiger
# kokkepige kokkepige
# ref: konkurrencedygtigere pred: mere konkurrencedygtig
# ref: konkurrencedygtigst pred: mest konkurrencedygtig
# konkurrencedygtigt konkurrencedygtigt
# konkurrencedygtige konkurrencedygtige
# ref: konkurrencedygtigst pred: mest konkurrencedygtig
# kuriøs kuriøs
# kuriøst kuriøst
# kuriøse kuriøse
# kvadratiske kvadratiske
# kvadratisk kvadratisk
# kvadratisk kvadratisk
# kvadratiske kvadratiske
# kønne kønne
# kønnere kønnere
# køn køn
# ref: kønnere pred: kønere
# kønnest kønnest
# køresyge køresyge
# køresyg køresyg
# køresygt køresygt
# køresyge køresyge
# labile labile
# labil labil
# labilt labilt
# labile labile
# lesbiske lesbiske
# lesbisk lesbisk
# lesbisk lesbisk
# lesbiske lesbiske
# ref: lillebrødres pred: lillebrors
# lillebrors lillebrors
# lillebrødrenes lillebrødrenes
# ref: lillebrorens pred: lillebrorets
# ref: lillebrødre pred: lillebror
# lillebror lillebror
# lipiders lipiders
# lipids lipids
# lipidernes lipidernes
# lipidets lipidets
# lipider lipider
# lipid lipid
# lybske lybske
# lybsk lybsk
# lybsk lybsk
# lybske lybske
# lydpotters lydpotters
# lydpottes lydpottes
# lydpotternes lydpotternes
# lydpottens lydpottens
# lydpotter lydpotter
# lydpotte lydpotte
# lystne lystne
# lysten lysten
# lystent lystent
# ref: lystne pred: lystene
# lågers lågers
# låges låges
# lågernes lågernes
# lågens lågens
# låger låger
# låge låge
# læbers læbers
# læbes læbes
# læbernes læbernes
# læbens læbens
# læber læber
# læbe læbe
# lækkersultne lækkersultne
# lækkersulten lækkersulten
# lækkersultent lækkersultent
# lækkersultne lækkersultne
# ref: læsehestes pred: læsehesters
# læsehests læsehests
# ref: læsehestenes pred: læsehesternes
# læsehestens læsehestens
# ref: læseheste pred: læsehester
# læsehest læsehest
# mandlige mandlige
# mandlig mandlig
# mandligt mandligt
# mandlige mandlige
# manifesters manifesters
# manifests manifests
# manifesternes manifesternes
# ref: manifestets pred: manifestens
# manifester manifester
# manifest manifest
# maniodepressive maniodepressive
# maniodepressiv maniodepressiv
# maniodepressivt maniodepressivt
# maniodepressive maniodepressive
# mariehøners mariehøners
# mariehønes mariehønes
# mariehønernes mariehønernes
# mariehønens mariehønens
# mariehøner mariehøner
# mariehøne mariehøne
# megalomaniers megalomaniers
# megalomanis megalomanis
# megalomaniernes megalomaniernes
# megalomaniens megalomaniens
# megalomanier megalomanier
# megalomani megalomani
# ref: midnætters pred: midnaters
# midnats midnats
# ref: midnætternes pred: midnatternes
# midnattens midnattens
# ref: midnætter pred: midnatter
# midnat midnat
# ref: millimeters pred: millimeteres
# millimeters millimeters
# millimeternes millimeternes
# millimeterens millimeterens
# ref: millimeter pred: millimetere
# millimeter millimeter
# mulers mulers
# mules mules
# mulernes mulernes
# mulens mulens
# muler muler
# mule mule
# musketters musketters
# muskets muskets
# musketternes musketternes
# muskettens muskettens
# musketter musketter
# musket musket
# mytiske mytiske
# mytisk mytisk
# mytisk mytisk
# mytiske mytiske
# neutroners neutroners
# neutrons neutrons
# neutronernes neutronernes
# neutronens neutronens
# neutroner neutroner
# neutron neutron
# ref: nudlers pred: nudellers
# nudels nudels
# nudlernes nudlernes
# ref: nudlens pred: nudellens
# nudler nudler
# nudel nudel
# nukleoners nukleoners
# nukleons nukleons
# nukleonernes nukleonernes
# nukleonens nukleonens
# nukleoner nukleoner
# nukleon nukleon
# nuttede nuttede
# nuttet nuttet
# nuttet nuttet
# nuttede nuttede
# odderes odderes
# odders odders
# oddernes oddernes
# odderens odderens
# oddere oddere
# odder odder
# oldhøjtyske oldhøjtyske
# oldhøjtysk oldhøjtysk
# oldhøjtysk oldhøjtysk
# oldhøjtyske oldhøjtyske
# omnivore omnivore
# omnivor omnivor
# omnivort omnivort
# omnivore omnivore
# oplysningers oplysningers
# oplysnings oplysnings
# oplysningernes oplysningernes
# oplysningens oplysningens
# oplysninger oplysninger
# oplysning oplysning
# ref: ordbøgers pred: ordbøges
# ordbogs ordbogs
# ordbøgernes ordbøgernes
# ordbogens ordbogens
# ref: ordbøger pred: ordbøge
# ordbog ordbog
# ref: ordrette pred: ordrede
# ordret ordret
# ordret ordret
# ref: ordrette pred: ordrede
# padders padders
# paddes paddes
# paddernes paddernes
# paddens paddens
# padder padder
# padde padde
# panerende panerende
# paneret paneret
# panerede panerede
# panere panere
# paneres paneres
# ref: parallellogrammers pred: parallellogrammes
# parallellograms parallellograms
# parallellogrammernes parallellogrammernes
# parallellogrammets parallellogrammets
# parallellogrammer parallellogrammer
# parallellogram parallellogram
# patenters patenters
# patents patents
# patenternes patenternes
# ref: patentets pred: patentens
# patenter patenter
# patent patent
# patetiske patetiske
# patetisk patetisk
# patetisk patetisk
# patetiske patetiske
# ref: patogene pred: patogne
# patogen patogen
# patogent patogent
# patogene patogene
# perioders perioders
# periodes periodes
# periodernes periodernes
# periodens periodens
# perioder perioder
# periode periode
# pinjers pinjers
# pinjes pinjes
# pinjernes pinjernes
# pinjens pinjens
# pinjer pinjer
# pinje pinje
# postalveolære postalveolære
# postalveolær postalveolær
# postalveolært postalveolært
# produktive produktive
# produktiv produktiv
# produktivt produktivt
# produktive produktive
# præpositioners præpositioners
# præpositions præpositions
# præpositionernes præpositionernes
# præpositionens præpositionens
# præpositioner præpositioner
# præposition præposition
# pulveres pulveres
# pulvers pulvers
# ref: pulvernes pred: pulverenes
# pulverets pulverets
# pulvere pulvere
# pulver pulver
# ref: punds pred: pundes
# punds punds
# pundenes pundenes
# pundets pundets
# ref: pund pred: punde
# pund pund
# mere pålidelig mere pålidelig
# mest pålidelige mest pålidelige
# pålidelig pålidelig
# mest pålidelig mest pålidelig
# pålidelige pålidelige
# ref: quarterbackers pred: quarterbackes
# quarterbacks quarterbacks
# ref: quarterbackernes pred: quarterbackenes
# quarterbackens quarterbackens
# ref: quarterbacker pred: quarterbacke
# quarterback quarterback
# ref: rekviemmers pred: rekviemers
# rekviems rekviems
# ref: rekviemmernes pred: rekviemernes
# ref: rekviemmets pred: rekviemets
# ref: rekviemmer pred: rekviemer
# rekviem rekviem
# rene rene
# ren ren
# renest renest
# rene rene
# renest renest
# retfærdige retfærdige
# retfærdig retfærdig
# retfærdigere retfærdigere
# ref: retfærdigst pred: mest retfærdig
# ref: retfærdigst pred: mest retfærdig
# retroaktive retroaktive
# retroaktiv retroaktiv
# retroaktivt retroaktivt
# retroaktive retroaktive
# rigelige rigelige
# rigeligere rigeligere
# rigeligste rigeligste
# rigeligst rigeligst
# rigeligt rigeligt
# rigtige rigtige
# rigtigere rigtigere
# rigtigst rigtigst
# rigtigt rigtigt
# rigtigere rigtigere
# røvsyge røvsyge
# røvsyg røvsyg
# røvsygt røvsygt
# røvsyge røvsyge
# salteste salteste
# salt salt
# saltest saltest
# salt salt
# salte salte
# savnende savnende
# savnet savnet
# savner savner
# savne savne
# savnes savnes
# semifinalers semifinalers
# semifinales semifinales
# semifinalernes semifinalernes
# semifinalens semifinalens
# semifinaler semifinaler
# semifinale semifinale
# sidste sidste
# sidste sidste
# sidste sidste
# sidste sidste
# skandalers skandalers
# skandales skandales
# skandalernes skandalernes
# skandalens skandalens
# skandaler skandaler
# skandale skandale
# skoves skoves
# skovs skovs
# skovenes skovenes
# ref: skovens pred: skovets
# skove skove
# skov skov
# ref: skyldigere pred: mere skyldig
# skyldig skyldig
# ref: skyldigst pred: mest skyldig
# skyldigt skyldigt
# skyldigst skyldigst
# ref: snakkesaligste pred: mest snakkesalige
# snakkesalig snakkesalig
# ref: snakkesaligere pred: mere snakkesalig
# ref: snakkesaligere pred: mere snakkesalig
# ref: snakkesaligst pred: mest snakkesalig
# ref: snaksommere pred: mere snaksom
# ref: snaksomst pred: mest snaksom
# ref: snaksommere pred: mere snaksom
# ref: snaksommere pred: mere snaksom
# snaksomst snaksomst
# statelige statelige
# stateligste stateligste
# ref: stateligere pred: mere statelig
# statelige statelige
# stateligst stateligst
# stegepanders stegepanders
# stegepandes stegepandes
# stegepandernes stegepandernes
# stegepandens stegepandens
# stegepander stegepander
# stegepande stegepande
# strubers strubers
# strubes strubes
# strubernes strubernes
# strubens strubens
# struber struber
# strube strube
# stupide stupide
# stupid stupid
# stupidt stupidt
# stupide stupide
# substituerende substituerende
# substitueret substitueret
# substituer substituer
# substituerede substituerede
# substituere substituere
# sunde sunde
# sundeste sundeste
# sunde sunde
# sundere sundere
# sundest sundest
# sære sære
# særere særere
# særeste særeste
# sær sær
# sære sære
# tankers tankers
# tankes tankes
# tankernes tankernes
# tankens tankens
# tanker tanker
# tanke tanke
# tavs tavs
# tavst tavst
# tavsest tavsest
# tavsere tavsere
# tavsest tavsest
# tilbøjelige tilbøjelige
# tilbøjelig tilbøjelig
# tilbøjeligt tilbøjeligt
# tilbøjelige tilbøjelige
# traditionelle traditionelle
# traditionel traditionel
# traditionelt traditionelt
# traditionelle traditionelle
# troldes troldes
# trolds trolds
# troldenes troldenes
# troldens troldens
# trolde trolde
# trold trold
# trådløse trådløse
# trådløs trådløs
# trådløst trådløst
# trådløse trådløse
# turbaners turbaners
# turbans turbans
# turbanernes turbanernes
# turbanens turbanens
# turbaner turbaner
# turban turban
# tyrkeres tyrkeres
# tyrkers tyrkers
# tyrkernes tyrkernes
# tyrkerens tyrkerens
# tyrkere tyrkere
# tyrker tyrker
# tyrkiske tyrkiske
# tyrkisk tyrkisk
# tyrkisk tyrkisk
# tyrkiske tyrkiske
# tyskertøsers tyskertøsers
# ref: tyskertøs' pred: tyskertøsss
# tyskertøsernes tyskertøsernes
# tyskertøsens tyskertøsens
# tyskertøser tyskertøser
# tyskertøs tyskertøs
# tømreres tømreres
# tømrers tømrers
# tømrernes tømrernes
# tømrerens tømrerens
# tømrere tømrere
# tømrer tømrer
# udstyrende udstyrende
# udstyr udstyr
# udstyrer udstyrer
# udstyrede udstyrede
# udstyres udstyres
# udtrykte udtrykte
# udtrykt udtrykt
# udtrykt udtrykt
# udtrykte udtrykte
# ugifte ugifte
# ugift ugift
# ref: ugift pred: ugiftt
# ugifte ugifte
# uidiomatiske uidiomatiske
# uidiomatisk uidiomatisk
# uidiomatisk uidiomatisk
# uidiomatiske uidiomatiske
# ungarske ungarske
# ungarsk ungarsk
# ungarsk ungarsk
# ungarske ungarske
# urgermanske urgermanske
# urgermansk urgermansk
# urgermansk urgermansk
# urgermanske urgermanske
# mere uskadt mere uskadt
# ref: mest uskadt pred: uskadtest
# ref: mest uskadt pred: uskadtest
# ref: mere uskadt pred: uskadtere
# ref: mest uskadt pred: uskadtest
# ustemte ustemte
# ustemt ustemt
# ustemt ustemt
# ustemte ustemte
# utrygge utrygge
# utryg utryg
# utrygt utrygt
# ref: utrygge pred: utryge
# vag vag
# vagest vagest
# vagt vagt
# vagest vagest
# vagest vagest
# velkendte velkendte
# velkendt velkendt
# velkendt velkendt
# velkendte velkendte
# velsignet velsignet
# velsign velsign
# velsigner velsigner
# velsignede velsignede
# velsignes velsignes
# ref: venners pred: vens
# vens vens
# ref: vennernes pred: venenes
# ref: vennens pred: venens
# ref: venner pred: vene
# ven ven
# venskabsbyers venskabsbyers
# venskabsbys venskabsbys
# venskabsbyernes venskabsbyernes
# venskabsbyens venskabsbyens
# venskabsbyer venskabsbyer
# venskabsby venskabsby
# ventilerende ventilerende
# ventilerer ventilerer
# ventilerede ventilerede
# ventileres ventileres
# ventileredes ventileredes
# vigtige vigtige
# vigtigere vigtigere
# vigtigere vigtigere
# vigtigere vigtigere
# virtuelle virtuelle
# virtuel virtuel
# virtuelt virtuelt
# virtuelle virtuelle
# voldtægters voldtægters
# voldtægts voldtægts
# voldtægternes voldtægternes
# voldtægtens voldtægtens
# voldtægter voldtægter
# voldtægt voldtægt
# vrede vrede
# vredeste vredeste
# vredt vredt
# vredest vredest
# vredest vredest
# vurderingers vurderingers
# vurderings vurderings
# vurderingernes vurderingernes
# vurderingens vurderingens
# vurderinger vurderinger
# vurdering vurdering
# vægtfylders vægtfylders
# vægtfyldes vægtfyldes
# vægtfyldernes vægtfyldernes
# vægtfyldens vægtfyldens
# vægtfylder vægtfylder
# vægtfylde vægtfylde
# værktøjers værktøjers
# værktøjs værktøjs
# værktøjernes værktøjernes
# værktøjets værktøjets
# værktøjer værktøjer
# værktøj værktøj
# vølvers vølvers
# vølves vølves
# vølvernes vølvernes
# vølvens vølvens
# vølver vølver
# vølve vølve
# ækle ækle
# ækleste ækleste
# ækel ækel
# ækle ækle
# æklere æklere
# øget øget
# øg øg
# øger øger
# øge øge
# øgedes øgedes
# økumeniske økumeniske
# økumenisk økumenisk
# økumenisk økumenisk
# økumeniske økumeniske
# østkysters østkysters
# østkysts østkysts
# østkysternes østkysternes
# østkystens østkystens
# østkyster østkyster
# østkyst østkyst
# 0.875
# livles/mul-language-code
# abondant abondant
# abonderions abonderions
# abonderais abonderais
# abonderaient abonderaient
# abonderons abonderons
# abonderai abonderai
# abondera abondera
# abonde abonde
# abondais abondais
# abondiez abondiez
# abondais abondais
# abondaient abondaient
# abondai abondai
# abondâtes abondâtes
# abondas abondas
# abondèrent abondèrent
# abonder abonder
# abondons abondons
# abondassiez abondassiez
# ref: abondât pred: abondast
# ref: en absolvant pred: en absoudant
# absoudrais absoudrais
# absoudrait absoudrait
# absoudrons absoudrons
# absoudras absoudras
# absoudront absoudront
# absoudra absoudra
# ref: absous pred: absoude
# ref: absolvez pred: absoudz
# ref: absolvent pred: absoudent
# ref: absout pred: absoudt
# ref: absolvais pred: absoudais
# ref: absolvais pred: absoudais
# ref: absolûmes pred: absoudâmes
# ref: absolûtes pred: absoudâtes
# ref: absolus pred: absoudas
# ref: absolurent pred: absoudèrent
# ref: absolut pred: absoud
# ref: absolves pred: absoudes
# ref: absolvent pred: absoudent
# adressant adressant
# adressé adressé
# adresserions adresserions
# adresserais adresserais
# adresserais adresserais
# adresserait adresserait
# adresseras adresseras
# adressez adressez
# adresses adresses
# adresse adresse
# adressions adressions
# adressais adressais
# adressais adressais
# adressaient adressaient
# adressait adressait
# adressai adressai
# adressez adressez
# adresse adresse
# adressions adressions
# adressent adressent
# en amnistiant en amnistiant
# amnistié amnistié
# amnistierions amnistierions
# amnistierais amnistierais
# amnistierait amnistierait
# amnistierai amnistierai
# amnistieras amnistieras
# amnistiera amnistiera
# amnistiez amnistiez
# amnistiais amnistiais
# amnistiais amnistiais
# amnistiaient amnistiaient
# amnistiait amnistiait
# amnistiâtes amnistiâtes
# amnistias amnistias
# ref: amnisties pred: amnistes
# amnistient amnistient
# amnistiassions amnistiassions
# amnistiasses amnistiasses
# amnistiassent amnistiassent
# en anluminant en anluminant
# ref: anlumineriiens pred: anluminerions
# ref: anlumineriiez pred: anlumineriez
# ref: anlumineroit pred: anluminerait
# anluminerons anluminerons
# anluminerai anluminerai
# ref: anlumineroiz pred: anluminerez
# anluminent anluminent
# ref: anluminiiens pred: anluminions
# anluminai anluminai
# anluminas anluminas
# ref: anluminerent pred: anluminèrent
# anluminons anluminons
# anlumine anlumine
# ref: anlumin pred: anlumine
# ref: anlumins pred: anlumines
# ref: anluminissons pred: anluminassions
# anluminasse anluminasse
# ref: anluminissoiz pred: anluminassiez
# anluminast anluminast
# en ardoisant en ardoisant
# ardoiserais ardoiserais
# ardoiseriez ardoiseriez
# ardoiserais ardoiserais
# ardoiserez ardoiserez
# ardoiseras ardoiseras
# ardoisez ardoisez
# ardoisent ardoisent
# ardoisions ardoisions
# ardoisiez ardoisiez
# ardoisait ardoisait
# ardoisèrent ardoisèrent
# ardoise ardoise
# ardoise ardoise
# ardoises ardoises
# ardoise ardoise
# ardoisassions ardoisassions
# ardoisasse ardoisasse
# ardoisassiez ardoisassiez
# ref: ardoisât pred: ardoisast
# baptizé baptizé
# baptizerions baptizerions
# ref: baptizerois pred: baptizerais
# baptizeriez baptizeriez
# ref: baptizerois pred: baptizerais
# ref: baptizeroient pred: baptizeraient
# baptizerai baptizerai
# baptizeront baptizeront
# baptizera baptizera
# baptizons baptizons
# baptize baptize
# baptize baptize
# ref: baptizois pred: baptizais
# ref: baptizoit pred: baptizait
# ref: baptizastes pred: baptizâtes
# baptiza baptiza
# baptizez baptizez
# ref: baptizez pred: baptiziez
# baptizes baptizes
# baptizassiez baptizassiez
# en boursant en boursant
# boursé boursé
# bourserions bourserions
# bourserais bourserais
# bourserait bourserait
# bourserez bourserez
# bourseras bourseras
# boursera boursera
# boursons boursons
# boursais boursais
# boursait boursait
# boursai boursai
# boursas boursas
# boursa boursa
# boursions boursions
# bourse bourse
# boursent boursent
# bourse bourse
# boursasses boursasses
# boursassent boursassent
# calibrerions calibrerions
# calibreriez calibreriez
# calibrerais calibrerais
# calibreraient calibreraient
# calibrerait calibrerait
# calibrerai calibrerai
# calibrerez calibrerez
# calibreras calibreras
# calibres calibres
# calibrent calibrent
# calibrions calibrions
# calibrâmes calibrâmes
# calibrèrent calibrèrent
# ref: calibra pred: calibrât
# calibrez calibrez
# calibre calibre
# calibriez calibriez
# calibres calibres
# calibrassiez calibrassiez
# calibrasses calibrasses
# ref: en carençant pred: en carencant
# carencerions carencerions
# carencerais carencerais
# carencerez carencerez
# carencez carencez
# carences carences
# carence carence
# ref: carenciez pred: carençiez
# carençais carençais
# carençaient carençaient
# carençait carençait
# carençai carençai
# carençâtes carençâtes
# carença carença
# carencer carencer
# carence carence
# carencions carencions
# carençassions carençassions
# carençasses carençasses
# ref: carençât pred: carençast
# en concluant en concluant
# ref: concluant pred: conclurant
# ref: conclu pred: concluré
# ref: concluriez pred: conclurez
# ref: conclurais pred: conclurerais
# ref: concluront pred: conclurent
# concluez concluez
# concluent concluent
# concluions concluions
# concluiez concluiez
# concluais concluais
# ref: concluaient pred: concluraient
# concluait concluait
# ref: conclûmes pred: conclurâmes
# ref: conclûtes pred: conclurâtes
# concluez concluez
# ref: conclus pred: conclu
# conclue conclue
# ref: conclue pred: conclu
# ref: conclusses pred: conclurasses
# congelé congelé
# ref: congèleriez pred: congeleriez
# ref: congèleraient pred: congeleraient
# ref: congèlerons pred: congelerons
# ref: congèleras pred: congeleras
# congelons congelons
# ref: congèlent pred: congelent
# ref: congèle pred: congele
# congelions congelions
# congelais congelais
# congeliez congeliez
# congelais congelais
# congelaient congelaient
# congelait congelait
# congelas congelas
# ref: congèle pred: congele
# congeliez congeliez
# congelassions congelassions
# congelasse congelasse
# congelasses congelasses
# deviserais deviserais
# deviserais deviserais
# deviserait deviserait
# deviserez deviserez
# deviseras deviseras
# devise devise
# devise devise
# devisiez devisiez
# devisais devisais
# devisaient devisaient
# devisâtes devisâtes
# devisas devisas
# devisèrent devisèrent
# deviser deviser
# devisons devisons
# devise devise
# devise devise
# devisassions devisassions
# devisasses devisasses
# ref: devisât pred: devisast
# décevant décevant
# ref: déçu pred: décevé
# ref: décevraient pred: décevoiraient
# ref: décevrait pred: décevoirait
# ref: décevra pred: décevoira
# décevons décevons
# ref: déçois pred: déceves
# décevions décevions
# décevais décevais
# décevait décevait
# ref: déçut pred: déceva
# ref: déçois pred: déceve
# décevions décevions
# déceviez déceviez
# ref: déçoives pred: déceves
# ref: déçoivent pred: décevent
# ref: déçussions pred: décevassions
# ref: déçusses pred: décevasses
# ref: déçussent pred: décevassent
# ref: déçût pred: décevast
# dégoisant dégoisant
# dégoisé dégoisé
# dégoiserais dégoiserais
# dégoiseraient dégoiseraient
# dégoiserait dégoiserait
# dégoiserai dégoiserai
# dégoiserez dégoiserez
# dégoisons dégoisons
# dégoises dégoises
# dégoise dégoise
# dégoisions dégoisions
# dégoisais dégoisais
# dégoisâmes dégoisâmes
# dégoisâtes dégoisâtes
# dégoisas dégoisas
# dégoisions dégoisions
# dégoisiez dégoisiez
# dégoise dégoise
# dégoisassions dégoisassions
# dégoisassiez dégoisassiez
# en dépoétisant en dépoétisant
# dépoétisant dépoétisant
# dépoétiserais dépoétiserais
# dépoétiserais dépoétiserais
# dépoétiserait dépoétiserait
# dépoétiserons dépoétiserons
# dépoétiserez dépoétiserez
# dépoétiseront dépoétiseront
# dépoétisera dépoétisera
# dépoétisais dépoétisais
# dépoétisaient dépoétisaient
# dépoétisâtes dépoétisâtes
# dépoétisas dépoétisas
# dépoétisèrent dépoétisèrent
# dépoétisez dépoétisez
# dépoétise dépoétise
# dépoétisiez dépoétisiez
# dépoétise dépoétise
# dépoétisasse dépoétisasse
# dépoétisassiez dépoétisassiez
# en désescaladant en désescaladant
# désescaladant désescaladant
# désescaladé désescaladé
# désescaladeriez désescaladeriez
# désescaladeraient désescaladeraient
# désescaladerait désescaladerait
# désescaladeras désescaladeras
# désescaladera désescaladera
# désescaladons désescaladons
# désescalade désescalade
# désescaladions désescaladions
# désescaladiez désescaladiez
# désescaladai désescaladai
# désescaladâtes désescaladâtes
# désescaladas désescaladas
# désescalada désescalada
# désescaladions désescaladions
# désescalades désescalades
# désescalade désescalade
# désescaladassions désescaladassions
# en embrasant en embrasant
# embrasant embrasant
# embrasé embrasé
# embraserais embraserais
# embraseriez embraseriez
# embraserait embraserait
# embraseras embraseras
# embraseront embraseront
# embrasons embrasons
# embrasez embrasez
# embrasent embrasent
# embrasaient embrasaient
# embrasait embrasait
# embrasâtes embrasâtes
# embrase embrase
# embrasiez embrasiez
# embrase embrase
# embrasassiez embrasassiez
# embrasassent embrasassent
# ref: embrasât pred: embrasast
# en encensant en encensant
# encensant encensant
# encensé encensé
# encenserais encenserais
# encenserai encenserai
# encenseras encenseras
# encenseront encenseront
# encensons encensons
# encense encense
# encensent encensent
# encense encense
# encensiez encensiez
# encensaient encensaient
# encensons encensons
# encense encense
# encenses encenses
# encensent encensent
# encensassions encensassions
# encensasses encensasses
# ref: encensât pred: encensast
# en ensablant en ensablant
# ensablerais ensablerais
# ensablerons ensablerons
# ensableras ensableras
# ensablera ensablera
# ensables ensables
# ensablent ensablent
# ensable ensable
# ensablions ensablions
# ensablais ensablais
# ensablaient ensablaient
# ensablait ensablait
# ensablai ensablai
# ensablâtes ensablâtes
# ensablas ensablas
# ensablèrent ensablèrent
# ensablions ensablions
# ensables ensables
# ensablassiez ensablassiez
# ref: ensablât pred: ensablast
# erigé erigé
# erigeriez erigeriez
# ref: erigeroient pred: erigeraient
# erigerai erigerai
# erigeras erigeras
# erigeront erigeront
# erigez erigez
# eriges eriges
# erigent erigent
# erigiez erigiez
# ref: erigeasmes pred: erigâmes
# ref: erigeastes pred: erigâtes
# ref: erigerent pred: erigeèrent
# ref: erigea pred: erige
# ref: erigeons pred: erigons
# erigez erigez
# erige erige
# erige erige
# eriges eriges
# erige erige
# en fartant en fartant
# farterais farterais
# farteriez farteriez
# farterais farterais
# farteraient farteraient
# farterait farterait
# farterai farterai
# farterez farterez
# fartons fartons
# farte farte
# fartes fartes
# fartait fartait
# fartâmes fartâmes
# fartons fartons
# fartions fartions
# farte farte
# fartes fartes
# fartassiez fartassiez
# fartasses fartasses
# fartassent fartassent
# en fissionnant en fissionnant
# fissionnant fissionnant
# fissionnerions fissionnerions
# fissionnerez fissionnerez
# fissionnera fissionnera
# fissionnez fissionnez
# fissionnions fissionnions
# fissionnais fissionnais
# fissionniez fissionniez
# fissionnâmes fissionnâmes
# fissionnai fissionnai
# fissionnas fissionnas
# fissionna fissionna
# fissionnons fissionnons
# fissionne fissionne
# fissionnions fissionnions
# fissionne fissionne
# fissionnent fissionnent
# fissionne fissionne
# fissionnassiez fissionnassiez
# en grattouillant en grattouillant
# grattouillerions grattouillerions
# grattouillerais grattouillerais
# grattouilleraient grattouilleraient
# grattouillerait grattouillerait
# grattouilleront grattouilleront
# grattouillera grattouillera
# grattouilles grattouilles
# grattouillais grattouillais
# grattouillai grattouillai
# grattouillâtes grattouillâtes
# grattouillas grattouillas
# grattouillons grattouillons
# grattouille grattouille
# grattouillions grattouillions
# grattouille grattouille
# grattouillassions grattouillassions
# grattouillasse grattouillasse
# grattouillassiez grattouillassiez
# ref: grattouillât pred: grattouillast
# génuflexionnerions génuflexionnerions
# génuflexionnerais génuflexionnerais
# génuflexionnerons génuflexionnerons
# génuflexionnera génuflexionnera
# génuflexionne génuflexionne
# génuflexionnez génuflexionnez
# génuflexionnes génuflexionnes
# génuflexionnent génuflexionnent
# génuflexionnaient génuflexionnaient
# génuflexionnâmes génuflexionnâmes
# génuflexionnâtes génuflexionnâtes
# génuflexionna génuflexionna
# génuflexionnons génuflexionnons
# génuflexionnez génuflexionnez
# génuflexionnions génuflexionnions
# génuflexionnes génuflexionnes
# génuflexionnassions génuflexionnassions
# génuflexionnassiez génuflexionnassiez
# génuflexionnassent génuflexionnassent
# ref: génuflexionnât pred: génuflexionnast
# ref: haitant pred: haitiant
# ref: haitié pred: haité
# ref: haiteriiez pred: haitieriez
# ref: haiteroient pred: haitieraient
# haiterai haiterai
# ref: haiteroiz pred: haitierez
# haitons haitons
# haites haites
# ref: haitoit pred: haitait
# ref: haitai pred: haitâme
# ref: haitas pred: haitât
# ref: haita pred: haitât
# haitier haitier
# ref: haitiez pred: haitez
# ref: hait pred: haite
# ref: hait pred: haite
# ref: haitissons pred: haitiassions
# ref: haitasse pred: haitiasse
# ref: haitassent pred: haitiassent
# ref: haitast pred: haitât
# ref: en hyperliant pred: en hyperlant
# ref: hyperlié pred: hyperlé
# hyperlierions hyperlierions
# hyperlierais hyperlierais
# ref: hyperlieraient pred: hyperleroient
# ref: hyperlierai pred: hyperlerai
# hyperlierez hyperlierez
# hyperlieront hyperlieront
# ref: hyperliez pred: hyperlez
# ref: hyperlies pred: hyperles
# ref: hyperliais pred: hyperlais
# ref: hyperliai pred: hyperlai
# ref: hyperlias pred: hyperlas
# ref: hyperlièrent pred: hyperlèrent
# hyperlier hyperlier
# ref: hyperlie pred: hyperle
# hyperliiez hyperliiez
# hyperlient hyperlient
# ref: hyperliassions pred: hyperlassions
# ref: hyperliassent pred: hyperlassent
# en induisant en induisant
# induisant induisant
# induirions induirions
# induirais induirais
# induirons induirons
# induirai induirai
# induiras induiras
# induiront induiront
# induit induit
# induisions induisions
# induisiez induisiez
# induisait induisait
# ref: induisîtes pred: induissiez
# ref: induisis pred: induis
# ref: induisez pred: induissez
# induis induis
# ref: induisions pred: induissons
# ref: induisent pred: induissent
# ref: induise pred: induis
# ref: induisissiez pred: induissiez
# lessé lessé
# ref: lesseriiez pred: lesseriez
# ref: lesseroies pred: lesserais
# ref: lesseroient pred: lesseraient
# ref: lesseroit pred: lesserait
# lesserons lesserons
# ref: lesseroiz pred: lesserez
# lesseras lesseras
# lesseront lesseront
# lessera lessera
# lessent lessent
# lesse lesse
# ref: lessoie pred: lessais
# ref: lessoient pred: lessaient
# ref: lessoit pred: lessait
# ref: lessastes pred: lessâtes
# lessa lessa
# ref: les pred: lesses
# lessasses lessasses
# lessassent lessassent
# lyncherais lyncherais
# lyncherait lyncherait
# lynchera lynchera
# lynche lynche
# lynchez lynchez
# lynchent lynchent
# lynche lynche
# lynchions lynchions
# lynchiez lynchiez
# lynchais lynchais
# lynchait lynchait
# lynchâmes lynchâmes
# lynchâtes lynchâtes
# lynchas lynchas
# lyncha lyncha
# lyncher lyncher
# lynchez lynchez
# lynche lynche
# lynchassions lynchassions
# lynchassiez lynchassiez
# maillocherais maillocherais
# maillocherais maillocherais
# maillocheraient maillocheraient
# maillochera maillochera
# maillochais maillochais
# maillochait maillochait
# maillochas maillochas
# maillochèrent maillochèrent
# maillocha maillocha
# maillocher maillocher
# maillochons maillochons
# maillochez maillochez
# mailloche mailloche
# mailloche mailloche
# maillochiez maillochiez
# mailloches mailloches
# maillochent maillochent
# maillochassions maillochassions
# maillochassiez maillochassiez
# ref: maillochât pred: maillochast
# mercyant mercyant
# mercyé mercyé
# mercyerez mercyerez
# mercyeras mercyeras
# mercyeront mercyeront
# mercyera mercyera
# mercye mercye
# mercyes mercyes
# mercye mercye
# ref: mercyois pred: mercyais
# mercyiez mercyiez
# ref: mercyerent pred: mercyèrent
# mercya mercya
# mercye mercye
# ref: mercyons pred: mercyions
# mercyes mercyes
# mercyent mercyent
# mercyasses mercyasses
# mercyassent mercyassent
# mercyast mercyast
# mithridatiseriez mithridatiseriez
# mithridatiserais mithridatiserais
# mithridatiseraient mithridatiseraient
# mithridatiserait mithridatiserait
# mithridatiserons mithridatiserons
# mithridatise mithridatise
# mithridatisions mithridatisions
# mithridatisais mithridatisais
# mithridatisais mithridatisais
# mithridatisaient mithridatisaient
# ref: mithridatisai pred: mithridatisa
# mithridatisâtes mithridatisâtes
# mithridatisèrent mithridatisèrent
# mithridatisa mithridatisa
# mithridatiser mithridatiser
# mithridatisez mithridatisez
# mithridatise mithridatise
# mithridatise mithridatise
# mithridatisasse mithridatisasse
# mithridatisassiez mithridatisassiez
# en narrant en narrant
# narrant narrant
# narrerais narrerais
# narrerait narrerait
# narrerai narrerai
# narreront narreront
# narre narre
# narrez narrez
# narrent narrent
# narraient narraient
# narrait narrait
# narrâmes narrâmes
# narrai narrai
# narrèrent narrèrent
# narrez narrez
# narrions narrions
# narre narre
# narriez narriez
# narrassions narrassions
# narrassent narrassent
# parachevé parachevé
# ref: parachèverais pred: paracheverais
# ref: parachèverait pred: paracheverait
# ref: parachèverons pred: paracheverons
# ref: parachèveront pred: paracheveront
# ref: parachèvera pred: parachevera
# ref: parachèvent pred: parachevent
# parachevaient parachevaient
# parachevait parachevait
# parachevâmes parachevâmes
# parachevai parachevai
# parachevâtes parachevâtes
# parachever parachever
# parachevez parachevez
# parachevions parachevions
# paracheviez paracheviez
# ref: parachève pred: paracheve
# parachevassiez parachevassiez
# parachevasses parachevasses
# ref: parachevât pred: parachevast
# remboursant remboursant
# rembourserions rembourserions
# rembourserais rembourserais
# rembourserais rembourserais
# rembourserons rembourserons
# rembourserai rembourserai
# rembourserez rembourserez
# remboursez remboursez
# rembourse rembourse
# remboursait remboursait
# remboursâmes remboursâmes
# remboursai remboursai
# remboursas remboursas
# remboursa remboursa
# remboursez remboursez
# remboursions remboursions
# rembourses rembourses
# remboursent remboursent
# rembourse rembourse
# remboursasses remboursasses
# en repetant en repetant
# repetant repetant
# repeté repeté
# ref: repeteroie pred: repeterais
# ref: repeteriiez pred: repeteriez
# ref: repeteroies pred: repeterais
# ref: repeteroient pred: repeteraient
# repeterons repeterons
# repeterai repeterai
# repetes repetes
# repete repete
# repetai repetai
# ref: repetastes pred: repetâtes
# repetas repetas
# repeta repeta
# repeter repeter
# repete repete
# ref: repetons pred: repetions
# ref: repetez pred: repetiez
# ref: repetissons pred: repetassions
# reverserions reverserions
# reverseriez reverseriez
# reverserais reverserais
# reverserez reverserez
# reverseront reverseront
# reversera reversera
# reverse reverse
# reversez reversez
# reverses reverses
# reversiez reversiez
# reversaient reversaient
# reversait reversait
# reversâmes reversâmes
# reversai reversai
# reverser reverser
# reversez reversez
# reversent reversent
# reverse reverse
# reversassions reversassions
# ref: reversât pred: reversast
# en revissant en revissant
# revissant revissant
# revissé revissé
# revisserions revisserions
# revisserais revisserais
# revisseraient revisseraient
# revissons revissons
# revisses revisses
# revissions revissions
# revissais revissais
# revissiez revissiez
# revissâtes revissâtes
# revissa revissa
# revisser revisser
# revissons revissons
# revisse revisse
# revissassions revissassions
# revissasse revissasse
# revissassiez revissassiez
# ref: revissât pred: revissast
# en rimaillant en rimaillant
# rimaillé rimaillé
# rimaillerions rimaillerions
# rimailleriez rimailleriez
# rimailleras rimailleras
# rimaillons rimaillons
# rimaillez rimaillez
# rimailles rimailles
# rimaille rimaille
# rimaillions rimaillions
# rimaillais rimaillais
# rimaillas rimaillas
# rimaillèrent rimaillèrent
# rimailler rimailler
# rimaillez rimaillez
# rimaille rimaille
# rimailliez rimailliez
# rimaillent rimaillent
# rimaillasse rimaillasse
# rimaillassiez rimaillassiez
# réouvrant réouvrant
# ref: réouvert pred: réouvré
# réouvririons réouvririons
# réouvrirais réouvrirais
# réouvririez réouvririez
# réouvrirait réouvrirait
# réouvrirai réouvrirai
# réouvriront réouvriront
# réouvrons réouvrons
# réouvrais réouvrais
# réouvrait réouvrait
# ref: réouvrîmes pred: réouvrissons
# réouvrir réouvrir
# ref: réouvrions pred: réouvrissons
# réouvre réouvre
# réouvres réouvres
# réouvrent réouvrent
# réouvrissions réouvrissions
# réouvrissiez réouvrissiez
# ref: réouvrît pred: réouvrisse
# en sapurant en sapurant
# sapuré sapuré
# ref: sapureroient pred: sapureraient
# ref: sapureroit pred: sapurerait
# sapurerai sapurerai
# ref: sapureroiz pred: sapurerez
# sapureras sapureras
# ref: sapur pred: sapure
# ref: sapuriiens pred: sapurions
# ref: sapuriiez pred: sapuriez
# ref: sapuroies pred: sapurais
# ref: sapurastes pred: sapurâtes
# ref: sapura pred: sapurât
# sapurer sapurer
# sapurez sapurez
# ref: sapurons pred: sapurions
# ref: sapurez pred: sapuriez
# ref: sapurt pred: sapure
# ref: sapurissoiz pred: sapurassiez
# sapurast sapurast
# ref: satisferions pred: satisfairions
# ref: satisferais pred: satisfairais
# ref: satisferai pred: satisfairai
# ref: satisferez pred: satisfairez
# ref: satisferont pred: satisfairont
# ref: satisfera pred: satisfaira
# ref: satisfaites pred: satisfez
# ref: satisfais pred: satisfes
# ref: satisfait pred: satisfe
# ref: satisfaisions pred: satisfions
# ref: satisfaisiez pred: satisfiez
# ref: satisfaisaient pred: satisfaient
# ref: satisfaisait pred: satisfait
# ref: satisfit pred: satisfait
# ref: satisfaisons pred: satisfons
# ref: satisfaites pred: satisfez
# ref: satisfasse pred: satisfe
# ref: satisfasse pred: satisfe
# ref: satisfissions pred: satisfassions
# ref: satisfissent pred: satisfassent
# en seinant en seinant
# seinant seinant
# seinerais seinerais
# seinerez seinerez
# seineront seineront
# seine seine
# seinez seinez
# seine seine
# seinais seinais
# seinais seinais
# seinaient seinaient
# seinait seinait
# seinas seinas
# seina seina
# seinez seinez
# seiniez seiniez
# seinent seinent
# seinassiez seinassiez
# seinasses seinasses
# ref: seinât pred: seinast
# en sevrant en sevrant
# ref: sèvrerions pred: sevrerions
# ref: sèvrerais pred: sevrerais
# ref: sèvreraient pred: sevreraient
# ref: sèvrerait pred: sevrerait
# ref: sèvrerez pred: sevrerez
# ref: sèvre pred: sevre
# sevrez sevrez
# ref: sèvrent pred: sevrent
# ref: sèvre pred: sevre
# sevrais sevrais
# sevrait sevrait
# sevrâmes sevrâmes
# sevra sevra
# sevrez sevrez
# sevrions sevrions
# ref: sèvrent pred: sevrent
# sevrassions sevrassions
# sevrasses sevrasses
# sevrassent sevrassent
# surabonderions surabonderions
# surabonderais surabonderais
# surabonderons surabonderons
# surabonderez surabonderez
# surabonderas surabonderas
# surabondons surabondons
# surabondent surabondent
# surabondions surabondions
# surabondiez surabondiez
# surabondâmes surabondâmes
# surabondai surabondai
# surabondèrent surabondèrent
# surabonder surabonder
# surabondons surabondons
# surabonde surabonde
# surabondions surabondions
# surabonde surabonde
# surabondent surabondent
# surabondassions surabondassions
# surabondassiez surabondassiez
# en tocquant en tocquant
# tocquant tocquant
# ref: tocquerois pred: tocquerais
# tocquerons tocquerons
# tocquerai tocquerai
# tocqueront tocqueront
# tocquera tocquera
# tocquent tocquent
# tocquions tocquions
# ref: tocquois pred: tocquais
# ref: tocquois pred: tocquais
# ref: tocquoit pred: tocquait
# ref: tocqua pred: tocquai
# ref: tocquerent pred: tocquèrent
# ref: tocquons pred: tocquions
# tocquassions tocquassions
# tocquasse tocquasse
# tocquassiez tocquassiez
# tocquasses tocquasses
# tocquast tocquast
# ref: transmis pred: transmetté
# transmettrait transmettrait
# transmettra transmettra
# transmets transmets
# transmettions transmettions
# transmettais transmettais
# transmettais transmettais
# transmettait transmettait
# ref: transmîmes pred: transmettâmes
# ref: transmit pred: transmett
# transmettons transmettons
# transmettez transmettez
# ref: transmets pred: transmet
# transmettions transmettions
# transmette transmette
# transmettiez transmettiez
# transmette transmette
# ref: transmissions pred: transmettassions
# ref: transmissent pred: transmettassent
# ref: transmît pred: transmettât
# en vociférant en vociférant
# vociféré vociféré
# vocifèrerions vocifèrerions
# vocifèrerais vocifèrerais
# vocifèrerait vocifèrerait
# ref: vocifèrerons pred: vociférerons
# vocifèreras vocifèreras
# vocifère vocifère
# vocifère vocifère
# vociférais vociférais
# vociféraient vociféraient
# vociférâmes vociférâmes
# vociférai vociférai
# vociféras vociféras
# vociférèrent vociférèrent
# ref: vociférons pred: vocifèrons
# ref: vocifériez pred: vocifèriez
# vociférassions vociférassions
# vociférassent vociférassent
# ref: vociférât pred: vociférast
# ébruiterions ébruiterions
# ébruiteriez ébruiteriez
# ébruiterais ébruiterais
# ébruiterai ébruiterai
# ébruite ébruite
# ébruite ébruite
# ébruitais ébruitais
# ébruitiez ébruitiez
# ébruitaient ébruitaient
# ébruitait ébruitait
# ébruitez ébruitez
# ébruite ébruite
# ébruitions ébruitions
# ébruitiez ébruitiez
# ébruitent ébruitent
# ébruite ébruite
# ébruitassions ébruitassions
# ébruitasses ébruitasses
# ébruitassent ébruitassent
# ref: ébruitât pred: ébruitast
# 0.784
# livles/mul-language-code
# ref: abstrávttaid pred: abstráktaid
# ref: abstrávtta pred: abstrákta
# ref: abstrávttaiguin pred: abstráktaiguin
# ref: abstrávttain pred: abstráktain
# abstráktan abstráktan
# ref: abstrávttaid pred: abstráktaid
# ref: abstrávtta pred: abstrákta
# ref: abstrávttaide pred: abstráktaide
# abstráktii abstráktii
# ref: abstrávttat pred: abstráktat
# abstrákta abstrákta
# ref: abstrávttain pred: abstráktain
# ref: abstrávttas pred: abstráktas
# ref: almmáskivččiime pred: almmáskkášeimme
# ref: almmáskivččiimet pred: almmáskkášeimmet
# ref: almmáskivččen pred: almmáskkášin
# ref: almmáskivččiide pred: almmáskkášeidde
# ref: almmáskivččiidet pred: almmáskkášeiddet
# ref: almmáskivččiiga pred: almmáskkášeigga
# ref: almmáskivččii pred: almmáskkášii
# ref: almmáskehkot pred: almmáskot
# ref: almmáskeahkki pred: almmáski
# ref: almmás pred: almmáske
# ref: almmáskehkoset pred: almmáskoset
# ref: almmáskehkos pred: almmáskos
# ref: almmáskežže pred: almmáskkežetne
# ref: almmáskeažžat pred: almmáskkežit
# ref: almmáskeažžabeahtti pred: almmáskkežeahppi
# ref: almmáskeažžabehtet pred: almmáskkežehpet
# ref: almmáskeaččat pred: almmáskkežat
# ref: almmáskežžet pred: almmáskkežit
# ref: almmáskeš pred: almmáskkeža
# ref: almmásketne pred: almmáske
# almmáskit almmáskit
# ref: almmáskan pred: almmásken
# ref: almmáskeahppi pred: almmáskibeahtti
# ref: almmáskehpet pred: almmáskit
# ref: almmáskat pred: almmáskit
# ref: almmáskeaba pred: almmáskiba
# ref: almmáska pred: almmáskit
# ref: almmáskeimme pred: almmáskiime
# ref: almmáskin pred: almmáskkin
# ref: almmáskeidde pred: almmáskkiide
# ref: almmáskeigga pred: almmáskkiiga
# almmáske almmáske
# ref: apmasiid pred: amasiid
# ref: apmasa pred: amasa
# ref: apmasiiguin pred: amasiiguin
# ref: apmasiin pred: amasiin
# amasin amasin
# ref: apmasiid pred: amasiid
# ref: apmasa pred: amasa
# ref: apmasiidda pred: amasiidda
# ref: apmasii pred: amasii
# ref: apmasat pred: amasat
# amas amas
# ref: apmasiin pred: amasiin
# ref: apmasis pred: amasis
# atomaid atomaid
# atoma atoma
# atomaiguin atomaiguin
# atomain atomain
# atoman atoman
# atomaid atomaid
# atoma atoma
# ref: atomaide pred: atommaide
# atomii atomii
# atomat atomat
# atoma atoma
# atomain atomain
# atomas atomas
# bieđgáleimmet bieđgáleimmet
# bieđgálin bieđgálin
# bieđgáleidde bieđgáleidde
# bieđgálit bieđgálit
# bieđgáleigga bieđgáleigga
# bieđgále bieđgále
# bieđgálii bieđgálii
# bieđgášeimme bieđgášeimme
# bieđgášeimmet bieđgášeimmet
# bieđgášeiddet bieđgášeiddet
# bieđgášit bieđgášit
# bieđgájehkon bieđgájehkon
# bieđgájeahkki bieđgájeahkki
# bieđgájehket bieđgájehket
# bieđgá bieđgá
# ref: bieđgájehkoska pred: bieđgájeahkki
# bieđgážetne bieđgážetne
# bieđgážit bieđgážit
# bieđgážan bieđgážan
# bieđgážeahppi bieđgážeahppi
# bieđgážehpet bieđgážehpet
# bieđgážeaba bieđgážeaba
# bieđgájetne bieđgájetne
# bieđgát bieđgát
# bieđgán bieđgán
# bieđgábeahtti bieđgábeahtti
# ref: bieđgábehtet pred: bieđgát
# ref: bieđgájit pred: bieđgát
# bieđgáimet bieđgáimet
# ref: bieđgájin pred: bieđgáin
# bieđgáidet bieđgáidet
# ref: bieđgájedje pred: bieđgáimet
# buddeleimme buddeleimme
# buddelin buddelin
# buddeleiddet buddeleiddet
# buddelit buddelit
# buddeleigga buddeleigga
# buddele buddele
# buddelii buddelii
# buddešeimmet buddešeimmet
# buddešin buddešin
# buddešeidde buddešeidde
# buddešit buddešit
# buddešeigga buddešeigga
# buddeše buddeše
# ref: buddejetnot pred: buddot
# ref: buddejehkon pred: buddon
# ref: buddejehket pred: buddet
# budde budde
# ref: buddejehkoset pred: buddoset
# buddežeahppi buddežeahppi
# buddežehpet buddežehpet
# buddežat buddežat
# buddežeaba buddežeaba
# buddet buddet
# budden budden
# buddebeahtti buddebeahtti
# ref: buddebehtet pred: buddet
# ref: buddejit pred: buddet
# ref: buddiime pred: buddeimme
# ref: buddejin pred: budden
# ref: buddiiga pred: buddeigga
# ref: buddejedje pred: budde
# báisttáleimmet báisttáleimmet
# báisttálin báisttálin
# báisttáleidde báisttáleidde
# báisttáleiddet báisttáleiddet
# báisttálit báisttálit
# báisttáleigga báisttáleigga
# báisttále báisttále
# báisttálii báisttálii
# báisttášeimme báisttášeimme
# báisttášin báisttášin
# báisttášeidde báisttášeidde
# báisttášeigga báisttášeigga
# báisttáše báisttáše
# báisttášii báisttášii
# báistu báistu
# báistot báistot
# báistet báistet
# báisttežan báisttežan
# báisttežehpet báisttežehpet
# báisttežeaba báisttežeaba
# báisttežit báisttežit
# báistteža báistteža
# báiste báiste
# báistibehtet báistibehtet
# ref: báistá pred: báisttá
# báisttiime báisttiime
# ref: báisttiimet pred: báisteimmet
# ref: báisten pred: báistten
# báisttiidet báisttiidet
# báisttiiga báisttiiga
# báiste báiste
# báisttii báisttii
# ref: bálgáidan pred: bálgájiid
# ref: bálgán pred: bálgána
# ref: bálgáidanguin pred: bálgájiiguin
# ref: bálgáinan pred: bálgániin
# ref: bálggisinin pred: bálgánin
# ref: bálgáidan pred: bálgániid
# ref: bálgán pred: bálgána
# ref: bálgáidasan pred: bálgájiide
# ref: bálgásan pred: bálgájii
# bálgán bálgán
# ref: bálgáinan pred: bálgániin
# ref: bálgástan pred: bálgáns
# báralaččaid báralaččaid
# báralačča báralačča
# báralaččaiguin báralaččaiguin
# báralaččain báralaččain
# ref: báralažžan pred: báralaččan
# báralaččaid báralaččaid
# báralačča báralačča
# báralaččaide báralaččaide
# ref: báralažžii pred: báralaččaide
# báralaččat báralaččat
# báralaš báralaš
# báralaččain báralaččain
# báralaččas báralaččas
# ref: bártnaleimme pred: bárdnaleimme
# ref: bártnaleimmet pred: bárdnaleimmet
# ref: bártnaleidde pred: bárdnaleidde
# ref: bártnaleiddet pred: bárdnaleiddet
# ref: bártnalit pred: bárnnalit
# ref: bártnaleigga pred: bárnnaleigga
# ref: bártnalii pred: bárnnalii
# ref: bártnašeimme pred: bárdnašeimme
# ref: bártnašeimmet pred: bárdnašeimmet
# ref: bártnašeidde pred: bárdnašeidde
# ref: bártnašit pred: bárdnašit
# bárdnon bárdnon
# ref: bárdni pred: bárdnu
# ref: bártna pred: bárdne
# bárdnoska bárdnoska
# bárdnoset bárdnoset
# bárdnos bárdnos
# ref: bártnažetne pred: bárdnažetne
# ref: bártnažit pred: bárnnažit
# ref: bártnažehpet pred: bárnnažehpet
# ref: bártnažeaba pred: bárnnažeaba
# ref: bártnaža pred: bárnnaža
# ref: bárdne pred: bárdna
# bárdnat bárdnat
# ...
# ref: nijiztłééʼ pred: nijitłį́
# ref: ndadiitłoh pred: ndadiitłih
# ref: ndiitłoh pred: ndiitłih
# ref: ndoohtłoh pred: ndoohtłih
# ref: ndíítłoh pred: ndíítłih
# ref: ndeidootłoh pred: ndadootłih
# ref: ndazhdootłoh pred: ndazhdootłih
# ref: nizhdootłoh pred: nizhdootłih
# ref: nizhdootłoh pred: nizhdootłih
# ref: ndeiilbąąs pred: nideiilbąąs
# ref: ndeiłbąąs pred: nideiłbąąs
# neiłbąąs neiłbąąs
# ref: njiłbąąs pred: nijiłbąąs
# ref: ndasiilbą́ą́z pred: nidasiilbą́ą́z
# ref: nisiilbą́ą́z pred: niilbą́ą́z
# niséłbą́ą́z niséłbą́ą́z
# ref: ndasoołbą́ą́z pred: nidasoołbą́ą́z
# nisoołbą́ą́z nisoołbą́ą́z
# nisíníłbą́ą́z nisíníłbą́ą́z
# ref: ndeisbą́ą́z pred: nidaałbą́ą́z
# neisbą́ą́z neisbą́ą́z
# neisbą́ą́z neisbą́ą́z
# ref: ndajisbą́ą́z pred: nidajisbą́ą́z
# ref: njisbą́ą́z pred: nijisbą́ą́z
# ref: ndiilbąs pred: ndiilbą́ą́z
# ref: ndadoołbąs pred: ndadoołbą́ą́z
# ref: ndoołbąs pred: ndoołbą́ą́z
# ref: neidoołbąs pred: ndoołbą́ą́z
# ref: neidoołbąs pred: ndoołbą́ą́z
# ref: ndazhdoołbąs pred: ndazhdoołbą́ą́z
# ref: nizhdoołbąs pred: nizhdoołbą́ą́z
# ref: nizhdoołbąs pred: nizhdoołbą́ą́z
# nidaałgizh nidaałgizh
# naałgizh naałgizh
# neiłgizh neiłgizh
# neiłgizh neiłgizh
# nidajiłgizh nidajiłgizh
# nijiłgizh nijiłgizh
# ref: nishiilgizh pred: niilgizh
# nishéłgizh nishéłgizh
# nidashoołgizh nidashoołgizh
# nishoołgizh nishoołgizh
# nishíníłgizh nishíníłgizh
# ref: nideishgizh pred: nidaałgizh
# neishgizh neishgizh
# nijishgizh nijishgizh
# ref: ndadiilgish pred: ndadiilgizh
# ref: ndiilgish pred: ndiilgizh
# ref: ndadoołgish pred: ndadoołgizh
# ref: ndoołgish pred: ndoołgizh
# ref: ndííłgish pred: ndííłgizh
# ref: ndeidoołgish pred: ndadoołgizh
# ref: neidoołgish pred: ndoołgizh
# ref: ndazhdoołgish pred: ndazhdoołgizh
# ref: nizhdoołgish pred: nizhdoołgizh
# ref: naasmaas pred: nishłmaas
# ref: ndaałmaas pred: nidaałmaas
# ref: naniłmaas pred: niłmaas
# ndeiłmaas ndeiłmaas
# neiłmaas neiłmaas
# neiłmaas neiłmaas
# ref: njiłmaas pred: nijiłmaas
# ref: njiłmaas pred: nijiłmaas
# ref: nisiilmááz pred: niilmaaz
# ref: ndasoołmááz pred: nidasoołmaaz
# ref: nisoołmááz pred: nisoołmaaz
# ref: nisíníłmááz pred: nisíníłmaaz
# ref: ndeismááz pred: nideismaaz
# ref: neismááz pred: neismaaz
# ref: neismááz pred: neismaaz
# ref: ndajismááz pred: nidajismaaz
# ndadiilmas ndadiilmas
# ndiilmas ndiilmas
# ndadoołmas ndadoołmas
# ndííłmas ndííłmas
# ref: ndeidoołmas pred: ndadoołmas
# ref: neidoołmas pred: ndoołmas
# nizhdoołmas nizhdoołmas
# ref: ndeiiltseed pred: nideiiltseed
# ref: neiiltseed pred: niiltseed
# ref: ndaałtseed pred: nidaałtseed
# ref: naałtseed pred: nisoołtseed
# ref: njiłtseed pred: nijiłtseed
# ref: njiłtseed pred: nijiłtseed
# ref: ndasiiltseed pred: nidasiiltsid
# ref: nisiiltseed pred: niiltsid
# ref: niséłtseed pred: niséłtsééd
# ref: ndasoołtseed pred: nidasoołtsid
# ref: ndeistseed pred: nidaałtsid
# ref: neistseed pred: neistsid
# ref: neistseed pred: neistsid
# ref: ndajistseed pred: nidajistsid
# ref: njistseed pred: nijistsid
# ndadiiltsił ndadiiltsił
# ndiiltsił ndiiltsił
# ref: ndeestsił pred: ndeeshtsił
# ndadoołtsił ndadoołtsił
# ndííłtsił ndííłtsił
# ref: neidoołtsił pred: ndoołtsił
# ref: neidoołtsił pred: ndoołtsił
# nizhdoołtsił nizhdoołtsił
# ref: ndeiiltʼiʼ pred: nideiiltʼiʼ
# ref: neiiltʼiʼ pred: niiltʼiʼ
# ref: ndaałtʼiʼ pred: nidaałtʼiʼ
# ndeiłtʼiʼ ndeiłtʼiʼ
# neiłtʼiʼ neiłtʼiʼ
# neiłtʼiʼ neiłtʼiʼ
# ref: njiłtʼiʼ pred: nijiłtʼiʼ
# ref: ndasiiltʼiʼ pred: nidasiiltʼiʼ
# niséłtʼiʼ niséłtʼiʼ
# ref: ndasoołtʼiʼ pred: nidasoołtʼiʼ
# nisoołtʼiʼ nisoołtʼiʼ
# nisíníłtʼiʼ nisíníłtʼiʼ
# neistʼiʼ neistʼiʼ
# ref: njistʼiʼ pred: nijistʼiʼ
# ref: njistʼiʼ pred: nijiłtʼiʼ
# ref: ndadiiltʼih pred: ndadiiltʼił
# ref: ndiiltʼih pred: ndiiltʼił
# ref: ndeeshtʼih pred: ndeeshtʼił
# ref: ndoołtʼih pred: ndoołtʼił
# ref: ndííłtʼih pred: ndííłtʼił
# ref: neidoołtʼih pred: ndoołtʼił
# ref: nizhdoołtʼih pred: nizhdoołtʼił
# ref: nizhdoołtʼih pred: nizhdoołtʼił
# ref: neiitʼeesh pred: niiʼeesh
# ref: naashʼeesh pred: nishʼeesh
# ref: ndaahʼeesh pred: nidaahʼeesh
# naahʼeesh naahʼeesh
# ref: naniʼeesh pred: niniʼeesh
# neiʼeesh neiʼeesh
# ref: njiʼeesh pred: nijiʼeesh
# ref: nishiitʼeezh pred: niitʼéézh
# ref: nishéʼeezh pred: nishʼéézh
# ref: ndashooʼeezh pred: nidashooʼéézh
# ref: nishooʼeezh pred: nishooʼéézh
# ref: nishíníʼeezh pred: nishíníʼéézh
# ref: ndeizhʼeezh pred: nidaashʼéézh
# ref: ndajizhʼeezh pred: nidajizhʼéézh
# ndadiitʼish ndadiitʼish
# ref: ndeeshʼish pred: ndeeshʼosh
# ndadoohʼish ndadoohʼish
# ref: ndííʼish pred: ndííʼééł
# ref: ndeidooʼish pred: ndadooʼosh
# ref: neidooʼish pred: ndooʼosh
# ndazhdooʼish ndazhdooʼish
# ref: nizhdooʼish pred: nizhdooʼosh
# ref: nizhdooʼish pred: nizhdooʼosh
# ref: daneedǫ́ǫ́z pred: nidasiidǫ́ǫ́z
# niidǫ́ǫ́z niidǫ́ǫ́z
# ref: neesdǫ́ǫ́z pred: nisédǫ́ǫ́z
# ref: danisoohdǫ́ǫ́z pred: nidasoodǫ́ǫ́z
# ref: noohdǫ́ǫ́z pred: noodǫ́ǫ́z
# ref: níínídǫ́ǫ́z pred: noodǫ́ǫ́z
# ref: daneesdǫ́ǫ́z pred: nideidǫ́ǫ́z
# noodǫ́ǫ́z noodǫ́ǫ́z
# noodǫ́ǫ́z noodǫ́ǫ́z
# ref: dazhneesdǫ́ǫ́z pred: dajídǫ́ǫ́z
# ref: jinoodǫ́ǫ́z pred: nijidǫ́ǫ́z
# ref: jinoodǫ́ǫ́z pred: nijidǫ́ǫ́z
# deiichʼid deiichʼid
# yishchʼid yishchʼid
# daahchʼid daahchʼid
# wohchʼid wohchʼid
# deichʼid deichʼid
# yichʼid yichʼid
# yichʼid yichʼid
# dajichʼid dajichʼid
# jichʼid jichʼid
# yíchʼid yíchʼid
# ref: daoochʼid pred: dashoochʼid
# woochʼid woochʼid
# ref: yíníchʼid pred: shíníchʼid
# dayííchʼid dayííchʼid
# yiyííchʼid yiyííchʼid
# ref: jííchʼid pred: joochʼid
# dadiichʼił dadiichʼił
# diichʼił diichʼił
# doohchʼił doohchʼił
# dííchʼił dííchʼił
# ref: deidoochʼił pred: dadoochʼił
# ref: yidoochʼił pred: doochʼił
# jidoochʼił jidoochʼił
# ref: dadiitsʼį́į́h pred: deiitsʼį́į́h
# diitsʼį́į́h diitsʼį́į́h
# ref: diistsʼį́į́h pred: deistsʼį́į́h
# ref: doohtsʼį́į́h pred: wohtsʼį́į́h
# ref: diitsʼį́į́h pred: nidiitsʼį́į́h
# ref: yidiitsʼį́į́h pred: diitsʼį́į́h
# ref: dazhdiitsʼį́į́h pred: dajidiitsʼį́į́h
# ref: dadisiitsʼą́ą́ʼ pred: dadiitsʼį́į́ʼ
# ref: disiitsʼą́ą́ʼ pred: diitsʼį́į́ʼ
# ref: disétsʼą́ą́ʼ pred: díítsʼį́į́ʼ
# ref: disootsʼą́ą́ʼ pred: doohtsʼį́į́ʼ
# ref: disínítsʼą́ą́ʼ pred: díítsʼį́į́ʼ
# ref: deidiiztsʼą́ą́ʼ pred: dadiitsʼį́į́ʼ
# ref: yidiiztsʼą́ą́ʼ pred: yidiitsʼį́į́ʼ
# ref: dazdiiztsʼą́ą́ʼ pred: dajíítsʼį́į́ʼ
# ref: jidiiztsʼą́ą́ʼ pred: jidiitsʼį́į́ʼ
# ref: jidiiztsʼą́ą́ʼ pred: jíítsʼį́į́ʼ
# ref: dadidiitsʼį́į́ł pred: dadiitsʼį́į́ł
# ref: dideestsʼį́į́ł pred: deeshtsʼį́į́ł
# ref: dadidoohtsʼį́į́ł pred: dadoohtsʼį́į́ł
# ref: didoohtsʼį́į́ł pred: doohtsʼį́į́ł
# ref: deididootsʼį́į́ł pred: dadidootsʼį́į́ł
# ref: dazhdidootsʼį́į́ł pred: dazhdootsʼį́į́ł
# deiigeeh deiigeeh
# yishgeeh yishgeeh
# daahgeeh daahgeeh
# nigeeh nigeeh
# ref: daageeh pred: deigeeh
# yigeeh yigeeh
# yigeeh yigeeh
# dajigeeh dajigeeh
# jigeeh jigeeh
# ref: dasiigoʼ pred: dasiigeeʼ
# ref: yiigoʼ pred: yiigeeʼ
# ref: dasoogoʼ pred: dasoogeeʼ
# ref: woogoʼ pred: woogeeʼ
# ref: yígoʼ pred: yiyíígeeʼ
# ref: yígoʼ pred: yiyíígeeʼ
# ref: deeshgoh pred: deeshgih
# ref: dadoohgoh pred: dadoohgih
# ref: dadoogoh pred: dadoogih
# ref: doogoh pred: doogih
# ref: dazhdoogoh pred: dazhdoogih
# ref: jidoogoh pred: jidoogih
# ref: jidoogoh pred: jidoogih
# ref: yiikááh pred: deiigááh
# ref: yishááh pred: yishhááh
# ref: wohkááh pred: daahghááh
# ref: wohʼaash pred: wohhááh
# ref: ninááh pred: nighááh
# yighááh yighááh
# yighááh yighááh
# ref: jiʼaash pred: dajighááh
# jighááh jighááh
# ref: yiikai pred: dasiigááʼ
# ref: yiitʼáázh pred: yiigááʼ
# ref: yíyá pred: yíghááʼ
# ref: woohkai pred: dasoogááʼ
# ref: yíʼáázh pred: dayííghááʼ
# ref: jííʼáázh pred: dajííghááʼ
# ref: jííyá pred: jííghááʼ
# ref: diikah pred: dadiighaał
# ref: diitʼash pred: diigááł
# ref: doohkah pred: dadoohgah
# ref: doogááł pred: dooghaał
# ref: doogááł pred: dooghaał
# ref: jidoogááł pred: jidooghaał
# jidoogááł jidoogááł
# ref: deíníigeeh pred: deiigoh
# yiigoh yiigoh
# ref: yishgoh pred: yígoʼ
# ref: deínóhgeeh pred: dasoogoh
# ref: wohgoh pred: woogoh
# ref: yígoh pred: sínígoh
# ref: deígeeh pred: dayíígoh
# ref: yigoh pred: yiyíígoh
# ref: yigoh pred: yiyíígoh
# ref: dajígeeh pred: dajizgoh
# joogoh joogoh
# ref: joogoh pred: jíígoh
# deiijeeh deiijeeh
# yiijeeh yiijeeh
# yishjeeh yishjeeh
# daahjeeh daahjeeh
# wohjeeh wohjeeh
# yijeeh yijeeh
# yijeeh yijeeh
# jijeeh jijeeh
# jijeeh jijeeh
# ref: shiijééʼ pred: yiiją́
# ref: shéjééʼ pred: yíjííją́
# ref: dashoojééʼ pred: dasoojiʼ
# ref: shoojééʼ pred: wooją́
# ref: yizhjééʼ pred: yiyííjééʼ
# ref: yizhjééʼ pred: yiyííjééʼ
# ref: jizhjééʼ pred: jíjííją́
# ref: dadiijah pred: dadiijih
# ref: diijah pred: diiljih
# ref: deeshjah pred: deeshjih
# ref: dadoojah pred: dadoohjih
# ref: dííjah pred: dííjih
# ref: dazhdoojah pred: dazhdoojih
# ref: jidoojah pred: jidoojih
# ref: deíníijį́į́h pred: deiijį́į́l
# yiijį́į́ł yiijį́į́ł
# ref: yishjį́į́ł pred: yíjį́į́ł
# ref: deínóhjį́į́h pred: dasoojį́į́ł
# ref: wohjį́į́ł pred: woojį́į́ł
# ref: yíjį́į́ł pred: níjį́į́ł
# ref: deíjį́į́h pred: dayííjį́į́ł
# yijį́į́ł yijį́į́ł
# yijį́į́ł yijį́į́ł
# ref: dajíjį́į́h pred: dajijį́į́ł
# ref: joojį́į́ł pred: jijį́į́ł
# ref: joojį́į́ł pred: jijį́į́ł
# ref: deíníiltłʼééh pred: dasiiltłʼiil
# yiiltłʼééł yiiltłʼééł
# ref: yishtłʼééł pred: yíltłʼééł
# ref: deínółtłʼééh pred: dasoołtłʼiil
# ref: wołtłʼééł pred: woołtłʼééł
# ref: yíltłʼééł pred: síníltłʼééł
# ref: deíltłʼééh pred: dayííltłʼééł
# yiltłʼééł yiltłʼééł
# yiltłʼééł yiltłʼééł
# ref: dajíltłʼééh pred: dajistłʼiil
# jooltłʼééł jooltłʼééł
# ref: jooltłʼééł pred: jííltłʼééł
# yiilʼaah yiilʼaah
# yishʼaah yishʼaah
# ref: daałʼaah pred: daahłʼaah
# wołʼaah wołʼaah
# nilʼaah nilʼaah
# deilʼaah deilʼaah
# yilʼaah yilʼaah
# dajilʼaah dajilʼaah
# jilʼaah jilʼaah
# jilʼaah jilʼaah
# ref: deiilʼaad pred: dasiilʼaaʼ
# ref: yiilʼaad pred: yiilʼaaʼ
# ref: daoołʼaad pred: dasoołʼaaʼ
# ref: woołʼaad pred: woołʼaaʼ
# ref: yínílʼaad pred: sínílʼááʼ
# ref: dayoolʼaad pred: dayíílʼááʼ
# ref: yoolʼaad pred: yiyíílʼaaʼ
# ref: joolʼaad pred: jíílʼááʼ
# ref: deeshʼaał pred: deeshʼah
# doołʼaał doołʼaał
# ref: deidoolʼaał pred: dadoolʼaał
# jidoolʼaał jidoolʼaał
# deiilzhood deiilzhood
# yiilzhood yiilzhood
# yishood yishood
# daahshood daahshood
# wohshood wohshood
# nishood nishood
# deishood deishood
# yishood yishood
# yishood yishood
# dajishood dajishood
# jishood jishood
# jishood jishood
# ref: dashiilzhóód pred: deiilzhood
# ref: yiilzhóód pred: yiilzhood
# ref: yíshóód pred: yíshood
# ref: dashooshóód pred: dashooshood
# ref: wooshóód pred: wooshood
# ref: yíníshóód pred: shíníshood
# ref: deishóód pred: dayííshood
# ref: yiyííshóód pred: yishood
# ref: yiyííshóód pred: yishood
# ref: dajishóód pred: dajishood
# ref: jííshóód pred: jooshood
# ref: jííshóód pred: jííshood
# deiilzhóósh deiilzhóósh
# yiilzhóósh yiilzhóósh
# yishóósh yishóósh
# daahshóósh daahshóósh
# wohshóósh wohshóósh
# nishóósh nishóósh
# deishóósh deishóósh
# yishóósh yishóósh
# yishóósh yishóósh
# dajishóósh dajishóósh
# jishóósh jishóósh
# jishóósh jishóósh
# deiilzhoozh deiilzhoozh
# yiilzhoozh yiilzhoozh
# ref: yíshoozh pred: yíshóózh
# ref: daooshoozh pred: dashooshozh
# wooshoozh wooshoozh
# ref: yíníshoozh pred: yíníshóózh
# ref: dayííshoozh pred: dayííshóózh
# ref: yiyííshoozh pred: yishóózh
# ref: yiyííshoozh pred: yishóózh
# ref: dajííshoozh pred: dajishoozh
# jííshoozh jííshoozh
# ref: jííshoozh pred: jííshóózh
# deiitłeeh deiitłeeh
# yiitłeeh yiitłeeh
# yishtłeeh yishtłeeh
# daahtłeeh daahtłeeh
# wohtłeeh wohtłeeh
# nitłeeh nitłeeh
# deitłeeh deitłeeh
# yitłeeh yitłeeh
# yitłeeh yitłeeh
# dajitłeeh dajitłeeh
# jitłeeh jitłeeh
# jitłeeh jitłeeh
# ref: dasiitłééʼ pred: dasiitłį́į́ʼ
# ref: yiitłééʼ pred: yiitłą́
# ref: yítłééʼ pred: yítłį́į́ʼ
# ref: dasootłééʼ pred: dasootłį́į́ʼ
# ref: wootłééʼ pred: wootłį́
# ref: yínítłééʼ pred: sínítłą́
# ref: deiztłééʼ pred: dayíítłééʼ
# yiyíítłééʼ yiyíítłééʼ
# ref: yiyíítłééʼ pred: yiyíítłą́
# ref: dajiztłééʼ pred: dajíítłį́
# ref: jíítłééʼ pred: jootłį́
# ref: jíítłééʼ pred: jíítłą́
# deiitsʼǫs deiitsʼǫs
# yiitsʼǫs yiitsʼǫs
# ref: daoohtsʼǫs pred: daahootsʼǫs
# ref: yiitsʼǫs pred: niitsʼǫs
# ref: yiyiitsʼǫs pred: yiitsʼǫs
# jiitsʼǫs jiitsʼǫs
# ref: dasootsʼǫs pred: dasootsʼǫz
# ref: sootsʼǫs pred: wootsʼǫ́ǫ́z
# ref: sínítsʼǫs pred: sínítsʼǫ́z
# ref: deiztsʼǫs pred: dayiitsʼǫz
# ref: yiztsʼǫs pred: yiyiitsʼǫz
# ref: yiztsʼǫs pred: yiyiitsʼǫ́z
# ref: dajiztsʼǫs pred: dajiitsʼǫz
# ref: jiztsʼǫs pred: jiitsʼǫ́z
# ref: jiztsʼǫs pred: jiitsʼǫ́z
# ref: dadiitsʼǫs pred: dadiitsʼǫł
# ref: deestsʼǫs pred: deeshtsʼǫł
# ref: doohtsʼǫs pred: doohtsʼǫł
# ref: díítsʼǫs pred: díítsʼǫł
# ref: deidootsʼǫs pred: dadootsʼǫł
# ref: yidootsʼǫs pred: yidootsʼǫł
# ref: dazhdootsʼǫs pred: dazhdootsʼǫł
# ref: jidootsʼǫs pred: jidootsʼǫł
# deiiltsééh deiiltsééh
# yiiltsééh yiiltsééh
# ref: yiistsééh pred: yishłtsééh
# ref: dayoołtsééh pred: daałtsééh
# ref: yiiłtsééh pred: niłtsééh
# deiyiiłtsééh deiyiiłtsééh
# ref: yiyiiłtsééh pred: yiiłtsééh
# ref: yiyiiłtsééh pred: yiiłtsééh
# dajiiłtsééh dajiiłtsééh
# jiiłtsééh jiiłtsééh
# ref: yiiltsą́ pred: yiiltsiʼ
# ref: yiiłtsą́ pred: yíníłtsiʼ
# ref: yoołtsą́ pred: woołtsiʼ
# ref: yiniłtsą́ pred: síníłtsiʼ
# ref: yiyiiłtsą́ pred: yiyiiłtsiʼ
# ref: dajiiłtsą́ pred: dajííłtsééʼ
# ref: jiiłtsą́ pred: jiiłtsiʼ
# ref: jiiłtsą́ pred: jiiłtsiʼ
# ref: deidiiltsééł pred: dadiiltsih
# ref: yideestsééł pred: deeshtsih
# ref: deidoołtsééł pred: dadoołtsih
# ref: yidoołtsééł pred: doołtsih
# ref: deizhdoołtsééł pred: dazhdoołtsih
# deiiltsóóh deiiltsóóh
# yiiltsóóh yiiltsóóh
# ref: yiistsóóh pred: yishłtsóóh
# ref: daoołtsóóh pred: daałtsóóh
# ref: woołtsóóh pred: wołtsóóh
# ref: yiiłtsóóh pred: niłtsóóh
# ref: dayiiłtsóóh pred: deiyiiłtsóóh
# ref: yiyiiłtsóóh pred: yiiłtsóóh
# ref: yiyiiłtsóóh pred: yiiłtsóóh
# dajiiłtsóóh dajiiłtsóóh
# jiiłtsóóh jiiłtsóóh
# jiiłtsóóh jiiłtsóóh
# ref: deiiltsoii pred: deiiltsoʼ
# ref: yiiltsoii pred: yiiltsoʼ
# ref: yiiłtsoii pred: yishtsoʼ
# ref: daoołtsoii pred: dasoołtsoʼ
# ref: woołtsoii pred: woołtsoʼ
# ref: yiniłtsoii pred: síníłtsoʼ
# ref: dayiiłtsoii pred: deiyííłtsoʼ
# ref: yiyiiłtsoii pred: yiyiiłtsoʼ
# ref: yiyiiłtsoii pred: yiyiiłtsoʼ
# ref: dajiiłtsoii pred: dajííłtsoʼ
# ref: jiiłtsoii pred: jiiłtsoʼ
# ref: jiiłtsoii pred: jiiłtsoʼ
# deiilchʼal deiilchʼal
# wołchʼal wołchʼal
# niłchʼal niłchʼal
# yiłchʼal yiłchʼal
# dajiłchʼal dajiłchʼal
# jiłchʼal jiłchʼal
# deiilchʼal deiilchʼal
# yíłchʼal yíłchʼal
# ref: daoołchʼal pred: dasoołchʼal
# woołchʼal woołchʼal
# ref: yíníłchʼal pred: shíníłchʼal
# yiyííłchʼal yiyííłchʼal
# yiyííłchʼal yiyííłchʼal
# dajííłchʼal dajííłchʼal
# ref: jííłchʼal pred: joołchʼal
# jííłchʼal jííłchʼal
# deeshchʼał deeshchʼał
# ref: deidoołchʼał pred: dadoołchʼał
# ref: yidoołchʼał pred: doołchʼał
# ref: yidoołchʼał pred: doołchʼał
# dazhdoołchʼał dazhdoołchʼał
# jidoołchʼał jidoołchʼał
# jidoołchʼał jidoołchʼał
# deiildin deiildin
# yiildin yiildin
# yishdin yishdin
# daałdin daałdin
# wołdin wołdin
# niłdin niłdin
# deiłdin deiłdin
# yiłdin yiłdin
# yiłdin yiłdin
# dajiłdin dajiłdin
# jiłdin jiłdin
# jiłdin jiłdin
# dasiildin dasiildin
# ref: siildin pred: yiildin
# ref: séłdin pred: yíłdin
# dasoołdin dasoołdin
# ref: soołdin pred: wołdin
# síníłdin síníłdin
# ref: deisdin pred: dayííłdin
# ref: yisdin pred: yiłdin
# ref: dajisdin pred: dajííłdin
# ref: jisdin pred: jííłdin
# ref: jisdin pred: jííłdin
# deiilghaał deiilghaał
# yiilghaał yiilghaał
# yishhaał yishhaał
# daałhaał daałhaał
# wołhaał wołhaał
# niłhaał niłhaał
# deiłhaał deiłhaał
# yiłhaał yiłhaał
# yiłhaał yiłhaał
# dajiłhaał dajiłhaał
# jiłhaał jiłhaał
# jiłhaał jiłhaał
# deiilghaal deiilghaal
# yiilghaal yiilghaal
# yíłhaal yíłhaal
# ref: daoołhaal pred: dasoołhaal
# woołhaal woołhaal
# ref: yíníłhaal pred: síníłhaal
# dayííłhaal dayííłhaal
# ref: yiyííłhaal pred: yiłhaal
# yiyííłhaal yiyííłhaal
# dajííłhaal dajííłhaal
# jííłhaal jííłhaal
# jííłhaal jííłhaal
# deiilnaad deiilnaad
# yiilnaad yiilnaad
# yishnaad yishnaad
# niłnaad niłnaad
# yiłnaad yiłnaad
# dajiłnaad dajiłnaad
# jiłnaad jiłnaad
# jiłnaad jiłnaad
# ref: deiilnáád pred: dasiilnaad
# ref: yiilnáád pred: yiilnaad
# yíłnáád yíłnáád
# ref: yíníłnáád pred: síníłnáád
# dayííłnáád dayííłnáád
# yiyííłnáád yiyííłnáád
# dajííłnáád dajííłnáád
# jííłnáád jííłnáád
# jííłnáád jííłnáád
# diilnał diilnał
# ref: deeshnał pred: deeshnáł
# doołnał doołnał
# ref: deidoołnał pred: dadoołnał
# jidoołnał jidoołnał
# deiilneʼ deiilneʼ
# yiilneʼ yiilneʼ
# yishneʼ yishneʼ
# daałneʼ daałneʼ
# wołneʼ wołneʼ
# niłneʼ niłneʼ
# deiłneʼ deiłneʼ
# yiłneʼ yiłneʼ
# yiłneʼ yiłneʼ
# dajiłneʼ dajiłneʼ
# jiłneʼ jiłneʼ
# jiłneʼ jiłneʼ
# ref: deiilneʼ pred: dasiilneʼ
# yiilneʼ yiilneʼ
# yíłneʼ yíłneʼ
# ref: daoołneʼ pred: dasoołneʼ
# woołneʼ woołneʼ
# ref: yíníłneʼ pred: síníłneʼ
# dayííłneʼ dayííłneʼ
# yiyííłneʼ yiyííłneʼ
# yiyííłneʼ yiyííłneʼ
# dajííłneʼ dajííłneʼ
# jííłneʼ jííłneʼ
# jííłneʼ jííłneʼ
# deiiltin deiiltin
# yiiltin yiiltin
# yishtin yishtin
# daałtin daałtin
# wołtin wołtin
# niłtin niłtin
# deiłtin deiłtin
# yiłtin yiłtin
# yiłtin yiłtin
# dajiłtin dajiłtin
# jiłtin jiłtin
# jiłtin jiłtin
# ref: dasiiltin pred: deiiltin
# ref: siiltin pred: yiiltin
# ref: séłtin pred: yíłtin
# dasoołtin dasoołtin
# ref: soołtin pred: wołtin
# síníłtin síníłtin
# ref: deistin pred: dayííłtin

# %%
# %cd /dss/dsshome1/03/ge87wod2/morphological-inflection/ByT5/
# Out:
# /dss/dsshome1/03/ge87wod2/morphological-inflection/ByT5
# /usr/local/lib/python3.10/dist-packages/IPython/core/magics/osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
