# %%
sigmorphon_path = ""
slavic_languages = []
datasets = [".tst",".dev",".trn"]
for dataset in datasets:
    for slavic_lang in slavic_languages:
        in_path = sigmorphon_path + slavic_lang + dataset
        with open (in_path,"r") as in_file:
            for line in in_file:
                lemma, features, target = line.strip().split("\t")
